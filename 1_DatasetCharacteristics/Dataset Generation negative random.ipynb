# %% [markdown]
# # Extract negative image tiles with the help of  Seamount database
#
# Use seamount database to avoid places that contain for sure seamounts.
# Further use the geoshape of the world to exclude landmass.
#
# - Open csv file with seamout data
# - load geoshape of the earth to exclude land
# - load image from gmrt.org, open bathmetry service and prevent location with seamounts
#
# Result is a folder with images with scale in 528x468 pixel size, of seafloor without seamounts.
#
# **Attention:** The data set must be checked manually to ensure that it does not contain tiles with seamounts that were not previously included in the database (.csv).

# %%
import os
import requests
import pandas as pd
import random
import math
import geopandas as gpd
from shapely.geometry import Point

# Parameters
csv_file = "seamounts.csv"  # Path to the .csv file
output_folder = "no_seamounts_galore_batch3"  # Folder to save downloaded images
tile_pixels = 800  # Width and height of the image in pixels
tile_width_deg = 1.0  # Fixed width in degrees
exclusion_radius_deg = 2.0  # Exclusion zone around each point (in degrees)
api_base_url = "https://www.gmrt.org/services/ImageServer"
max_attempts = 10  # Max number of attempts to find valid points

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# Load CSV file with the points to avoid
try:
    df = pd.read_csv(csv_file)
    print(f"Loaded {len(df)} records from {csv_file}.")
except Exception as e:
    print(f"Error loading .csv file: {e}")
    exit()

# Create a list of points to avoid (exclusion zones)
exclude_points = [(row["LAT"], row["LONG"]) for index, row in df.iterrows()]
print(f"Exclusion zones defined for {len(exclude_points)} points.")

# Load the Natural Earth ocean shapefile
# You'll need to download this shapefile from Natural Earth
ocean_shapefile = "ne_10m_ocean.shp"  # Change this to the path where you saved the shapefile
oceans = gpd.read_file(ocean_shapefile)

# Function to check if a location is in the ocean using geospatial data
def is_ocean(lat, lon):
    point = Point(lon, lat)  # Create a Point object with longitude and latitude
    return oceans.contains(point).any()  # Check if the point is in the ocean

# Function to generate random points outside exclusion zones
def generate_random_point():
    # Generate random latitudes and longitudes
    lat = random.uniform(-90, 90)
    lon = random.uniform(-180, 180)
    
    # Check if the point is within any exclusion zone
    for excl_lat, excl_lon in exclude_points:
        distance = math.sqrt((lat - excl_lat)**2 + (lon - excl_lon)**2)
        if distance < exclusion_radius_deg:
            return generate_random_point()  # Recursively try again if within exclusion zone
    
    return lat, lon

# Function to download the image tile
def download_tile(center_lat, center_lon, file_name):
    # Adjust height based on Mercator projection
    adjusted_height_deg = tile_width_deg * math.cos(math.radians(center_lat))
    
    # Calculate tile bounds
    minlatitude = center_lat - (adjusted_height_deg / 2)
    maxlatitude = center_lat + (adjusted_height_deg / 2)
    minlongitude = center_lon - (tile_width_deg / 2)
    maxlongitude = center_lon + (tile_width_deg / 2)

    # Prepare API parameters
    params = {
        "minlatitude": minlatitude,
        "maxlatitude": maxlatitude,
        "minlongitude": minlongitude,
        "maxlongitude": maxlongitude,
        "width": tile_pixels,
        "height": tile_pixels,  # Ensure the image is square
        "mask": "false",
        "download": "true",
    }

    # Construct file name
    output_file = os.path.join(output_folder, f"{file_name}.png")

    # Download the image
    print(f"Downloading square image for {file_name} at {center_lat}, {center_lon}...")
    response = requests.get(api_base_url, params=params)

    if response.status_code == 200:
        # Save the image
        with open(output_file, "wb") as file:
            file.write(response.content)
        print(f"Saved: {output_file}")
    else:
        print(f"Failed to download for {file_name} - HTTP {response.status_code}")

# Generate random points and download tiles
attempts = 0
tiles_downloaded = 0

while attempts < max_attempts:
    try:
        # Generate a random point outside the exclusion zones
        random_lat, random_lon = generate_random_point()
        file_name = f"tile_{random_lat:.1f}_{random_lon:.1f}"

        # Check if the location is ocean before downloading
        if is_ocean(random_lat, random_lon):
            # Download the image tile for this point
            download_tile(random_lat, random_lon, file_name)

            tiles_downloaded += 1
            print(f"Downloaded {tiles_downloaded} tile(s).")

            # Stop if enough tiles are downloaded
            if tiles_downloaded >= 1000:
                break
        else:
            print(f"Skipping tile at {random_lat}, {random_lon} - Not over ocean.")

    except Exception as e:
        print(f"Error during attempt {attempts}: {e}")
        attempts += 1

print(f"Download complete. {tiles_downloaded} tiles downloaded.")
# Out:
# Loaded 33452 records from seamounts.csv.
# Exclusion zones defined for 33452 points.
# Skipping tile at 50.43469740330232, -112.91171640841705 - Not over ocean.
# Skipping tile at 69.5799285312344, 116.80037511807512 - Not over ocean.
# Downloading square image for tile_72.3_-125.8 at 72.32281001650176, -125.84886800085923...
# Saved: no_seamounts_galore_batch3/tile_72.3_-125.8.png
# Downloaded 1 tile(s).
# Downloading square image for tile_-48.6_-156.8 at -48.63660904216226, -156.793340701961...
# Saved: no_seamounts_galore_batch3/tile_-48.6_-156.8.png
# Downloaded 2 tile(s).
# Skipping tile at -78.92775945495167, 70.44805671126832 - Not over ocean.
# Skipping tile at -69.12593852042805, 99.20405241946116 - Not over ocean.
# Downloading square image for tile_42.9_36.6 at 42.904975650760406, 36.60195103404317...
# Saved: no_seamounts_galore_batch3/tile_42.9_36.6.png
# Downloaded 3 tile(s).
# Skipping tile at -68.13980041097929, 66.84233476477664 - Not over ocean.
# Downloading square image for tile_77.2_106.3 at 77.22107522478399, 106.34015687178754...
# Saved: no_seamounts_galore_batch3/tile_77.2_106.3.png
# Downloaded 4 tile(s).
# Skipping tile at 53.16234601976262, 23.072904968479577 - Not over ocean.
# Skipping tile at 67.47786343333277, 174.67719115685196 - Not over ocean.
# Skipping tile at 51.83822076168218, 133.74401517921655 - Not over ocean.
# Downloading square image for tile_87.2_175.2 at 87.23729594342544, 175.18992858287487...
# Saved: no_seamounts_galore_batch3/tile_87.2_175.2.png
# Downloaded 5 tile(s).
# Skipping tile at 19.358731510587404, 98.17366442012263 - Not over ocean.
# Skipping tile at 63.904731394279935, 163.23974485287 - Not over ocean.
# Downloading square image for tile_-11.6_146.6 at -11.588759829984213, 146.60784183838166...
# Saved: no_seamounts_galore_batch3/tile_-11.6_146.6.png
# Downloaded 6 tile(s).
# Skipping tile at -75.85813055420996, -12.866935560520375 - Not over ocean.
# Skipping tile at -71.34347161350908, 65.25008924345107 - Not over ocean.
# Skipping tile at 42.686018863045035, 22.050513155331828 - Not over ocean.
# Downloading square image for tile_21.9_89.0 at 21.890235126247532, 89.00043258538335...
# Saved: no_seamounts_galore_batch3/tile_21.9_89.0.png
# Downloaded 7 tile(s).
# Skipping tile at -0.17814649798381765, -68.59266458439532 - Not over ocean.
# Downloading square image for tile_45.5_-138.4 at 45.490537164415144, -138.38272568646556...
# Saved: no_seamounts_galore_batch3/tile_45.5_-138.4.png
# Downloaded 8 tile(s).
# Skipping tile at 55.83589890877289, 55.55607738303084 - Not over ocean.
# Downloading square image for tile_-6.8_85.9 at -6.8302497495159855, 85.91999570093657...
# Saved: no_seamounts_galore_batch3/tile_-6.8_85.9.png
# Downloaded 9 tile(s).
# Downloading square image for tile_-60.0_131.1 at -60.01512170985412, 131.09781926076028...
# Saved: no_seamounts_galore_batch3/tile_-60.0_131.1.png
# Downloaded 10 tile(s).
# Skipping tile at 34.685899054051134, -82.40643467133465 - Not over ocean.
# Downloading square image for tile_-65.6_-67.9 at -65.58302214795685, -67.93229008306884...
# Saved: no_seamounts_galore_batch3/tile_-65.6_-67.9.png
# Downloaded 11 tile(s).
# Downloading square image for tile_-72.4_-48.9 at -72.37249767604612, -48.866086302317086...
# Saved: no_seamounts_galore_batch3/tile_-72.4_-48.9.png
# Downloaded 12 tile(s).
# Skipping tile at -26.944834412694753, 19.62281924224436 - Not over ocean.
# Skipping tile at 70.50282408811537, -94.40655051486814 - Not over ocean.
# Downloading square image for tile_52.6_147.6 at 52.63389505129524, 147.59075054915616...
# Saved: no_seamounts_galore_batch3/tile_52.6_147.6.png
# Downloaded 13 tile(s).
# Skipping tile at 81.18372863426615, -91.95321633567765 - Not over ocean.
# Skipping tile at 51.00764902791141, 23.80990503055304 - Not over ocean.
# Skipping tile at 34.465615611010776, -93.12159747797723 - Not over ocean.
# Skipping tile at 65.30275993845297, -92.909906331548 - Not over ocean.
# Downloading square image for tile_-47.9_-56.0 at -47.920186984851384, -55.96788146670421...
# Saved: no_seamounts_galore_batch3/tile_-47.9_-56.0.png
# Downloaded 14 tile(s).
# Skipping tile at -77.48724612225975, -76.60482446348757 - Not over ocean.
# Downloading square image for tile_-31.7_-48.6 at -31.727687504299226, -48.6412430336033...
# Saved: no_seamounts_galore_batch3/tile_-31.7_-48.6.png
# Downloaded 15 tile(s).
# Downloading square image for tile_-64.6_-128.0 at -64.64158945566578, -128.0281428158335...
# Saved: no_seamounts_galore_batch3/tile_-64.6_-128.0.png
# Downloaded 16 tile(s).
# Skipping tile at 43.78749459531031, 27.30632342074307 - Not over ocean.
# Downloading square image for tile_20.3_-141.4 at 20.27188358991802, -141.37959803177455...
# Saved: no_seamounts_galore_batch3/tile_20.3_-141.4.png
# Downloaded 17 tile(s).
# Downloading square image for tile_-43.8_-21.9 at -43.7605881908198, -21.864788861094667...
# Saved: no_seamounts_galore_batch3/tile_-43.8_-21.9.png
# Downloaded 18 tile(s).
# Skipping tile at 50.30333044531625, 34.29056592438758 - Not over ocean.
# Downloading square image for tile_-37.9_126.8 at -37.91777984827458, 126.82840491886901...
# Saved: no_seamounts_galore_batch3/tile_-37.9_126.8.png
# Downloaded 19 tile(s).
# Downloading square image for tile_88.3_132.1 at 88.28328377441696, 132.06316748394056...
# Saved: no_seamounts_galore_batch3/tile_88.3_132.1.png
# Downloaded 20 tile(s).
# Downloading square image for tile_70.2_-59.0 at 70.20668231237869, -58.96744199574242...
# Saved: no_seamounts_galore_batch3/tile_70.2_-59.0.png
# Downloaded 21 tile(s).
# Skipping tile at 69.18740894592909, 103.02251779027733 - Not over ocean.
# Skipping tile at 54.3965491998388, -66.72501441003884 - Not over ocean.
# Skipping tile at 52.085353635324225, 67.75418577263977 - Not over ocean.
# Downloading square image for tile_56.2_7.9 at 56.205702641935574, 7.877897058344445...
# Saved: no_seamounts_galore_batch3/tile_56.2_7.9.png
# Downloaded 22 tile(s).
# Skipping tile at 60.89455542792447, 160.49796349887845 - Not over ocean.
# Skipping tile at 21.29947965888715, -5.436911357945945 - Not over ocean.
# Skipping tile at 51.49726795482843, -96.69837030065678 - Not over ocean.
# Skipping tile at 68.5208323194264, 142.3809494279431 - Not over ocean.
# Skipping tile at 61.58907884543416, -47.06849942868689 - Not over ocean.
# Skipping tile at 32.644366110653166, 68.99248389342966 - Not over ocean.
# Skipping tile at -6.782981717022878, -60.19861442115359 - Not over ocean.
# Skipping tile at -5.996501327306419, -39.468918805155084 - Not over ocean.
# Skipping tile at -26.117213161039757, -65.79915783616683 - Not over ocean.
# Downloading square image for tile_66.7_42.2 at 66.72781934366685, 42.23269841923161...
# Saved: no_seamounts_galore_batch3/tile_66.7_42.2.png
# Downloaded 23 tile(s).
# Downloading square image for tile_5.0_90.3 at 4.989314468145537, 90.26651697188066...
# Saved: no_seamounts_galore_batch3/tile_5.0_90.3.png
# Downloaded 24 tile(s).
# Skipping tile at 56.874759038112046, -158.09776655225141 - Not over ocean.
# Skipping tile at 50.668145384832115, 73.2019399015822 - Not over ocean.
# Downloading square image for tile_-34.1_121.2 at -34.13607227310593, 121.16824085309565...
# Saved: no_seamounts_galore_batch3/tile_-34.1_121.2.png
# Downloaded 25 tile(s).
# Downloading square image for tile_74.3_121.7 at 74.2773346373369, 121.7220857830107...
# Saved: no_seamounts_galore_batch3/tile_74.3_121.7.png
# Downloaded 26 tile(s).
# Downloading square image for tile_-66.1_-56.7 at -66.12466556611994, -56.746035240000936...
# Saved: no_seamounts_galore_batch3/tile_-66.1_-56.7.png
# Downloaded 27 tile(s).
# Downloading square image for tile_79.6_87.4 at 79.57104260977556, 87.38089822881665...
# Saved: no_seamounts_galore_batch3/tile_79.6_87.4.png
# Downloaded 28 tile(s).
# Skipping tile at -83.40196296547111, -17.538861777516928 - Not over ocean.
# Downloading square image for tile_-62.6_-5.5 at -62.623097995637366, -5.463257777513036...
# Saved: no_seamounts_galore_batch3/tile_-62.6_-5.5.png
# Downloaded 29 tile(s).
# Skipping tile at 39.58648556917268, 39.53465837749397 - Not over ocean.
# Skipping tile at 7.979010421902331, -63.065584490157875 - Not over ocean.
# Skipping tile at 33.30740802530529, 46.78420007619124 - Not over ocean.
# Skipping tile at -80.39719810289043, -94.23414647195987 - Not over ocean.
# Downloading square image for tile_60.1_-52.3 at 60.09959092925189, -52.277005242164336...
# Saved: no_seamounts_galore_batch3/tile_60.1_-52.3.png
# Downloaded 30 tile(s).
# Skipping tile at 28.88814650556192, 104.73849428394539 - Not over ocean.
# Downloading square image for tile_-46.1_118.8 at -46.09739343536444, 118.82596621204766...
# Saved: no_seamounts_galore_batch3/tile_-46.1_118.8.png
# Downloaded 31 tile(s).
# Skipping tile at 27.00313198742569, 3.4267610462950415 - Not over ocean.
# Downloading square image for tile_-63.2_127.9 at -63.20765984042431, 127.93181319569277...
# Saved: no_seamounts_galore_batch3/tile_-63.2_127.9.png
# Downloaded 32 tile(s).
# Skipping tile at -32.135060042683634, 121.61657833399812 - Not over ocean.
# Downloading square image for tile_74.9_-4.1 at 74.91676932965748, -4.050017982811227...
# Saved: no_seamounts_galore_batch3/tile_74.9_-4.1.png
# Downloaded 33 tile(s).
# Skipping tile at 34.67359757810961, 54.96119861332585 - Not over ocean.
# Skipping tile at 55.283117540093144, 65.77289214011157 - Not over ocean.
# Downloading square image for tile_-51.5_174.6 at -51.5346239545521, 174.63902875266643...
# Saved: no_seamounts_galore_batch3/tile_-51.5_174.6.png
# Downloaded 34 tile(s).
# Downloading square image for tile_89.3_152.0 at 89.28944545959502, 151.98436902975163...
# Saved: no_seamounts_galore_batch3/tile_89.3_152.0.png
# Downloaded 35 tile(s).
# Downloading square image for tile_60.0_-84.8 at 60.01082636142192, -84.81202426035675...
# Saved: no_seamounts_galore_batch3/tile_60.0_-84.8.png
# Downloaded 36 tile(s).
# Downloading square image for tile_-63.7_-138.1 at -63.68760827663249, -138.06879602702514...
# Saved: no_seamounts_galore_batch3/tile_-63.7_-138.1.png
# Downloaded 37 tile(s).
# Skipping tile at 50.32731186457846, 89.41864193071234 - Not over ocean.
# Skipping tile at -71.64676936175005, 65.83403862399467 - Not over ocean.
# Downloading square image for tile_-1.9_-114.8 at -1.904401918421172, -114.79019652685616...
# Saved: no_seamounts_galore_batch3/tile_-1.9_-114.8.png
# Downloaded 38 tile(s).
# Downloading square image for tile_-78.2_165.8 at -78.15842095277513, 165.8033151010966...
# Saved: no_seamounts_galore_batch3/tile_-78.2_165.8.png
# Downloaded 39 tile(s).
# Skipping tile at 49.10301865584432, -57.92570232807424 - Not over ocean.
# Skipping tile at -22.639967287468536, -56.54456760001207 - Not over ocean.
# Skipping tile at -3.5268208655318034, -57.309370728008275 - Not over ocean.
# Skipping tile at -69.76696422743123, 111.38471924203691 - Not over ocean.
# Downloading square image for tile_-50.9_46.1 at -50.88148492840201, 46.07253307462511...
# Saved: no_seamounts_galore_batch3/tile_-50.9_46.1.png
# Downloaded 40 tile(s).
# Skipping tile at -75.73546697904013, -85.6348524087512 - Not over ocean.
# Downloading square image for tile_-75.5_-154.8 at -75.46865851998817, -154.75005690326415...
# Saved: no_seamounts_galore_batch3/tile_-75.5_-154.8.png
# Downloaded 41 tile(s).
# Skipping tile at 45.83848554347881, 123.18133160313596 - Not over ocean.
# Skipping tile at 44.47549210393046, -104.98866646257125 - Not over ocean.
# Downloading square image for tile_61.8_-34.0 at 61.822227942195525, -34.02048000169961...
# Saved: no_seamounts_galore_batch3/tile_61.8_-34.0.png
# Downloaded 42 tile(s).
# Skipping tile at 67.71746436488414, -47.53705839996604 - Not over ocean.
# Skipping tile at 56.54144733429996, 88.24076537858264 - Not over ocean.
# Downloading square image for tile_77.0_-16.4 at 76.99274773988691, -16.38202337874307...
# Saved: no_seamounts_galore_batch3/tile_77.0_-16.4.png
# Downloaded 43 tile(s).
# Skipping tile at -86.84665454762177, 125.08070270565258 - Not over ocean.
# Skipping tile at -19.693488289797898, 48.60107021248666 - Not over ocean.
# Downloading square image for tile_75.5_165.8 at 75.48567557763025, 165.76267034352264...
# Saved: no_seamounts_galore_batch3/tile_75.5_165.8.png
# Downloaded 44 tile(s).
# Downloading square image for tile_74.2_-19.9 at 74.23602030866621, -19.931296463775936...
# Saved: no_seamounts_galore_batch3/tile_74.2_-19.9.png
# Downloaded 45 tile(s).
# Downloading square image for tile_18.3_66.3 at 18.338613371721706, 66.28807446403096...
# Saved: no_seamounts_galore_batch3/tile_18.3_66.3.png
# Downloaded 46 tile(s).
# Skipping tile at 27.782322212270557, 28.21602875432825 - Not over ocean.
# Skipping tile at -6.511871826153154, 33.32385072127215 - Not over ocean.
# Skipping tile at 21.503310227385384, 74.0016313829521 - Not over ocean.
# Downloading square image for tile_-16.4_50.7 at -16.365339474462516, 50.68333551731635...
# Saved: no_seamounts_galore_batch3/tile_-16.4_50.7.png
# Downloaded 47 tile(s).
# Skipping tile at -84.63992120146716, -99.64934960206388 - Not over ocean.
# Skipping tile at 61.12422741660771, 93.87736417191167 - Not over ocean.
# Downloading square image for tile_81.1_48.9 at 81.06142220636869, 48.894898713139185...
# Saved: no_seamounts_galore_batch3/tile_81.1_48.9.png
# Downloaded 48 tile(s).
# Skipping tile at -89.04068440158422, -156.2587852909232 - Not over ocean.
# Skipping tile at -85.38745234797035, -66.46991451044366 - Not over ocean.
# Downloading square image for tile_28.3_-74.5 at 28.27829194960971, -74.49009584125928...
# Saved: no_seamounts_galore_batch3/tile_28.3_-74.5.png
# Downloaded 49 tile(s).
# Skipping tile at 78.09401667946995, -37.174260122093386 - Not over ocean.
# Skipping tile at 20.921885219444675, 8.586105379647023 - Not over ocean.
# Downloading square image for tile_-51.1_-63.5 at -51.0944771202064, -63.48005690182322...
# Saved: no_seamounts_galore_batch3/tile_-51.1_-63.5.png
# Downloaded 50 tile(s).
# Skipping tile at -87.06287980772458, -53.10532722891675 - Not over ocean.
# Downloading square image for tile_-49.2_-100.9 at -49.20993565420677, -100.86395684262176...
# Saved: no_seamounts_galore_batch3/tile_-49.2_-100.9.png
# Downloaded 51 tile(s).
# Skipping tile at -25.458623158518037, 17.31024753833111 - Not over ocean.
# Skipping tile at 21.109867342599998, -16.046830169973134 - Not over ocean.
# Downloading square image for tile_89.1_-172.0 at 89.0832248861881, -172.04763321946896...
# Saved: no_seamounts_galore_batch3/tile_89.1_-172.0.png
# Downloaded 52 tile(s).
# Skipping tile at -87.27478719021926, -24.661641538175957 - Not over ocean.
# Downloading square image for tile_59.1_-92.9 at 59.06183264500282, -92.87870693484673...
# Saved: no_seamounts_galore_batch3/tile_59.1_-92.9.png
# Downloaded 53 tile(s).
# Skipping tile at -75.93587875749103, 57.837237639735065 - Not over ocean.
# Skipping tile at -73.59855149141256, -3.7016027481125207 - Not over ocean.
# Skipping tile at 45.659930401245674, 4.764340019445967 - Not over ocean.
# Skipping tile at 72.62424934742907, -115.41966700570018 - Not over ocean.
# Skipping tile at 75.24633206231542, 104.6502805884059 - Not over ocean.
# Downloading square image for tile_89.4_-128.1 at 89.4469547005842, -128.12877705022046...
# Saved: no_seamounts_galore_batch3/tile_89.4_-128.1.png
# Downloaded 54 tile(s).
# Skipping tile at -4.409416277140508, -57.242522905930215 - Not over ocean.
# Skipping tile at 32.72035323003283, 8.32898809843229 - Not over ocean.
# Skipping tile at 48.40818897471766, -114.9980105917937 - Not over ocean.
# Downloading square image for tile_11.4_66.2 at 11.366230357182033, 66.24617272992722...
# Saved: no_seamounts_galore_batch3/tile_11.4_66.2.png
# Downloaded 55 tile(s).
# Downloading square image for tile_-38.9_-103.1 at -38.94107579651688, -103.14147429278269...
# Saved: no_seamounts_galore_batch3/tile_-38.9_-103.1.png
# Downloaded 56 tile(s).
# Skipping tile at -28.486907231468358, 119.0598713374007 - Not over ocean.
# Skipping tile at -88.04935122180326, 12.217880197142904 - Not over ocean.
# Skipping tile at -75.16514935783438, 111.2192410038378 - Not over ocean.
# Downloading square image for tile_86.8_-179.7 at 86.81180469988377, -179.68638546172173...
# Saved: no_seamounts_galore_batch3/tile_86.8_-179.7.png
# Downloaded 57 tile(s).
# Downloading square image for tile_-61.6_112.5 at -61.613110599460896, 112.51413001628481...
# Saved: no_seamounts_galore_batch3/tile_-61.6_112.5.png
# Downloaded 58 tile(s).
# Skipping tile at 52.81188612220038, 109.19022163972056 - Not over ocean.
# Skipping tile at -67.36569179832955, 124.19618996389136 - Not over ocean.
# Downloading square image for tile_61.6_-17.7 at 61.59107225571046, -17.709029724327195...
# Saved: no_seamounts_galore_batch3/tile_61.6_-17.7.png
# Downloaded 59 tile(s).
# Skipping tile at 63.75691810681292, 111.91557687700123 - Not over ocean.
# Downloading square image for tile_84.2_-142.5 at 84.19695624956381, -142.51620426946135...
# Saved: no_seamounts_galore_batch3/tile_84.2_-142.5.png
# Downloaded 60 tile(s).
# Skipping tile at -88.8168078249366, -170.22597517905226 - Not over ocean.
# Downloading square image for tile_-48.5_-164.7 at -48.49057962516263, -164.7050648832319...
# Saved: no_seamounts_galore_batch3/tile_-48.5_-164.7.png
# Downloaded 61 tile(s).
# Skipping tile at 52.78433511668766, 122.6045825644523 - Not over ocean.
# Downloading square image for tile_74.3_40.1 at 74.25841494003876, 40.08794531401165...
# Saved: no_seamounts_galore_batch3/tile_74.3_40.1.png
# Downloaded 62 tile(s).
# Downloading square image for tile_-60.1_92.1 at -60.09486013199423, 92.13016628133022...
# Saved: no_seamounts_galore_batch3/tile_-60.1_92.1.png
# Downloaded 63 tile(s).
# Skipping tile at 77.75159426215828, -58.05890934617469 - Not over ocean.
# Downloading square image for tile_21.8_-22.1 at 21.820911299184758, -22.072384193970265...
# Saved: no_seamounts_galore_batch3/tile_21.8_-22.1.png
# Downloaded 64 tile(s).
# Downloading square image for tile_-34.5_162.4 at -34.474560811172545, 162.36905059357775...
# Saved: no_seamounts_galore_batch3/tile_-34.5_162.4.png
# Downloaded 65 tile(s).
# Skipping tile at -79.02295288239118, -143.60240815815382 - Not over ocean.
# Skipping tile at 29.007191293759874, 86.45752564274699 - Not over ocean.
# Skipping tile at 47.20046273710659, 107.89659457000863 - Not over ocean.
# Skipping tile at 42.09703349051006, 85.79755338600876 - Not over ocean.
# Skipping tile at 23.218300415525846, 21.684018948486198 - Not over ocean.
# Skipping tile at -66.60129839902999, 131.13666540430353 - Not over ocean.
# Downloading square image for tile_-28.0_164.4 at -28.00581048292151, 164.41365713542558...
# Saved: no_seamounts_galore_batch3/tile_-28.0_164.4.png
# Downloaded 66 tile(s).
# Skipping tile at 74.77481102146399, -80.2800783919749 - Not over ocean.
# Downloading square image for tile_-78.2_-169.6 at -78.2232431397246, -169.64039191025336...
# Saved: no_seamounts_galore_batch3/tile_-78.2_-169.6.png
# Downloaded 67 tile(s).
# Downloading square image for tile_86.7_176.8 at 86.7498026780444, 176.80635612919394...
# Saved: no_seamounts_galore_batch3/tile_86.7_176.8.png
# Downloaded 68 tile(s).
# Downloading square image for tile_78.2_-94.0 at 78.2325773485872, -93.99091701351824...
# Saved: no_seamounts_galore_batch3/tile_78.2_-94.0.png
# Downloaded 69 tile(s).
# Downloading square image for tile_48.2_-123.5 at 48.15791858631738, -123.47614768490315...
# Saved: no_seamounts_galore_batch3/tile_48.2_-123.5.png
# Downloaded 70 tile(s).
# Skipping tile at 20.95489070639728, 19.66778556233345 - Not over ocean.
# Downloading square image for tile_-61.2_-91.5 at -61.15669523081186, -91.4697252242647...
# Saved: no_seamounts_galore_batch3/tile_-61.2_-91.5.png
# Downloaded 71 tile(s).
# Skipping tile at 73.18927301231744, 99.44785640780685 - Not over ocean.
# Skipping tile at 4.986250930805312, 115.74219560598408 - Not over ocean.
# Downloading square image for tile_-55.3_156.1 at -55.286009526758285, 156.05383135570952...
# Saved: no_seamounts_galore_batch3/tile_-55.3_156.1.png
# Downloaded 72 tile(s).
# Skipping tile at 68.20948073235039, 153.6285940451392 - Not over ocean.
# Downloading square image for tile_-29.9_31.1 at -29.895739109461076, 31.05998368508142...
# Saved: no_seamounts_galore_batch3/tile_-29.9_31.1.png
# Downloaded 73 tile(s).
# Downloading square image for tile_-45.7_-33.7 at -45.68231328488441, -33.679136040887784...
# Saved: no_seamounts_galore_batch3/tile_-45.7_-33.7.png
# Downloaded 74 tile(s).
# Skipping tile at -5.8817984750342305, -57.563578548192126 - Not over ocean.
# Downloading square image for tile_27.5_-23.4 at 27.503753229458567, -23.38585845002339...
# Saved: no_seamounts_galore_batch3/tile_27.5_-23.4.png
# Downloaded 75 tile(s).
# Skipping tile at -84.447186989591, -133.793586621442 - Not over ocean.
# Skipping tile at -26.73060096676081, 151.77532631871242 - Not over ocean.
# Skipping tile at -23.941516414203008, 118.65208325368394 - Not over ocean.
# Skipping tile at 48.53875887819049, -71.2259709869185 - Not over ocean.
# Skipping tile at -80.96254637876909, -12.037284784357922 - Not over ocean.
# Downloading square image for tile_89.3_94.7 at 89.29051776954242, 94.68053957735964...
# Saved: no_seamounts_galore_batch3/tile_89.3_94.7.png
# Downloaded 76 tile(s).
# Skipping tile at 80.59992357315465, -74.16762745361461 - Not over ocean.
# Skipping tile at 76.27070222576992, -50.72003391267853 - Not over ocean.
# Skipping tile at 41.99333584091673, -116.9352550811958 - Not over ocean.
# Skipping tile at 40.7339311570162, -123.25461960687934 - Not over ocean.
# Downloading square image for tile_86.6_69.5 at 86.63232405460076, 69.487419222321...
# Saved: no_seamounts_galore_batch3/tile_86.6_69.5.png
# Downloaded 77 tile(s).
# Skipping tile at 34.77348609679386, 10.283956438113876 - Not over ocean.
# Skipping tile at -69.37661476719515, 142.2974111346319 - Not over ocean.
# Skipping tile at -81.93566452170786, 131.88306478442757 - Not over ocean.
# Downloading square image for tile_-70.5_71.0 at -70.49741843730196, 70.99406110099034...
# Saved: no_seamounts_galore_batch3/tile_-70.5_71.0.png
# Downloaded 78 tile(s).
# Skipping tile at 71.86467177963618, 55.476525534207326 - Not over ocean.
# Downloading square image for tile_-69.9_-40.7 at -69.8705007603086, -40.73366991879382...
# Saved: no_seamounts_galore_batch3/tile_-69.9_-40.7.png
# Downloaded 79 tile(s).
# Skipping tile at -76.76352409414672, -137.8902270717606 - Not over ocean.
# Downloading square image for tile_88.7_-29.6 at 88.72666824155809, -29.585222945976767...
# Saved: no_seamounts_galore_batch3/tile_88.7_-29.6.png
# Downloaded 80 tile(s).
# Skipping tile at 45.99606014772226, -98.86439935616058 - Not over ocean.
# Downloading square image for tile_82.4_-169.6 at 82.37189739647914, -169.6051744511646...
# Saved: no_seamounts_galore_batch3/tile_82.4_-169.6.png
# Downloaded 81 tile(s).
# Skipping tile at 74.55231487539993, -48.44152633870621 - Not over ocean.
# Skipping tile at -4.559111005566336, 26.791573677088138 - Not over ocean.
# Skipping tile at 53.95399654066034, 87.45001840863375 - Not over ocean.
# Skipping tile at -67.92019037186785, 64.7091846173931 - Not over ocean.
# Skipping tile at -68.26227080022048, 104.80580436056863 - Not over ocean.
# Skipping tile at 64.29249763500272, -45.930613983297434 - Not over ocean.
# Downloading square image for tile_14.5_81.1 at 14.495012991793601, 81.11731448251152...
# Saved: no_seamounts_galore_batch3/tile_14.5_81.1.png
# Downloaded 82 tile(s).
# Skipping tile at 56.08955759872859, -114.2985437146254 - Not over ocean.
# Skipping tile at -87.25896161467455, 53.30697740661654 - Not over ocean.
# Downloading square image for tile_-29.0_-23.7 at -29.003836046131262, -23.722147482827495...
# Saved: no_seamounts_galore_batch3/tile_-29.0_-23.7.png
# Downloaded 83 tile(s).
# Skipping tile at 52.80849312572556, 125.06487740354976 - Not over ocean.
# Skipping tile at 68.91855705628737, -34.76012019583027 - Not over ocean.
# Downloading square image for tile_-39.9_102.6 at -39.933291626075444, 102.63182605915557...
# Saved: no_seamounts_galore_batch3/tile_-39.9_102.6.png
# Downloaded 84 tile(s).
# Downloading square image for tile_-15.0_1.3 at -14.971879592178055, 1.2984126319725817...
# Saved: no_seamounts_galore_batch3/tile_-15.0_1.3.png
# Downloaded 85 tile(s).
# Skipping tile at 46.34349517952222, 79.36642390654345 - Not over ocean.
# Downloading square image for tile_80.2_-112.4 at 80.22922735646262, -112.3860583062351...
# Saved: no_seamounts_galore_batch3/tile_80.2_-112.4.png
# Downloaded 86 tile(s).
# Downloading square image for tile_84.5_152.2 at 84.46733453549888, 152.16889463340237...
# Saved: no_seamounts_galore_batch3/tile_84.5_152.2.png
# Downloaded 87 tile(s).
# Downloading square image for tile_-62.4_-81.5 at -62.37401420656995, -81.49076467759964...
# Saved: no_seamounts_galore_batch3/tile_-62.4_-81.5.png
# Downloaded 88 tile(s).
# Skipping tile at 44.90114793831208, -71.41241565875877 - Not over ocean.
# Skipping tile at 47.01837988576082, 43.0137674465401 - Not over ocean.
# Downloading square image for tile_54.5_-52.3 at 54.498208959199246, -52.28132577685...
# Saved: no_seamounts_galore_batch3/tile_54.5_-52.3.png
# Downloaded 89 tile(s).
# Skipping tile at 68.8245476845255, -36.0890627005042 - Not over ocean.
# Skipping tile at 64.54086746406335, -45.32106963388887 - Not over ocean.
# Skipping tile at 28.100385478605588, 52.77833193181522 - Not over ocean.
# Downloading square image for tile_56.1_148.8 at 56.14655133464743, 148.84608531772716...
# Saved: no_seamounts_galore_batch3/tile_56.1_148.8.png
# Downloaded 90 tile(s).
# Downloading square image for tile_70.3_-57.5 at 70.30707416856148, -57.45103323459527...
# Saved: no_seamounts_galore_batch3/tile_70.3_-57.5.png
# Downloaded 91 tile(s).
# Downloading square image for tile_83.5_46.4 at 83.47047774252846, 46.449515455782404...
# Saved: no_seamounts_galore_batch3/tile_83.5_46.4.png
# Downloaded 92 tile(s).
# Skipping tile at 45.34576658790573, -85.89432629618192 - Not over ocean.
# Skipping tile at -88.85011325933309, -96.904258633556 - Not over ocean.
# Skipping tile at 51.79481938859746, 43.70778129840596 - Not over ocean.
# Skipping tile at -81.40032616969583, -35.12696320926298 - Not over ocean.
# Skipping tile at -84.7044929403769, 16.271306771773425 - Not over ocean.
# Skipping tile at 55.138301679972216, 54.18945312871895 - Not over ocean.
# Downloading square image for tile_66.7_-163.4 at 66.66706311667357, -163.37391048414958...
# Saved: no_seamounts_galore_batch3/tile_66.7_-163.4.png
# Downloaded 93 tile(s).
# Skipping tile at -78.48129716687914, 46.89493375290394 - Not over ocean.
# Downloading square image for tile_84.9_-40.3 at 84.94036963600021, -40.332916759133354...
# Saved: no_seamounts_galore_batch3/tile_84.9_-40.3.png
# Downloaded 94 tile(s).
# Downloading square image for tile_72.7_31.3 at 72.67247770986589, 31.29276418498509...
# Saved: no_seamounts_galore_batch3/tile_72.7_31.3.png
# Downloaded 95 tile(s).
# Downloading square image for tile_84.9_-39.5 at 84.93527842637724, -39.4991699304737...
# Saved: no_seamounts_galore_batch3/tile_84.9_-39.5.png
# Downloaded 96 tile(s).
# Downloading square image for tile_18.8_107.7 at 18.849918359823363, 107.74633531635709...
# Saved: no_seamounts_galore_batch3/tile_18.8_107.7.png
# Downloaded 97 tile(s).
# Skipping tile at -85.60062294678092, -65.9871856759487 - Not over ocean.
# Skipping tile at -18.99078155195177, 129.44633310383085 - Not over ocean.
# Skipping tile at 49.34611341117966, 74.31000064839753 - Not over ocean.
# Downloading square image for tile_83.8_140.5 at 83.82414727928185, 140.48385924557255...
# Saved: no_seamounts_galore_batch3/tile_83.8_140.5.png
# Downloaded 98 tile(s).
# Skipping tile at 62.51648029704515, 106.59838191479298 - Not over ocean.
# Skipping tile at 68.1098134646044, 87.00744688166293 - Not over ocean.
# Downloading square image for tile_88.8_24.7 at 88.8405788532063, 24.686383831651995...
# Saved: no_seamounts_galore_batch3/tile_88.8_24.7.png
# Downloaded 99 tile(s).
# Downloading square image for tile_-76.4_-42.9 at -76.43986276273101, -42.85441283342087...
# Saved: no_seamounts_galore_batch3/tile_-76.4_-42.9.png
# Downloaded 100 tile(s).
# Downloading square image for tile_-65.9_73.9 at -65.9342993538568, 73.87177417865908...
# Saved: no_seamounts_galore_batch3/tile_-65.9_73.9.png
# Downloaded 101 tile(s).
# Skipping tile at 39.952358812410324, -86.25959404679207 - Not over ocean.
# Downloading square image for tile_62.9_-75.2 at 62.86935834694984, -75.22810380500226...
# Saved: no_seamounts_galore_batch3/tile_62.9_-75.2.png
# Downloaded 102 tile(s).
# Skipping tile at 36.75877296673059, 38.99059523320156 - Not over ocean.
# Skipping tile at 14.630528900990086, -83.97396758271984 - Not over ocean.
# Downloading square image for tile_89.6_111.6 at 89.6044209590265, 111.60909081171087...
