# %% [markdown]
# Key change to main: downloads only the IDs already present in the seamounts_bboxes folder

# %% [markdown]
# ## Preparing Data

# %%
import csv
from dbfread import DBF

def dbf_to_csv(dbf_filename, csv_filename):
    # Open the .dbf file using dbfread
    dbf = DBF(dbf_filename, load=True)
    
    # Open a .csv file to write the data
    with open(csv_filename, mode='w', newline='', encoding='utf-8') as csv_file:
        writer = csv.writer(csv_file)
        
        # Write the header (field names from the .dbf file)
        writer.writerow(dbf.field_names)
        
        # Write the rows of data
        for record in dbf:
            writer.writerow(record.values())

# Example usage
dbf_filename = 'seamounts.dbf'  # Replace with the path to your .dbf file
csv_filename = 'seamounts.csv'  # Replace with your desired output .csv file name

dbf_to_csv(dbf_filename, csv_filename)

# %% [markdown]
# ## Download data

# %%
import os
import requests
import pandas as pd
import math

# Parameters
csv_file = "seamounts.csv"  # Path to the .csv file
output_folder = "seamounts_galore"  # Folder to save downloaded images
tile_pixels = 800  # Width and height of the image in pixels
tile_width_deg = 1.0  # Fixed width in degrees
api_base_url = "https://www.gmrt.org/services/ImageServer"
existing_images_folder = "seamounts_bboxes"  # Folder containing the existing images

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# Load CSV file
try:
    df = pd.read_csv(csv_file)
    print(f"Loaded {len(df)} records from {csv_file}.")
except Exception as e:
    print(f"Error loading .csv file: {e}")
    exit()

# List all files in the existing images folder
existing_files = set(os.path.splitext(f)[0] for f in os.listdir(existing_images_folder) if f.endswith('_1.png'))

# List all files in the output folder
output_files = set(os.path.splitext(f)[0] for f in os.listdir(output_folder) if f.endswith('.png'))

# Process each record
for index, row in df.iterrows():
    try:
        # Extract data from the row
        file_name = str(row["PEAKID"])  # Use PEAKID as the file name
        if f"{file_name}_1" not in existing_files:
            print(f"Skipping PEAKID {file_name}, no matching image in {existing_images_folder}.")
            continue  # Skip if no matching file exists

        # Skip if image already exists in the output folder
        if file_name in output_files:
            print(f"Skipping PEAKID {file_name}, image already exists in {output_folder}.")
            continue  # Skip if the image is already present in the output folder

        center_lon = float(row["LONG"])  # Longitude from LONG
        center_lat = float(row["LAT"])  # Latitude from LAT

        # Calculate the adjusted height for square tiles
        adjusted_height_deg = tile_width_deg * math.cos(math.radians(center_lat))

        # Calculate tile bounds
        minlatitude = center_lat - (adjusted_height_deg / 2)
        maxlatitude = center_lat + (adjusted_height_deg / 2)
        minlongitude = center_lon - (tile_width_deg / 2)
        maxlongitude = center_lon + (tile_width_deg / 2)

        # Debugging: Print calculated values
        print(f"PEAKID: {file_name}")
        print(f"Center Lat: {center_lat}, Center Lon: {center_lon}")
        print(f"Adjusted Height (degrees): {adjusted_height_deg}")
        print(f"Bounds: {minlatitude} to {maxlatitude}, {minlongitude} to {maxlongitude}")

        # Prepare API parameters
        params = {
            "minlatitude": minlatitude,
            "maxlatitude": maxlatitude,
            "minlongitude": minlongitude,
            "maxlongitude": maxlongitude,
            "width": tile_pixels,
            "mask": "false",
            "download": "true",
        }

        # Construct file name
        output_file = os.path.join(output_folder, f"{file_name}.png")

        # Download the image
        print(f"Downloading square image for PEAKID {file_name} at {center_lat}, {center_lon}...")
        response = requests.get(api_base_url, params=params)

        if response.status_code == 200:
            # Save the image
            with open(output_file, "wb") as file:
                file.write(response.content)
            print(f"Saved: {output_file}")
        else:
            print(f"Failed to download for PEAKID {file_name} - HTTP {response.status_code}")

    except Exception as e:
        print(f"Error processing row {index}: {e}")

print("Download complete.")
# Out:
# Loaded 33452 records from seamounts.csv.
# Skipping PEAKID 26000.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 26157.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 26158.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 26228.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 26229.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 26297.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 26298.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 26407.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 26408.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 26653.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 26664.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 26665.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 27029.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 27045.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 27112.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 27347.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 27393.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 27394.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 27395.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 27396.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 27397.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 27499.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 27586.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 27587.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 27724.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 28090.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 28199.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 28200.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 28323.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 28390.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 28459.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 28618.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 28621.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 28833.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 29041.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 29502.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 29503.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 29633.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 29731.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 29732.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 29745.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 29746.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 29747.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 29748.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 29876.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 29877.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 29924.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 29945.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30190.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30209.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30210.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30211.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30236.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30261.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30262.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30269.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30279.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30280.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30327.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30342.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30343.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30349.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30362.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30363.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30364.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30365.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30369.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30374.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30390.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30391.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30392.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30393.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30394.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30395.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30396.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30419.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30468.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30493.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30544.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30546.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30547.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30548.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30549.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30550.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30631.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30655.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30656.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30733.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30938.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30939.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30974.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 30985.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 31043.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 31044.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 31093.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 31094.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 31095.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 31134.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 31135.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 31857.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 31859.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 31867.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 32828.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 33023.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 33092.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 35640.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 35687.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 35756.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 40611.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 40752.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 40994.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 43283.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 43738.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 45591.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 49447.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 50198.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 50199.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 54436.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 54928.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 56177.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 56178.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 59156.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 59202.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 61761.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 62796.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 65202.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 68086.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 76959.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 77016.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 78483.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 78831.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 79774.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 80010.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 80240.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 80423.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 80571.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 80658.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 85959.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 87212.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 89339.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 90706.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 91718.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 92349.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 99950.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 117387.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 122575.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 136790.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 141504.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 144629.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 161599.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 256440.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 264278.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 267085.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 268142.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 275752.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 284224.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 286306.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 287300.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 296128.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 304341.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 305376.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 305377.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 307899.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 308697.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 312808.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 314217.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 315103.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 315910.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 316457.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 316859.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 317780.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 318958.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 321773.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 327272.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 327640.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 327684.0, image already exists in seamounts_galore.
# Skipping PEAKID 327984.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 328153.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 328292.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 331374.0, image already exists in seamounts_galore.
# Skipping PEAKID 332569.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 334029.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 334323.0, image already exists in seamounts_galore.
# Skipping PEAKID 335178.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 336027.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 336209.0, image already exists in seamounts_galore.
# Skipping PEAKID 337316.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 341202.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 342226.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 342986.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 343094.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 343095.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 343974.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 344467.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 345391.0, image already exists in seamounts_galore.
# Skipping PEAKID 345470.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 347014.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 347017.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 347394.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 348772.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 349283.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 352109.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 353017.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 353435.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 355079.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 355122.0, image already exists in seamounts_galore.
# Skipping PEAKID 355295.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 355925.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 358995.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 359272.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 360059.0, image already exists in seamounts_galore.
# Skipping PEAKID 360152.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 360187.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 360340.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 360738.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 360739.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 360905.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 364206.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 364376.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 366605.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 367765.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 367935.0, image already exists in seamounts_galore.
# Skipping PEAKID 367936.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 367942.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 368417.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 368509.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 369538.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 370103.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 370718.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 370719.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 371151.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 373307.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 373787.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 374512.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 374918.0, image already exists in seamounts_galore.
# Skipping PEAKID 375595.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 377289.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 377293.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 378660.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 381456.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 382341.0, no matching image in seamounts_bboxes.
# Skipping PEAKID
0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980289.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980324.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980396.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980397.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980509.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980545.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980546.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980588.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980589.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980619.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980620.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980622.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980665.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980666.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980687.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980721.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980768.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980805.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980806.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980807.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980808.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980865.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4980992.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981142.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981170.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981212.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981279.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981316.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981317.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981318.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981319.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981320.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981321.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981522.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981601.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981634.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981733.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981765.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981766.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981955.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981991.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4981992.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4982240.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4983035.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4983070.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4983211.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4984099.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4984208.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4984623.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4984651.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4984652.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4984871.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4984872.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4985205.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4986245.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4986336.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4987585.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4987621.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4988894.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4989109.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4989110.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4989111.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4989112.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4989113.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4989114.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4989115.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4989116.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4989117.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4989118.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4991382.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4991716.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4991717.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4991747.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4992057.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4992572.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4995709.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4995771.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4995794.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4995795.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4997350.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4997394.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4997425.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4998392.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4998393.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4998479.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4999095.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4999430.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4999462.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 4999913.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 5000862.0, no matching image in seamounts_bboxes.
# Skipping PEAKID 5000879.0, no matching image in seamounts_bboxes.
# Download complete.

# %% [markdown]
# To load more seamounts, it would be necessary to find out the highest number in the image titles, then to modify the .csv to only contain the seamounts after that and then to run the above script again.

# %% [markdown]
# ## Filter high-res data

# %%
import cv2
import os
import numpy as np

def crop_fixed_border(image, crop_pixels=70):
    """Crop a fixed number of pixels from each border."""
    height, width, _ = image.shape
    if height > crop_pixels * 2 and width > crop_pixels * 2:
        return image[crop_pixels:height-crop_pixels, crop_pixels:width-crop_pixels]
    else:
        print(f"Warning: Crop size too large for image {width}x{height}. Returning original image.")
        return image

def detect_blur(image, threshold=100.0):
    """Detect if an image is blurry using the variance of the Laplacian."""
    # Compute the Laplacian variance
    laplacian_var = cv2.Laplacian(image, cv2.CV_64F).var()
    is_blurry = laplacian_var < threshold
    return laplacian_var, is_blurry

def process_images(input_folder, high_res_folder, low_res_folder, crop_pixels=70, threshold=100.0):
    """Process images: crop, detect blur, and organize into folders."""
    os.makedirs(high_res_folder, exist_ok=True)
    os.makedirs(low_res_folder, exist_ok=True)

    log = []
    for filename in os.listdir(input_folder):
        file_path = os.path.join(input_folder, filename)
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.tif')):
            try:
                # Load the image
                image = cv2.imread(file_path)
                if image is None:
                    print(f"Image {file_path} is corrupt or unreadable.")
                    continue
                
                # Crop the image
                cropped_image = crop_fixed_border(image, crop_pixels)
                
                # Convert to grayscale for sharpness detection
                gray_image = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2GRAY)
                
                # Detect blur
                lap_var, is_blurry = detect_blur(gray_image, threshold)
                log.append((filename, lap_var, is_blurry))
                
                # Move files to the appropriate folder
                if is_blurry:
                    os.rename(file_path, os.path.join(low_res_folder, filename))
                else:
                    os.rename(file_path, os.path.join(high_res_folder, filename))
            
            except Exception as e:
                print(f"Error processing {file_path}: {e}")

    # Save log to a CSV file
    with open(os.path.join(high_res_folder, 'log.csv'), 'w') as log_file:
        log_file.write('Filename,Laplacian Variance,Blurry\n')
        for entry in log:
            log_file.write(f"{entry[0]},{entry[1]:.2f},{entry[2]}\n")

# Example usage
input_folder = './seamounts_galore'
high_res_folder = './seamounts_galore/high_res'
low_res_folder = './seamounts_galore/low_res'
process_images(input_folder, high_res_folder, low_res_folder, crop_pixels=70, threshold=150.0)
