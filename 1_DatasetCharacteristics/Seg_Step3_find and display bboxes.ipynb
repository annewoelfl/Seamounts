# %% [markdown]
# Preprocessing

# %%
import os
import cv2

# Parameters
image_folder = "seamount_images_equal_tiles"  # Root directory of the dataset
output_folder = "seamount_images_equal_tiles_cropped"  # Temporary folder for cropped images
# image_size = (128, 128)  # Image dimensions for the model
crop_pixels = 65  # Pixels to crop from each border

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# Function to crop borders from an image
def crop_fixed_border(image, crop_pixels=5):
    height, width, _ = image.shape
    if height > crop_pixels * 2 and width > crop_pixels * 2:
        cropped_image = image[crop_pixels:height-crop_pixels, crop_pixels:width-crop_pixels]
        return cropped_image
    else:
        return image  # Return original image if cropping not possible

# Preprocess images (cropping and resizing)
print("Preprocessing images...")

# Loop through all files in the image folder
for filename in os.listdir(image_folder):
    image_path = os.path.join(image_folder, filename)
    
    # Check if the file is an image (you can expand the check for other image formats)
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        # Read the image
        image = cv2.imread(image_path)
        
        # Crop the image
        cropped_image = crop_fixed_border(image, crop_pixels)
        
        # Save the cropped image to the output folder
        output_image_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_image_path, cropped_image)

print("Preprocessing complete.")
# Out:
# Preprocessing images...
# Preprocessing complete.

# %% [markdown]
# Matching

# %%
import cv2
import os
import pandas as pd

# Function to find smaller map tile in the corresponding larger map tile using the floating window approach
def find_and_mark_tiles(large_tile_folder, small_tile_folder, output_csv, start_scale=0.1, scale_step=0.1, max_scale=5, manual_correction_x=0, manual_correction_y=0):
    # List to store results
    results = []
    
    # Get list of files in both folders
    large_tiles = os.listdir(large_tile_folder)
    small_tiles = os.listdir(small_tile_folder)

    # Debug: print the list of files in both folders
    print("Large tiles:", large_tiles)
    print("Small tiles:", small_tiles)

    # Create a dictionary of small tiles indexed by PEAKID
    small_tiles_dict = {}
    for small_tile_name in small_tiles:
        # Extract the PEAKID from the smaller tile's filename (assuming format [PEAKID]_1.png)
        peak_id = small_tile_name.split('_')[0]
        small_tiles_dict[peak_id] = small_tile_name

    # Debug: print the small tiles dictionary
    print("Small tiles dictionary:", small_tiles_dict)

    # Iterate through each large tile
    for large_tile_name in large_tiles:
        # Extract the PEAKID from the larger tile's filename (assuming format [PEAKID].png)
        peak_id = large_tile_name.split('.')[0]

        # Ensure the PEAKID matches the format of the small tile (i.e., keep the '.0' if present)
        peak_id = str(float(peak_id))  # This will preserve the ".0" if present
        
        # Debug: print the current large tile being processed
        print(f"Processing large tile: {large_tile_name}, PEAKID: {peak_id}")
        
        # Check if there is a corresponding small tile for this PEAKID
        if peak_id in small_tiles_dict:
            small_tile_name = small_tiles_dict[peak_id]
            large_tile_path = os.path.join(large_tile_folder, large_tile_name)
            small_tile_path = os.path.join(small_tile_folder, small_tile_name)

            # Debug: print the paths of the current large and small tiles
            print(f"Found corresponding small tile: {small_tile_name}")
            print(f"Large tile path: {large_tile_path}")
            print(f"Small tile path: {small_tile_path}")

            # Check if the marked image already exists
            marked_image_path = os.path.join('marked_images', f"marked_{large_tile_name}")
            if os.path.exists(marked_image_path):
                print(f"Skipping already processed large tile: {large_tile_name}")
                continue  # Skip this large tile if it's already processed

            # Read the images
            large_tile = cv2.imread(large_tile_path, cv2.IMREAD_COLOR)
            small_tile = cv2.imread(small_tile_path, cv2.IMREAD_COLOR)

            if large_tile is None:
                print(f"Error: Unable to load large tile {large_tile_path}")
                continue
            if small_tile is None:
                print(f"Error: Unable to load small tile {small_tile_path}")
                continue

            # Get the center of the large tile
            large_tile_center = (large_tile.shape[1] // 2, large_tile.shape[0] // 2)

            # Perform floating window approach: resize and match the small tile centered on the large tile
            max_match_val = 0
            best_match_loc = None
            best_resized_tile = None

            # Start with the small tile and gradually increase its size
            for scale_factor in frange(start_scale, max_scale + scale_step, scale_step):  # Start from start_scale, scale by scale_step
                if scale_factor <= 0:  # Skip non-positive scale factors
                    continue
                
                # Resize the small tile
                new_width = int(small_tile.shape[1] * scale_factor)
                new_height = int(small_tile.shape[0] * scale_factor)

                # Ensure width and height are positive values
                if new_width <= 0 or new_height <= 0:
                    continue  # Skip if the new dimensions are not valid
                
                resized_small_tile = cv2.resize(small_tile, (new_width, new_height))

                # Calculate the top-left corner to center the resized tile on the large tile
                top_left_x = large_tile_center[0] - resized_small_tile.shape[1] // 2
                top_left_y = large_tile_center[1] - resized_small_tile.shape[0] // 2

                # Ensure the top-left corner is within the bounds of the large tile
                if top_left_x < 0 or top_left_y < 0 or top_left_x + resized_small_tile.shape[1] > large_tile.shape[1] or top_left_y + resized_small_tile.shape[0] > large_tile.shape[0]:
                    continue  # Skip if the resized tile is out of bounds

                # Extract the region of interest (ROI) from the large tile where the small tile will be overlaid
                roi = large_tile[top_left_y:top_left_y + resized_small_tile.shape[0], top_left_x:top_left_x + resized_small_tile.shape[1]]

                # Perform template matching
                result = cv2.matchTemplate(roi, resized_small_tile, cv2.TM_CCOEFF_NORMED)
                min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)

                # Debug: print the result of template matching for each scale
                print(f"Scale factor {scale_factor}: Max value: {max_val}, Location: {max_loc}")

                # If the match is better than the previous best match, update the best match
                if max_val > max_match_val:
                    max_match_val = max_val
                    best_match_loc = (top_left_x + max_loc[0], top_left_y + max_loc[1])  # Adjust the location
                    best_resized_tile = resized_small_tile

            # If a good match is found, draw a rectangle around the matched region
            if max_match_val > 0.8:  # You can adjust the threshold as needed
                top_left = best_match_loc
                h, w = best_resized_tile.shape[:2]
                bottom_right = (top_left[0] + w, top_left[1] + h)

                # Apply manual correction
                top_left = (top_left[0] - manual_correction_x, top_left[1] - manual_correction_y)
                bottom_right = (bottom_right[0] + manual_correction_x, bottom_right[1] + manual_correction_y)

                # Draw the corrected rectangle
                cv2.rectangle(large_tile, top_left, bottom_right, (0, 255, 0), 2)

                # Store the coordinates of the box
                results.append({
                    'large_tile': large_tile_name,
                    'small_tile': small_tile_name,
                    'top_left_x': top_left[0],
                    'top_left_y': top_left[1],
                    'bottom_right_x': bottom_right[0],
                    'bottom_right_y': bottom_right[1]
                })

                # Optionally, save the marked image to a file
                os.makedirs('marked_images', exist_ok=True)
                cv2.imwrite(marked_image_path, large_tile)
                print(f"Marked image saved to: {marked_image_path}")

            else:
                print(f"No good match found for {large_tile_name} and {small_tile_name}")

        else:
            print(f"No corresponding small tile found for PEAKID: {peak_id}")

    # Debug: print the results
    print(f"Found {len(results)} matches.")
    
    # Convert the results to a pandas DataFrame and save to CSV
    if results:
        df = pd.DataFrame(results)
        df.to_csv(output_csv, index=False)
        print(f"Results saved to {output_csv}")
    else:
        print("No matches to save.")

# Helper function to generate a range of floating point numbers
def frange(start, stop, step):
    while start < stop:
        yield round(start, 2)  # Round to avoid floating-point precision issues
        start += step

# Example usage
find_and_mark_tiles('seamounts_galore_cropped', 'seamounts_bboxes_cropped', 'output_pixel_coordinates.csv', start_scale=0.1, scale_step=0.1, max_scale=5, manual_correction_x=5, manual_correction_y=5)
# Out:
# Large tiles: ['1001431.0.png', '1013016.0.png', '1025041.0.png', '2002867.0.png', '2076096.0.png', '2120674.0.png', '2203770.0.png', '2325818.0.png', '2327372.0.png', '2358338.0.png', '2392192.0.png', '2392966.0.png', '2394421.0.png', '2395572.0.png', '2401816.0.png', '2414507.0.png', '2419181.0.png', '2438586.0.png', '2451447.0.png', '2474642.0.png', '2486137.0.png', '2554156.0.png', '2581063.0.png', '2593656.0.png', '2619027.0.png', '2624703.0.png', '2627248.0.png', '2657009.0.png', '2681196.0.png', '2691027.0.png', '2692198.0.png', '2698278.0.png', '2701105.0.png', '2708692.0.png', '2709245.0.png', '2711567.0.png', '2714397.0.png', '2725962.0.png', '2747848.0.png', '2754015.0.png', '2759106.0.png', '2772117.0.png', '2779873.0.png', '2798451.0.png', '2799659.0.png', '2799865.0.png', '2809584.0.png', '2819970.0.png', '2841042.0.png', '2853267.0.png', '2858689.0.png', '2859007.0.png', '2862843.0.png', '2887480.0.png', '2915152.0.png', '2938197.0.png', '2948196.0.png', '2948771.0.png', '2969582.0.png', '2977724.0.png', '2990037.0.png', '3006956.0.png', '3025152.0.png', '3040350.0.png', '3052025.0.png', '3052364.0.png', '3075749.0.png', '3102700.0.png', '3124927.0.png', '3136367.0.png', '3144556.0.png', '3150169.0.png', '3151439.0.png', '3152402.0.png', '3153478.0.png', '3157722.0.png', '3162926.0.png', '3164590.0.png', '3171106.0.png', '3171779.0.png', '3178074.0.png', '3179633.0.png', '3180885.0.png', '3196254.0.png', '3208217.0.png', '3212787.0.png', '3217863.0.png', '3225859.0.png', '3236197.0.png', '3243668.0.png', '3244844.0.png', '3251562.0.png', '3261427.0.png', '3267268.0.png', '3270824.0.png', '3276211.0.png', '3279108.0.png', '3284791.0.png', '3285799.0.png', '3285828.0.png', '3287082.0.png', '3313632.0.png', '3320133.0.png', '3322589.0.png', '3324235.0.png', '3336410.0.png', '3347335.0.png', '3354850.0.png', '3361406.0.png', '336209.0.png', '3363688.0.png', '3373064.0.png', '3376699.0.png', '3378505.0.png', '3383881.0.png', '3386477.0.png', '3391881.0.png', '3396855.0.png', '3409397.0.png', '3421463.0.png', '3425473.0.png', '3441619.0.png', '3448638.0.png', '3449432.0.png', '3487419.0.png', '3493043.0.png', '3498905.0.png', '3499812.0.png', '3499845.0.png', '3513265.0.png', '3528703.0.png', '3543250.0.png', '3544822.0.png', '3557823.0.png', '3562248.0.png', '3563758.0.png', '3565688.0.png', '3570863.0.png', '3572596.0.png', '3576846.0.png', '3581119.0.png', '3584918.0.png', '360059.0.png', '3607579.0.png', '3619236.0.png', '3619783.0.png', '3651446.0.png', '3670350.0.png', '3672630.0.png', '3672999.0.png', '3674682.0.png', '3675614.0.png', '3684081.0.png', '3693466.0.png', '3704975.0.png', '3709055.0.png', '3709895.0.png', '3712994.0.png']
Location: (0, 0)
# Scale factor 0.4: Max value: 0.9418448805809021, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9979196786880493, Location: (0, 0)
# Scale factor 0.6: Max value: 0.9583093523979187, Location: (0, 0)
# Scale factor 0.7: Max value: 0.8584060072898865, Location: (0, 0)
# Scale factor 0.8: Max value: 0.7605100274085999, Location: (0, 0)
# Marked image saved to: marked_images\marked_1013016.0.png
# Processing large tile: 1025041.0.png, PEAKID: 1025041.0
# Found corresponding small tile: 1025041.0_1.png
# Large tile path: seamounts_galore_cropped\1025041.0.png
# Small tile path: seamounts_bboxes_cropped\1025041.0_1.png
# Scale factor 0.1: Max value: 0.029033752158284187, Location: (0, 0)
# Scale factor 0.2: Max value: 0.3269037902355194, Location: (0, 0)
# Scale factor 0.3: Max value: 0.5002273321151733, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6687799692153931, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9398252367973328, Location: (0, 0)
# Scale factor 0.6: Max value: 0.686327338218689, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5564699769020081, Location: (0, 0)
# Marked image saved to: marked_images\marked_1025041.0.png
# Processing large tile: 2002867.0.png, PEAKID: 2002867.0
# Found corresponding small tile: 2002867.0_1.png
# Large tile path: seamounts_galore_cropped\2002867.0.png
# Small tile path: seamounts_bboxes_cropped\2002867.0_1.png
# Scale factor 0.1: Max value: 0.18105538189411163, Location: (0, 0)
# Scale factor 0.2: Max value: 0.30268582701683044, Location: (0, 0)
# Scale factor 0.3: Max value: 0.42200174927711487, Location: (0, 0)
# Scale factor 0.4: Max value: 0.5443093776702881, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9643468856811523, Location: (0, 0)
# Scale factor 0.6: Max value: 0.5696674585342407, Location: (0, 0)
# Scale factor 0.7: Max value: 0.4821763336658478, Location: (0, 0)
# Marked image saved to: marked_images\marked_2002867.0.png
# Processing large tile: 2076096.0.png, PEAKID: 2076096.0
# Found corresponding small tile: 2076096.0_1.png
# Large tile path: seamounts_galore_cropped\2076096.0.png
# Small tile path: seamounts_bboxes_cropped\2076096.0_1.png
# Scale factor 0.1: Max value: 0.4087561368942261, Location: (0, 0)
# Scale factor 0.2: Max value: 0.4068600833415985, Location: (0, 0)
# Scale factor 0.3: Max value: 0.49168410897254944, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6698100566864014, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9761107563972473, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7052262425422668, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5707098245620728, Location: (0, 0)
# Scale factor 0.8: Max value: 0.4710065722465515, Location: (0, 0)
# Scale factor 0.9: Max value: 0.3935696482658386, Location: (0, 0)
# Scale factor 1.0: Max value: 0.32821378111839294, Location: (0, 0)
# Scale factor 1.1: Max value: 0.28257668018341064, Location: (0, 0)
# Marked image saved to: marked_images\marked_2076096.0.png
# Processing large tile: 2120674.0.png, PEAKID: 2120674.0
# Found corresponding small tile: 2120674.0_1.png
# Large tile path: seamounts_galore_cropped\2120674.0.png
# Small tile path: seamounts_bboxes_cropped\2120674.0_1.png
# Scale factor 0.1: Max value: 0.16027791798114777, Location: (0, 0)
# Scale factor 0.2: Max value: 0.27428358793258667, Location: (0, 0)
# Scale factor 0.3: Max value: 0.4380553662776947, Location: (0, 0)
# Scale factor 0.4: Max value: 0.5813761949539185, Location: (0, 0)
# Scale factor 0.5: Max value: 0.942564845085144, Location: (0, 0)
# Scale factor 0.6: Max value: 0.6357334852218628, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5713431239128113, Location: (0, 0)
# Scale factor 0.8: Max value: 0.4984527826309204, Location: (0, 0)
# Scale factor 0.9: Max value: 0.4318670928478241, Location: (0, 0)
# Marked image saved to: marked_images\marked_2120674.0.png
# Processing large tile: 2203770.0.png, PEAKID: 2203770.0
# Found corresponding small tile: 2203770.0_1.png
# Large tile path: seamounts_galore_cropped\2203770.0.png
# Small tile path: seamounts_bboxes_cropped\2203770.0_1.png
# Scale factor 0.1: Max value: 0.5899001359939575, Location: (0, 0)
# Scale factor 0.2: Max value: 0.578467607498169, Location: (0, 0)
# Scale factor 0.3: Max value: 0.6652278900146484, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7806124091148376, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9934110641479492, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7573873400688171, Location: (0, 0)
# Scale factor 0.7: Max value: 0.6202778816223145, Location: (0, 0)
# Scale factor 0.8: Max value: 0.5567014813423157, Location: (0, 0)
# Scale factor 0.9: Max value: 0.4709211587905884, Location: (0, 0)
# Scale factor 1.0: Max value: 0.3697323203086853, Location: (0, 0)
# Marked image saved to: marked_images\marked_2203770.0.png
# Processing large tile: 2325818.0.png, PEAKID: 2325818.0
# Found corresponding small tile: 2325818.0_1.png
# Large tile path: seamounts_galore_cropped\2325818.0.png
# Small tile path: seamounts_bboxes_cropped\2325818.0_1.png
# Scale factor 0.1: Max value: 0.5137298107147217, Location: (0, 0)
# Scale factor 0.2: Max value: 0.5189799666404724, Location: (0, 0)
# Scale factor 0.3: Max value: 0.49351266026496887, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7370451092720032, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9760098457336426, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7753413319587708, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5765621066093445, Location: (0, 0)
# Scale factor 0.8: Max value: 0.4556771218776703, Location: (0, 0)
# Scale factor 0.9: Max value: 0.3544657528400421, Location: (0, 0)
# Scale factor 1.0: Max value: 0.2807227075099945, Location: (0, 0)
# Marked image saved to: marked_images\marked_2325818.0.png
# Processing large tile: 2327372.0.png, PEAKID: 2327372.0
# Found corresponding small tile: 2327372.0_1.png
# Large tile path: seamounts_galore_cropped\2327372.0.png
# Small tile path: seamounts_bboxes_cropped\2327372.0_1.png
# Scale factor 0.1: Max value: 0.1939687877893448, Location: (0, 0)
# Scale factor 0.2: Max value: 0.3366173505783081, Location: (0, 0)
# Scale factor 0.3: Max value: 0.44581475853919983, Location: (0, 0)
# Scale factor 0.4: Max value: 0.5858328342437744, Location: (0, 0)
# Scale factor 0.5: Max value: 0.918182909488678, Location: (0, 0)
# Scale factor 0.6: Max value: 0.5991347432136536, Location: (0, 0)
# Scale factor 0.7: Max value: 0.45442524552345276, Location: (0, 0)
# Scale factor 0.8: Max value: 0.40468087792396545, Location: (0, 0)
# Scale factor 0.9: Max value: 0.36184611916542053, Location: (0, 0)
# Scale factor 1.0: Max value: 0.29494044184684753, Location: (0, 0)
# Scale factor 1.1: Max value: 0.27250194549560547, Location: (0, 0)
# Scale factor 1.2: Max value: 0.24634379148483276, Location: (0, 0)
# Marked image saved to: marked_images\marked_2327372.0.png
# Processing large tile: 2358338.0.png, PEAKID: 2358338.0
# Found corresponding small tile: 2358338.0_1.png
# Large tile path: seamounts_galore_cropped\2358338.0.png
# Small tile path: seamounts_bboxes_cropped\2358338.0_1.png
# Scale factor 0.1: Max value: 0.43103858828544617, Location: (0, 0)
# Scale factor 0.2: Max value: 0.39191678166389465, Location: (0, 0)
# Scale factor 0.3: Max value: 0.659099280834198, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7981396913528442, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9863461852073669, Location: (0, 0)
# Scale factor 0.6: Max value: 0.8106047511100769, Location: (0, 0)
# Scale factor 0.7: Max value: 0.6906548738479614, Location: (0, 0)
# Scale factor 0.8: Max value: 0.5757635831832886, Location: (0, 0)
# Scale factor 0.9: Max value: 0.4901995062828064, Location: (0, 0)
# Scale factor 1.0: Max value: 0.4329380989074707, Location: (0, 0)
# Scale factor 1.1: Max value: 0.3728894293308258, Location: (0, 0)
# Scale factor 1.2: Max value: 0.31001564860343933, Location: (0, 0)
# Scale factor 1.3: Max value: 0.25266319513320923, Location: (0, 0)
# Scale factor 1.4: Max value: 0.21615730226039886, Location: (0, 0)
# Scale factor 1.5: Max value: 0.18208055198192596, Location: (0, 0)
# Scale factor 1.6: Max value: 0.1580287516117096, Location: (0, 0)
# Marked image saved to: marked_images\marked_2358338.0.png
# Processing large tile: 2392192.0.png, PEAKID: 2392192.0
# Found corresponding small tile: 2392192.0_1.png
# Large tile path: seamounts_galore_cropped\2392192.0.png
# Small tile path: seamounts_bboxes_cropped\2392192.0_1.png
# Scale factor 0.1: Max value: 0.1387510895729065, Location: (0, 0)
# Scale factor 0.2: Max value: 0.059193044900894165, Location: (0, 0)
# Scale factor 0.3: Max value: 0.07375605404376984, Location: (0, 0)
# Scale factor 0.4: Max value: 0.2493671476840973, Location: (0, 0)
# Scale factor 0.5: Max value: 0.
Location: (0, 0)
# Scale factor 0.8: Max value: 0.5025942325592041, Location: (0, 0)
# Scale factor 0.9: Max value: 0.39107730984687805, Location: (0, 0)
# Scale factor 1.0: Max value: 0.29304322600364685, Location: (0, 0)
# Scale factor 1.1: Max value: 0.21177922189235687, Location: (0, 0)
# Scale factor 1.2: Max value: 0.1505233496427536, Location: (0, 0)
# Scale factor 1.3: Max value: 0.10494541376829147, Location: (0, 0)
# Marked image saved to: marked_images\marked_2419181.0.png
# Processing large tile: 2438586.0.png, PEAKID: 2438586.0
# Found corresponding small tile: 2438586.0_1.png
# Large tile path: seamounts_galore_cropped\2438586.0.png
# Small tile path: seamounts_bboxes_cropped\2438586.0_1.png
# Scale factor 0.1: Max value: 0.25567781925201416, Location: (0, 0)
# Scale factor 0.2: Max value: 0.21034547686576843, Location: (0, 0)
# Scale factor 0.3: Max value: 0.2953650951385498, Location: (0, 0)
# Scale factor 0.4: Max value: 0.5951189994812012, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9529372453689575, Location: (0, 0)
# Scale factor 0.6: Max value: 0.6233726143836975, Location: (0, 0)
# Scale factor 0.7: Max value: 0.40673425793647766, Location: (0, 0)
# Scale factor 0.8: Max value: 0.24495691061019897, Location: (0, 0)
# Scale factor 0.9: Max value: 0.14681540429592133, Location: (0, 0)
# Scale factor 1.0: Max value: 0.0969104915857315, Location: (0, 0)
# Scale factor 1.1: Max value: 0.07207545638084412, Location: (0, 0)
# Scale factor 1.2: Max value: 0.06116623803973198, Location: (0, 0)
# Marked image saved to: marked_images\marked_2438586.0.png
# Processing large tile: 2451447.0.png, PEAKID: 2451447.0
# Found corresponding small tile: 2451447.0_1.png
# Large tile path: seamounts_galore_cropped\2451447.0.png
# Small tile path: seamounts_bboxes_cropped\2451447.0_1.png
# Scale factor 0.1: Max value: 0.22412292659282684, Location: (0, 0)
# Scale factor 0.2: Max value: 0.3426971137523651, Location: (0, 0)
# Scale factor 0.3: Max value: 0.44830814003944397, Location: (0, 0)
# Scale factor 0.4: Max value: 0.5062182545661926, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9456031322479248, Location: (0, 0)
# Scale factor 0.6: Max value: 0.46666279435157776, Location: (0, 0)
# Scale factor 0.7: Max value: 0.41269615292549133, Location: (0, 0)
# Scale factor 0.8: Max value: 0.356838196516037, Location: (0, 0)
# Scale factor 0.9: Max value: 0.31761664152145386, Location: (0, 0)
# Scale factor 1.0: Max value: 0.2511454224586487, Location: (0, 0)
# Scale factor 1.1: Max value: 0.21675889194011688, Location: (0, 0)
# Marked image saved to: marked_images\marked_2451447.0.png
# Processing large tile: 2474642.0.png, PEAKID: 2474642.0
# Found corresponding small tile: 2474642.0_1.png
# Large tile path: seamounts_galore_cropped\2474642.0.png
# Small tile path: seamounts_bboxes_cropped\2474642.0_1.png
# Scale factor 0.1: Max value: 0.22164733707904816, Location: (0, 0)
# Scale factor 0.2: Max value: 0.33862000703811646, Location: (0, 0)
# Scale factor 0.3: Max value: 0.5395859479904175, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7208394408226013, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9791949391365051, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7007221579551697, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5769039392471313, Location: (0, 0)
# Scale factor 0.8: Max value: 0.4612194299697876, Location: (0, 0)
# Scale factor 0.9: Max value: 0.34408414363861084, Location: (0, 0)
# Scale factor 1.0: Max value: 0.2612774074077606, Location: (0, 0)
# Scale factor 1.1: Max value: 0.18612642586231232, Location: (0, 0)
# Scale factor 1.2: Max value: 0.15160799026489258, Location: (0, 0)
# Marked image saved to: marked_images\marked_2474642.0.png
# Processing large tile: 2486137.0.png, PEAKID: 2486137.0
# Found corresponding small tile: 2486137.0_1.png
# Large tile path: seamounts_galore_cropped\2486137.0.png
# Small tile path: seamounts_bboxes_cropped\2486137.0_1.png
# Scale factor 0.1: Max value: 0.262998104095459, Location: (0, 0)
# Scale factor 0.2: Max value: 0.19394318759441376, Location: (0, 0)
# Scale factor 0.3: Max value: 0.4437049925327301, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6594954133033752, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9668306112289429, Location: (0, 0)
# Scale factor 0.6: Max value: 0.6894844174385071, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5425110459327698, Location: (0, 0)
# Scale factor 0.8: Max value: 0.43230801820755005, Location: (0, 0)
# Scale factor 0.9: Max value: 0.3538573384284973, Location: (0, 0)
# Scale factor 1.0: Max value: 0.28429585695266724, Location: (0, 0)
# Scale factor 1.1: Max value: 0.23782432079315186, Location: (0, 0)
# Scale factor 1.2: Max value: 0.1792406588792801, Location: (0, 0)
# Scale factor 1.3: Max value: 0.15142735838890076, Location: (0, 0)
# Scale factor 1.4: Max value: 0.1174282357096672, Location: (0, 0)
# Scale factor 1.5: Max value: 0.08804277330636978, Location: (0, 0)
# Scale factor 1.6: Max value: 0.05532651022076607, Location: (0, 0)
# Marked image saved to: marked_images\marked_2486137.0.png
# Processing large tile: 2554156.0.png, PEAKID: 2554156.0
# Found corresponding small tile: 2554156.0_1.png
# Large tile path: seamounts_galore_cropped\2554156.0.png
# Small tile path: seamounts_bboxes_cropped\2554156.0_1.png
# Scale factor 0.1: Max value: 0.15550236403942108, Location: (0, 0)
# Scale factor 0.2: Max value: 0.2184435874223709, Location: (0, 0)
# Scale factor 0.3: Max value: 0.32805299758911133, Location: (0, 0)
# Scale factor 0.4: Max value: 0.4705609977245331, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9223640561103821, Location: (0, 0)
# Scale factor 0.6: Max value: 0.529434084892273, Location: (0, 0)
# Scale factor 0.7: Max value: 0.2997119724750519, Location: (0, 0)
# Scale factor 0.8: Max value: 0.23376035690307617, Location: (0, 0)
# Scale factor 0.9: Max value: 0.19283829629421234, Location: (0, 0)
# Scale factor 1.0: Max value: 0.14582136273384094, Location: (0, 0)
# Scale factor 1.1: Max value: 0.10984142124652863, Location: (0, 0)
# Scale factor 1.2: Max value: 0.0756329596042633, Location: (0, 0)
# Scale factor 1.3: Max value: 0.030861232429742813, Location: (0, 0)
# Marked image saved to: marked_images\marked_2554156.0.png
# Processing large tile: 2581063.0.png, PEAKID: 2581063.0
# Found corresponding small tile: 2581063.0_1.png
# Large tile path: seamounts_galore_cropped\2581063.0.png
# Small tile path: seamounts_bboxes_cropped\2581063.0_1.png
# Scale factor 0.1: Max value: 0.1796206682920456, Location: (0, 0)
# Scale factor 0.2: Max value: 0.1193399652838707, Location: (0, 0)
# Scale factor 0.3: Max value: 0.38212499022483826, Location: (0, 0)
# Scale factor 0.4: Max value: 0.722997784614563, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9583215117454529, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7521520853042603, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5681944489479065, Location: (0, 0)
# Scale factor 0.8: Max value: 0.39959532022476196, Location: (0, 0)
# Scale factor 0.9: Max value: 0.287109375, Location: (0, 0)
# Scale factor 1.0: Max value: 0.19616049528121948, Location: (0, 0)
# Scale factor 1.1: Max value: 0.15068380534648895, Location: (0, 0)
# Scale factor 1.2: Max value: 0.1279449313879013, Location: (0, 0)
# Scale factor 1.3: Max value: 0.09956425428390503, Location: (0, 0)
# Scale factor 1.4: Max value: 0.08609453588724136, Location: (0, 0)
# Scale factor 1.5: Max value: 0.07803279161453247, Location: (0, 0)
# Marked image saved to: marked_images\marked_2581063.0.png
# Processing large tile: 2593656.0.png, PEAKID: 2593656.0
# Found corresponding small tile: 2593656.0_1.png
# Large tile path: seamounts_galore_cropped\2593656.0.png
# Small tile path: seamounts_bboxes_cropped\2593656.0_1.png
# Scale factor 0.1: Max value: 0.46632304787635803, Location: (0, 0)
# Scale factor 0.2: Max value: 0.6332951784133911, Location: (0, 0)
# Scale factor 0.3: Max value: 0.8165845274925232, Location: (0, 0)
# Scale factor 0.4: Max value: 0.9478192925453186, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9963683485984802, Location: (0, 0)
# Scale factor 0.6: Max value: 0.964168906211853, Location: (0, 0)
# Scale factor 0.7: Max value: 0.8993324041366577, Location: (0, 0)
# Scale factor 0.8: Max value: 0.8222271800041199, Location: (0, 0)
# Scale factor 0.9: Max value: 0.7399533987045288, Location: (0, 0)
# Scale factor 1.0: Max value: 0.6331979632377625, Location: (0, 0)
# Scale factor 1.1: Max value: 0.5419282913208008, Location: (0, 0)
# Scale factor 1.2: Max value: 0.4744665026664734, Location: (0, 0)
# Scale factor 1.3: Max value: 0.4273446500301361, Location: (0, 0)
# Marked image saved to: marked_images\marked_2593656.0.png
# Processing large tile: 2619027.0.png, PEAKID: 2619027.0
# Found corresponding small tile: 2619027.0_1.png
# Large tile path: seamounts_galore_cropped\2619027.0.png
# Small tile path: seamounts_bboxes_cropped\2619027.0_1.png
# Scale factor 0.1: Max value: 0.538145899772644, Location: (0, 0)
# Scale factor 0.2: Max value: 0.6342054009437561, Location: (0, 0)
# Scale factor 0.3: Max value: 0.7404528260231018, Location: (0, 0)
# Scale factor 0.4: Max value: 0.8036333918571472, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9712480306625366, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7593513131141663, Location: (0, 0)
# Scale factor 0.7: Max value: 0.6561383008956909, Location: (0, 0)
# Scale factor 0.8: Max value: 0.5680897235870361, Location: (0, 0)
# Scale factor 0.9: Max value: 0.5074210166931152, Location: (0, 0)
# Scale factor 1.0: Max value: 0.4421547055244446, Location: (0, 0)
# Scale factor 1.1: Max value: 0.40599384903907776, Location: (0, 0)
# Scale factor 1.2: Max value: 0.3450676202774048, Location: (0, 0)
# Scale factor 1.3: Max value: 0.29347577691078186, Location: (0, 0)
# Marked image saved to: marked_images\marked_2619027.0.png
# Processing large tile: 2624703.0.png, PEAKID: 2624703.0
# Found corresponding small tile: 2624703.0_1.png
# Large tile path: seamounts_galore_cropped\2624703.0.png
# Small tile path: seamounts_bboxes_cropped\2624703.0_1.png
# Scale factor 0.1: Max value: 0.15474539995193481, Location: (0, 0)
# Scale factor 0.2: Max value: 0.3610069453716278, Location: (0, 0)
# Scale factor 0.3: Max value: 0.564828097820282, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7583727240562439, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9160324335098267, Location: (0, 0)
# Scale factor 0.6: Max value: 0.695929765701294, Location: (0, 0)
# Scale factor 0.7: Max value: 0.605930507183075, Location: (0, 0)
# Scale factor 0.8: Max value: 0.48322948813438416, Location: (0, 0)
# Scale factor 0.9: Max value: 0.38027286529541016, Location: (0, 0)
# Scale factor 1.0: Max value: 0.28253456950187683, Location: (0, 0)
# Scale factor 1.1: Max value: 0.24082051217556, Location: (0, 0)
# Scale factor 1.2: Max value: 0.21083992719650269, Location: (0, 0)
# Scale factor 1.3: Max value: 0.17350080609321594, Location: (0, 0)
# Scale factor 1.4: Max value: 0.14153580367565155, Location: (0, 0)
# Marked image saved to: marked_images\marked_2624703.0.png
# Processing large tile: 2627248.0.png, PEAKID: 2627248.0
# Found corresponding small tile: 2627248.0_1.png
# Large tile path: seamounts_galore_cropped\2627248.0.png
# Small tile path: seamounts_bboxes_cropped\2627248.0_1.png
# Scale factor 0.1: Max value: 0.7605826258659363, Location: (0, 0)
# Scale factor 0.2: Max value: 0.8354179263114929, Location: (0, 0)
# Scale factor 0.3: Max value: 0.9085890650749207, Location: (0, 0)
# Scale factor 0.4: Max value: 0.9677572250366211, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9949839115142822, Location: (0, 0)
# Scale factor 0.6: Max value: 0.9639499187469482, Location: (0, 0)
# Scale factor 0.7: Max value: 0.8899996280670166, Location: (0, 0)
# Scale factor 0.8: Max value: 0.7803037166595459, Location: (0, 0)
# Scale factor 0.9: Max value: 0.6458892822265625, Location: (0, 0)
# Scale factor 1.0: Max value: 0.5039845108985901, Location: (0, 0)
# Scale factor 1.1: Max value: 0.3906949758529663, Location: (0, 0)
# Scale factor 1.2: Max value: 0.3021487891674042, Location: (0, 0)
# Marked image saved to: marked_images\marked_2627248.0.png
# Processing large tile: 2657009.0.png, PEAKID: 2657009.0
# Found corresponding small tile: 2657009.0_1.png
# Large tile path: seamounts_galore_cropped\2657009.0.png
# Small tile path: seamounts_bboxes_cropped\2657009.0_1.png
# Scale factor 0.1: Max value: 0.5214758515357971, Location: (0, 0)
# Scale factor 0.2: Max value: 0.543331503868103, Location: (0, 0)
# Scale factor 0.3: Max value: 0.6081350445747375, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6800776124000549, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9283186197280884, Location: (0, 0)
# Scale factor 0.6: Max value: 0.6556795835494995, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5557971596717834, Location: (0, 0)
# Scale factor 0.8: Max value: 0.43089306354522705, Location: (0, 0)
# Scale factor 0.9: Max value: 0.35109880566596985, Location: (0, 0)
# Scale factor 1.0: Max value: 0.2981904447078705, Location: (0, 0)
# Scale factor 1.1: Max value: 0.2777884900569916, Location: (0, 0)
# Scale factor 1.2: Max value: 0.2528979778289795, Location: (0, 0)
# Scale factor 1.3: Max value: 0.22914640605449677, Location: (0, 0)
# Scale factor 1.4: Max value: 0.21811828017234802, Location: (0, 0)
# Scale factor 1.5: Max value: 0.20519517362117767, Location: (0, 0)
# Scale factor 1.6: Max value: 0.2024177610874176, Location: (0, 0)
# Scale factor 1.7: Max value: 0.1919374316930771, Location: (0, 0)
# Scale factor 1.8: Max value: 0.18069514632225037, Location: (0, 0)
# Marked image saved to: marked_images\marked_2657009.0.png
# Processing large tile: 2681196.0.png, PEAKID: 2681196.0
# Found corresponding small tile: 2681196.0_1.png
# Large tile path: seamounts_galore_cropped\2681196.0.png
# Small tile path: seamounts_bboxes_cropped\2681196.0_1.png
# Scale factor 0.1: Max value: 0.21104882657527924, Location: (0, 0)
# Scale factor 0.2: Max value: 0.5122767686843872, Location: (0, 0)
# Scale factor 0.3: Max value: 0.6785333752632141, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7854463458061218, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9719171524047852, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7781811356544495, Location: (0, 0)
# Scale factor 0.7: Max value: 0.6774684190750122, Location: (0, 0)
# Scale factor 0.8: Max value: 0.5925431847572327, Location: (0, 0)
# Scale factor 0.9: Max value: 0.5022829174995422, Location: (0, 0)
# Scale factor 1.0: Max value: 0.42219215631484985, Location: (0, 0)
# Scale factor 1.1: Max value: 0.3715006411075592, Location: (0, 0)
# Marked image saved to: marked_images\marked_2681196.0.png
# Processing large tile: 2691027.0.png, PEAKID: 2691027.0
# Found corresponding small tile: 2691027.0_1.png
# Large tile path: seamounts_galore_cropped\2691027.0.png
# Small tile path: seamounts_bboxes_cropped\2691027.0_1.png
# Scale factor 0.1: Max value: 0.5901986956596375, Location: (0, 0)
# Scale factor 0.2: Max value: 0.6253901124000549, Location: (0, 0)
# Scale factor 0.3: Max value: 0.7757440209388733, Location: (0, 0)
# Scale factor 0.4: Max value: 0.837020218372345, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9660976529121399, Location: (0, 0)
# Scale factor 0.6: Max value: 0.812791645526886, Location: (0, 0)
# Scale factor 0.7: Max value: 0.7023537755012512, Location: (0, 0)
# Scale factor 0.8: Max value: 0.5740779042243958, Location: (0, 0)
# Scale factor 0.9: Max value: 0.48956817388534546, Location: (0, 0)
# Scale factor 1.0: Max value: 0.4117131531238556, Location: (0, 0)
# Scale factor 1.1: Max value: 0.346668004989624, Location: (0, 0)
# Scale factor 1.2: Max value: 0.28524431586265564, Location: (0, 0)
# Scale factor 1.3: Max value: 0.25781023502349854, Location: (0, 0)
# Scale factor 1.4: Max value: 0.21936535835266113, Location: (0, 0)
# Scale factor 1.5: Max value: 0.19019068777561188, Location: (0, 0)
# Scale factor 1.6: Max value: 0.17792470753192902, Location: (0, 0)
# Marked image saved to: marked_images\marked_2691027.0.png
# Processing large tile: 2692198.0.png, PEAKID: 2692198.0
# Found corresponding small tile: 2692198.0_1.png
# Large tile path: seamounts_galore_cropped\2692198.0.png
# Small tile path: seamounts_bboxes_cropped\2692198.0_1.png
# Scale factor 0.1: Max value: 0.5507791638374329, Location: (0, 0)
# Scale factor 0.2: Max value: 0.6153241395950317, Location: (0, 0)
# Scale factor 0.3: Max value: 0.7193707823753357, Location: (0, 0)
# Scale factor 0.4: Max value: 0.8092083930969238, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9775375127792358, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7887150049209595, Location: (0, 0)
# Scale factor 0.7: Max value: 0.6533241271972656, Location: (0, 0)
# Scale factor 0.8: Max value: 0.5580850839614868, Location: (0, 0)
# Scale factor 0.9: Max value: 0.4827486276626587, Location: (0, 0)
# Scale factor 1.0: Max value: 0.4181057810783386, Location: (0, 0)
# Scale factor 1.1: Max value: 0.3695424795150757, Location: (0, 0)
# Scale factor 1.2: Max value: 0.3178921043872833, Location: (0, 0)
# Scale factor 1.3: Max value: 0.28773194551467896, Location: (0, 0)
# Scale factor 1.4: Max value: 0.25353148579597473, Location: (0, 0)
# Scale factor 1.5: Max value: 0.2256394326686859, Location: (0, 0)
# Marked image saved to: marked_images\marked_2692198.0.png
# Processing large tile: 2698278.0.png, PEAKID: 2698278.0
# Found corresponding small tile: 2698278.0_1.png
# Large tile path: seamounts_galore_cropped\2698278.0.png
# Small tile path: seamounts_bboxes_cropped\2698278.0_1.png
# Scale factor 0.1: Max value: 0.4370425045490265, Location: (0, 0)
# Scale factor 0.2: Max value: 0.4923991560935974, Location: (0, 0)
# Scale factor 0.3: Max value: 0.5850403308868408, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7235879898071289, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9767687320709229, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7033270001411438, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5442699193954468, Location: (0, 0)
# Scale factor 0.8: Max value: 0.40795859694480896, Location: (0, 0)
# Scale factor 0.9: Max value: 0.3198549747467041, Location: (0, 0)
# Scale factor 1.0: Max value: 0.2511194348335266, Location: (0, 0)
# Scale factor 1.1: Max value: 0.18445618450641632, Location: (0, 0)
# Scale factor 1.2: Max value: 0.12056068331003189, Location: (0, 0)
# Scale factor 1.3: Max value: 0.05649997293949127, Location: (0, 0)
# Marked image saved to: marked_images\marked_2698278.0.png
# Processing large tile: 2701105.0.png, PEAKID: 2701105.0
# Found corresponding small tile: 2701105.0_1.png
# Large tile path: seamounts_galore_cropped\2701105.0.png
# Small tile path: seamounts_bboxes_cropped\2701105.0_1.png
# Scale factor 0.1: Max value: 0.30551278591156006, Location: (0, 0)
# Scale factor 0.2: Max value: 0.41461506485939026, Location: (0, 0)
# Scale factor 0.3: Max value: 0.47143539786338806, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6687151193618774, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9423741102218628, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7336247563362122, Location: (0, 0)
# Scale factor 0.7: Max value: 0.588173508644104, Location: (0, 0)
# Scale factor 0.8: Max value: 0.5059175491333008, Location: (0, 0)
# Scale factor 0.9: Max value: 0.42235898971557617, Location: (0, 0)
# Scale factor 1.0: Max value: 0.3666532635688782, Location: (0, 0)
# Scale factor 1.1: Max value: 0.3272015452384949, Location: (0, 0)
# Scale factor 1.2: Max value: 0.27821609377861023, Location: (0, 0)
# Scale factor 1.3: Max value: 0.23569023609161377, Location: (0, 0)
# Scale factor 1.4: Max value: 0.20913365483283997, Location: (0, 0)
# Scale factor 1.5: Max value: 0.1919250786304474, Location: (0, 0)
# Scale factor 1.6: Max value: 0.1694161742925644, Location: (0, 0)
# Scale factor 1.7: Max value: 0.15145725011825562, Location: (0, 0)
# Scale factor 1.8: Max value: 0.1468534767627716, Location: (0, 0)
# Scale factor 1.9: Max value: 0.1455817073583603, Location: (0, 0)
# Scale factor 2.0: Max value: 0.14240670204162598, Location: (0, 0)
# Scale factor 2.1: Max value: 0.13226227462291718, Location: (0, 0)
# Scale factor 2.2: Max value: 0.11580051481723785, Location: (0, 0)
# Scale factor 2.3: Max value: 0.10110840946435928, Location: (0, 0)
# Scale factor 2.4: Max value: 0.08145660907030106, Location: (0, 0)
# Scale factor 2.5: Max value: 0.053428493440151215, Location: (0, 0)
# Marked image saved to: marked_images\marked_2701105.0.png
# Processing large tile: 2708692.0.png, PEAKID: 2708692.0
# Found corresponding small tile: 2708692.0_1.png
# Large tile path: seamounts_galore_cropped\2708692.0.png
# Small tile path: seamounts_bboxes_cropped\2708692.0_1.png
# Scale factor 0.1: Max value: 0.5815756320953369, Location: (0, 0)
# Scale factor 0.2: Max value: 0.5953997373580933, Location: (0, 0)
# Scale factor 0.3: Max value: 0.5876638293266296, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6832265853881836, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9230452179908752, Location: (0, 0)
# Scale factor 0.6: Max value: 0.6828464865684509, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5798200368881226, Location: (0, 0)
# Scale factor 0.8: Max value: 0.4837994873523712, Location: (0, 0)
# Scale factor 0.9: Max value: 0.4252306818962097, Location: (0, 0)
# Scale factor 1.0: Max value: 0.3838396966457367, Location: (0, 0)
# Scale factor 1.1: Max value: 0.3519946038722992, Location: (0, 0)
# Marked image saved to: marked_images\marked_2708692.0.png
# Processing large tile: 2709245.0.png, PEAKID: 2709245.0
# Found corresponding small tile: 2709245.0_1.png
# Large tile path: seamounts_galore_cropped\2709245.0.png
# Small tile path: seamounts_bboxes_cropped\2709245.0_1.png
# Scale factor 0.1: Max value: 0.13756099343299866, Location: (0, 0)
# Scale factor 0.2: Max value: 0.10496345907449722, Location: (0, 0)
# Scale factor 0.3: Max value: 0.1711146980524063, Location: (0, 0)
# Scale factor 0.4: Max value: 0.2022969275712967, Location: (0, 0)
# Scale factor 0.5: Max value: 0.8375338315963745, Location: (0, 0)
# Scale factor 0.6: Max value: 0.18599927425384521, Location: (0, 0)
# Scale factor 0.7: Max value: 0.1363777220249176, Location: (0, 0)
# ...
# Found corresponding small tile: 3672999.0_1.png
# Large tile path: seamounts_galore_cropped\3672999.0.png
# Small tile path: seamounts_bboxes_cropped\3672999.0_1.png
# Scale factor 0.1: Max value: 0.36536577343940735, Location: (0, 0)
# Scale factor 0.2: Max value: 0.4644407629966736, Location: (0, 0)
# Scale factor 0.3: Max value: 0.5991585850715637, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7340131998062134, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9608935117721558, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7626527547836304, Location: (0, 0)
# Scale factor 0.7: Max value: 0.6555885672569275, Location: (0, 0)
# Scale factor 0.8: Max value: 0.5701558589935303, Location: (0, 0)
# Scale factor 0.9: Max value: 0.49907800555229187, Location: (0, 0)
# Scale factor 1.0: Max value: 0.4264645278453827, Location: (0, 0)
# Scale factor 1.1: Max value: 0.380772203207016, Location: (0, 0)
# Scale factor 1.2: Max value: 0.3381096124649048, Location: (0, 0)
# Scale factor 1.3: Max value: 0.31218191981315613, Location: (0, 0)
# Scale factor 1.4: Max value: 0.289651095867157, Location: (0, 0)
# Scale factor 1.5: Max value: 0.2738165259361267, Location: (0, 0)
# Scale factor 1.6: Max value: 0.25467708706855774, Location: (0, 0)
# Marked image saved to: marked_images\marked_3672999.0.png
# Processing large tile: 3674682.0.png, PEAKID: 3674682.0
# Found corresponding small tile: 3674682.0_1.png
# Large tile path: seamounts_galore_cropped\3674682.0.png
# Small tile path: seamounts_bboxes_cropped\3674682.0_1.png
# Scale factor 0.1: Max value: 0.16616199910640717, Location: (0, 0)
# Scale factor 0.2: Max value: 0.23019148409366608, Location: (0, 0)
# Scale factor 0.3: Max value: 0.3142004907131195, Location: (0, 0)
# Scale factor 0.4: Max value: 0.3764592409133911, Location: (0, 0)
# Scale factor 0.5: Max value: 0.912848949432373, Location: (0, 0)
# Scale factor 0.6: Max value: 0.38736194372177124, Location: (0, 0)
# Scale factor 0.7: Max value: 0.20883341133594513, Location: (0, 0)
# Scale factor 0.8: Max value: 0.1435742825269699, Location: (0, 0)
# Scale factor 0.9: Max value: 0.11432395130395889, Location: (0, 0)
# Scale factor 1.0: Max value: 0.14163357019424438, Location: (0, 0)
# Scale factor 1.1: Max value: 0.1388767659664154, Location: (0, 0)
# Scale factor 1.2: Max value: 0.1311190128326416, Location: (0, 0)
# Scale factor 1.3: Max value: 0.1293482929468155, Location: (0, 0)
# Scale factor 1.4: Max value: 0.09523271769285202, Location: (0, 0)
# Scale factor 1.5: Max value: 0.06375773996114731, Location: (0, 0)
# Scale factor 1.6: Max value: 0.01858237385749817, Location: (0, 0)
# Scale factor 1.7: Max value: 0.009791401214897633, Location: (0, 0)
# Scale factor 1.8: Max value: 0.011731539852917194, Location: (0, 0)
# Scale factor 1.9: Max value: 0.010025651194155216, Location: (0, 0)
# Scale factor 2.0: Max value: 0.012514072470366955, Location: (0, 0)
# Scale factor 2.1: Max value: 0.019346103072166443, Location: (0, 0)
# Scale factor 2.2: Max value: 0.025875110179185867, Location: (0, 0)
# Scale factor 2.3: Max value: 0.026118719950318336, Location: (0, 0)
# Scale factor 2.4: Max value: 0.019994154572486877, Location: (0, 0)
# Scale factor 2.5: Max value: 0.02740224078297615, Location: (0, 0)
# Scale factor 2.6: Max value: 0.03015381470322609, Location: (0, 0)
# Marked image saved to: marked_images\marked_3674682.0.png
# Processing large tile: 3675614.0.png, PEAKID: 3675614.0
# Found corresponding small tile: 3675614.0_1.png
# Large tile path: seamounts_galore_cropped\3675614.0.png
# Small tile path: seamounts_bboxes_cropped\3675614.0_1.png
# Scale factor 0.1: Max value: 0.1163778230547905, Location: (0, 0)
# Scale factor 0.2: Max value: 0.17767123878002167, Location: (0, 0)
# Scale factor 0.3: Max value: 0.391650915145874, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6710590124130249, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9687816500663757, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7285917401313782, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5482205748558044, Location: (0, 0)
# Scale factor 0.8: Max value: 0.4278061091899872, Location: (0, 0)
# Scale factor 0.9: Max value: 0.33050259947776794, Location: (0, 0)
# Scale factor 1.0: Max value: 0.24695047736167908, Location: (0, 0)
# Scale factor 1.1: Max value: 0.20808541774749756, Location: (0, 0)
# Scale factor 1.2: Max value: 0.17203088104724884, Location: (0, 0)
# Scale factor 1.3: Max value: 0.1428452581167221, Location: (0, 0)
# Scale factor 1.4: Max value: 0.11804356426000595, Location: (0, 0)
# Scale factor 1.5: Max value: 0.10368197411298752, Location: (0, 0)
# Scale factor 1.6: Max value: 0.08179446309804916, Location: (0, 0)
# Scale factor 1.7: Max value: 0.05520278587937355, Location: (0, 0)
# Scale factor 1.8: Max value: 0.037453651428222656, Location: (0, 0)
# Scale factor 1.9: Max value: 0.030957231298089027, Location: (0, 0)
# Scale factor 2.0: Max value: 0.028706945478916168, Location: (0, 0)
# Scale factor 2.1: Max value: 0.021143289282917976, Location: (0, 0)
# Scale factor 2.2: Max value: 0.02228359878063202, Location: (0, 0)
# Marked image saved to: marked_images\marked_3675614.0.png
# Processing large tile: 3684081.0.png, PEAKID: 3684081.0
# Found corresponding small tile: 3684081.0_1.png
# Large tile path: seamounts_galore_cropped\3684081.0.png
# Small tile path: seamounts_bboxes_cropped\3684081.0_1.png
# Scale factor 0.1: Max value: 0.16302859783172607, Location: (0, 0)
# Scale factor 0.2: Max value: 0.29875481128692627, Location: (0, 0)
# Scale factor 0.3: Max value: 0.4237973093986511, Location: (0, 0)
# Scale factor 0.4: Max value: 0.5170097351074219, Location: (0, 0)
# Scale factor 0.5: Max value: 0.8118540048599243, Location: (0, 0)
# Scale factor 0.6: Max value: 0.4215812087059021, Location: (0, 0)
# Scale factor 0.7: Max value: 0.3488897681236267, Location: (0, 0)
# Scale factor 0.8: Max value: 0.29829877614974976, Location: (0, 0)
# Scale factor 0.9: Max value: 0.2797703146934509, Location: (0, 0)
# Scale factor 1.0: Max value: 0.18461498618125916, Location: (0, 0)
# Scale factor 1.1: Max value: 0.13572439551353455, Location: (0, 0)
# Scale factor 1.2: Max value: 0.12348252534866333, Location: (0, 0)
# Scale factor 1.3: Max value: 0.08125319331884384, Location: (0, 0)
# Scale factor 1.4: Max value: 0.07283684611320496, Location: (0, 0)
# Scale factor 1.5: Max value: 0.0887075886130333, Location: (0, 0)
# Scale factor 1.6: Max value: 0.09179990738630295, Location: (0, 0)
# Scale factor 1.7: Max value: 0.04468404874205589, Location: (0, 0)
# Scale factor 1.8: Max value: 0.02211339771747589, Location: (0, 0)
# Scale factor 1.9: Max value: 0.0076792435720562935, Location: (0, 0)
# Scale factor 2.0: Max value: 0.015339621342718601, Location: (0, 0)
# Scale factor 2.1: Max value: 0.03698325529694557, Location: (0, 0)
# Scale factor 2.2: Max value: 0.03195935860276222, Location: (0, 0)
# Scale factor 2.3: Max value: 0.022126784548163414, Location: (0, 0)
# Scale factor 2.4: Max value: 0.02886989898979664, Location: (0, 0)
# Marked image saved to: marked_images\marked_3684081.0.png
# Processing large tile: 3693466.0.png, PEAKID: 3693466.0
# Found corresponding small tile: 3693466.0_1.png
# Large tile path: seamounts_galore_cropped\3693466.0.png
# Small tile path: seamounts_bboxes_cropped\3693466.0_1.png
# Scale factor 0.1: Max value: 0.22799676656723022, Location: (0, 0)
# Scale factor 0.2: Max value: 0.21118803322315216, Location: (0, 0)
# Scale factor 0.3: Max value: 0.25392216444015503, Location: (0, 0)
# Scale factor 0.4: Max value: 0.38392338156700134, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9202952980995178, Location: (0, 0)
# Scale factor 0.6: Max value: 0.44903847575187683, Location: (0, 0)
# Scale factor 0.7: Max value: 0.3368472754955292, Location: (0, 0)
# Scale factor 0.8: Max value: 0.26561239361763, Location: (0, 0)
# Scale factor 0.9: Max value: 0.2448795735836029, Location: (0, 0)
# Scale factor 1.0: Max value: 0.20187434554100037, Location: (0, 0)
# Scale factor 1.1: Max value: 0.19840407371520996, Location: (0, 0)
# Scale factor 1.2: Max value: 0.19154271483421326, Location: (0, 0)
# Scale factor 1.3: Max value: 0.18503312766551971, Location: (0, 0)
# Scale factor 1.4: Max value: 0.1866634488105774, Location: (0, 0)
# Scale factor 1.5: Max value: 0.17896153032779694, Location: (0, 0)
# Marked image saved to: marked_images\marked_3693466.0.png
# Processing large tile: 3704975.0.png, PEAKID: 3704975.0
# Found corresponding small tile: 3704975.0_1.png
# Large tile path: seamounts_galore_cropped\3704975.0.png
# Small tile path: seamounts_bboxes_cropped\3704975.0_1.png
# Scale factor 0.1: Max value: 0.1462480127811432, Location: (0, 0)
# Scale factor 0.2: Max value: 0.24071262776851654, Location: (0, 0)
# Scale factor 0.3: Max value: 0.32476893067359924, Location: (0, 0)
# Scale factor 0.4: Max value: 0.40324825048446655, Location: (0, 0)
# Scale factor 0.5: Max value: 0.8840173482894897, Location: (0, 0)
# Scale factor 0.6: Max value: 0.41431236267089844, Location: (0, 0)
# Scale factor 0.7: Max value: 0.3350391983985901, Location: (0, 0)
# Scale factor 0.8: Max value: 0.2943846881389618, Location: (0, 0)
# Scale factor 0.9: Max value: 0.25233525037765503, Location: (0, 0)
# Scale factor 1.0: Max value: 0.18346670269966125, Location: (0, 0)
# Scale factor 1.1: Max value: 0.13606630265712738, Location: (0, 0)
# Scale factor 1.2: Max value: 0.10642167180776596, Location: (0, 0)
# Scale factor 1.3: Max value: 0.06904719024896622, Location: (0, 0)
# Scale factor 1.4: Max value: 0.05542239174246788, Location: (0, 0)
# Scale factor 1.5: Max value: 0.04261445999145508, Location: (0, 0)
# Marked image saved to: marked_images\marked_3704975.0.png
# Processing large tile: 3709055.0.png, PEAKID: 3709055.0
# Found corresponding small tile: 3709055.0_1.png
# Large tile path: seamounts_galore_cropped\3709055.0.png
# Small tile path: seamounts_bboxes_cropped\3709055.0_1.png
# Scale factor 0.1: Max value: -0.12941955029964447, Location: (0, 0)
# Scale factor 0.2: Max value: 0.2776542603969574, Location: (0, 0)
# Scale factor 0.3: Max value: 0.4144134819507599, Location: (0, 0)
# Scale factor 0.4: Max value: 0.619117021560669, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9727203845977783, Location: (0, 0)
# Scale factor 0.6: Max value: 0.6722947955131531, Location: (0, 0)
# Scale factor 0.7: Max value: 0.4557408094406128, Location: (0, 0)
# Scale factor 0.8: Max value: 0.31417304277420044, Location: (0, 0)
# Scale factor 0.9: Max value: 0.23267999291419983, Location: (0, 0)
# Scale factor 1.0: Max value: 0.11947804689407349, Location: (0, 0)
# Scale factor 1.1: Max value: 0.05290117859840393, Location: (0, 0)
# Scale factor 1.2: Max value: 0.018720846623182297, Location: (0, 0)
# Scale factor 1.3: Max value: -0.02168126590549946, Location: (0, 0)
# Scale factor 1.4: Max value: -0.05985764041543007, Location: (0, 0)
# Scale factor 1.5: Max value: -0.11073342710733414, Location: (0, 0)
# Scale factor 1.6: Max value: -0.1477155089378357, Location: (0, 0)
# Marked image saved to: marked_images\marked_3709055.0.png
# Processing large tile: 3709895.0.png, PEAKID: 3709895.0
# Found corresponding small tile: 3709895.0_1.png
# Large tile path: seamounts_galore_cropped\3709895.0.png
# Small tile path: seamounts_bboxes_cropped\3709895.0_1.png
# Scale factor 0.1: Max value: 0.3884802758693695, Location: (0, 0)
# Scale factor 0.2: Max value: 0.5746358633041382, Location: (0, 0)
# Scale factor 0.3: Max value: 0.5113001465797424, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6770849227905273, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9767225384712219, Location: (0, 0)
# Scale factor 0.6: Max value: 0.6454641222953796, Location: (0, 0)
# Scale factor 0.7: Max value: 0.48018306493759155, Location: (0, 0)
# Scale factor 0.8: Max value: 0.38878223299980164, Location: (0, 0)
# Scale factor 0.9: Max value: 0.35730743408203125, Location: (0, 0)
# Scale factor 1.0: Max value: 0.3078305721282959, Location: (0, 0)
# Scale factor 1.1: Max value: 0.2768785059452057, Location: (0, 0)
# Scale factor 1.2: Max value: 0.23619142174720764, Location: (0, 0)
# Scale factor 1.3: Max value: 0.21832308173179626, Location: (0, 0)
# Scale factor 1.4: Max value: 0.1921555995941162, Location: (0, 0)
# Scale factor 1.5: Max value: 0.1549973338842392, Location: (0, 0)
# Scale factor 1.6: Max value: 0.11707106232643127, Location: (0, 0)
# Scale factor 1.7: Max value: 0.10375289618968964, Location: (0, 0)
# Scale factor 1.8: Max value: 0.09979497641324997, Location: (0, 0)
# Scale factor 1.9: Max value: 0.0785980299115181, Location: (0, 0)
# Scale factor 2.0: Max value: 0.07198368012905121, Location: (0, 0)
# Scale factor 2.1: Max value: 0.06109558045864105, Location: (0, 0)
# Scale factor 2.2: Max value: 0.05145598202943802, Location: (0, 0)
# Scale factor 2.3: Max value: 0.044302914291620255, Location: (0, 0)
# Scale factor 2.4: Max value: 0.03371572121977806, Location: (0, 0)
# Scale factor 2.5: Max value: 0.028693770989775658, Location: (0, 0)
# Scale factor 2.6: Max value: 0.027418063953518867, Location: (0, 0)
# Scale factor 2.7: Max value: 0.03270970657467842, Location: (0, 0)
# Scale factor 2.8: Max value: 0.040458794683218, Location: (0, 0)
# Scale factor 2.9: Max value: 0.04400715231895447, Location: (0, 0)
# Scale factor 3.0: Max value: 0.036725807934999466, Location: (0, 0)
# Scale factor 3.1: Max value: 0.0318739116191864, Location: (0, 0)
# Scale factor 3.2: Max value: 0.029654260724782944, Location: (0, 0)
# Scale factor 3.3: Max value: 0.030081341043114662, Location: (0, 0)
# Scale factor 3.4: Max value: 0.03371695056557655, Location: (0, 0)
# Scale factor 3.5: Max value: 0.03671286255121231, Location: (0, 0)
# Scale factor 3.6: Max value: 0.03756682574748993, Location: (0, 0)
# Scale factor 3.7: Max value: 0.038087956607341766, Location: (0, 0)
# Scale factor 3.8: Max value: 0.03496453911066055, Location: (0, 0)
# Scale factor 3.9: Max value: 0.029543885961174965, Location: (0, 0)
# Scale factor 4.0: Max value: 0.01925649866461754, Location: (0, 0)
# Scale factor 4.1: Max value: 0.013467921875417233, Location: (0, 0)
# Marked image saved to: marked_images\marked_3709895.0.png
# Processing large tile: 3712994.0.png, PEAKID: 3712994.0
# Found corresponding small tile: 3712994.0_1.png
# Large tile path: seamounts_galore_cropped\3712994.0.png
# Small tile path: seamounts_bboxes_cropped\3712994.0_1.png
# Scale factor 0.1: Max value: -0.1023741215467453, Location: (0, 0)
# Scale factor 0.2: Max value: 0.486091673374176, Location: (0, 0)
# Scale factor 0.3: Max value: 0.6952690482139587, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7710641622543335, Location: (0, 0)
# Scale factor 0.5: Max value: 0.979557991027832, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7956414818763733, Location: (0, 0)
# Scale factor 0.7: Max value: 0.693405032157898, Location: (0, 0)
# Scale factor 0.8: Max value: 0.6260609030723572, Location: (0, 0)
# Scale factor 0.9: Max value: 0.558824896812439, Location: (0, 0)
# Scale factor 1.0: Max value: 0.4649486839771271, Location: (0, 0)
# Scale factor 1.1: Max value: 0.409259170293808, Location: (0, 0)
# Scale factor 1.2: Max value: 0.35954004526138306, Location: (0, 0)
# Scale factor 1.3: Max value: 0.31023862957954407, Location: (0, 0)
# Scale factor 1.4: Max value: 0.2821853458881378, Location: (0, 0)
# Scale factor 1.5: Max value: 0.23577596247196198, Location: (0, 0)
# Scale factor 1.6: Max value: 0.1906920224428177, Location: (0, 0)
# Scale factor 1.7: Max value: 0.15199290215969086, Location: (0, 0)
# Scale factor 1.8: Max value: 0.12203437834978104, Location: (0, 0)
# Scale factor 1.9: Max value: 0.10641589760780334, Location: (0, 0)
# Scale factor 2.0: Max value: 0.08514441549777985, Location: (0, 0)
# Scale factor 2.1: Max value: 0.06474489718675613, Location: (0, 0)
# Scale factor 2.2: Max value: 0.04565826803445816, Location: (0, 0)
# Scale factor 2.3: Max value: 0.026748087257146835, Location: (0, 0)
# Scale factor 2.4: Max value: 0.014307742938399315, Location: (0, 0)
# Scale factor 2.5: Max value: 0.005632649175822735, Location: (0, 0)
# Scale factor 2.6: Max value: -0.0003342771087773144, Location: (0, 0)
# Scale factor 2.7: Max value: -0.006192993838340044, Location: (0, 0)
# Marked image saved to: marked_images\marked_3712994.0.png
# Found 158 matches.
# Results saved to output_pixel_coordinates.csv
