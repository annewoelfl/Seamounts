# %% [markdown]
# Preprocessing

# %%
import os
import cv2

# Parameters
image_folder = "seamounts_bboxes"  # Root directory of the dataset
output_folder = "seamounts_bboxes_cropped"  # Temporary folder for cropped images
# image_size = (128, 128)  # Image dimensions for the model
crop_pixels = 65  # Pixels to crop from each border

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# Function to crop borders from an image
def crop_fixed_border(image, crop_pixels=5):
    height, width, _ = image.shape
    if height > crop_pixels * 2 and width > crop_pixels * 2:
        cropped_image = image[crop_pixels:height-crop_pixels, crop_pixels:width-crop_pixels]
        return cropped_image
    else:
        return image  # Return original image if cropping not possible

# Preprocess images (cropping and resizing)
print("Preprocessing images...")

# Loop through all files in the image folder
for filename in os.listdir(image_folder):
    image_path = os.path.join(image_folder, filename)
    
    # Check if the file is an image (you can expand the check for other image formats)
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        # Read the image
        image = cv2.imread(image_path)
        
        # Crop the image
        cropped_image = crop_fixed_border(image, crop_pixels)
        
        # Save the cropped image to the output folder
        output_image_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_image_path, cropped_image)

print("Preprocessing complete.")
# Out:
# Preprocessing images...
# Preprocessing complete.

# %% [markdown]
# Matching

# %%
import cv2
import os
import pandas as pd

# Function to find smaller map tile in the corresponding larger map tile using the floating window approach
def find_and_mark_tiles(large_tile_folder, small_tile_folder, output_csv, start_scale=0.1, scale_step=0.1, max_scale=5, manual_correction_x=0, manual_correction_y=0):
    # List to store results
    results = []
    
    # Get list of files in both folders
    large_tiles = os.listdir(large_tile_folder)
    small_tiles = os.listdir(small_tile_folder)

    # Debug: print the list of files in both folders
    print("Large tiles:", large_tiles)
    print("Small tiles:", small_tiles)

    # Create a dictionary of small tiles indexed by PEAKID
    small_tiles_dict = {}
    for small_tile_name in small_tiles:
        # Extract the PEAKID from the smaller tile's filename (assuming format [PEAKID]_1.png)
        peak_id = small_tile_name.split('_')[0]
        small_tiles_dict[peak_id] = small_tile_name

    # Debug: print the small tiles dictionary
    print("Small tiles dictionary:", small_tiles_dict)

    # Iterate through each large tile
    for large_tile_name in large_tiles:
        # Extract the PEAKID from the larger tile's filename (assuming format [PEAKID].png)
        peak_id = large_tile_name.split('.')[0]

        # Ensure the PEAKID matches the format of the small tile (i.e., keep the '.0' if present)
        peak_id = str(float(peak_id))  # This will preserve the ".0" if present
        
        # Debug: print the current large tile being processed
        print(f"Processing large tile: {large_tile_name}, PEAKID: {peak_id}")
        
        # Check if there is a corresponding small tile for this PEAKID
        if peak_id in small_tiles_dict:
            small_tile_name = small_tiles_dict[peak_id]
            large_tile_path = os.path.join(large_tile_folder, large_tile_name)
            small_tile_path = os.path.join(small_tile_folder, small_tile_name)

            # Debug: print the paths of the current large and small tiles
            print(f"Found corresponding small tile: {small_tile_name}")
            print(f"Large tile path: {large_tile_path}")
            print(f"Small tile path: {small_tile_path}")

            # Check if the marked image already exists
            marked_image_path = os.path.join('marked_images', f"marked_{large_tile_name}")
            if os.path.exists(marked_image_path):
                print(f"Skipping already processed large tile: {large_tile_name}")
                continue  # Skip this large tile if it's already processed

            # Read the images
            large_tile = cv2.imread(large_tile_path, cv2.IMREAD_COLOR)
            small_tile = cv2.imread(small_tile_path, cv2.IMREAD_COLOR)

            if large_tile is None:
                print(f"Error: Unable to load large tile {large_tile_path}")
                continue
            if small_tile is None:
                print(f"Error: Unable to load small tile {small_tile_path}")
                continue

            # Get the center of the large tile
            large_tile_center = (large_tile.shape[1] // 2, large_tile.shape[0] // 2)

            # Perform floating window approach: resize and match the small tile centered on the large tile
            max_match_val = 0
            best_match_loc = None
            best_resized_tile = None

            # Start with the small tile and gradually increase its size
            for scale_factor in frange(start_scale, max_scale + scale_step, scale_step):  # Start from start_scale, scale by scale_step
                if scale_factor <= 0:  # Skip non-positive scale factors
                    continue
                
                # Resize the small tile
                new_width = int(small_tile.shape[1] * scale_factor)
                new_height = int(small_tile.shape[0] * scale_factor)

                # Ensure width and height are positive values
                if new_width <= 0 or new_height <= 0:
                    continue  # Skip if the new dimensions are not valid
                
                resized_small_tile = cv2.resize(small_tile, (new_width, new_height))

                # Calculate the top-left corner to center the resized tile on the large tile
                top_left_x = large_tile_center[0] - resized_small_tile.shape[1] // 2
                top_left_y = large_tile_center[1] - resized_small_tile.shape[0] // 2

                # Ensure the top-left corner is within the bounds of the large tile
                if top_left_x < 0 or top_left_y < 0 or top_left_x + resized_small_tile.shape[1] > large_tile.shape[1] or top_left_y + resized_small_tile.shape[0] > large_tile.shape[0]:
                    continue  # Skip if the resized tile is out of bounds

                # Extract the region of interest (ROI) from the large tile where the small tile will be overlaid
                roi = large_tile[top_left_y:top_left_y + resized_small_tile.shape[0], top_left_x:top_left_x + resized_small_tile.shape[1]]

                # Perform template matching
                result = cv2.matchTemplate(roi, resized_small_tile, cv2.TM_CCOEFF_NORMED)
                min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)

                # Debug: print the result of template matching for each scale
                print(f"Scale factor {scale_factor}: Max value: {max_val}, Location: {max_loc}")

                # If the match is better than the previous best match, update the best match
                if max_val > max_match_val:
                    max_match_val = max_val
                    best_match_loc = (top_left_x + max_loc[0], top_left_y + max_loc[1])  # Adjust the location
                    best_resized_tile = resized_small_tile

            # If a good match is found, draw a rectangle around the matched region
            if max_match_val > 0.8:  # You can adjust the threshold as needed
                top_left = best_match_loc
                h, w = best_resized_tile.shape[:2]
                bottom_right = (top_left[0] + w, top_left[1] + h)

                # Apply manual correction
                top_left = (top_left[0] - manual_correction_x, top_left[1] - manual_correction_y)
                bottom_right = (bottom_right[0] + manual_correction_x, bottom_right[1] + manual_correction_y)

                # Draw the corrected rectangle
                cv2.rectangle(large_tile, top_left, bottom_right, (0, 255, 0), 2)

                # Store the coordinates of the box
                results.append({
                    'large_tile': large_tile_name,
                    'small_tile': small_tile_name,
                    'top_left_x': top_left[0],
                    'top_left_y': top_left[1],
                    'bottom_right_x': bottom_right[0],
                    'bottom_right_y': bottom_right[1]
                })

                # Optionally, save the marked image to a file
                os.makedirs('marked_images', exist_ok=True)
                cv2.imwrite(marked_image_path, large_tile)
                print(f"Marked image saved to: {marked_image_path}")

            else:
                print(f"No good match found for {large_tile_name} and {small_tile_name}")

        else:
            print(f"No corresponding small tile found for PEAKID: {peak_id}")

    # Debug: print the results
    print(f"Found {len(results)} matches.")
    
    # Convert the results to a pandas DataFrame and save to CSV
    if results:
        df = pd.DataFrame(results)
        df.to_csv(output_csv, index=False)
        print(f"Results saved to {output_csv}")
    else:
        print("No matches to save.")

# Helper function to generate a range of floating point numbers
def frange(start, stop, step):
    while start < stop:
        yield round(start, 2)  # Round to avoid floating-point precision issues
        start += step

# Example usage
find_and_mark_tiles('seamounts_galore_cropped', 'seamounts_bboxes_cropped', 'output_pixel_coordinates.csv', start_scale=0.1, scale_step=0.1, max_scale=5, manual_correction_x=5, manual_correction_y=5)
# Out:
# Large tiles: ['1008052.0.png', '1012613.0.png', '1012621.0.png', '2041242.0.png', '2119867.0.png', '2163605.0.png', '2193938.0.png', '2195378.0.png', '2212753.0.png', '2273092.0.png', '2297645.0.png', '2309570.0.png', '2322734.0.png', '2331848.0.png', '2336783.0.png', '2341370.0.png', '2368431.0.png', '2380627.0.png', '2388515.0.png', '2394993.0.png', '2419528.0.png', '2474327.0.png', '2522959.0.png', '2556370.0.png', '2560396.0.png', '2569746.0.png', '2597905.0.png', '2638201.0.png', '2639980.0.png', '2660201.0.png', '2672315.0.png', '2677791.0.png', '2691796.0.png', '2763354.0.png', '2774685.0.png', '2785016.0.png', '2786527.0.png', '2798534.0.png', '2814673.0.png', '2818805.0.png', '2835485.0.png', '2838648.0.png', '2848549.0.png', '2851391.0.png', '2873599.0.png', '2884163.0.png', '2888345.0.png', '2902589.0.png', '2909179.0.png', '2910949.0.png', '2946425.0.png', '2952050.0.png', '2955241.0.png', '2971903.0.png', '2979182.0.png', '2982979.0.png', '2997933.0.png', '3016624.0.png', '3017911.0.png', '3023057.0.png', '3024416.0.png', '3034731.0.png', '3048330.0.png', '3065426.0.png', '3082871.0.png', '3098339.0.png', '3099015.0.png', '3109615.0.png', '3114058.0.png', '3119848.0.png', '3124294.0.png', '3131778.0.png', '3133734.0.png', '3137402.0.png', '3142549.0.png', '3143564.0.png', '3149074.0.png', '3161956.0.png', '3168319.0.png', '3174135.0.png', '3183484.0.png', '3185313.0.png', '3193584.0.png', '3196254.0.png', '3197462.0.png', '3202326.0.png', '3209221.0.png', '3214785.0.png', '3221657.0.png', '3224670.0.png', '3246636.0.png', '3251574.0.png', '3259376.0.png', '3285812.0.png', '3290997.0.png', '3305514.0.png', '3308179.0.png', '3308373.0.png', '3313134.0.png', '3314699.0.png', '3315769.0.png', '3327661.0.png', '3327966.0.png', '3335369.0.png', '3342996.0.png', '3358842.0.png', '3365031.0.png', '3376684.0.png', '3376699.0.png', '3389598.0.png', '3397680.0.png', '3398636.0.png', '3400298.0.png', '3403726.0.png', '3409169.0.png', '3422242.0.png', '3425210.0.png', '3427982.0.png', '3432834.0.png', '3433386.0.png', '3435816.0.png', '3443964.0.png', '3445497.0.png', '3455297.0.png', '3455840.0.png', '3458772.0.png', '3459203.0.png', '3460273.0.png', '3472231.0.png', '3478496.0.png', '3494
Location: (0, 0)
# Scale factor 0.7: Max value: 0.6296512484550476, Location: (0, 0)
# Scale factor 0.8: Max value: 0.35888752341270447, Location: (0, 0)
# Marked image saved to: marked_images\marked_1012613.0.png
# Processing large tile: 1012621.0.png, PEAKID: 1012621.0
# Found corresponding small tile: 1012621.0_1.png
# Large tile path: seamounts_galore_cropped\1012621.0.png
# Small tile path: seamounts_bboxes_cropped\1012621.0_1.png
# Scale factor 0.1: Max value: 0.07676822692155838, Location: (0, 0)
# Scale factor 0.2: Max value: 0.36504441499710083, Location: (0, 0)
# Scale factor 0.3: Max value: 0.6130279302597046, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7903704643249512, Location: (0, 0)
# Scale factor 0.5: Max value: 0.99658203125, Location: (0, 0)
# Scale factor 0.6: Max value: 0.8120111227035522, Location: (0, 0)
# Scale factor 0.7: Max value: 0.7224580645561218, Location: (0, 0)
# Scale factor 0.8: Max value: 0.6406691670417786, Location: (0, 0)
# Scale factor 0.9: Max value: 0.5431382060050964, Location: (0, 0)
# Marked image saved to: marked_images\marked_1012621.0.png
# Processing large tile: 2041242.0.png, PEAKID: 2041242.0
# Found corresponding small tile: 2041242.0_1.png
# Large tile path: seamounts_galore_cropped\2041242.0.png
# Small tile path: seamounts_bboxes_cropped\2041242.0_1.png
# Scale factor 0.1: Max value: 0.186376690864563, Location: (0, 0)
# Scale factor 0.2: Max value: 0.2562517523765564, Location: (0, 0)
# Scale factor 0.3: Max value: 0.3937756419181824, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6734081506729126, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9941097497940063, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7884557843208313, Location: (0, 0)
# Scale factor 0.7: Max value: 0.45646798610687256, Location: (0, 0)
# Scale factor 0.8: Max value: 0.28825733065605164, Location: (0, 0)
# Scale factor 0.9: Max value: 0.2619282007217407, Location: (0, 0)
# Scale factor 1.0: Max value: 0.23947575688362122, Location: (0, 0)
# Scale factor 1.1: Max value: 0.14740468561649323, Location: (0, 0)
# Scale factor 1.2: Max value: 0.09629236906766891, Location: (0, 0)
# Marked image saved to: marked_images\marked_2041242.0.png
# Processing large tile: 2119867.0.png, PEAKID: 2119867.0
# Found corresponding small tile: 2119867.0_1.png
# Large tile path: seamounts_galore_cropped\2119867.0.png
# Small tile path: seamounts_bboxes_cropped\2119867.0_1.png
# Scale factor 0.1: Max value: 0.0700957328081131, Location: (0, 0)
# Scale factor 0.2: Max value: 0.06609949469566345, Location: (0, 0)
# Scale factor 0.3: Max value: 0.17803841829299927, Location: (0, 0)
# Scale factor 0.4: Max value: 0.5218644738197327, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9699010848999023, Location: (0, 0)
# Scale factor 0.6: Max value: 0.5350719094276428, Location: (0, 0)
# Scale factor 0.7: Max value: 0.34584447741508484, Location: (0, 0)
# Scale factor 0.8: Max value: 0.20602265000343323, Location: (0, 0)
# Scale factor 0.9: Max value: 0.13435772061347961, Location: (0, 0)
# Scale factor 1.0: Max value: 0.11203990131616592, Location: (0, 0)
# Marked image saved to: marked_images\marked_2119867.0.png
# Processing large tile: 2163605.0.png, PEAKID: 2163605.0
# Found corresponding small tile: 2163605.0_1.png
# Large tile path: seamounts_galore_cropped\2163605.0.png
# Small tile path: seamounts_bboxes_cropped\2163605.0_1.png
# Scale factor 0.1: Max value: 0.1927081197500229, Location: (0, 0)
# Scale factor 0.2: Max value: -0.15287426114082336, Location: (0, 0)
# Scale factor 0.3: Max value: -0.01168948132544756, Location: (0, 0)
# Scale factor 0.4: Max value: 0.24003352224826813, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9546254277229309, Location: (0, 0)
# Scale factor 0.6: Max value: 0.2572101950645447, Location: (0, 0)
# Scale factor 0.7: Max value: 0.11208739876747131, Location: (0, 0)
# Scale factor 0.8: Max value: 0.0723901316523552, Location: (0, 0)
# Scale factor 0.9: Max value: 0.012890464626252651, Location: (0, 0)
# Scale factor 1.0: Max value: -0.02253267727792263, Location: (0, 0)
# Scale factor 1.1: Max value: -0.022140951827168465, Location: (0, 0)
# Scale factor 1.2: Max value: -0.06080620735883713, Location: (0, 0)
# Scale factor 1.3: Max value: -0.06884149461984634, Location: (0, 0)
# Scale factor 1.4: Max value: -0.06702291965484619, Location: (0, 0)
# Scale factor 1.5: Max value: -0.045012157410383224, Location: (0, 0)
# Marked image saved to: marked_images\marked_2163605.0.png
# Processing large tile: 2193938.0.png, PEAKID: 2193938.0
# Found corresponding small tile: 2193938.0_1.png
# Large tile path: seamounts_galore_cropped\2193938.0.png
# Small tile path: seamounts_bboxes_cropped\2193938.0_1.png
# Scale factor 0.1: Max value: 0.4443419873714447, Location: (0, 0)
# Scale factor 0.2: Max value: 0.4361957013607025, Location: (0, 0)
# Scale factor 0.3: Max value: 0.4642917215824127, Location: (0, 0)
# Scale factor 0.4: Max value: 0.5381538271903992, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9605581164360046, Location: (0, 0)
# Scale factor 0.6: Max value: 0.5451968908309937, Location: (0, 0)
# Scale factor 0.7: Max value: 0.43751582503318787, Location: (0, 0)
# Scale factor 0.8: Max value: 0.39554575085639954, Location: (0, 0)
# Scale factor 0.9: Max value: 0.34836792945861816, Location: (0, 0)
# Marked image saved to: marked_images\marked_2193938.0.png
# Processing large tile: 2195378.0.png, PEAKID: 2195378.0
# Found corresponding small tile: 2195378.0_1.png
# Large tile path: seamounts_galore_cropped\2195378.0.png
# Small tile path: seamounts_bboxes_cropped\2195378.0_1.png
# Scale factor 0.1: Max value: 0.26838797330856323, Location: (0, 0)
# Scale factor 0.2: Max value: 0.38054510951042175, Location: (0, 0)
# Scale factor 0.3: Max value: 0.40044036507606506, Location: (0, 0)
# Scale factor 0.4: Max value: 0.5134996175765991, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9505548477172852, Location: (0, 0)
# Scale factor 0.6: Max value: 0.5171406269073486, Location: (0, 0)
# Scale factor 0.7: Max value: 0.4401531219482422, Location: (0, 0)
# Scale factor 0.8: Max value: 0.36018848419189453, Location: (0, 0)
# Scale factor 0.9: Max value: 0.27506333589553833, Location: (0, 0)
# Marked image saved to: marked_images\marked_2195378.0.png
# Processing large tile: 2212753.0.png, PEAKID: 2212753.0
# Found corresponding small tile: 2212753.0_1.png
# Large tile path: seamounts_galore_cropped\2212753.0.png
# Small tile path: seamounts_bboxes_cropped\2212753.0_1.png
# Scale factor 0.1: Max value: 0.6914666295051575, Location: (0, 0)
# Scale factor 0.2: Max value: 0.5938950181007385, Location: (0, 0)
# Scale factor 0.3: Max value: 0.7442193031311035, Location: (0, 0)
# Scale factor 0.4: Max value: 0.836230993270874, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9848273396492004, Location: (0, 0)
# Scale factor 0.6: Max value: 0.8852930665016174, Location: (0, 0)
# Scale factor 0.7: Max value: 0.7003647685050964, Location: (0, 0)
# Scale factor 0.8: Max value: 0.609139084815979, Location: (0, 0)
# Scale factor 0.9: Max value: 0.6031996607780457, Location: (0, 0)
# Scale factor 1.0: Max value: 0.
# Scale factor 1.2: Max value: 0.05591339245438576, Location: (0, 0)
# Scale factor 1.3: Max value: 0.05531977862119675, Location: (0, 0)
# Scale factor 1.4: Max value: 0.06986153870820999, Location: (0, 0)
# Scale factor 1.5: Max value: 0.08071813732385635, Location: (0, 0)
# Scale factor 1.6: Max value: 0.07156433165073395, Location: (0, 0)
# Scale factor 1.7: Max value: 0.07398293167352676, Location: (0, 0)
# Scale factor 1.8: Max value: 0.05045456066727638, Location: (0, 0)
# Scale factor 1.9: Max value: 0.05440128594636917, Location: (0, 0)
# Scale factor 2.0: Max value: 0.05058909207582474, Location: (0, 0)
# Scale factor 2.1: Max value: 0.03569755703210831, Location: (0, 0)
# Scale factor 2.2: Max value: 0.01579972915351391, Location: (0, 0)
# Scale factor 2.3: Max value: 0.008837256580591202, Location: (0, 0)
# Scale factor 2.4: Max value: 0.026561513543128967, Location: (0, 0)
# Scale factor 2.5: Max value: 0.05235763266682625, Location: (0, 0)
# Scale factor 2.6: Max value: 0.0779479593038559, Location: (0, 0)
# Scale factor 2.7: Max value: 0.10120854526758194, Location: (0, 0)
# Marked image saved to: marked_images\marked_2273092.0.png
# Processing large tile: 2297645.0.png, PEAKID: 2297645.0
# Found corresponding small tile: 2297645.0_1.png
# Large tile path: seamounts_galore_cropped\2297645.0.png
# Small tile path: seamounts_bboxes_cropped\2297645.0_1.png
# Scale factor 0.1: Max value: 0.6408187747001648, Location: (0, 0)
# Scale factor 0.2: Max value: 0.7145808935165405, Location: (0, 0)
# Scale factor 0.3: Max value: 0.7899675965309143, Location: (0, 0)
# Scale factor 0.4: Max value: 0.85313481092453, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9825960397720337, Location: (0, 0)
# Scale factor 0.6: Max value: 0.828022301197052, Location: (0, 0)
# Scale factor 0.7: Max value: 0.7555522918701172, Location: (0, 0)
# Scale factor 0.8: Max value: 0.687491774559021, Location: (0, 0)
# Scale factor 0.9: Max value: 0.6362602710723877, Location: (0, 0)
# Scale factor 1.0: Max value: 0.5887404084205627, Location: (0, 0)
# Marked image saved to: marked_images\marked_2297645.0.png
# Processing large tile: 2309570.0.png, PEAKID: 2309570.0
# Found corresponding small tile: 2309570.0_1.png
# Large tile path: seamounts_galore_cropped\2309570.0.png
# Small tile path: seamounts_bboxes_cropped\2309570.0_1.png
# Scale factor 0.1: Max value: 0.2088315635919571, Location: (0, 0)
# Scale factor 0.2: Max value: -0.005250043701380491, Location: (0, 0)
# Scale factor 0.3: Max value: 0.3528538644313812, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6466496586799622, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9575866460800171, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7089863419532776, Location: (0, 0)
# Scale factor 0.7: Max value: 0.44019582867622375, Location: (0, 0)
# Scale factor 0.8: Max value: 0.27553167939186096, Location: (0, 0)
# Scale factor 0.9: Max value: 0.14298506081104279, Location: (0, 0)
# Scale factor 1.0: Max value: 0.05037733539938927, Location: (0, 0)
# Scale factor 1.1: Max value: -0.025444412603974342, Location: (0, 0)
# Scale factor 1.2: Max value: -0.0847923755645752, Location: (0, 0)
# Scale factor 1.3: Max value: -0.11977958679199219, Location: (0, 0)
# Scale factor 1.4: Max value: -0.13107606768608093, Location: (0, 0)
# Marked image saved to: marked_images\marked_2309570.0.png
# Processing large tile: 2322734.0.png, PEAKID: 2322734.0
# Found corresponding small tile: 2322734.0_1.png
# Large tile path: seamounts_galore_cropped\2322734.0.png
# Small tile path: seamounts_bboxes_cropped\2322734.0_1.png
# Scale factor 0.1: Max value: 0.5221785306930542, Location: (0, 0)
# Scale factor 0.2: Max value: 0.3980923891067505, Location: (0, 0)
# Scale factor 0.3: Max value: 0.6111490726470947, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7312588691711426, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9616639018058777, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7269834876060486, Location: (0, 0)
# Scale factor 0.7: Max value: 0.6157186627388, Location: (0, 0)
# Scale factor 0.8: Max value: 0.4869542717933655, Location: (0, 0)
# Scale factor 0.9: Max value: 0.35010361671447754, Location: (0, 0)
# Scale factor 1.0: Max value: 0.21358828246593475, Location: (0, 0)
# Scale factor 1.1: Max value: 0.13529105484485626, Location: (0, 0)
# Scale factor 1.2: Max value: 0.06596706062555313, Location: (0, 0)
# Scale factor 1.3: Max value: 0.020035160705447197, Location: (0, 0)
# Scale factor 1.4: Max value: 0.013517437502741814, Location: (0, 0)
# Scale factor 1.5: Max value: 0.013684581033885479, Location: (0, 0)
# Scale factor 1.6: Max value: -0.008918638341128826, Location: (0, 0)
# Scale factor 1.7: Max value: -0.0016240737168118358, Location: (0, 0)
# Scale factor 1.8: Max value: 0.009437758475542068, Location: (0, 0)
# Scale factor 1.9: Max value: 0.029890600591897964, Location: (0, 0)
# Scale factor 2.0: Max value: 0.043946292251348495, Location: (0, 0)
# Scale factor 2.1: Max value: 0.054828912019729614, Location: (0, 0)
# Scale factor 2.2: Max value: 0.0570484958589077, Location: (0, 0)
# Marked image saved to: marked_images\marked_2322734.0.png
# Processing large tile: 2331848.0.png, PEAKID: 2331848.0
# Found corresponding small tile: 2331848.0_1.png
# Large tile path: seamounts_galore_cropped\2331848.0.png
# Small tile path: seamounts_bboxes_cropped\2331848.0_1.png
# Scale factor 0.1: Max value: 0.4131755828857422, Location: (0, 0)
# Scale factor 0.2: Max value: 0.4735229015350342, Location: (0, 0)
# Scale factor 0.3: Max value: 0.6926676630973816, Location: (0, 0)
# Scale factor 0.4: Max value: 0.8733373880386353, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9936104416847229, Location: (0, 0)
# Scale factor 0.6: Max value: 0.8616575002670288, Location: (0, 0)
# Scale factor 0.7: Max value: 0.693268895149231, Location: (0, 0)
# Scale factor 0.8: Max value: 0.5686808824539185, Location: (0, 0)
# Scale factor 0.9: Max value: 0.48873353004455566, Location: (0, 0)
# Scale factor 1.0: Max value: 0.43448707461357117, Location: (0, 0)
# Scale factor 1.1: Max value: 0.36508792638778687, Location: (0, 0)
# Marked image saved to: marked_images\marked_2331848.0.png
# Processing large tile: 2336783.0.png, PEAKID: 2336783.0
# Found corresponding small tile: 2336783.0_1.png
# Large tile path: seamounts_galore_cropped\2336783.0.png
# Small tile path: seamounts_bboxes_cropped\2336783.0_1.png
# Scale factor 0.1: Max value: 0.08420244604349136, Location: (0, 0)
# Scale factor 0.2: Max value: 0.2530635595321655, Location: (0, 0)
# Scale factor 0.3: Max value: 0.3374141752719879, Location: (0, 0)
# Scale factor 0.4: Max value: 0.4451078772544861, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9034906029701233, Location: (0, 0)
# Scale factor 0.6: Max value: 0.4520966410636902, Location: (0, 0)
# Scale factor 0.7: Max value: 0.369592547416687, Location: (0, 0)
# Scale factor 0.8: Max value: 0.3245767652988434, Location: (0, 0)
# Scale factor 0.9: Max value: 0.27496597170829773, Location: (0, 0)
# Scale factor 1.0: Max value: 0.2620481550693512, Location: (0, 0)
# Scale factor 1.1: Max value: 0.24849025905132294, Location: (0, 0)
# Scale factor 1.2: Max value: 0.23056338727474213, Location: (0, 0)
# Scale factor 1.3: Max value: 0.21677471697330475, Location: (0, 0)
# Scale factor 1.4: Max value: 0.20190222561359406, Location: (0, 0)
# Marked image saved to: marked_images\marked_2336783.0.png
# Processing large tile: 2341370.0.png, PEAKID: 2341370.0
# Found corresponding small tile: 2341370.0_1.png
# Large tile path: seamounts_galore_cropped\2341370.0.png
# Small tile path: seamounts_bboxes_cropped\2341370.0_1.png
# Scale factor 0.1: Max value: 0.38495078682899475, Location: (0, 0)
# Scale factor 0.2: Max value: 0.09687726199626923, Location: (0, 0)
# Scale factor 0.3: Max value: 0.24890625476837158, Location: (0, 0)
# Scale factor 0.4: Max value: 0.40198343992233276, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9460921287536621, Location: (0, 0)
# Scale factor 0.6: Max value: 0.4393830895423889, Location: (0, 0)
# Scale factor 0.7: Max value: 0.2760709822177887, Location: (0, 0)
# Scale factor 0.8: Max value: 0.19123826920986176, Location: (0, 0)
# Scale factor 0.9: Max value: 0.12987667322158813, Location: (0, 0)
# Scale factor 1.0: Max value: 0.08622898906469345, Location: (0, 0)
# Scale factor 1.1: Max value: 0.07478298991918564, Location: (0, 0)
# Scale factor 1.2: Max value: 0.06259047240018845, Location: (0, 0)
# Scale factor 1.3: Max value: 0.05391205474734306, Location: (0, 0)
# Scale factor 1.4: Max value: 0.08389341086149216, Location: (0, 0)
# Scale factor 1.5: Max value: 0.08615371584892273, Location: (0, 0)
# Scale factor 1.6: Max value: 0.0856097936630249, Location: (0, 0)
# Scale factor 1.7: Max value: 0.07259248942136765, Location: (0, 0)
# Scale factor 1.8: Max value: 0.0750051960349083, Location: (0, 0)
# Marked image saved to: marked_images\marked_2341370.0.png
# Processing large tile: 2368431.0.png, PEAKID: 2368431.0
# Found corresponding small tile: 2368431.0_1.png
# Large tile path: seamounts_galore_cropped\2368431.0.png
# Small tile path: seamounts_bboxes_cropped\2368431.0_1.png
# Scale factor 0.1: Max value: 0.49020421504974365, Location: (0, 0)
# Scale factor 0.2: Max value: 0.5787093639373779, Location: (0, 0)
# Scale factor 0.3: Max value: 0.7088826894760132, Location: (0, 0)
# Scale factor 0.4: Max value: 0.8867223262786865, Location: (0, 0)
# Scale factor 0.5: Max value: 0.992279589176178, Location: (0, 0)
# Scale factor 0.6: Max value: 0.9175705909729004, Location: (0, 0)
# Scale factor 0.7: Max value: 0.8046080470085144, Location: (0, 0)
# Scale factor 0.8: Max value: 0.7105091214179993, Location: (0, 0)
# Scale factor 0.9: Max value: 0.6282672882080078, Location: (0, 0)
# Scale factor 1.0: Max value: 0.5669677257537842, Location: (0, 0)
# Scale factor 1.1: Max value: 0.5154411792755127, Location: (0, 0)
# Scale factor 1.2: Max value: 0.46744561195373535, Location: (0, 0)
# Scale factor 1.3: Max value: 0.4294820725917816, Location: (0, 0)
# Scale factor 1.4: Max value: 0.39007776975631714, Location: (0, 0)
# Marked image saved to: marked_images\marked_2368431.0.png
# Processing large tile: 2380627.0.png, PEAKID: 2380627.0
# Found corresponding small tile: 2380627.0_1.png
# Large tile path: seamounts_galore_cropped\2380627.0.png
# Small tile path: seamounts_bboxes_cropped\2380627.0_1.png
# Scale factor 0.1: Max value: 0.20257550477981567, Location: (0, 0)
# Scale factor 0.2: Max value: 0.37504521012306213, Location: (0, 0)
# Scale factor 0.3: Max value: 0.5417935252189636, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6879357695579529, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9370582699775696, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7048531174659729, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5722287893295288, Location: (0, 0)
# Scale factor 0.8: Max value: 0.49327486753463745, Location: (0, 0)
# Scale factor 0.9: Max value: 0.4314427077770233, Location: (0, 0)
# Scale factor 1.0: Max value: 0.37100160121917725, Location: (0, 0)
# Marked image saved to: marked_images\marked_2380627.0.png
# Processing large tile: 2388515.0.png, PEAKID: 2388515.0
# Found corresponding small tile: 2388515.0_1.png
# Large tile path: seamounts_galore_cropped\2388515.0.png
# Small tile path: seamounts_bboxes_cropped\2388515.0_1.png
# Scale factor 0.1: Max value: 0.1653100848197937, Location: (0, 0)
# Scale factor 0.2: Max value: 0.23427169024944305, Location: (0, 0)
# Scale factor 0.3: Max value: 0.33612295985221863, Location: (0, 0)
# Scale factor 0.4: Max value: 0.5909628868103027, Location: (0, 0)
# Scale factor 0.5: Max value: 0.896618127822876, Location: (0, 0)
# Scale factor 0.6: Max value: 0.6315291523933411, Location: (0, 0)
# Scale factor 0.7: Max value: 0.4147007167339325, Location: (0, 0)
# Scale factor 0.8: Max value: 0.28456398844718933, Location: (0, 0)
# Scale factor 0.9: Max value: 0.202419713139534, Location: (0, 0)
# Scale factor 1.0: Max value: 0.15988115966320038, Location: (0, 0)
# Marked image saved to: marked_images\marked_2388515.0.png
# Processing large tile: 2394993.0.png, PEAKID: 2394993.0
# Found corresponding small tile: 2394993.0_1.png
# Large tile path: seamounts_galore_cropped\2394993.0.png
# Small tile path: seamounts_bboxes_cropped\2394993.0_1.png
# Scale factor 0.1: Max value: 0.1515917330980301, Location: (0, 0)
# Scale factor 0.2: Max value: 0.23006537556648254, Location: (0, 0)
# Scale factor 0.3: Max value: 0.36435315012931824, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6380552053451538, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9624985456466675, Location: (0, 0)
# Scale factor 0.6: Max value: 0.5782747864723206, Location: (0, 0)
# Scale factor 0.7: Max value: 0.3937743902206421, Location: (0, 0)
# Scale factor 0.8: Max value: 0.2802563011646271, Location: (0, 0)
# Scale factor 0.9: Max value: 0.2022126466035843, Location: (0, 0)
# Scale factor 1.0: Max value: 0.13804350793361664, Location: (0, 0)
# Scale factor 1.1: Max value: 0.0965191200375557, Location: (0, 0)
# Marked image saved to: marked_images\marked_2394993.0.png
# Processing large tile: 2419528.0.png, PEAKID: 2419528.0
# Found corresponding small tile: 2419528.0_1.png
# Large tile path: seamounts_galore_cropped\2419528.0.png
# Small tile path: seamounts_bboxes_cropped\2419528.0_1.png
# Scale factor 0.1: Max value: -0.3414219617843628, Location: (0, 0)
# Scale factor 0.2: Max value: 0.0833464041352272, Location: (0, 0)
# Scale factor 0.3: Max value: 0.5722618103027344, Location: (0, 0)
# Scale factor 0.4: Max value: 0.8933475613594055, Location: (0, 0)
# Scale factor 0.5: Max value: 0.997961163520813, Location: (0, 0)
# Scale factor 0.6: Max value: 0.9405005574226379, Location: (0, 0)
# Scale factor 0.7: Max value: 0.877705991268158, Location: (0, 0)
# Scale factor 0.8: Max value: 0.7894507050514221, Location: (0, 0)
# Scale factor 0.9: Max value: 0.6895891427993774, Location: (0, 0)
# Scale factor 1.0: Max value: 0.5962619781494141, Location: (0, 0)
# Scale factor 1.1: Max value: 0.5041220188140869, Location: (0, 0)
# Marked image saved to: marked_images\marked_2419528.0.png
# Processing large tile: 2474327.0.png, PEAKID: 2474327.0
# Found corresponding small tile: 2474327.0_1.png
# Large tile path: seamounts_galore_cropped\2474327.0.png
# Small tile path: seamounts_bboxes_cropped\2474327.0_1.png
# Scale factor 0.1: Max value: 0.21280227601528168, Location: (0, 0)
# Scale factor 0.2: Max value: 0.13364563882350922, Location: (0, 0)
# Scale factor 0.3: Max value: 0.213518887758255, Location: (0, 0)
# Scale factor 0.4: Max value: 0.48137304186820984, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9622737765312195, Location: (0, 0)
# Scale factor 0.6: Max value: 0.5368053913116455, Location: (0, 0)
# Scale factor 0.7: Max value: 0.31055954098701477, Location: (0, 0)
# Scale factor 0.8: Max value: 0.19931961596012115, Location: (0, 0)
# Scale factor 0.9: Max value: 0.10173647105693817, Location: (0, 0)
# Scale factor 1.0: Max value: 0.06595265120267868, Location: (0, 0)
# Scale factor 1.1: Max value: 0.06115201860666275, Location: (0, 0)
# Scale factor 1.2: Max value: 0.09231536090373993, Location: (0, 0)
# Scale factor 1.3: Max value: 0.10399175435304642, Location: (0, 0)
# Scale factor 1.4: Max value: 0.11080862581729889, Location: (0, 0)
# Scale factor 1.5: Max value: 0.11531826853752136, Location: (0, 0)
# Scale factor 1.6: Max value: 0.09469394385814667, Location: (0, 0)
# Marked image saved to: marked_images\marked_2474327.0.png
# Processing large tile: 2522959.0.png, PEAKID: 2522959.0
# Found corresponding small tile: 2522959.0_1.png
# Large tile path: seamounts_galore_cropped\2522959.0.png
# Small tile path: seamounts_bboxes_cropped\2522959.0_1.png
# Scale factor 0.1: Max value: 0.04704682528972626, Location: (0, 0)
# Scale factor 0.2: Max value: -0.008116455748677254, Location: (0, 0)
# Scale factor 0.3: Max value: 0.2414214164018631, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7278577089309692, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9598812460899353, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7428895831108093, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5345775485038757, Location: (0, 0)
# Scale factor 0.8: Max value: 0.329741895198822, Location: (0, 0)
# Scale factor 0.9: Max value: 0.2214057892560959, Location: (0, 0)
# Scale factor 1.0: Max value: 0.13781946897506714, Location: (0, 0)
# Scale factor 1.1: Max value: 0.08345227688550949, Location: (0, 0)
# Scale factor 1.2: Max value: 0.030213307589292526, Location: (0, 0)
# Scale factor 1.3: Max value: -0.002032719785347581, Location: (0, 0)
# Marked image saved to: marked_images\marked_2522959.0.png
# Processing large tile: 2556370.0.png, PEAKID: 2556370.0
# Found corresponding small tile: 2556370.0_1.png
# Large tile path: seamounts_galore_cropped\2556370.0.png
# Small tile path: seamounts_bboxes_cropped\2556370.0_1.png
# Scale factor 0.1: Max value: 0.19310805201530457, Location: (0, 0)
# Scale factor 0.2: Max value: 0.3552531599998474, Location: (0, 0)
# Scale factor 0.3: Max value: 0.3798753023147583, Location: (0, 0)
# Scale factor 0.4: Max value: 0.5423843264579773, Location: (0, 0)
# Scale factor 0.5: Max value: 0.982417643070221, Location: (0, 0)
# Scale factor 0.6: Max value: 0.6124520897865295, Location: (0, 0)
# Scale factor 0.7: Max value: 0.4293573796749115, Location: (0, 0)
# Scale factor 0.8: Max value: 0.3561040759086609, Location: (0, 0)
# Scale factor 0.9: Max value: 0.3161231279373169, Location: (0, 0)
# Scale factor 1.0: Max value: 0.2821740210056305, Location: (0, 0)
# Scale factor 1.1: Max value: 0.2755582928657532, Location: (0, 0)
# Marked image saved to: marked_images\marked_2556370.0.png
# Processing large tile: 2560396.0.png, PEAKID: 2560396.0
# Found corresponding small tile: 2560396.0_1.png
# Large tile path: seamounts_galore_cropped\2560396.0.png
# Small tile path: seamounts_bboxes_cropped\2560396.0_1.png
# Scale factor 0.1: Max value: 0.3234357237815857, Location: (0, 0)
# Scale factor 0.2: Max value: 0.4623522460460663, Location: (0, 0)
# Scale factor 0.3: Max value: 0.5680581331253052, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7671087384223938, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9915127158164978, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7843421101570129, Location: (0, 0)
# Scale factor 0.7: Max value: 0.6198166608810425, Location: (0, 0)
# Scale factor 0.8: Max value: 0.531613290309906, Location: (0, 0)
# Scale factor 0.9: Max value: 0.4901390075683594, Location: (0, 0)
# Scale factor 1.0: Max value: 0.4375852644443512, Location: (0, 0)
# Scale factor 1.1: Max value: 0.3664817214012146, Location: (0, 0)
# Marked image saved to: marked_images\marked_2560396.0.png
# Processing large tile: 2569746.0.png, PEAKID: 2569746.0
# Found corresponding small tile: 2569746.0_1.png
# Large tile path: seamounts_galore_cropped\2569746.0.png
# Small tile path: seamounts_bboxes_cropped\2569746.0_1.png
# Scale factor 0.1: Max value: 0.7098675966262817, Location: (0, 0)
# Scale factor 0.2: Max value: 0.8246957659721375, Location: (0, 0)
# Scale factor 0.3: Max value: 0.8909010291099548, Location: (0, 0)
# Scale factor 0.4: Max value: 0.9380058646202087, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9983737468719482, Location: (0, 0)
# Scale factor 0.6: Max value: 0.9322628974914551, Location: (0, 0)
# Scale factor 0.7: Max value: 0.8066886067390442, Location: (0, 0)
# Scale factor 0.8: Max value: 0.6949247121810913, Location: (0, 0)
# Scale factor 0.9: Max value: 0.6294957399368286, Location: (0, 0)
# Scale factor 1.0: Max value: 0.5893248915672302, Location: (0, 0)
# Scale factor 1.1: Max value: 0.5383098721504211, Location: (0, 0)
# Scale factor 1.2: Max value: 0.47860172390937805, Location: (0, 0)
# Scale factor 1.3: Max value: 0.41311225295066833, Location: (0, 0)
# Scale factor 1.4: Max value: 0.36248859763145447, Location: (0, 0)
# Marked image saved to: marked_images\marked_2569746.0.png
# Processing large tile: 2597905.0.png, PEAKID: 2597905.0
# Found corresponding small tile: 2597905.0_1.png
# Large tile path: seamounts_galore_cropped\2597905.0.png
# Small tile path: seamounts_bboxes_cropped\2597905.0_1.png
# Scale factor 0.1: Max value: 0.3232262432575226, Location: (0, 0)
# Scale factor 0.2: Max value: 0.4588302969932556, Location: (0, 0)
# Scale factor 0.3: Max value: 0.6307248473167419, Location: (0, 0)
# Scale factor 0.4: Max value: 0.884194552898407, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9961739182472229, Location: (0, 0)
# Scale factor 0.6: Max value: 0.9188557863235474, Location: (0, 0)
# Scale factor 0.7: Max value: 0.7852920293807983, Location: (0, 0)
# Scale factor 0.8: Max value: 0.6641712188720703, Location: (0, 0)
# Scale factor 0.9: Max value: 0.5883113741874695, Location: (0, 0)
# Scale factor 1.0: Max value: 0.5303478240966797, Location: (0, 0)
# Scale factor 1.1: Max value: 0.48825666308403015, Location: (0, 0)
# Scale factor 1.2: Max value: 0.44098401069641113, Location: (0, 0)
# Scale factor 1.3: Max value: 0.3817053437232971, Location: (0, 0)
# Scale factor 1.4: Max value: 0.32818692922592163, Location: (0, 0)
# Scale factor 1.5: Max value: 0.2753413915634155, Location: (0, 0)
# Scale factor 1.6: Max value: 0.24544654786586761, Location: (0, 0)
# Scale factor 1.7: Max value: 0.23882204294204712, Location: (0, 0)
# Scale factor 1.8: Max value: 0.2534259259700775, Location: (0, 0)
# Marked image saved to: marked_images\marked_2597905.0.png
# Processing large tile: 2638201.0.png, PEAKID: 2638201.0
# Found corresponding small tile: 2638201.0_1.png
# Large tile path: seamounts_galore_cropped\2638201.0.png
# Small tile path: seamounts_bboxes_cropped\2638201.0_1.png
# Scale factor 0.1: Max value: 0.10748884081840515, Location: (0, 0)
# Scale factor 0.2: Max value: 0.043211355805397034, Location: (0, 0)
# Scale factor 0.3: Max value: 0.16639330983161926, Location: (0, 0)
# Scale factor 0.4: Max value: 0.3992542028427124, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9599775075912476, Location: (0, 0)
# Scale factor 0.6: Max value: 0.2966157793998718, Location: (0, 0)
# Scale factor 0.7: Max value: 0.08835366368293762, Location: (0, 0)
# Scale factor 0.8: Max value: 0.08123335242271423, Location: (0, 0)
# Scale factor 0.9: Max value: 0.13033485412597656, Location: (0, 0)
# Scale factor 1.0: Max value: 0.13389010727405548, Location: (0, 0)
# Scale factor 1.1: Max value: 0.09459175914525986, Location: (0, 0)
# Scale factor 1.2: Max value: 0.0705438181757927, Location: (0, 0)
# Scale factor 1.3: Max value: 0.01815563067793846, Location: (0, 0)
# Scale factor 1.4: Max value: 0.006695652846246958, Location: (0, 0)
# Marked image saved to: marked_images\marked_2638201.0.png
# Processing large tile: 2639980.0.png, PEAKID: 2639980.0
# Found corresponding small tile: 2639980.0_1.png
# Large tile path: seamounts_galore_cropped\2639980.0.png
# Small tile path: seamounts_bboxes_cropped\2639980.0_1.png
# Scale factor 0.1: Max value: 0.4557473361492157, Location: (0, 0)
# Scale factor 0.2: Max value: 0.600239098072052, Location: (0, 0)
# Scale factor 0.3: Max value: 0.6564212441444397, Location: (0, 0)
# Scale factor 0.4: Max value: 0.738016664981842, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9628704786300659, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7269411087036133, Location: (0, 0)
# Scale factor 0.7: Max value: 0.6485183835029602, Location: (0, 0)
# Scale factor 0.8: Max value: 0.5804234743118286, Location: (0, 0)
# Scale factor 0.9: Max value: 0.5292395353317261, Location: (0, 0)
# Scale factor 1.0: Max value: 0.47463151812553406, Location: (0, 0)
# Scale factor 1.1: Max value: 0.44774264097213745, Location: (0, 0)
# Scale factor 1.2: Max value: 0.43440648913383484, Location: (0, 0)
# Marked image saved to: marked_images\marked_2639980.0.png
# Processing large tile: 2660201.0.png, PEAKID: 2660201.0
# Found corresponding small tile: 2660201.0_1.png
# Large tile path: seamounts_galore_cropped\2660201.0.png
# Small tile path: seamounts_bboxes_cropped\2660201.0_1.png
# Scale factor 0.1: Max value: 0.6254226565361023, Location: (0, 0)
# Scale factor 0.2: Max value: 0.7008971571922302, Location: (0, 0)
# Scale factor 0.3: Max value: 0.8184486031532288, Location: (0, 0)
# Scale factor 0.4: Max value: 0.9157088398933411, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9893104434013367, Location: (0, 0)
# Scale factor 0.6: Max value: 0.9229291081428528, Location: (0, 0)
# Scale factor 0.7: Max value: 0.7959792613983154, Location: (0, 0)
# Scale factor 0.8: Max value: 0.6916384100914001, Location: (0, 0)
# Scale factor 0.9: Max value: 0.6020026803016663, Location: (0, 0)
# Scale factor 1.0: Max value: 0.5399105548858643, Location: (0, 0)
# ...
# No good match found for 862086.0.png and 862086.0_1.png
# Processing large tile: 886308.0.png, PEAKID: 886308.0
# Found corresponding small tile: 886308.0_1.png
# Large tile path: seamounts_galore_cropped\886308.0.png
# Small tile path: seamounts_bboxes_cropped\886308.0_1.png
# Scale factor 0.1: Max value: 0.6674146056175232, Location: (0, 0)
# Scale factor 0.2: Max value: 0.7010419964790344, Location: (0, 0)
# Scale factor 0.3: Max value: 0.8096991777420044, Location: (0, 0)
# Scale factor 0.4: Max value: 0.9230128526687622, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9967540502548218, Location: (0, 0)
# Scale factor 0.6: Max value: 0.9469747543334961, Location: (0, 0)
# Scale factor 0.7: Max value: 0.831008791923523, Location: (0, 0)
# Scale factor 0.8: Max value: 0.6956819295883179, Location: (0, 0)
# Scale factor 0.9: Max value: 0.5602094531059265, Location: (0, 0)
# Scale factor 1.0: Max value: 0.42404991388320923, Location: (0, 0)
# Scale factor 1.1: Max value: 0.3082139492034912, Location: (0, 0)
# Scale factor 1.2: Max value: 0.23196469247341156, Location: (0, 0)
# Scale factor 1.3: Max value: 0.17808902263641357, Location: (0, 0)
# Scale factor 1.4: Max value: 0.1353137493133545, Location: (0, 0)
# Scale factor 1.5: Max value: 0.10283029824495316, Location: (0, 0)
# Scale factor 1.6: Max value: 0.0743640810251236, Location: (0, 0)
# Marked image saved to: marked_images\marked_886308.0.png
# Processing large tile: 901639.0.png, PEAKID: 901639.0
# Found corresponding small tile: 901639.0_1.png
# Large tile path: seamounts_galore_cropped\901639.0.png
# Small tile path: seamounts_bboxes_cropped\901639.0_1.png
# Skipping already processed large tile: 901639.0.png
# Processing large tile: 913515.0.png, PEAKID: 913515.0
# Found corresponding small tile: 913515.0_1.png
# Large tile path: seamounts_galore_cropped\913515.0.png
# Small tile path: seamounts_bboxes_cropped\913515.0_1.png
# Scale factor 0.1: Max value: 0.5762101411819458, Location: (0, 0)
# Scale factor 0.2: Max value: 0.5983926057815552, Location: (0, 0)
# Scale factor 0.3: Max value: 0.6843927502632141, Location: (0, 0)
# Scale factor 0.4: Max value: 0.8360490202903748, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9971124529838562, Location: (0, 0)
# Scale factor 0.6: Max value: 0.8336032629013062, Location: (0, 0)
# Scale factor 0.7: Max value: 0.6676796674728394, Location: (0, 0)
# Scale factor 0.8: Max value: 0.5575842261314392, Location: (0, 0)
# Scale factor 0.9: Max value: 0.5046642422676086, Location: (0, 0)
# Scale factor 1.0: Max value: 0.4593963325023651, Location: (0, 0)
# Scale factor 1.1: Max value: 0.4202989637851715, Location: (0, 0)
# Scale factor 1.2: Max value: 0.3642757833003998, Location: (0, 0)
# Scale factor 1.3: Max value: 0.3059568703174591, Location: (0, 0)
# Scale factor 1.4: Max value: 0.2613186538219452, Location: (0, 0)
# Scale factor 1.5: Max value: 0.21587401628494263, Location: (0, 0)
# Marked image saved to: marked_images\marked_913515.0.png
# Processing large tile: 914526.0.png, PEAKID: 914526.0
# Found corresponding small tile: 914526.0_1.png
# Large tile path: seamounts_galore_cropped\914526.0.png
# Small tile path: seamounts_bboxes_cropped\914526.0_1.png
# Scale factor 0.1: Max value: 0.2617450952529907, Location: (0, 0)
# Scale factor 0.2: Max value: 0.34820273518562317, Location: (0, 0)
# Scale factor 0.3: Max value: 0.5834742784500122, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6429306268692017, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9788423180580139, Location: (0, 0)
# Scale factor 0.6: Max value: 0.6284629702568054, Location: (0, 0)
# Scale factor 0.7: Max value: 0.49232611060142517, Location: (0, 0)
# Scale factor 0.8: Max value: 0.3984903395175934, Location: (0, 0)
# Scale factor 0.9: Max value: 0.3384184241294861, Location: (0, 0)
# Scale factor 1.0: Max value: 0.2947634756565094, Location: (0, 0)
# Scale factor 1.1: Max value: 0.2567768692970276, Location: (0, 0)
# Scale factor 1.2: Max value: 0.22107522189617157, Location: (0, 0)
# Scale factor 1.3: Max value: 0.18859481811523438, Location: (0, 0)
# Scale factor 1.4: Max value: 0.13884304463863373, Location: (0, 0)
# Scale factor 1.5: Max value: 0.11138741672039032, Location: (0, 0)
# Scale factor 1.6: Max value: 0.08503181487321854, Location: (0, 0)
# Scale factor 1.7: Max value: 0.06867389380931854, Location: (0, 0)
# Scale factor 1.8: Max value: 0.04286564886569977, Location: (0, 0)
# Marked image saved to: marked_images\marked_914526.0.png
# Processing large tile: 940136.0.png, PEAKID: 940136.0
# Found corresponding small tile: 940136.0_1.png
# Large tile path: seamounts_galore_cropped\940136.0.png
# Small tile path: seamounts_bboxes_cropped\940136.0_1.png
# Scale factor 0.1: Max value: 0.5276037454605103, Location: (0, 0)
# Scale factor 0.2: Max value: 0.5630289912223816, Location: (0, 0)
# Scale factor 0.3: Max value: 0.5482269525527954, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6620348691940308, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9212048053741455, Location: (0, 0)
# Scale factor 0.6: Max value: 0.6343467235565186, Location: (0, 0)
# Scale factor 0.7: Max value: 0.42358508706092834, Location: (0, 0)
# Scale factor 0.8: Max value: 0.29338571429252625, Location: (0, 0)
# Scale factor 0.9: Max value: 0.2655054032802582, Location: (0, 0)
# Scale factor 1.0: Max value: 0.25582069158554077, Location: (0, 0)
# Scale factor 1.1: Max value: 0.2515179216861725, Location: (0, 0)
# Scale factor 1.2: Max value: 0.23345878720283508, Location: (0, 0)
# Scale factor 1.3: Max value: 0.1911502629518509, Location: (0, 0)
# Scale factor 1.4: Max value: 0.16065199673175812, Location: (0, 0)
# Scale factor 1.5: Max value: 0.11288145184516907, Location: (0, 0)
# Scale factor 1.6: Max value: 0.07582993805408478, Location: (0, 0)
# Scale factor 1.7: Max value: 0.04426133632659912, Location: (0, 0)
# Scale factor 1.8: Max value: 0.02653207629919052, Location: (0, 0)
# Scale factor 1.9: Max value: 0.0240671094506979, Location: (0, 0)
# Scale factor 2.0: Max value: 0.02516220696270466, Location: (0, 0)
# Scale factor 2.1: Max value: 0.0229837317019701, Location: (0, 0)
# Scale factor 2.2: Max value: 0.022490641102194786, Location: (0, 0)
# Scale factor 2.3: Max value: 0.020832408219575882, Location: (0, 0)
# Scale factor 2.4: Max value: 0.01664453186094761, Location: (0, 0)
# Scale factor 2.5: Max value: 0.017751028761267662, Location: (0, 0)
# Scale factor 2.6: Max value: 0.006915274541825056, Location: (0, 0)
# Scale factor 2.7: Max value: 0.005284924525767565, Location: (0, 0)
# Scale factor 2.8: Max value: -0.0027230202686041594, Location: (0, 0)
# Scale factor 2.9: Max value: -0.009456765837967396, Location: (0, 0)
# Scale factor 3.0: Max value: -0.004000822547823191, Location: (0, 0)
# Scale factor 3.1: Max value: 0.0016588026192039251, Location: (0, 0)
# Scale factor 3.2: Max value: 0.0026474115438759327, Location: (0, 0)
# Scale factor 3.3: Max value: -0.0007280611316673458, Location: (0, 0)
# Scale factor 3.4: Max value: -0.0003224721585866064, Location: (0, 0)
# Scale factor 3.5: Max value: 0.003459726693108678, Location: (0, 0)
# Scale factor 3.6: Max value: 0.0028702355921268463, Location: (0, 0)
# Marked image saved to: marked_images\marked_940136.0.png
# Processing large tile: 943370.0.png, PEAKID: 943370.0
# Found corresponding small tile: 943370.0_1.png
# Large tile path: seamounts_galore_cropped\943370.0.png
# Small tile path: seamounts_bboxes_cropped\943370.0_1.png
# Scale factor 0.1: Max value: 0.5868649482727051, Location: (0, 0)
# Scale factor 0.2: Max value: 0.6529353857040405, Location: (0, 0)
# Scale factor 0.3: Max value: 0.8044111132621765, Location: (0, 0)
# Scale factor 0.4: Max value: 0.9340836405754089, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9827437996864319, Location: (0, 0)
# Scale factor 0.6: Max value: 0.9154947400093079, Location: (0, 0)
# Scale factor 0.7: Max value: 0.8144280910491943, Location: (0, 0)
# Scale factor 0.8: Max value: 0.7125090956687927, Location: (0, 0)
# Scale factor 0.9: Max value: 0.6361198425292969, Location: (0, 0)
# Scale factor 1.0: Max value: 0.5749754905700684, Location: (0, 0)
# Scale factor 1.1: Max value: 0.5259184241294861, Location: (0, 0)
# Scale factor 1.2: Max value: 0.4939362406730652, Location: (0, 0)
# Scale factor 1.3: Max value: 0.4706342816352844, Location: (0, 0)
# Scale factor 1.4: Max value: 0.45080628991127014, Location: (0, 0)
# Marked image saved to: marked_images\marked_943370.0.png
# Processing large tile: 978275.0.png, PEAKID: 978275.0
# Found corresponding small tile: 978275.0_1.png
# Large tile path: seamounts_galore_cropped\978275.0.png
# Small tile path: seamounts_bboxes_cropped\978275.0_1.png
# Scale factor 0.1: Max value: 0.07442107796669006, Location: (0, 0)
# Scale factor 0.2: Max value: 0.17431983351707458, Location: (0, 0)
# Scale factor 0.3: Max value: 0.323253333568573, Location: (0, 0)
# Scale factor 0.4: Max value: 0.4010235071182251, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9342815279960632, Location: (0, 0)
# Scale factor 0.6: Max value: 0.4106290340423584, Location: (0, 0)
# Scale factor 0.7: Max value: 0.27391213178634644, Location: (0, 0)
# Scale factor 0.8: Max value: 0.23413491249084473, Location: (0, 0)
# Scale factor 0.9: Max value: 0.17946219444274902, Location: (0, 0)
# Scale factor 1.0: Max value: 0.14736422896385193, Location: (0, 0)
# Scale factor 1.1: Max value: 0.15445207059383392, Location: (0, 0)
# Scale factor 1.2: Max value: 0.1506219357252121, Location: (0, 0)
# Marked image saved to: marked_images\marked_978275.0.png
# Processing large tile: 979828.0.png, PEAKID: 979828.0
# Found corresponding small tile: 979828.0_1.png
# Large tile path: seamounts_galore_cropped\979828.0.png
# Small tile path: seamounts_bboxes_cropped\979828.0_1.png
# Scale factor 0.1: Max value: 0.2884705364704132, Location: (0, 0)
# Scale factor 0.2: Max value: 0.19991140067577362, Location: (0, 0)
# Scale factor 0.3: Max value: 0.2597603499889374, Location: (0, 0)
# Scale factor 0.4: Max value: 0.36785000562667847, Location: (0, 0)
# Scale factor 0.5: Max value: 0.8662530183792114, Location: (0, 0)
# Scale factor 0.6: Max value: 0.3856714069843292, Location: (0, 0)
# Scale factor 0.7: Max value: 0.30797529220581055, Location: (0, 0)
# Scale factor 0.8: Max value: 0.21059083938598633, Location: (0, 0)
# Scale factor 0.9: Max value: 0.1486128270626068, Location: (0, 0)
# Scale factor 1.0: Max value: 0.09770563989877701, Location: (0, 0)
# Scale factor 1.1: Max value: 0.05134236440062523, Location: (0, 0)
# Marked image saved to: marked_images\marked_979828.0.png
# Processing large tile: 982564.0.png, PEAKID: 982564.0
# Found corresponding small tile: 982564.0_1.png
# Large tile path: seamounts_galore_cropped\982564.0.png
# Small tile path: seamounts_bboxes_cropped\982564.0_1.png
# Scale factor 0.1: Max value: 0.5435974597930908, Location: (0, 0)
# Scale factor 0.2: Max value: 0.6752687096595764, Location: (0, 0)
# Scale factor 0.3: Max value: 0.6990156769752502, Location: (0, 0)
# Scale factor 0.4: Max value: 0.8090749979019165, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9825011491775513, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7805820107460022, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5940236449241638, Location: (0, 0)
# Scale factor 0.8: Max value: 0.4665329158306122, Location: (0, 0)
# Scale factor 0.9: Max value: 0.3503950536251068, Location: (0, 0)
# Scale factor 1.0: Max value: 0.25334474444389343, Location: (0, 0)
# Scale factor 1.1: Max value: 0.1877174824476242, Location: (0, 0)
# Scale factor 1.2: Max value: 0.15287718176841736, Location: (0, 0)
# Marked image saved to: marked_images\marked_982564.0.png
# Processing large tile: 985045.0.png, PEAKID: 985045.0
# Found corresponding small tile: 985045.0_1.png
# Large tile path: seamounts_galore_cropped\985045.0.png
# Small tile path: seamounts_bboxes_cropped\985045.0_1.png
# Scale factor 0.1: Max value: 0.31607043743133545, Location: (0, 0)
# Scale factor 0.2: Max value: 0.6176975965499878, Location: (0, 0)
# Scale factor 0.3: Max value: 0.6529384255409241, Location: (0, 0)
# Scale factor 0.4: Max value: 0.807151734828949, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9904937744140625, Location: (0, 0)
# Scale factor 0.6: Max value: 0.8397809863090515, Location: (0, 0)
# Scale factor 0.7: Max value: 0.6671969294548035, Location: (0, 0)
# Scale factor 0.8: Max value: 0.49218663573265076, Location: (0, 0)
# Scale factor 0.9: Max value: 0.32032036781311035, Location: (0, 0)
# Scale factor 1.0: Max value: 0.20747143030166626, Location: (0, 0)
# Scale factor 1.1: Max value: 0.12658333778381348, Location: (0, 0)
# Scale factor 1.2: Max value: 0.07352134585380554, Location: (0, 0)
# Scale factor 1.3: Max value: 0.05544489249587059, Location: (0, 0)
# Marked image saved to: marked_images\marked_985045.0.png
# Processing large tile: 990642.0.png, PEAKID: 990642.0
# Found corresponding small tile: 990642.0_1.png
# Large tile path: seamounts_galore_cropped\990642.0.png
# Small tile path: seamounts_bboxes_cropped\990642.0_1.png
# Scale factor 0.1: Max value: -0.34346795082092285, Location: (0, 0)
# Scale factor 0.2: Max value: 0.09055296331644058, Location: (0, 0)
# Scale factor 0.3: Max value: 0.1630460023880005, Location: (0, 0)
# Scale factor 0.4: Max value: 0.577723503112793, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9903237223625183, Location: (0, 0)
# Scale factor 0.6: Max value: 0.6802279949188232, Location: (0, 0)
# Scale factor 0.7: Max value: 0.33569246530532837, Location: (0, 0)
# Scale factor 0.8: Max value: 0.09516391903162003, Location: (0, 0)
# Scale factor 0.9: Max value: -0.028537878766655922, Location: (0, 0)
# Scale factor 1.0: Max value: -0.0811307281255722, Location: (0, 0)
# Marked image saved to: marked_images\marked_990642.0.png
# Processing large tile: 991601.0.png, PEAKID: 991601.0
# Found corresponding small tile: 991601.0_1.png
# Large tile path: seamounts_galore_cropped\991601.0.png
# Small tile path: seamounts_bboxes_cropped\991601.0_1.png
# Scale factor 0.1: Max value: 0.16170215606689453, Location: (0, 0)
# Scale factor 0.2: Max value: 0.2594239413738251, Location: (0, 0)
# Scale factor 0.3: Max value: 0.33510687947273254, Location: (0, 0)
# Scale factor 0.4: Max value: 0.5289666652679443, Location: (0, 0)
# Scale factor 0.5: Max value: 0.962186872959137, Location: (0, 0)
# Scale factor 0.6: Max value: 0.5784533619880676, Location: (0, 0)
# Scale factor 0.7: Max value: 0.44371530413627625, Location: (0, 0)
# Scale factor 0.8: Max value: 0.3676373362541199, Location: (0, 0)
# Scale factor 0.9: Max value: 0.349165678024292, Location: (0, 0)
# Scale factor 1.0: Max value: 0.29888999462127686, Location: (0, 0)
# Scale factor 1.1: Max value: 0.24281123280525208, Location: (0, 0)
# Scale factor 1.2: Max value: 0.15921925008296967, Location: (0, 0)
# Scale factor 1.3: Max value: 0.11968167871236801, Location: (0, 0)
# Scale factor 1.4: Max value: 0.13603292405605316, Location: (0, 0)
# Scale factor 1.5: Max value: 0.11720014363527298, Location: (0, 0)
# Marked image saved to: marked_images\marked_991601.0.png
# Processing large tile: 999759.0.png, PEAKID: 999759.0
# Found corresponding small tile: 999759.0_1.png
# Large tile path: seamounts_galore_cropped\999759.0.png
# Small tile path: seamounts_bboxes_cropped\999759.0_1.png
# Scale factor 0.1: Max value: 0.08722464740276337, Location: (0, 0)
# Scale factor 0.2: Max value: 0.13492698967456818, Location: (0, 0)
# Scale factor 0.3: Max value: 0.3580283522605896, Location: (0, 0)
# Scale factor 0.4: Max value: 0.4577880799770355, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9445141553878784, Location: (0, 0)
# Scale factor 0.6: Max value: 0.4740881323814392, Location: (0, 0)
# Scale factor 0.7: Max value: 0.3100414276123047, Location: (0, 0)
# Scale factor 0.8: Max value: 0.2720181941986084, Location: (0, 0)
# Scale factor 0.9: Max value: 0.21595951914787292, Location: (0, 0)
# Scale factor 1.0: Max value: 0.14023196697235107, Location: (0, 0)
# Scale factor 1.1: Max value: 0.10061588883399963, Location: (0, 0)
# Scale factor 1.2: Max value: 0.06447583436965942, Location: (0, 0)
# Scale factor 1.3: Max value: 0.036002032458782196, Location: (0, 0)
# Marked image saved to: marked_images\marked_999759.0.png
# Found 470 matches.
# Results saved to output_pixel_coordinates.csv
