# %% [markdown]
# Preprocessing

# %%
import os
import cv2

# Parameters
image_folder = "seamounts_galore"  # Root directory of the dataset
output_folder = "seamounts_galore_cropped"  # Temporary folder for cropped images
# image_size = (128, 128)  # Image dimensions for the model
crop_pixels = 65  # Pixels to crop from each border

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# Function to crop borders from an image
def crop_fixed_border(image, crop_pixels=5):
    height, width, _ = image.shape
    if height > crop_pixels * 2 and width > crop_pixels * 2:
        cropped_image = image[crop_pixels:height-crop_pixels, crop_pixels:width-crop_pixels]
        return cropped_image
    else:
        return image  # Return original image if cropping not possible

# Preprocess images (cropping and resizing)
print("Preprocessing images...")

# Loop through all files in the image folder
for filename in os.listdir(image_folder):
    image_path = os.path.join(image_folder, filename)
    
    # Check if the file is an image (you can expand the check for other image formats)
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        # Read the image
        image = cv2.imread(image_path)
        
        # Crop the image
        cropped_image = crop_fixed_border(image, crop_pixels)
        
        # Save the cropped image to the output folder
        output_image_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_image_path, cropped_image)

print("Preprocessing complete.")
# Out:
# Preprocessing images...
# Preprocessing complete.

# %% [markdown]
# Matching

# %%
import cv2
import os
import pandas as pd

# Function to find smaller map tile in the corresponding larger map tile using the floating window approach
def find_and_mark_tiles(large_tile_folder, small_tile_folder, output_csv, start_scale=0.1, scale_step=0.1, max_scale=5, manual_correction_x=0, manual_correction_y=0):
    # List to store results
    results = []
    
    # Get list of files in both folders
    large_tiles = os.listdir(large_tile_folder)
    small_tiles = os.listdir(small_tile_folder)

    # Debug: print the list of files in both folders
    print("Large tiles:", large_tiles)
    print("Small tiles:", small_tiles)

    # Create a dictionary of small tiles indexed by PEAKID
    small_tiles_dict = {}
    for small_tile_name in small_tiles:
        # Extract the PEAKID from the smaller tile's filename (assuming format [PEAKID]_1.png)
        peak_id = small_tile_name.split('_')[0]
        small_tiles_dict[peak_id] = small_tile_name

    # Debug: print the small tiles dictionary
    print("Small tiles dictionary:", small_tiles_dict)

    # Iterate through each large tile
    for large_tile_name in large_tiles:
        # Extract the PEAKID from the larger tile's filename (assuming format [PEAKID].png)
        peak_id = large_tile_name.split('.')[0]

        # Ensure the PEAKID matches the format of the small tile (i.e., keep the '.0' if present)
        peak_id = str(float(peak_id))  # This will preserve the ".0" if present
        
        # Debug: print the current large tile being processed
        print(f"Processing large tile: {large_tile_name}, PEAKID: {peak_id}")
        
        # Check if there is a corresponding small tile for this PEAKID
        if peak_id in small_tiles_dict:
            small_tile_name = small_tiles_dict[peak_id]
            large_tile_path = os.path.join(large_tile_folder, large_tile_name)
            small_tile_path = os.path.join(small_tile_folder, small_tile_name)

            # Debug: print the paths of the current large and small tiles
            print(f"Found corresponding small tile: {small_tile_name}")
            print(f"Large tile path: {large_tile_path}")
            print(f"Small tile path: {small_tile_path}")

            # Check if the marked image already exists
            marked_image_path = os.path.join('marked_images', f"marked_{large_tile_name}")
            if os.path.exists(marked_image_path):
                print(f"Skipping already processed large tile: {large_tile_name}")
                continue  # Skip this large tile if it's already processed

            # Read the images
            large_tile = cv2.imread(large_tile_path, cv2.IMREAD_COLOR)
            small_tile = cv2.imread(small_tile_path, cv2.IMREAD_COLOR)

            if large_tile is None:
                print(f"Error: Unable to load large tile {large_tile_path}")
                continue
            if small_tile is None:
                print(f"Error: Unable to load small tile {small_tile_path}")
                continue

            # Get the center of the large tile
            large_tile_center = (large_tile.shape[1] // 2, large_tile.shape[0] // 2)

            # Perform floating window approach: resize and match the small tile centered on the large tile
            max_match_val = 0
            best_match_loc = None
            best_resized_tile = None

            # Start with the small tile and gradually increase its size
            for scale_factor in frange(start_scale, max_scale + scale_step, scale_step):  # Start from start_scale, scale by scale_step
                if scale_factor <= 0:  # Skip non-positive scale factors
                    continue
                
                # Resize the small tile
                new_width = int(small_tile.shape[1] * scale_factor)
                new_height = int(small_tile.shape[0] * scale_factor)

                # Ensure width and height are positive values
                if new_width <= 0 or new_height <= 0:
                    continue  # Skip if the new dimensions are not valid
                
                resized_small_tile = cv2.resize(small_tile, (new_width, new_height))

                # Calculate the top-left corner to center the resized tile on the large tile
                top_left_x = large_tile_center[0] - resized_small_tile.shape[1] // 2
                top_left_y = large_tile_center[1] - resized_small_tile.shape[0] // 2

                # Ensure the top-left corner is within the bounds of the large tile
                if top_left_x < 0 or top_left_y < 0 or top_left_x + resized_small_tile.shape[1] > large_tile.shape[1] or top_left_y + resized_small_tile.shape[0] > large_tile.shape[0]:
                    continue  # Skip if the resized tile is out of bounds

                # Extract the region of interest (ROI) from the large tile where the small tile will be overlaid
                roi = large_tile[top_left_y:top_left_y + resized_small_tile.shape[0], top_left_x:top_left_x + resized_small_tile.shape[1]]

                # Perform template matching
                result = cv2.matchTemplate(roi, resized_small_tile, cv2.TM_CCOEFF_NORMED)
                min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)

                # Debug: print the result of template matching for each scale
                print(f"Scale factor {scale_factor}: Max value: {max_val}, Location: {max_loc}")

                # If the match is better than the previous best match, update the best match
                if max_val > max_match_val:
                    max_match_val = max_val
                    best_match_loc = (top_left_x + max_loc[0], top_left_y + max_loc[1])  # Adjust the location
                    best_resized_tile = resized_small_tile

            # If a good match is found, draw a rectangle around the matched region
            if max_match_val > 0.8:  # You can adjust the threshold as needed
                top_left = best_match_loc
                h, w = best_resized_tile.shape[:2]
                bottom_right = (top_left[0] + w, top_left[1] + h)

                # Apply manual correction
                top_left = (top_left[0] - manual_correction_x, top_left[1] - manual_correction_y)
                bottom_right = (bottom_right[0] + manual_correction_x, bottom_right[1] + manual_correction_y)

                # Draw the corrected rectangle
                cv2.rectangle(large_tile, top_left, bottom_right, (0, 255, 0), 2)

                # Store the coordinates of the box
                results.append({
                    'large_tile': large_tile_name,
                    'small_tile': small_tile_name,
                    'top_left_x': top_left[0],
                    'top_left_y': top_left[1],
                    'bottom_right_x': bottom_right[0],
                    'bottom_right_y': bottom_right[1]
                })

                # Optionally, save the marked image to a file
                os.makedirs('marked_images', exist_ok=True)
                cv2.imwrite(marked_image_path, large_tile)
                print(f"Marked image saved to: {marked_image_path}")

            else:
                print(f"No good match found for {large_tile_name} and {small_tile_name}")

        else:
            print(f"No corresponding small tile found for PEAKID: {peak_id}")

    # Debug: print the results
    print(f"Found {len(results)} matches.")
    
    # Convert the results to a pandas DataFrame and save to CSV
    if results:
        df = pd.DataFrame(results)
        df.to_csv(output_csv, index=False)
        print(f"Results saved to {output_csv}")
    else:
        print("No matches to save.")

# Helper function to generate a range of floating point numbers
def frange(start, stop, step):
    while start < stop:
        yield round(start, 2)  # Round to avoid floating-point precision issues
        start += step

# Example usage
find_and_mark_tiles('seamounts_galore_cropped', 'seamounts_bboxes_cropped', 'output_pixel_coordinates.csv', start_scale=0.1, scale_step=0.1, max_scale=5, manual_correction_x=5, manual_correction_y=5)
# Out:
# Large tiles: ['1001431.0.png', '1002429.0.png', '1003839.0.png', '1004664.0.png', '1007519.0.png', '1007770.0.png', '1008052.0.png', '1008335.0.png', '1008533.0.png', '1009530.0.png', '1009623.0.png', '1010492.0.png', '1010711.0.png', '1011443.0.png', '1011784.0.png', '1012338.0.png', '1012819.0.png', '1013016.0.png', '1013413.0.png', '1014184.0.png', '1017477.0.png', '1017550.0.png', '1017619.0.png', '1017887.0.png', '1018014.0.png', '1020767.0.png', '1021167.0.png', '1021845.0.png', '1022519.0.png', '1023970.0.png', '1025041.0.png', '1025384.0.png', '1025574.0.png', '1027701.0.png', '1849939.0.png', '1917755.0.png', '1919284.0.png', '1938179.0.png', '1963835.0.png', '2002867.0.png', '2004018.0.png', '2034526.0.png', '2037408.0.png', '2041242.0.png', '2065058.0.png', '2076096.0.png', '2076953.0.png', '2079834.0.png', '2081441.0.png', '2091329.0.png', '2100593.0.png', '2106905.0.png', '2112638.0.png', '2120674.0.png', '2129800.0.png', '2130931.0.png', '2143106.0.png', '2148941.0.png', '2163996.0.png', '2169437.0.png', '2184279.0.png', '2191581.0.png', '2203511.0.png', '2203770.0.png', '2205347.0.png', '2226329.0.png', '2233714.0.png', '2276422.0.png', '2287714.0.png', '2294530.0.png', '2296833.0.png', '2312937.0.png', '2313680.0.png', '2320088.0.png', '2321989.0.png', '2322734.0.png', '2325818.0.png', '2327372.0.png', '2332062.0.png', '2334408.0.png', '2335185.0.png', '2338265.0.png', '2358338.0.png', '2359084.0.png', '2360282.0.png', '2361418.0.png', '2370336.0.png', '2371848.0.png', '2391423.0.png', '2392192.0.png', '2392966.0.png', '2394421.0.png', '2395572.0.png', '2401816.0.png', '2414507.0.png', '2415267.0.png', '2419175.0.png', '2419181.0.png', '2425143.0.png', '2438586.0.png', '2440339.0.png', '2442511.0.png', '2448495.0.png', '2451447.0.png', '2460439.0.png', '2474642.0.png', '2484665.0.png', '2486137.0.png', '2488977.0.png', '2498299.0.png', '2499904.0.png', '2515499.0.png', '2537548.0.png', '2539130.0.png', '2541510.0.png', '2541781.0.png', '2543822.0.png', '2552699.0.png', '2554156.0.png', '2562402.0.png', '2566673.0.png', '2573039.0.png', '2574076.0.png', '2579235.0.png', '2581063.0.png', '2583173.0.png', '2593656.0.png', '2594747.0.png', '2595936.0.png', '2602007.0.png', '2602826.0.png', '2606148.0.png', '2606905.0.png', '2610937.0.png', '2611
Location: (0, 0)
# Scale factor 1.0: Max value: 0.5416575074195862, Location: (0, 0)
# Scale factor 1.1: Max value: 0.45772525668144226, Location: (0, 0)
# Scale factor 1.2: Max value: 0.3782194256782532, Location: (0, 0)
# Marked image saved to: marked_images\marked_979782.0.png
# Processing large tile: 979799.0.png, PEAKID: 979799.0
# Found corresponding small tile: 979799.0_1.png
# Large tile path: seamounts_galore_cropped\979799.0.png
# Small tile path: seamounts_bboxes_cropped\979799.0_1.png
# Scale factor 0.1: Max value: 0.4259454011917114, Location: (0, 0)
# Scale factor 0.2: Max value: 0.6903489232063293, Location: (0, 0)
# Scale factor 0.3: Max value: 0.745905339717865, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7805154323577881, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9805021286010742, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7178981900215149, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5985397696495056, Location: (0, 0)
# Scale factor 0.8: Max value: 0.46843984723091125, Location: (0, 0)
# Scale factor 0.9: Max value: 0.3407248854637146, Location: (0, 0)
# Scale factor 1.0: Max value: 0.2234179526567459, Location: (0, 0)
# Scale factor 1.1: Max value: 0.14345581829547882, Location: (0, 0)
# Marked image saved to: marked_images\marked_979799.0.png
# Processing large tile: 980516.0.png, PEAKID: 980516.0
# Found corresponding small tile: 980516.0_1.png
# Large tile path: seamounts_galore_cropped\980516.0.png
# Small tile path: seamounts_bboxes_cropped\980516.0_1.png
# Scale factor 0.1: Max value: 0.5401589870452881, Location: (0, 0)
# Scale factor 0.2: Max value: 0.6962046027183533, Location: (0, 0)
# Scale factor 0.3: Max value: 0.8498135805130005, Location: (0, 0)
# Scale factor 0.4: Max value: 0.9551993608474731, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9975859522819519, Location: (0, 0)
# Scale factor 0.6: Max value: 0.9611908793449402, Location: (0, 0)
# Scale factor 0.7: Max value: 0.8781828880310059, Location: (0, 0)
# Scale factor 0.8: Max value: 0.7560558915138245, Location: (0, 0)
# Scale factor 0.9: Max value: 0.5956059694290161, Location: (0, 0)
# Scale factor 1.0: Max value: 0.4447184205055237, Location: (0, 0)
# Scale factor 1.1: Max value: 0.3367854356765747, Location: (0, 0)
# Scale factor 1.2: Max value: 0.25844594836235046, Location: (0, 0)
# Marked image saved to: marked_images\marked_980516.0.png
# Processing large tile: 981346.0.png, PEAKID: 981346.0
# Found corresponding small tile: 981346.0_1.png
# Large tile path: seamounts_galore_cropped\981346.0.png
# Small tile path: seamounts_bboxes_cropped\981346.0_1.png
# Scale factor 0.1: Max value: -0.3064190745353699, Location: (0, 0)
# Scale factor 0.2: Max value: 0.1943308264017105, Location: (0, 0)
# Scale factor 0.3: Max value: 0.31251782178878784, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6184753179550171, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9545713663101196, Location: (0, 0)
# Scale factor 0.6: Max value: 0.6279698610305786, Location: (0, 0)
# Scale factor 0.7: Max value: 0.4737565815448761, Location: (0, 0)
# Scale factor 0.8: Max value: 0.34772175550460815, Location: (0, 0)
# Scale factor 0.9: Max value: 0.23050670325756073, Location: (0, 0)
# Scale factor 1.0: Max value: 0.11970913410186768, Location: (0, 0)
# Scale factor 1.1: Max value: 0.09647436439990997, Location: (0, 0)
# Marked image saved to: marked_images\marked_981346.0.png
# Processing large tile: 984507.0.png, PEAKID: 984507.0
# Found corresponding small tile: 984507.0_1.png
# Large tile path: seamounts_galore_cropped\984507.0.png
# Small tile path: seamounts_bboxes_cropped\984507.0_1.png
# Scale factor 0.1: Max value: 0.27946633100509644, Location: (0, 0)
# Scale factor 0.2: Max value: 0.2823679447174072, Location: (0, 0)
# Scale factor 0.3: Max value: 0.4849078059196472, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6487305164337158, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9544979929924011, Location: (0, 0)
# Scale factor 0.6: Max value: 0.6345813274383545, Location: (0, 0)
# Scale factor 0.7: Max value: 0.48785752058029175, Location: (0, 0)
# Scale factor 0.8: Max value: 0.39395779371261597, Location: (0, 0)
# Scale factor 0.9: Max value: 0.32585620880126953, Location: (0, 0)
# Scale factor 1.0: Max value: 0.25505879521369934, Location: (0, 0)
# Scale factor 1.1: Max value: 0.1838988959789276, Location: (0, 0)
# Marked image saved to: marked_images\marked_984507.0.png
# Processing large tile: 985373.0.png, PEAKID: 985373.0
# Found corresponding small tile: 985373.0_1.png
# Large tile path: seamounts_galore_cropped\985373.0.png
# Small tile path: seamounts_bboxes_cropped\985373.0_1.png
# Scale factor 0.1: Max value: 0.6126198172569275, Location: (0, 0)
# Scale factor 0.2: Max value: 0.6507049202919006, Location: (0, 0)
# Scale factor 0.3: Max value: 0.6931544542312622, Location: (0, 0)
# Scale factor 0.4: Max value: 0.7962700128555298, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9834248423576355, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7878733277320862, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5505220293998718, Location: (0, 0)
# Scale factor 0.8: Max value: 0.3847762644290924, Location: (0, 0)
# Scale factor 0.9: Max value: 0.30703917145729065, Location: (0, 0)
# Scale factor 1.0: Max value: 0.27206745743751526, Location: (0, 0)
# Scale factor 1.1: Max value: 0.25758835673332214, Location: (0, 0)
# Scale factor 1.2: Max value: 0.23068761825561523, Location: (0, 0)
# Scale factor 1.3: Max value: 0.21834790706634521, Location: (0, 0)
# Marked image saved to: marked_images\marked_985373.0.png
# Processing large tile: 989044.0.png, PEAKID: 989044.0
# Found corresponding small tile: 989044.0_1.png
# Large tile path: seamounts_galore_cropped\989044.0.png
# Small tile path: seamounts_bboxes_cropped\989044.0_1.png
# Scale factor 0.1: Max value: 0.2820301949977875, Location: (0, 0)
# Scale factor 0.2: Max value: 0.44114285707473755, Location: (0, 0)
# Scale factor 0.3: Max value: 0.5610403418540955, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6717344522476196, Location: (0, 0)
# Scale factor 0.5: Max value: 0.795717179775238, Location: (0, 0)
# Scale factor 0.6: Max value: 0.658801794052124, Location: (0, 0)
# Scale factor 0.7: Max value: 0.4648587107658386, Location: (0, 0)
# Scale factor 0.8: Max value: 0.37182602286338806, Location: (0, 0)
# Scale factor 0.9: Max value: 0.3733998239040375, Location: (0, 0)
# Scale factor 1.0: Max value: 0.34027260541915894, Location: (0, 0)
# Scale factor 1.1: Max value: 0.260895699262619, Location: (0, 0)
# Scale factor 1.2: Max value: 0.1593976616859436, Location: (0, 0)
# Scale factor 1.3: Max value: 0.0835379958152771, Location: (0, 0)
# Scale factor 1.4: Max value: 0.009624842554330826, Location: (0, 0)
# Scale factor 1.5: Max value: -0.054084740579128265, Location: (0, 0)
# Scale factor 1.6: Max value: -0.08937045186758041, Location: (0, 0)
# Scale factor 1.7: Max value: -0.1024424135684967, Location: (0, 0)
# Scale factor 1.8: Max value: -0.10299285501241684, Location: (0, 0)
# Scale factor 1.9: Max value: -0.0850718766450882, Location: (0, 0)
# Scale factor 2.0: Max value: -0.07742432504892349, Location: (0, 0)
# Scale factor 2.1: Max value: -0.07442833483219147, Location: (0, 0)
# Scale factor 2.2: Max value: -0.058200653642416, Location: (0, 0)
# Scale factor 2.3: Max value: -0.03192480280995369, Location: (0, 0)
# Scale factor 2.4: Max value: -0.014594286680221558, Location: (0, 0)
# Scale factor 2.5: Max value: -0.005605286918580532, Location: (0, 0)
# Scale factor 2.6: Max value: 0.007648475468158722, Location: (0, 0)
# Scale factor 2.7: Max value: 0.015816593542695045, Location: (0, 0)
# Scale factor 2.8: Max value: 0.027459995821118355, Location: (0, 0)
# Scale factor 2.9: Max value: 0.03421774134039879, Location: (0, 0)
# Scale factor 3.0: Max value: 0.04335196688771248, Location: (0, 0)
# Scale factor 3.1: Max value: 0.04843151941895485, Location: (0, 0)
# Scale factor 3.2: Max value: 0.05690297484397888, Location: (0, 0)
# Scale factor 3.3: Max value: 0.06171564385294914, Location: (0, 0)
# Scale factor 3.4: Max value: 0.05936388298869133, Location: (0, 0)
# Scale factor 3.5: Max value: 0.055735643953084946, Location: (0, 0)
# Scale factor 3.6: Max value: 0.04939445108175278, Location: (0, 0)
# No good match found for 989044.0.png and 989044.0_1.png
# Processing large tile: 989815.0.png, PEAKID: 989815.0
# Found corresponding small tile: 989815.0_1.png
# Large tile path: seamounts_galore_cropped\989815.0.png
# Small tile path: seamounts_bboxes_cropped\989815.0_1.png
# Scale factor 0.1: Max value: 0.7746078372001648, Location: (0, 0)
# Scale factor 0.2: Max value: 0.8474655151367188, Location: (0, 0)
# Scale factor 0.3: Max value: 0.8961736559867859, Location: (0, 0)
# Scale factor 0.4: Max value: 0.9505777359008789, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9985125064849854, Location: (0, 0)
# Scale factor 0.6: Max value: 0.9542226195335388, Location: (0, 0)
# Scale factor 0.7: Max value: 0.8598106503486633, Location: (0, 0)
# Scale factor 0.8: Max value: 0.7475952506065369, Location: (0, 0)
# Scale factor 0.9: Max value: 0.630682110786438, Location: (0, 0)
# Scale factor 1.0: Max value: 0.5262645483016968, Location: (0, 0)
# Scale factor 1.1: Max value: 0.43541815876960754, Location: (0, 0)
# Marked image saved to: marked_images\marked_989815.0.png
# Processing large tile: 994105.0.png, PEAKID: 994105.0
# Found corresponding small tile: 994105.0_1.png
# Large tile path: seamounts_galore_cropped\994105.0.png
# Small tile path: seamounts_bboxes_cropped\994105.0_1.png
# Scale factor 0.1: Max value: 0.5256415605545044, Location: (0, 0)
# Scale factor 0.2: Max value: 0.5295270681381226, Location: (0, 0)
# Scale factor 0.3: Max value: 0.7276141047477722, Location: (0, 0)
# Scale factor 0.4: Max value: 0.8522951006889343, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9991304874420166, Location: (0, 0)
# Scale factor 0.6: Max value: 0.8702953457832336, Location: (0, 0)
# Scale factor 0.7: Max value: 0.7286744117736816, Location: (0, 0)
# Scale factor 0.8: Max value: 0.622424304485321, Location: (0, 0)
# Scale factor 0.9: Max value: 0.5323276519775391, Location: (0, 0)
# Scale factor 1.0: Max value: 0.4593757688999176, Location: (0, 0)
# Scale factor 1.1: Max value: 0.390220582485199, Location: (0, 0)
# Marked image saved to: marked_images\marked_994105.0.png
# Processing large tile: 994739.0.png, PEAKID: 994739.0
# Found corresponding small tile: 994739.0_1.png
# Large tile path: seamounts_galore_cropped\994739.0.png
# Small tile path: seamounts_bboxes_cropped\994739.0_1.png
# Scale factor 0.1: Max value: 0.5431115627288818, Location: (0, 0)
# Scale factor 0.2: Max value: 0.6670712828636169, Location: (0, 0)
# Scale factor 0.3: Max value: 0.8046252727508545, Location: (0, 0)
# Scale factor 0.4: Max value: 0.9323344230651855, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9961551427841187, Location: (0, 0)
# Scale factor 0.6: Max value: 0.9548295736312866, Location: (0, 0)
# Scale factor 0.7: Max value: 0.8540686368942261, Location: (0, 0)
# Scale factor 0.8: Max value: 0.7359409928321838, Location: (0, 0)
# Scale factor 0.9: Max value: 0.6376941204071045, Location: (0, 0)
# Scale factor 1.0: Max value: 0.5611573457717896, Location: (0, 0)
# Scale factor 1.1: Max value: 0.5042579770088196, Location: (0, 0)
# Marked image saved to: marked_images\marked_994739.0.png
# Processing large tile: 995504.0.png, PEAKID: 995504.0
# Found corresponding small tile: 995504.0_1.png
# Large tile path: seamounts_galore_cropped\995504.0.png
# Small tile path: seamounts_bboxes_cropped\995504.0_1.png
# Scale factor 0.1: Max value: 0.6872239708900452, Location: (0, 0)
# Scale factor 0.2: Max value: 0.7018351554870605, Location: (0, 0)
# Scale factor 0.3: Max value: 0.6391182541847229, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6601650714874268, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9809855818748474, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7100854516029358, Location: (0, 0)
# Scale factor 0.7: Max value: 0.5721238851547241, Location: (0, 0)
# Scale factor 0.8: Max value: 0.49038392305374146, Location: (0, 0)
# Scale factor 0.9: Max value: 0.4467465281486511, Location: (0, 0)
# Scale factor 1.0: Max value: 0.40751728415489197, Location: (0, 0)
# Scale factor 1.1: Max value: 0.33155763149261475, Location: (0, 0)
# Scale factor 1.2: Max value: 0.26678481698036194, Location: (0, 0)
# Scale factor 1.3: Max value: 0.2164466232061386, Location: (0, 0)
# Marked image saved to: marked_images\marked_995504.0.png
# Processing large tile: 996625.0.png, PEAKID: 996625.0
# Found corresponding small tile: 996625.0_1.png
# Large tile path: seamounts_galore_cropped\996625.0.png
# Small tile path: seamounts_bboxes_cropped\996625.0_1.png
# Scale factor 0.1: Max value: 0.699505627155304, Location: (0, 0)
# Scale factor 0.2: Max value: 0.7967994213104248, Location: (0, 0)
# Scale factor 0.3: Max value: 0.8671523928642273, Location: (0, 0)
# Scale factor 0.4: Max value: 0.9487716555595398, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9899556636810303, Location: (0, 0)
# Scale factor 0.6: Max value: 0.945967435836792, Location: (0, 0)
# Scale factor 0.7: Max value: 0.8387163281440735, Location: (0, 0)
# Scale factor 0.8: Max value: 0.6793261170387268, Location: (0, 0)
# Scale factor 0.9: Max value: 0.49708130955696106, Location: (0, 0)
# Scale factor 1.0: Max value: 0.3105699419975281, Location: (0, 0)
# Scale factor 1.1: Max value: 0.17672738432884216, Location: (0, 0)
# Scale factor 1.2: Max value: 0.04685644432902336, Location: (0, 0)
# Scale factor 1.3: Max value: -0.04911712184548378, Location: (0, 0)
# Scale factor 1.4: Max value: -0.11815039813518524, Location: (0, 0)
# Scale factor 1.5: Max value: -0.1695902943611145, Location: (0, 0)
# Scale factor 1.6: Max value: -0.20911723375320435, Location: (0, 0)
# Scale factor 1.7: Max value: -0.22653670608997345, Location: (0, 0)
# Scale factor 1.8: Max value: -0.2330169379711151, Location: (0, 0)
# Scale factor 1.9: Max value: -0.22827188670635223, Location: (0, 0)
# Scale factor 2.0: Max value: -0.20438098907470703, Location: (0, 0)
# Scale factor 2.1: Max value: -0.16609901189804077, Location: (0, 0)
# Scale factor 2.2: Max value: -0.11911356449127197, Location: (0, 0)
# Marked image saved to: marked_images\marked_996625.0.png
# Processing large tile: 997214.0.png, PEAKID: 997214.0
# Found corresponding small tile: 997214.0_1.png
# Large tile path: seamounts_galore_cropped\997214.0.png
# Small tile path: seamounts_bboxes_cropped\997214.0_1.png
# Scale factor 0.1: Max value: 0.6661480665206909, Location: (0, 0)
# Scale factor 0.2: Max value: 0.7939713597297668, Location: (0, 0)
# Scale factor 0.3: Max value: 0.8801016211509705, Location: (0, 0)
# Scale factor 0.4: Max value: 0.9332631230354309, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9903761148452759, Location: (0, 0)
# Scale factor 0.6: Max value: 0.9461595416069031, Location: (0, 0)
# Scale factor 0.7: Max value: 0.8534679412841797, Location: (0, 0)
# Scale factor 0.8: Max value: 0.7640117406845093, Location: (0, 0)
# Scale factor 0.9: Max value: 0.6795253157615662, Location: (0, 0)
# Scale factor 1.0: Max value: 0.6004032492637634, Location: (0, 0)
# Marked image saved to: marked_images\marked_997214.0.png
# Processing large tile: 998828.0.png, PEAKID: 998828.0
# Found corresponding small tile: 998828.0_1.png
# Large tile path: seamounts_galore_cropped\998828.0.png
# Small tile path: seamounts_bboxes_cropped\998828.0_1.png
# Scale factor 0.1: Max value: 0.6891152858734131, Location: (0, 0)
# Scale factor 0.2: Max value: 0.6541736721992493, Location: (0, 0)
# Scale factor 0.3: Max value: 0.44096246361732483, Location: (0, 0)
# Scale factor 0.4: Max value: 0.6746432781219482, Location: (0, 0)
# Scale factor 0.5: Max value: 0.9967182874679565, Location: (0, 0)
# Scale factor 0.6: Max value: 0.7529890537261963, Location: (0, 0)
# Scale factor 0.7: Max value: 0.596009373664856, Location: (0, 0)
# Scale factor 0.8: Max value: 0.5106895565986633, Location: (0, 0)
# Scale factor 0.9: Max value: 0.42204439640045166, Location: (0, 0)
# Scale factor 1.0: Max value: 0.32117509841918945, Location: (0, 0)
# Marked image saved to: marked_images\marked_998828.0.png
# Found 1792 matches.
# Results saved to output_pixel_coordinates.csv
