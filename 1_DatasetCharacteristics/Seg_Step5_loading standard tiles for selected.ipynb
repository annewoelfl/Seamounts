# %% [markdown]
# Key functionality: downloads only the IDs already present in the marked_images folder

# %% [markdown]
# ## Download data

# %%
import os
import requests
import pandas as pd
import math

# Parameters
csv_file = "seamounts.csv"  # Path to the .csv file
marked_images_folder = "marked_images"  # Folder containing already marked images
output_folder = "seamounts_seg"  # Folder to save downloaded images
tile_pixels = 800  # Width and height of the image in pixels
tile_width_deg = 1.0  # Fixed width in degrees
api_base_url = "https://www.gmrt.org/services/ImageServer"

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# Get a set of PEAKIDs from the marked_images folder
marked_peaks = set()
for file_name in os.listdir(marked_images_folder):
    if file_name.startswith("marked_") and file_name.endswith(".png"):
        # Extract the PEAKID from the file name
        peak_id = file_name[len("marked_"):-len(".png")]
        marked_peaks.add(peak_id)

print(f"Found {len(marked_peaks)} marked images in {marked_images_folder}.")

# Load CSV file
try:
    df = pd.read_csv(csv_file)
    print(f"Loaded {len(df)} records from {csv_file}.")
except Exception as e:
    print(f"Error loading .csv file: {e}")
    exit()

# Process each record
for index, row in df.iterrows():
    try:
        # Extract data from the row
        file_name = str(row["PEAKID"])  # Use PEAKID as the file name
        center_lon = float(row["LONG"])  # Longitude from LONG
        center_lat = float(row["LAT"])  # Latitude from LAT

        # Check if this PEAKID exists in the marked_images folder
        if file_name not in marked_peaks:
            print(f"Skipping PEAKID {file_name} as it's not in marked_images.")
            continue  # Skip this PEAKID

        # Calculate the adjusted height for square tiles
        adjusted_height_deg = tile_width_deg * math.cos(math.radians(center_lat))

        # Calculate tile bounds
        minlatitude = center_lat - (adjusted_height_deg / 2)
        maxlatitude = center_lat + (adjusted_height_deg / 2)
        minlongitude = center_lon - (tile_width_deg / 2)
        maxlongitude = center_lon + (tile_width_deg / 2)

        # Debugging: Print calculated values
        print(f"PEAKID: {file_name}")
        print(f"Center Lat: {center_lat}, Center Lon: {center_lon}")
        print(f"Adjusted Height (degrees): {adjusted_height_deg}")
        print(f"Bounds: {minlatitude} to {maxlatitude}, {minlongitude} to {maxlongitude}")

        # Prepare API parameters
        params = {
            "minlatitude": minlatitude,
            "maxlatitude": maxlatitude,
            "minlongitude": minlongitude,
            "maxlongitude": maxlongitude,
            "width": tile_pixels,
            "mask": "false",
            "download": "true",
        }

        # Construct the output file path
        output_file = os.path.join(output_folder, f"{file_name}.png")

        # Download the image
        print(f"Downloading square image for PEAKID {file_name} at {center_lat}, {center_lon}...")
        response = requests.get(api_base_url, params=params)

        if response.status_code == 200:
            # Save the image
            with open(output_file, "wb") as file:
                file.write(response.content)
            print(f"Saved: {output_file}")
        else:
            print(f"Failed to download for PEAKID {file_name} - HTTP {response.status_code}")

    except Exception as e:
        print(f"Error processing row {index}: {e}")

print("Download complete.")
# Out:
# Found 499 marked images in marked_images.
# Loaded 33452 records from seamounts.csv.
# Skipping PEAKID 26000.0 as it's not in marked_images.
# Skipping PEAKID 26157.0 as it's not in marked_images.
# Skipping PEAKID 26158.0 as it's not in marked_images.
# Skipping PEAKID 26228.0 as it's not in marked_images.
# Skipping PEAKID 26229.0 as it's not in marked_images.
# Skipping PEAKID 26297.0 as it's not in marked_images.
# Skipping PEAKID 26298.0 as it's not in marked_images.
# Skipping PEAKID 26407.0 as it's not in marked_images.
# Skipping PEAKID 26408.0 as it's not in marked_images.
# Skipping PEAKID 26653.0 as it's not in marked_images.
# Skipping PEAKID 26664.0 as it's not in marked_images.
# Skipping PEAKID 26665.0 as it's not in marked_images.
# Skipping PEAKID 27029.0 as it's not in marked_images.
# Skipping PEAKID 27045.0 as it's not in marked_images.
# Skipping PEAKID 27112.0 as it's not in marked_images.
# Skipping PEAKID 27347.0 as it's not in marked_images.
# Skipping PEAKID 27393.0 as it's not in marked_images.
# Skipping PEAKID 27394.0 as it's not in marked_images.
# Skipping PEAKID 27395.0 as it's not in marked_images.
# Skipping PEAKID 27396.0 as it's not in marked_images.
# Skipping PEAKID 27397.0 as it's not in marked_images.
# Skipping PEAKID 27499.0 as it's not in marked_images.
# Skipping PEAKID 27586.0 as it's not in marked_images.
# Skipping PEAKID 27587.0 as it's not in marked_images.
# Skipping PEAKID 27724.0 as it's not in marked_images.
# Skipping PEAKID 28090.0 as it's not in marked_images.
# Skipping PEAKID 28199.0 as it's not in marked_images.
# Skipping PEAKID 28200.0 as it's not in marked_images.
# Skipping PEAKID 28323.0 as it's not in marked_images.
# Skipping PEAKID 28390.0 as it's not in marked_images.
# Skipping PEAKID 28459.0 as it's not in marked_images.
# Skipping PEAKID 28618.0 as it's not in marked_images.
# Skipping PEAKID 28621.0 as it's not in marked_images.
# Skipping PEAKID 28833.0 as it's not in marked_images.
# Skipping PEAKID 29041.0 as it's not in marked_images.
# Skipping PEAKID 29502.0 as it's not in marked_images.
# Skipping PEAKID 29503.0 as it's not in marked_images.
# Skipping PEAKID 29633.0 as it's not in marked_images.
# Skipping PEAKID 29731.0 as it's not in marked_images.
# Skipping PEAKID 29732.0 as it's not in marked_images.
# Skipping PEAKID 29745.0 as it's not in marked_images.
# Skipping PEAKID 29746.0 as it's not in marked_images.
# Skipping PEAKID 29747.0 as it's not in marked_images.
# Skipping PEAKID 29748.0 as it's not in marked_images.
# Skipping PEAKID 29876.0 as it's not in marked_images.
# Skipping PEAKID 29877.0 as it's not in marked_images.
# Skipping PEAKID 29924.0 as it's not in marked_images.
# Skipping PEAKID 29945.0 as it's not in marked_images.
# Skipping PEAKID 30190.0 as it's not in marked_images.
# Skipping PEAKID 30209.0 as it's not in marked_images.
# Skipping PEAKID 30210.0 as it's not in marked_images.
# Skipping PEAKID 30211.0 as it's not in marked_images.
# Skipping PEAKID 30236.0 as it's not in marked_images.
# Skipping PEAKID 30261.0 as it's not in marked_images.
# Skipping PEAKID 30262.0 as it's not in marked_images.
# Skipping PEAKID 30269.0 as it's not in marked_images.
# Skipping PEAKID 30279.0 as it's not in marked_images.
# Skipping PEAKID 30280.0 as it's not in marked_images.
# Skipping PEAKID 30327.0 as it's not in marked_images.
# Skipping PEAKID 30342.0 as it's not in marked_images.
# Skipping PEAKID 30343.0 as it's not in marked_images.
# Skipping PEAKID 30349.0 as it's not in marked_images.
# Skipping PEAKID 30362.0 as it's not in marked_images.
# Skipping PEAKID 30363.0 as it's not in marked_images.
# Skipping PEAKID 30364.0 as it's not in marked_images.
# Skipping PEAKID 30365.0 as it's not in marked_images.
# Skipping PEAKID 30369.0 as it's not in marked_images.
# Skipping PEAKID 30374.0 as it's not in marked_images.
# Skipping PEAKID 30390.0 as it's not in marked_images.
# Skipping PEAKID 30391.0 as it's not in marked_images.
# Skipping PEAKID 30392.0 as it's not in marked_images.
# Skipping PEAKID 30393.0 as it's not in marked_images.
# Skipping PEAKID 30394.0 as it's not in marked_images.
# Skipping PEAKID 30395.0 as it's not in marked_images.
# Skipping PEAKID 30396.0 as it's not in marked_images.
# Skipping PEAKID 30419.0 as it's not in marked_images.
# Skipping PEAKID 30468.0 as it's not in marked_images.
# Skipping PEAKID 30493.0 as it's not in marked_images.
# Skipping PEAKID 30544.0 as it's not in marked_images.
# Skipping PEAKID 30546.0 as it's not in marked_images.
# Skipping PEAKID 30547.0 as it's not in marked_images.
# Skipping PEAKID 30548.0 as it's not in marked_images.
# Skipping PEAKID 30549.0 as it's not in marked_images.
# Skipping PEAKID 30550.0 as it's not in marked_images.
# Skipping PEAKID 30631.0 as it's not in marked_images.
# Skipping PEAKID 30655.0 as it's not in marked_images.
# Skipping PEAKID 30656.0 as it's not in marked_images.
# Skipping PEAKID 30733.0 as it's not in marked_images.
# Skipping PEAKID 30938.0 as it's not in marked_images.
# Skipping PEAKID 30939.0 as it's not in marked_images.
# Skipping PEAKID 30974.0 as it's not in marked_images.
# Skipping PEAKID 30985.0 as it's not in marked_images.
# Skipping PEAKID 31043.0 as it's not in marked_images.
# Skipping PEAKID 31044.0 as it's not in marked_images.
# Skipping PEAKID 31093.0 as it's not in marked_images.
# Skipping PEAKID 31094.0 as it's not in marked_images.
# Skipping PEAKID 31095.0 as it's not in marked_images.
# Skipping PEAKID 31134.0 as it's not in marked_images.
# Skipping PEAKID 31135.0 as it's not in marked_images.
# Skipping PEAKID 31857.0 as it's not in marked_images.
# Skipping PEAKID 31859.0 as it's not in marked_images.
# Skipping PEAKID 31867.0 as it's not in marked_images.
# Skipping PEAKID 32828.0 as it's not in marked_images.
# Skipping PEAKID 33023.0 as it's not in marked_images.
# Skipping PEAKID 33092.0 as it's not in marked_images.
# Skipping PEAKID 35640.0 as it's not in marked_images.
# Skipping PEAKID 35687.0 as it's not in marked_images.
# Skipping PEAKID 35756.0 as it's not in marked_images.
# Skipping PEAKID 40611.0 as it's not in marked_images.
# Skipping PEAKID 40752.0 as it's not in marked_images.
# Skipping PEAKID 40994.0 as it's not in marked_images.
# Skipping PEAKID 43283.0 as it's not in marked_images.
# Skipping PEAKID 43738.0 as it's not in marked_images.
# Skipping PEAKID 45591.0 as it's not in marked_images.
# Skipping PEAKID 49447.0 as it's not in marked_images.
# Skipping PEAKID 50198.0 as it's not in marked_images.
# Skipping PEAKID 50199.0 as it's not in marked_images.
# Skipping PEAKID 54436.0 as it's not in marked_images.
# Skipping PEAKID 54928.0 as it's not in marked_images.
# Skipping PEAKID 56177.0 as it's not in marked_images.
# Skipping PEAKID 56178.0 as it's not in marked_images.
# Skipping PEAKID 59156.0 as it's not in marked_images.
# Skipping PEAKID 59202.0 as it's not in marked_images.
# Skipping PEAKID 61761.0 as it's not in marked_images.
# Skipping PEAKID 62796.0 as it's not in marked_images.
# Skipping PEAKID 65202.0 as it's not in marked_images.
# Skipping PEAKID 68086.0 as it's not in marked_images.
# Skipping PEAKID 76959.0 as it's not in marked_images.
# Skipping PEAKID 77016.0 as it's not in marked_images.
# Skipping PEAKID 78483.0 as it's not in marked_images.
# Skipping PEAKID 78831.0 as it's not in marked_images.
# Skipping PEAKID 79774.0 as it's not in marked_images.
# Skipping PEAKID 80010.0 as it's not in marked_images.
# Skipping PEAKID 80240.0 as it's not in marked_images.
# Skipping PEAKID 80423.0 as it's not in marked_images.
# Skipping PEAKID 80571.0 as it's not in marked_images.
# Skipping PEAKID 80658.0 as it's not in marked_images.
# Skipping PEAKID 85959.0 as it's not in marked_images.
# Skipping PEAKID 87212.0 as it's not in marked_images.
# Skipping PEAKID 89339.0 as it's not in marked_images.
# Skipping PEAKID 90706.0 as it's not in marked_images.
# Skipping PEAKID 91718.0 as it's not in marked_images.
# Skipping PEAKID 92349.0 as it's not in marked_images.
# Skipping PEAKID 99950.0 as it's not in marked_images.
# Skipping PEAKID 117387.0 as it's not in marked_images.
# Skipping PEAKID 122575.0 as it's not in marked_images.
# Skipping PEAKID 136790.0 as it's not in marked_images.
# Skipping PEAKID 141504.0 as it's not in marked_images.
# Skipping PEAKID 144629.0 as it's not in marked_images.
# Skipping PEAKID 161599.0 as it's not in marked_images.
# Skipping PEAKID 256440.0 as it's not in marked_images.
# Skipping PEAKID 264278.0 as it's not in marked_images.
# Skipping PEAKID 267085.0 as it's not in marked_images.
# Skipping PEAKID 268142.0 as it's not in marked_images.
# Skipping PEAKID 275752.0 as it's not in marked_images.
# Skipping PEAKID 284224.0 as it's not in marked_images.
# Skipping PEAKID 286306.0 as it's not in marked_images.
# Skipping PEAKID 287300.0 as it's not in marked_images.
# Skipping PEAKID 296128.0 as it's not in marked_images.
# Skipping PEAKID 304341.0 as it's not in marked_images.
# Skipping PEAKID 305376.0 as it's not in marked_images.
# Skipping PEAKID 305377.0 as it's not in marked_images.
# Skipping PEAKID 307899.0 as it's not in marked_images.
# Skipping PEAKID 308697.0 as it's not in marked_images.
# Skipping PEAKID 312808.0 as it's not in marked_images.
# Skipping PEAKID 314217.0 as it's not in marked_images.
# Skipping PEAKID 315103.0 as it's not in marked_images.
# Skipping PEAKID 315910.0 as it's not in marked_images.
# Skipping PEAKID 316457.0 as it's not in marked_images.
# Skipping PEAKID 316859.0 as it's not in marked_images.
# Skipping PEAKID 317780.0 as it's not in marked_images.
# Skipping PEAKID 318958.0 as it's not in marked_images.
# Skipping PEAKID 321773.0 as it's not in marked_images.
# Skipping PEAKID 327272.0 as it's not in marked_images.
# Skipping PEAKID 327640.0 as it's not in marked_images.
# Skipping PEAKID 327684.0 as it's not in marked_images.
# Skipping PEAKID 327984.0 as it's not in marked_images.
# Skipping PEAKID 328153.0 as it's not in marked_images.
# Skipping PEAKID 328292.0 as it's not in marked_images.
# Skipping PEAKID 331374.0 as it's not in marked_images.
# Skipping PEAKID 332569.0 as it's not in marked_images.
# Skipping PEAKID 334029.0 as it's not in marked_images.
# Skipping PEAKID 334323.0 as it's not in marked_images.
# Skipping PEAKID 335178.0 as it's not in marked_images.
# Skipping PEAKID 336027.0 as it's not in marked_images.
# PEAKID: 336209.0
# Center Lat: 52.3630696614999, Center Lon: 169.637499999999
# Adjusted Height (degrees): 0.6106557121666831
# Bounds: 52.057741805416555 to 52.668397517583244, 169.137499999999 to 170.137499999999
# Downloading square image for PEAKID 336209.0 at 52.3630696614999, 169.637499999999...
# Saved: seamounts_seg\336209.0.png
# Skipping PEAKID 337316.0 as it's not in marked_images.
# Skipping PEAKID 341202.0 as it's not in marked_images.
# Skipping PEAKID 342226.0 as it's not in marked_images.
# Skipping PEAKID 342986.0 as it's not in marked_images.
# Skipping PEAKID 343094.0 as it's not in marked_images.
# Skipping PEAKID 343095.0 as it's not in marked_images.
# Skipping PEAKID 343974.0 as it's not in marked_images.
# Skipping PEAKID 344467.0 as it's not in marked_images.
# Skipping PEAKID 345391.0 as it's not in marked_images.
# Skipping PEAKID 345470.0 as it's not in marked_images.
# Skipping PEAKID 347014.0 as it's not in marked_images.
# Skipping PEAKID 347017.0 as it's not in marked_images.
# Skipping PEAKID 347394.0 as it's not in marked_images.
# Skipping PEAKID 348772.0 as it's not in marked_images.
# Skipping PEAKID 349283.0 as it's not in marked_images.
# Skipping PEAKID 352109.0 as it's not in marked_images.
# Skipping PEAKID 353017.0 as it's not in marked_images.
# Skipping PEAKID 353435.0 as it's not in marked_images.
# Skipping PEAKID 355079.0 as it's not in marked_images.
# Skipping PEAKID 355122.0 as it's not in marked_images.
# Skipping PEAKID 355295.0 as it's not in marked_images.
# Skipping PEAKID 355925.0 as it's not in marked_images.
# Skipping PEAKID 358995.0 as it's not in marked_images.
# Skipping PEAKID 359272.0 as it's not in marked_images.
# PEAKID: 360059.0
# Center Lat: 50.1130696614999, Center Lon: 177.6875
# Adjusted Height (degrees): 0.641274617894072
# Bounds: 49.792432352552865 to 50.433706970446934, 177.1875 to 178.1875
# Downloading square image for PEAKID 360059.0 at 50.1130696614999, 177.6875...
# Saved: seamounts_seg\360059.0.png
# Skipping PEAKID 360152.0 as it's not in marked_images.
# Skipping PEAKID 360187.0 as it's not in marked_images.
# Skipping PEAKID 360340.0 as it's not in marked_images.
# Skipping PEAKID 360738.0 as it's not in marked_images.
# Skipping PEAKID 360739.0 as it's not in marked_images.
# Skipping PEAKID 360905.0 as it's not in marked_images.
# Skipping PEAKID 364206.0 as it's not in marked_images.
# Skipping PEAKID 364376.0 as it's not in marked_images.
# Skipping PEAKID 366605.0 as it's not in marked_images.
# Skipping PEAKID 367765.0 as it's not in marked_images.
# Skipping PEAKID 367935.0 as it's not in marked_images.
# Skipping PEAKID 367936.0 as it's not in marked_images.
# Skipping PEAKID 367942.0 as it's not in marked_images.
# Skipping PEAKID 368417.0 as it's not in marked_images.
# Skipping PEAKID 368509.0 as it's not in marked_images.
# Skipping PEAKID 369538.0 as it's not in marked_images.
# Skipping PEAKID 370103.0 as it's not in marked_images.
# Skipping PEAKID 370718.0 as it's not in marked_images.
# Skipping PEAKID 370719.0 as it's not in marked_images.
# Skipping PEAKID 371151.0 as it's not in marked_images.
# Skipping PEAKID 373307.0 as it's not in marked_images.
# Skipping PEAKID 373787.0 as it's not in marked_images.
# Skipping PEAKID 374512.0 as it's not in marked_images.
# Skipping PEAKID 374918.0 as it's not in marked_images.
# Skipping PEAKID 375595.0 as it's not in marked_images.
# Skipping PEAKID 377289.0 as it's not in marked_images.
# Skipping PEAKID 377293.0 as it's not in marked_images.
# Skipping PEAKID 378660.0 as it's not in marked_images.
# Skipping PEAKID 381456.0 as it's not in marked_images.
# Skipping PEAKID 382341.0 as it's not in marked_images.
# Skipping PEAKID 382368.0 as it's not in marked_images.
# Skipping PEAKID 384110.0 as it's not in marked_images.
# Skipping PEAKID 386525.0 as it's not in marked_images.
# Skipping PEAKID 389693.0 as it's not in marked_images.
# Skipping PEAKID 390078.0 as it's not in marked_images.
# Skipping PEAKID 390425.0 as it's not in marked_images.
# Skipping PEAKID 391054.0 as it's not in marked_images.
# Skipping PEAKID 391367.0 as it's not in marked_images.
# Skipping PEAKID 391878.0 as it's not in marked_images.
# Skipping PEAKID 392377.0 as it's not in marked_images.
# Skipping PEAKID 393106.0 as it's not in marked_images.
# Skipping PEAKID 393335.0 as it's not in marked_images.
# Skipping PEAKID 393721.0 as it's not in marked_images.
# Skipping PEAKID 394767.0 as it's not in marked_images.
# Skipping PEAKID 397210.0 as it's not in marked_images.
# Skipping PEAKID 400199.0 as it's not in marked_images.
# Skipping PEAKID 400581.0 as it's not in marked_images.
# Skipping PEAKID 400711.0 as it's not in marked_images.
# Skipping PEAKID 401188.0 as it's not in marked_images.
# Skipping PEAKID 401316.0 as it's not in marked_images.
# Skipping PEAKID 402448.0 as it's not in marked_images.
# Skipping PEAKID 402571.0 as it's not in marked_images.
# Skipping PEAKID 403123.0 as it's not in marked_images.
# Skipping PEAKID 403880.0 as it's not in marked_images.
# Skipping PEAKID 404440.0 as it's not in marked_images.
# Skipping PEAKID 405841.0 as it's not in marked_images.
# Skipping PEAKID 406421.0 as it's not in marked_images.
# Skipping PEAKID 406449.0 as it's not in marked_images.
# Skipping PEAKID 406802.0 as it's not in marked_images.
# Skipping PEAKID 409778.0 as it's not in marked_images.
# Skipping PEAKID 410202.0 as it's not in marked_images.
# Skipping PEAKID 410530.0 as it's not in marked_images.
# Skipping PEAKID 410649.0 as it's not in marked_images.
# Skipping PEAKID 410989.0 as it's not in marked_images.
# Skipping PEAKID 411808.0 as it's not in marked_images.
# PEAKID: 412667.0
# Center Lat: 44.7269585502999, Center Lon: -34.3597222221999
# Adjusted Height (degrees): 0.7104684371199276
# Bounds: 44.371724331739934 to 45.08219276885986, -34.8597222221999 to -33.8597222221999
# Downloading square image for PEAKID 412667.0 at 44.7269585502999, -34.3597222221999...
# Saved: seamounts_seg\412667.0.png
# Skipping PEAKID 413531.0 as it's not in marked_images.
# Skipping PEAKID 414388.0 as it's not in marked_images.
# Skipping PEAKID 416146.0 as it's not in marked_images.
# Skipping PEAKID 416948.0 as it's not in marked_images.
# Skipping PEAKID 417030.0 as it's not in marked_images.
# Skipping PEAKID 418831.0 as it's not in marked_images.
# Skipping PEAKID 419648.0 as it's not in marked_images.
# Skipping PEAKID 420672.0 as it's not in marked_images.
# Skipping PEAKID 420835.0 as it's not in marked_images.
# Skipping PEAKID 420911.0 as it's not in marked_images.
# Skipping PEAKID 421419.0 as it's not in marked_images.
# Skipping PEAKID 421727.0 as it's not in marked_images.
# Skipping PEAKID 421766.0 as it's not in marked_images.
# Skipping PEAKID 422114.0 as it's not in marked_images.
# Skipping PEAKID 422698.0 as it's not in marked_images.
# Skipping PEAKID 423030.0 as it's not in marked_images.
# Skipping PEAKID 423062.0 as it's not in marked_images.
# Skipping PEAKID 423603.0 as it's not in marked_images.
# Skipping PEAKID 424171.0 as it's not in marked_images.
# PEAKID: 424420.0
# Center Lat: 43.1991807726, Center Lon: -20.8319444444
# Adjusted Height (degrees): 0.7289784151489044
# Bounds: 42.83469156502555 to 43.56366998017445, -21.3319444444 to -20.3319444444
# Downloading square image for PEAKID 424420.0 at 43.1991807726, -20.8319444444...
# Saved: seamounts_seg\424420.0.png
# Skipping PEAKID 425211.0 as it's not in marked_images.
# Skipping PEAKID 425883.0 as it's not in marked_images.
# Skipping PEAKID 426252.0 as it's not in marked_images.
# Skipping PEAKID 426744.0 as it's not in marked_images.
# Skipping PEAKID 426745.0 as it's not in marked_images.
# Skipping PEAKID 426831.0 as it's not in marked_images.
# Skipping PEAKID 427027.0 as it's not in marked_images.
# Skipping PEAKID 427234.0 as it's not in marked_images.
# Skipping PEAKID 428303.0 as it's not in marked_images.
# Skipping PEAKID 428434.0 as it's not in marked_images.
# Skipping PEAKID 428653.0 as it's not in marked_images.
# Skipping PEAKID 428941.0 as it's not in marked_images.
# Skipping PEAKID 430087.0 as it's not in marked_images.
# Skipping PEAKID 430404.0 as it's not in marked_images.
# Skipping PEAKID 430588.0 as it's not in marked_images.
# Skipping PEAKID 430589.0 as it's not in marked_images.
# Skipping PEAKID 431711.0 as it's not in marked_images.
# Skipping PEAKID 433462.0 as it's not in marked_images.
# Skipping PEAKID 433492.0 as it's not in marked_images.
# Skipping PEAKID 433957.0 as it's not in marked_images.
# Skipping PEAKID 434263.0 as it's not in marked_images.
# Skipping PEAKID 434270.0 as it's not in marked_images.
# Skipping PEAKID 434765.0 as it's not in marked_images.
# PEAKID: 434824.0
# Center Lat: 41.7352918837, Center Lon: 170.206944443999
# Adjusted Height (degrees): 0.7462282856686637
# Bounds: 41.36217774086567 to 42.10840602653433, 169.706944443999 to 170.706944443999
# Downloading square image for PEAKID 434824.0 at 41.7352918837, 170.206944443999...
# Saved: seamounts_seg\434824.0.png
# Skipping PEAKID 434825.0 as it's not in marked_images.
# Skipping PEAKID 434898.0 as it's not in marked_images.
# Skipping PEAKID 435430.0 as it's not in marked_images.
# Skipping PEAKID 436405.0 as it's not in marked_images.
# Skipping PEAKID 436624.0 as it's not in marked_images.
# Skipping PEAKID 436625.0 as it's not in marked_images.
# Skipping PEAKID 436798.0 as it's not in marked_images.
# Skipping PEAKID 437439.0 as it's not in marked_images.
# Skipping PEAKID 437582.0 as it's not in marked_images.
# Skipping PEAKID 437898.0 as it's not in marked_images.
# Skipping PEAKID 438316.0 as it's not in marked_images.
# Skipping PEAKID 438859.0 as it's not in marked_images.
# Skipping PEAKID 439270.0 as it's not in marked_images.
# Skipping PEAKID 440767.0 as it's not in marked_images.
# PEAKID: 440886.0
# Center Lat: 40.9047363281, Center Lon: -128.920833332999
# Adjusted Height (degrees): 0.7557993427502088
# Bounds: 40.526836656724896 to 41.282635999475104, -129.420833332999 to -128.420833332999
# Downloading square image for PEAKID 440886.0 at 40.9047363281, -128.920833332999...
# Saved: seamounts_seg\440886.0.png
# Skipping PEAKID 441314.0 as it's not in marked_images.
# Skipping PEAKID 441370.0 as it's not in marked_images.
# Skipping PEAKID 442032.0 as it's not in marked_images.
# Skipping PEAKID 442689.0 as it's not in marked_images.
# Skipping PEAKID 443319.0 as it's not in marked_images.
# Skipping PEAKID 444031.0 as it's not in marked_images.
# Skipping PEAKID 445250.0 as it's not in marked_images.
# Skipping PEAKID 445275.0 as it's not in marked_images.
# Skipping PEAKID 446339.0 as it's not in marked_images.
# Skipping PEAKID 446966.0 as it's not in marked_images.
# Skipping PEAKID 447939.0 as it's not in marked_images.
# Skipping PEAKID 448568.0 as it's not in marked_images.
# Skipping PEAKID 449693.0 as it's not in marked_images.
# Skipping PEAKID 450234.0 as it's not in marked_images.
# Skipping PEAKID 450361.0 as it's not in marked_images.
# Skipping PEAKID 451559.0 as it's not in marked_images.
# Skipping PEAKID 451871.0 as it's not in marked_images.
# Skipping PEAKID 452890.0 as it's not in marked_images.
# Skipping PEAKID 453211.0 as it's not in marked_images.
# Skipping PEAKID 453420.0 as it's not in marked_images.
# Skipping PEAKID 454125.0 as it's not in marked_images.
# Skipping PEAKID 454408.0 as it's not in marked_images.
# Skipping PEAKID 454608.0 as it's not in marked_images.
# Skipping PEAKID 454697.0 as it's not in marked_images.
# Skipping PEAKID 456592.0 as it's not in marked_images.
# Skipping PEAKID 457679.0 as it's not in marked_images.
# Skipping PEAKID 457778.0 as it's not in marked_images.
# Skipping PEAKID 457821.0 as it's not in marked_images.
# Skipping PEAKID 458482.0 as it's not in marked_images.
# Skipping PEAKID 458568.0 as it's not in marked_images.
# Skipping PEAKID 459259.0 as it's not in marked_images.
# Skipping PEAKID 460651.0 as it's not in marked_images.
# Skipping PEAKID 460828.0 as it's not in marked_images.
# Skipping PEAKID 461595.0 as it's not in marked_images.
# Skipping PEAKID 461753.0 as it's not in marked_images.
# Skipping PEAKID 461755.0 as it's not in marked_images.
# Skipping PEAKID 461853.0 as it's not in marked_images.
# Skipping PEAKID 461953.0 as it's not in marked_images.
# Skipping PEAKID 462023.0 as it's not in marked_images.
# Skipping PEAKID 462071.0 as it's not in marked_images.
# Skipping PEAKID 462858.0 as it's not in marked_images.
# PEAKID: 463254.0
# Center Lat: 38.0464029947999, Center Lon: -60.8374999999999
# Adjusted Height (degrees): 0.7875118802078586
# Bounds: 37.65264705469597 to 38.44015893490383, -61.3374999999999 to -60.3374999999999
# Downloading square image for PEAKID 463254.0 at 38.0464029947999, -60.8374999999999...
# Saved: seamounts_seg\463254.0.png
# Skipping PEAKID 463528.0 as it's not in marked_images.
# Skipping PEAKID 463806.0 as it's not in marked_images.
# Skipping PEAKID 464135.0 as it's not in marked_images.
# Skipping PEAKID 464433.0 as it's not in marked_images.
# Skipping PEAKID 464474.0 as it's not in marked_images.
# Skipping PEAKID 464607.0 as it's not in marked_images.
# Skipping PEAKID 465662.0 as it's not in marked_images.
# Skipping PEAKID 465753.0 as it's not in marked_images.
# Skipping PEAKID 465802.0 as it's not in marked_images.
# Skipping PEAKID 466734.0 as it's not in marked_images.
# Skipping PEAKID 466794.0 as it's not in marked_images.
# Skipping PEAKID 466796.0 as it's not in marked_images.
# Skipping PEAKID 467034.0 as it's not in marked_images.
# Skipping PEAKID 467241.0 as it's not in marked_images.
# Skipping PEAKID 467340.0 as it's not in marked_images.
# Skipping PEAKID 467781.0 as it's not in marked_images.
# Skipping PEAKID 468014.0 as it's not in marked_images.
# Skipping PEAKID 468076.0 as it's not in marked_images.
# Skipping PEAKID 468301.0 as it's not in marked_images.
# Skipping PEAKID 468634.0 as it's not in marked_images.
# Skipping PEAKID 468662.0 as it's not in marked_images.
# Skipping PEAKID 468825.0 as it's not in marked_images.
# Skipping PEAKID 469153.0 as it's not in marked_images.
# Skipping PEAKID 469836.0 as it's not in marked_images.
# Skipping PEAKID 470036.0 as it's not in marked_images.
# Skipping PEAKID 470082.0 as it's not in marked_images.
# PEAKID: 471046.0
# Center Lat: 36.8630696614999, Center Lon: -125.604166667
# Adjusted Height (degrees): 0.8000714968040059
# Bounds: 36.463033913097895 to 37.263105409901904, -126.104166667 to -125.104166667
# Downloading square image for PEAKID 471046.0 at 36.8630696614999, -125.604166667...
# Saved: seamounts_seg\471046.0.png
# Skipping PEAKID 471346.0 as it's not in marked_images.
# Skipping PEAKID 471405.0 as it's not in marked_images.
# Skipping PEAKID 471460.0 as it's not in marked_images.
# Skipping PEAKID 471601.0 as it's not in marked_images.
# Skipping PEAKID 471656.0 as it's not in marked_images.
# Skipping PEAKID 472126.0 as it's not in marked_images.
# Skipping PEAKID 472310.0 as it's not in marked_images.
# Skipping PEAKID 472380.0 as it's not in marked_images.
# Skipping PEAKID 472825.0 as it's not in marked_images.
# Skipping PEAKID 472831.0 as it's not in marked_images.
# Skipping PEAKID 472927.0 as it's not in marked_images.
# Skipping PEAKID 472928.0 as it's not in marked_images.
# Skipping PEAKID 473098.0 as it's not in marked_images.
# Skipping PEAKID 473798.0 as it's not in marked_images.
# Skipping PEAKID 474087.0 as it's not in marked_images.
# PEAKID: 474704.0
# Center Lat: 36.2519585503, Center Lon: 175.451388888999
# Adjusted Height (degrees): 0.8064243909691504
# Bounds: 35.848746354815425 to 36.65517074578458, 174.951388888999 to 175.951388888999
# Downloading square image for PEAKID 474704.0 at 36.2519585503, 175.451388888999...
# Saved: seamounts_seg\474704.0.png
# Skipping PEAKID 475640.0 as it's not in marked_images.
# Skipping PEAKID 475893.0 as it's not in marked_images.
# Skipping PEAKID 476155.0 as it's not in marked_images.
# Skipping PEAKID 476591.0 as it's not in marked_images.
# Skipping PEAKID 476761.0 as it's not in marked_images.
# Skipping PEAKID 477306.0 as it's not in marked_images.
# Skipping PEAKID 477596.0 as it's not in marked_images.
# Skipping PEAKID 477859.0 as it's not in marked_images.
# Skipping PEAKID 478991.0 as it's not in marked_images.
# Skipping PEAKID 479472.0 as it's not in marked_images.
# Skipping PEAKID 479695.0 as it's not in marked_images.
# Skipping PEAKID 480092.0 as it's not in marked_images.
# Skipping PEAKID 480645.0 as it's not in marked_images.
# Skipping PEAKID 480813.0 as it's not in marked_images.
# Skipping PEAKID 480818.0 as it's not in marked_images.
# Skipping PEAKID 481445.0 as it's not in marked_images.
# Skipping PEAKID 481620.0 as it's not in marked_images.
# Skipping PEAKID 481863.0 as it's not in marked_images.
# Skipping PEAKID 481917.0 as it's not in marked_images.
# Skipping PEAKID 481969.0 as it's not in marked_images.
# Skipping PEAKID 482125.0 as it's not in marked_images.
# Skipping PEAKID 482540.0 as it's not in marked_images.
# Skipping PEAKID 482541.0 as it's not in marked_images.
# Skipping PEAKID 482560.0 as it's not in marked_images.
# Skipping PEAKID 482569.0 as it's not in marked_images.
# Skipping PEAKID 482690.0 as it's not in marked_images.
# Skipping PEAKID 482695.0 as it's not in marked_images.
# PEAKID: 482771.0
# Center Lat: 35.0130696614999, Center Lon: -52.3041666666999
# Adjusted Height (degrees): 0.8190211852460368
# Bounds: 34.603559068876876 to 35.42258025412292, -52.8041666666999 to -51.8041666666999
# Downloading square image for PEAKID 482771.0 at 35.0130696614999, -52.3041666666999...
# Saved: seamounts_seg\482771.0.png
# Skipping PEAKID 482881.0 as it's not in marked_images.
# Skipping PEAKID 483058.0 as it's not in marked_images.
# Skipping PEAKID 483248.0 as it's not in marked_images.
# Skipping PEAKID 483285.0 as it's not in marked_images.
# Skipping PEAKID 483454.0 as it's not in marked_images.
# Skipping PEAKID 483886.0 as it's not in marked_images.
# Skipping PEAKID 484132.0 as it's not in marked_images.
# PEAKID: 484714.0
# Center Lat: 34.7464029948, Center Lon: -163.779166667
# Adjusted Height (degrees): 0.8216827204825808
# Bounds: 34.33556163455871 to 35.15724435504129, -164.279166667 to -163.279166667
# Downloading square image for PEAKID 484714.0 at 34.7464029948, -163.779166667...
# Saved: seamounts_seg\484714.0.png
# Skipping PEAKID 485144.0 as it's not in marked_images.
# Skipping PEAKID 485600.0 as it's not in marked_images.
# Skipping PEAKID 485617.0 as it's not in marked_images.
# Skipping PEAKID 485632.0 as it's not in marked_images.
# Skipping PEAKID 486131.0 as it's not in marked_images.
# Skipping PEAKID 486719.0 as it's not in marked_images.
# Skipping PEAKID 486890.0 as it's not in marked_images.
# Skipping PEAKID 487049.0 as it's not in marked_images.
# Skipping PEAKID 487163.0 as it's not in marked_images.
# Skipping PEAKID 487886.0 as it's not in marked_images.
# Skipping PEAKID 487916.0 as it's not in marked_images.
# Skipping PEAKID 488328.0 as it's not in marked_images.
# PEAKID: 488767.0
# Center Lat: 34.1464029947999, Center Lon: -176.412499999999
# Adjusted Height (degrees): 0.8276060099683699
# Bounds: 33.73259998981572 to 34.56020599978408, -176.912499999999 to -175.912499999999
# Downloading square image for PEAKID 488767.0 at 34.1464029947999, -176.412499999999...
# Saved: seamounts_seg\488767.0.png
# Skipping PEAKID 488919.0 as it's not in marked_images.
# Skipping PEAKID 489521.0 as it's not in marked_images.
# Skipping PEAKID 490398.0 as it's not in marked_images.
# Skipping PEAKID 490876.0 as it's not in marked_images.
# PEAKID: 491093.0
# Center Lat: 33.8230696615, Center Lon: -14.3841666667
# Adjusted Height (degrees): 0.8307604141915307
# Bounds: 33.407689454404235 to 34.238449868595765, -14.8841666667 to -13.8841666667
# Downloading square image for PEAKID 491093.0 at 33.8230696615, -14.3841666667...
# Saved: seamounts_seg\491093.0.png
# Skipping PEAKID 492189.0 as it's not in marked_images.
# Skipping PEAKID 492678.0 as it's not in marked_images.
# Skipping PEAKID 492784.0 as it's not in marked_images.
# Skipping PEAKID 492805.0 as it's not in marked_images.
# Skipping PEAKID 492859.0 as it's not in marked_images.
# Skipping PEAKID 492968.0 as it's not in marked_images.
# Skipping PEAKID 493200.0 as it's not in marked_images.
# Skipping PEAKID 493537.0 as it's not in marked_images.
# Skipping PEAKID 493698.0 as it's not in marked_images.
# Skipping PEAKID 493776.0 as it's not in marked_images.
# Skipping PEAKID 493884.0 as it's not in marked_images.
# Skipping PEAKID 493984.0 as it's not in marked_images.
# Skipping PEAKID 494102.0 as it's not in marked_images.
# Skipping PEAKID 494132.0 as it's not in marked_images.
# Skipping PEAKID 494133.0 as it's not in marked_images.
# Skipping PEAKID 494191.0 as it's not in marked_images.
# Skipping PEAKID 494273.0 as it's not in marked_images.
# Skipping PEAKID 494672.0 as it's not in marked_images.
# Skipping PEAKID 495197.0 as it's not in marked_images.
# Skipping PEAKID 495294.0 as it's not in marked_images.
# PEAKID: 495762.0
# Center Lat: 33.1880696615, Center Lon: -28.1541666667
# Adjusted Height (degrees): 0.836878310951945
# Bounds: 32.76963050602403 to 33.606508816975975, -28.6541666667 to -27.6541666667
# Downloading square image for PEAKID 495762.0 at 33.1880696615, -28.1541666667...
# Saved: seamounts_seg\495762.0.png
# Skipping PEAKID 496244.0 as it's not in marked_images.
# Skipping PEAKID 497344.0 as it's not in marked_images.
# Skipping PEAKID 498156.0 as it's not in marked_images.
# Skipping PEAKID 498393.0 as it's not in marked_images.
# Skipping PEAKID 498694.0 as it's not in marked_images.
# Skipping PEAKID 498829.0 as it's not in marked_images.
# PEAKID: 498972.0
# Center Lat: 32.7408474392, Center Lon: -54.2013888888999
# Adjusted Height (degrees): 0.841125418751003
# Bounds: 32.3202847298245 to 33.161410148575506, -54.7013888888999 to -53.7013888888999
# Downloading square image for PEAKID 498972.0 at 32.7408474392, -54.2013888888999...
# Saved: seamounts_seg\498972.0.png
# Skipping PEAKID 499037.0 as it's not in marked_images.
# Skipping PEAKID 499277.0 as it's not in marked_images.
# Skipping PEAKID 499391.0 as it's not in marked_images.
# Skipping PEAKID 499833.0 as it's not in marked_images.
# Skipping PEAKID 500132.0 as it's not in marked_images.
# Skipping PEAKID 501776.0 as it's not in marked_images.
# Skipping PEAKID 502193.0 as it's not in marked_images.
# Skipping PEAKID 502194.0 as it's not in marked_images.
# Skipping PEAKID 503867.0 as it's not in marked_images.
# Skipping PEAKID 503917.0 as it's not in marked_images.
# Skipping PEAKID 504136.0 as it's not in marked_images.
# Skipping PEAKID 504304.0 as it's not in marked_images.
# Skipping PEAKID 504526.0 as it's not in marked_images.
# Skipping PEAKID 504528.0 as it's not in marked_images.
# Skipping PEAKID 504529.0 as it's not in marked_images.
# Skipping PEAKID 504712.0 as it's not in marked_images.
# Skipping PEAKID 504819.0 as it's not in marked_images.
# Skipping PEAKID 504944.0 as it's not in marked_images.
# Skipping PEAKID 505395.0 as it's not in marked_images.
# Skipping PEAKID 505482.0 as it's not in marked_images.
# Skipping PEAKID 506352.0 as it's not in marked_images.
# Skipping PEAKID 506768.0 as it's not in marked_images.
# Skipping PEAKID 506902.0 as it's not in marked_images.
# Skipping PEAKID 507050.0 as it's not in marked_images.
# Skipping PEAKID 507578.0 as it's not in marked_images.
# Skipping PEAKID 507933.0 as it's not in marked_images.
# Skipping PEAKID 508340.0 as it's not in marked_images.
# Skipping PEAKID 508413.0 as it's not in marked_images.
# Skipping PEAKID 508683.0 as it's not in marked_images.
# Skipping PEAKID 508946.0 as it's not in marked_images.
# Skipping PEAKID 509063.0 as it's not in marked_images.
# Skipping PEAKID 509250.0 as it's not in marked_images.
# Skipping PEAKID 509451.0 as it's not in marked_images.
# Skipping PEAKID 509599.0 as it's not in marked_images.
# Skipping PEAKID 509832.0 as it's not in marked_images.
# Skipping PEAKID 510422.0 as it's not in marked_images.
# Skipping PEAKID 510682.0 as it's not in marked_images.
# Skipping PEAKID 511415.0 as it's not in marked_images.
# Skipping PEAKID 511566.0 as it's not in marked_images.
# Skipping PEAKID 511642.0 as it's not in marked_images.
# PEAKID: 512094.0
# Center Lat: 31.1047363281, Center Lon: -13.7041666667
# Adjusted Height (degrees): 0.856224382695168
# Bounds: 30.676624136752416 to 31.532848519447583, -14.2041666667 to -13.2041666667
# Downloading square image for PEAKID 512094.0 at 31.1047363281, -13.7041666667...
# Saved: seamounts_seg\512094.0.png
# Skipping PEAKID 512444.0 as it's not in marked_images.
# Skipping PEAKID 512894.0 as it's not in marked_images.
# PEAKID: 513718.0
# Center Lat: 30.9380696614999, Center Lon: -138.920833332999
# Adjusted Height (degrees): 0.8577234985073862
# Bounds: 30.509207912246207 to 31.36693141075359, -139.420833332999 to -138.420833332999
# Downloading square image for PEAKID 513718.0 at 30.9380696614999, -138.920833332999...
# Saved: seamounts_seg\513718.0.png
# Skipping PEAKID 514369.0 as it's not in marked_images.
# Skipping PEAKID 515210.0 as it's not in marked_images.
# Skipping PEAKID 515371.0 as it's not in marked_images.
# PEAKID: 515426.0
# Center Lat: 30.7630696615, Center Lon: 158.729166666999
# Adjusted Height (degrees): 0.8592897587804947
# Bounds: 30.333424782109756 to 31.192714540890247, 158.229166666999 to 159.229166666999
# Downloading square image for PEAKID 515426.0 at 30.7630696615, 158.729166666999...
# Saved: seamounts_seg\515426.0.png
# Skipping PEAKID 516286.0 as it's not in marked_images.
# Skipping PEAKID 516446.0 as it's not in marked_images.
# Skipping PEAKID 516780.0 as it's not in marked_images.
# Skipping PEAKID 517485.0 as it's not in marked_images.
# Skipping PEAKID 517656.0 as it's not in marked_images.
# Skipping PEAKID 517746.0 as it's not in marked_images.
# Skipping PEAKID 518587.0 as it's not in marked_images.
# Skipping PEAKID 519028.0 as it's not in marked_images.
# Skipping PEAKID 519219.0 as it's not in marked_images.
# Skipping PEAKID 519304.0 as it's not in marked_images.
# Skipping PEAKID 519648.0 as it's not in marked_images.
# Skipping PEAKID 519807.0 as it's not in marked_images.
# Skipping PEAKID 519899.0 as it's not in marked_images.
# Skipping PEAKID 519970.0 as it's not in marked_images.
# Skipping PEAKID 520041.0 as it's not in marked_images.
# Skipping PEAKID 520273.0 as it's not in marked_images.
# Skipping PEAKID 520431.0 as it's not in marked_images.
# Skipping PEAKID 520611.0 as it's not in marked_images.
# Skipping PEAKID 520774.0 as it's not in marked_images.
# Skipping PEAKID 520946.0 as it's not in marked_images.
# PEAKID: 521041.0
# Center Lat: 30.1964029948, Center Lon: -172.7375
# Adjusted Height (degrees): 0.8643063796334798
# Bounds: 29.76424980498326 to 30.62855618461674, -173.2375 to -172.2375
# Downloading square image for PEAKID 521041.0 at 30.1964029948, -172.7375...
# Saved: seamounts_seg\521041.0.png
# Skipping PEAKID 521666.0 as it's not in marked_images.
# PEAKID: 521672.0
# Center Lat: 30.1380696615, Center Lon: 157.349999999999
# Adjusted Height (degrees): 0.864818005355181
# Bounds: 29.70566065882241 to 30.570478664177593, 156.849999999999 to 157.849999999999
# Downloading square image for PEAKID 521672.0 at 30.1380696615, 157.349999999999...
# Saved: seamounts_seg\521672.0.png
# Skipping PEAKID 521683.0 as it's not in marked_images.
# Skipping PEAKID 521783.0 as it's not in marked_images.
# Skipping PEAKID 522259.0 as it's not in marked_images.
# Skipping PEAKID 523042.0 as it's not in marked_images.
# Skipping PEAKID 523121.0 as it's not in marked_images.
# Skipping PEAKID 523859.0 as it's not in marked_images.
# Skipping PEAKID 523942.0 as it's not in marked_images.
# Skipping PEAKID 524135.0 as it's not in marked_images.
# Skipping PEAKID 524424.0 as it's not in marked_images.
# PEAKID: 524508.0
# Center Lat: 29.8519585503, Center Lon: -148.256944444
# Adjusted Height (degrees): 0.8673144168853988
# Bounds: 29.4183013418573 to 30.2856157587427, -148.756944444 to -147.756944444
# Downloading square image for PEAKID 524508.0 at 29.8519585503, -148.256944444...
# Saved: seamounts_seg\524508.0.png
# Skipping PEAKID 524748.0 as it's not in marked_images.
# Skipping PEAKID 524972.0 as it's not in marked_images.
# Skipping PEAKID 525079.0 as it's not in marked_images.
# Skipping PEAKID 525208.0 as it's not in marked_images.
# PEAKID: 525652.0
# Center Lat: 29.7380696614999, Center Lon: 138.795833332999
# Adjusted Height (degrees): 0.8683021196973975
# Bounds: 29.3039186016512 to 30.172220721348598, 138.295833332999 to 139.295833332999
# Downloading square image for PEAKID 525652.0 at 29.7380696614999, 138.795833332999...
# Saved: seamounts_seg\525652.0.png
# Skipping PEAKID 525804.0 as it's not in marked_images.
# Skipping PEAKID 526198.0 as it's not in marked_images.
# Skipping PEAKID 526693.0 as it's not in marked_images.
# Skipping PEAKID 526861.0 as it's not in marked_images.
# Skipping PEAKID 526991.0 as it's not in marked_images.
# Skipping PEAKID 526997.0 as it's not in marked_images.
# Skipping PEAKID 527083.0 as it's not in marked_images.
# Skipping PEAKID 527218.0 as it's not in marked_images.
# Skipping PEAKID 527438.0 as it's not in marked_images.
# Skipping PEAKID 527514.0 as it's not in marked_images.
# Skipping PEAKID 528087.0 as it's not in marked_images.
# Skipping PEAKID 528872.0 as it's not in marked_images.
# Skipping PEAKID 528951.0 as it's not in marked_images.
# Skipping PEAKID 529335.0 as it's not in marked_images.
# Skipping PEAKID 529481.0 as it's not in marked_images.
# Skipping PEAKID 529666.0 as it's not in marked_images.
# Skipping PEAKID 529749.0 as it's not in marked_images.
# Skipping PEAKID 530397.0 as it's not in marked_images.
# Skipping PEAKID 530635.0 as it's not in marked_images.
# Skipping PEAKID 531798.0 as it's not in marked_images.
# Skipping PEAKID 533658.0 as it's not in marked_images.
# Skipping PEAKID 533739.0 as it's not in marked_images.
# Skipping PEAKID 534672.0 as it's not in marked_images.
# Skipping PEAKID 535291.0 as it's not in marked_images.
# Skipping PEAKID 536270.0 as it's not in marked_images.
# Skipping PEAKID 536709.0 as it's not in marked_images.
# Skipping PEAKID 536784.0 as it's not in marked_images.
# Skipping PEAKID 537045.0 as it's not in marked_images.
# Skipping PEAKID 537244.0 as it's not in marked_images.
# Skipping PEAKID 539229.0 as it's not in marked_images.
# Skipping PEAKID 539262.0 as it's not in marked_images.
# Skipping PEAKID 539320.0 as it's not in marked_images.
# Skipping PEAKID 539397.0 as it's not in marked_images.
# Skipping PEAKID 539398.0 as it's not in marked_images.
# Skipping PEAKID 539636.0 as it's not in marked_images.
# Skipping PEAKID 540074.0 as it's not in marked_images.
# Skipping PEAKID 540634.0 as it's not in marked_images.
# Skipping PEAKID 541533.0 as it's not in marked_images.
# PEAKID: 541616.0
# Center Lat: 27.9797363281, Center Lon: -177.954166667
# Adjusted Height (degrees): 0.883113574607103
# Bounds: 27.53817954079645 to 28.42129311540355, -178.454166667 to -177.454166667
# Downloading square image for PEAKID 541616.0 at 27.9797363281, -177.954166667...
# Saved: seamounts_seg\541616.0.png
# Skipping PEAKID 541623.0 as it's not in marked_images.
# Skipping PEAKID 542020.0 as it's not in marked_images.
# Skipping PEAKID 543247.0 as it's not in marked_images.
# Skipping PEAKID 543327.0 as it's not in marked_images.
# Skipping PEAKID 543560.0 as it's not in marked_images.
# Skipping PEAKID 543567.0 as it's not in marked_images.
# Skipping PEAKID 543637.0 as it's not in marked_images.
# Skipping PEAKID 544991.0 as it's not in marked_images.
# Skipping PEAKID 545143.0 as it's not in marked_images.
# Skipping PEAKID 545148.0 as it's not in marked_images.
# Skipping PEAKID 545345.0 as it's not in marked_images.
# Skipping PEAKID 545731.0 as it's not in marked_images.
# Skipping PEAKID 546240.0 as it's not in marked_images.
# Skipping PEAKID 546242.0 as it's not in marked_images.
# Skipping PEAKID 547141.0 as it's not in marked_images.
# Skipping PEAKID 547823.0 as it's not in marked_images.
# Skipping PEAKID 549108.0 as it's not in marked_images.
# Skipping PEAKID 549178.0 as it's not in marked_images.
# PEAKID: 549179.0
# Center Lat: 27.1297363281, Center Lon: -161.479166666999
# Adjusted Height (degrees): 0.8899762583648492
# Bounds: 26.68474819891758 to 27.574724457282425, -161.979166666999 to -160.979166666999
# Downloading square image for PEAKID 549179.0 at 27.1297363281, -161.479166666999...
# Saved: seamounts_seg\549179.0.png
# Skipping PEAKID 549334.0 as it's not in marked_images.
# Skipping PEAKID 549406.0 as it's not in marked_images.
# Skipping PEAKID 550384.0 as it's not in marked_images.
# Skipping PEAKID 550620.0 as it's not in marked_images.
# Skipping PEAKID 550763.0 as it's not in marked_images.
# Skipping PEAKID 550825.0 as it's not in marked_images.
# Skipping PEAKID 551297.0 as it's not in marked_images.
# Skipping PEAKID 551299.0 as it's not in marked_images.
# Skipping PEAKID 551371.0 as it's not in marked_images.
# Skipping PEAKID 551611.0 as it's not in marked_images.
# Skipping PEAKID 551700.0 as it's not in marked_images.
# Skipping PEAKID 552343.0 as it's not in marked_images.
# Skipping PEAKID 552591.0 as it's not in marked_images.
# Skipping PEAKID 552639.0 as it's not in marked_images.
# Skipping PEAKID 553047.0 as it's not in marked_images.
# Skipping PEAKID 553440.0 as it's not in marked_images.
# Skipping PEAKID 553943.0 as it's not in marked_images.
# Skipping PEAKID 554143.0 as it's not in marked_images.
# Skipping PEAKID 554210.0 as it's not in marked_images.
# Skipping PEAKID 554605.0 as it's not in marked_images.
# Skipping PEAKID 554663.0 as it's not in marked_images.
# Skipping PEAKID 555137.0 as it's not in marked_images.
# Skipping PEAKID 555602.0 as it's not in marked_images.
# Skipping PEAKID 555630.0 as it's not in marked_images.
# Skipping PEAKID 556060.0 as it's not in marked_images.
# Skipping PEAKID 556402.0 as it's not in marked_images.
# Skipping PEAKID 556497.0 as it's not in marked_images.
# Skipping PEAKID 556510.0 as it's not in marked_images.
# Skipping PEAKID 556648.0 as it's not in marked_images.
# Skipping PEAKID 556881.0 as it's not in marked_images.
# Skipping PEAKID 557022.0 as it's not in marked_images.
# Skipping PEAKID 557105.0 as it's not in marked_images.
# Skipping PEAKID 557169.0 as it's not in marked_images.
# Skipping PEAKID 557340.0 as it's not in marked_images.
# Skipping PEAKID 557636.0 as it's not in marked_images.
# Skipping PEAKID 557820.0 as it's not in marked_images.
# Skipping PEAKID 557827.0 as it's not in marked_images.
# Skipping PEAKID 557893.0 as it's not in marked_images.
# Skipping PEAKID 558057.0 as it's not in marked_images.
# Skipping PEAKID 558259.0 as it's not in marked_images.
# Skipping PEAKID 558356.0 as it's not in marked_images.
# Skipping PEAKID 558503.0 as it's not in marked_images.
# Skipping PEAKID 558631.0 as it's not in marked_images.
# Skipping PEAKID 558938.0 as it's not in marked_images.
# Skipping PEAKID 558940.0 as it's not in marked_images.
# Skipping PEAKID 559082.0 as it's not in marked_images.
# Skipping PEAKID 559380.0 as it's not in marked_images.
# Skipping PEAKID 559523.0 as it's not in marked_images.
# Skipping PEAKID 559614.0 as it's not in marked_images.
# Skipping PEAKID 559861.0 as it's not in marked_images.
# Skipping PEAKID 559999.0 as it's not in marked_images.
# Skipping PEAKID 560068.0 as it's not in marked_images.
# Skipping PEAKID 560256.0 as it's not in marked_images.
# Skipping PEAKID 560305.0 as it's not in marked_images.
# Skipping PEAKID 560313.0 as it's not in marked_images.
# Skipping PEAKID 560389.0 as it's not in marked_images.
# Skipping PEAKID 560734.0 as it's not in marked_images.
# Skipping PEAKID 560883.0 as it's not in marked_images.
# Skipping PEAKID 561071.0 as it's not in marked_images.
# Skipping PEAKID 561345.0 as it's not in marked_images.
# Skipping PEAKID 561492.0 as it's not in marked_images.
# Skipping PEAKID 561594.0 as it's not in marked_images.
# Skipping PEAKID 561786.0 as it's not in marked_images.
# Skipping PEAKID 561866.0 as it's not in marked_images.
# Skipping PEAKID 561869.0 as it's not in marked_images.
# Skipping PEAKID 561921.0 as it's not in marked_images.
# Skipping PEAKID 561925.0 as it's not in marked_images.
# Skipping PEAKID 562080.0 as it's not in marked_images.
# Skipping PEAKID 562156.0 as it's not in marked_images.
# Skipping PEAKID 562314.0 as it's not in marked_images.
# Skipping PEAKID 562386.0 as it's not in marked_images.
# Skipping PEAKID 562673.0 as it's not in marked_images.
# Skipping PEAKID 562905.0 as it's not in marked_images.
# Skipping PEAKID 563097.0 as it's not in marked_images.
# Skipping PEAKID 563578.0 as it's not in marked_images.
# Skipping PEAKID 563875.0 as it's not in marked_images.
# Skipping PEAKID 563951.0 as it's not in marked_images.
# Skipping PEAKID 564102.0 as it's not in marked_images.
# Skipping PEAKID 564131.0 as it's not in marked_images.
# Skipping PEAKID 564207.0 as it's not in marked_images.
# Skipping PEAKID 564276.0 as it's not in marked_images.
# Skipping PEAKID 564573.0 as it's not in marked_images.
# Skipping PEAKID 564796.0 as it's not in marked_images.
# Skipping PEAKID 565016.0 as it's not in marked_images.
# Skipping PEAKID 565090.0 as it's not in marked_images.
# PEAKID: 565196.0
# Center Lat: 25.3325141059, Center Lon: -19.3819444443999
# Adjusted Height (degrees): 0.9038398878306396
# Bounds: 24.88059416198468 to 25.78443404981532, -19.8819444443999 to -18.8819444443999
# Downloading square image for PEAKID 565196.0 at 25.3325141059, -19.3819444443999...
# Saved: seamounts_seg\565196.0.png
# Skipping PEAKID 565243.0 as it's not in marked_images.
# Skipping PEAKID 565654.0 as it's not in marked_images.
# Skipping PEAKID 566468.0 as it's not in marked_images.
# Skipping PEAKID 566871.0 as it's not in marked_images.
# Skipping PEAKID 567186.0 as it's not in marked_images.
# Skipping PEAKID 567370.0 as it's not in marked_images.
# Skipping PEAKID 567764.0 as it's not in marked_images.
# Skipping PEAKID 567784.0 as it's not in marked_images.
# Skipping PEAKID 568085.0 as it's not in marked_images.
# Skipping PEAKID 568159.0 as it's not in marked_images.
# Skipping PEAKID 568462.0 as it's not in marked_images.
# Skipping PEAKID 569185.0 as it's not in marked_images.
# Skipping PEAKID 569187.0 as it's not in marked_images.
# Skipping PEAKID 569470.0 as it's not in marked_images.
# Skipping PEAKID 569485.0 as it's not in marked_images.
# Skipping PEAKID 569952.0 as it's not in marked_images.
# Skipping PEAKID 570631.0 as it's not in marked_images.
# Skipping PEAKID 570910.0 as it's not in marked_images.
# Skipping PEAKID 572143.0 as it's not in marked_images.
# Skipping PEAKID 572194.0 as it's not in marked_images.
# ...
# Skipping PEAKID 4965543.0 as it's not in marked_images.
# Skipping PEAKID 4965547.0 as it's not in marked_images.
# Skipping PEAKID 4965548.0 as it's not in marked_images.
# Skipping PEAKID 4965798.0 as it's not in marked_images.
# Skipping PEAKID 4966207.0 as it's not in marked_images.
# Skipping PEAKID 4966220.0 as it's not in marked_images.
# Skipping PEAKID 4966221.0 as it's not in marked_images.
# Skipping PEAKID 4966266.0 as it's not in marked_images.
# Skipping PEAKID 4966294.0 as it's not in marked_images.
# Skipping PEAKID 4966329.0 as it's not in marked_images.
# Skipping PEAKID 4966330.0 as it's not in marked_images.
# Skipping PEAKID 4966396.0 as it's not in marked_images.
# Skipping PEAKID 4966485.0 as it's not in marked_images.
# Skipping PEAKID 4966719.0 as it's not in marked_images.
# Skipping PEAKID 4966928.0 as it's not in marked_images.
# Skipping PEAKID 4966973.0 as it's not in marked_images.
# Skipping PEAKID 4966993.0 as it's not in marked_images.
# Skipping PEAKID 4967023.0 as it's not in marked_images.
# Skipping PEAKID 4967024.0 as it's not in marked_images.
# Skipping PEAKID 4967077.0 as it's not in marked_images.
# Skipping PEAKID 4967274.0 as it's not in marked_images.
# Skipping PEAKID 4967303.0 as it's not in marked_images.
# Skipping PEAKID 4967315.0 as it's not in marked_images.
# Skipping PEAKID 4967411.0 as it's not in marked_images.
# Skipping PEAKID 4967689.0 as it's not in marked_images.
# Skipping PEAKID 4967723.0 as it's not in marked_images.
# Skipping PEAKID 4967940.0 as it's not in marked_images.
# Skipping PEAKID 4967941.0 as it's not in marked_images.
# Skipping PEAKID 4968097.0 as it's not in marked_images.
# Skipping PEAKID 4968283.0 as it's not in marked_images.
# Skipping PEAKID 4968428.0 as it's not in marked_images.
# Skipping PEAKID 4968481.0 as it's not in marked_images.
# Skipping PEAKID 4968482.0 as it's not in marked_images.
# Skipping PEAKID 4968662.0 as it's not in marked_images.
# Skipping PEAKID 4968667.0 as it's not in marked_images.
# Skipping PEAKID 4968716.0 as it's not in marked_images.
# Skipping PEAKID 4968729.0 as it's not in marked_images.
# Skipping PEAKID 4968806.0 as it's not in marked_images.
# Skipping PEAKID 4968807.0 as it's not in marked_images.
# Skipping PEAKID 4968819.0 as it's not in marked_images.
# Skipping PEAKID 4968820.0 as it's not in marked_images.
# Skipping PEAKID 4968842.0 as it's not in marked_images.
# Skipping PEAKID 4968844.0 as it's not in marked_images.
# Skipping PEAKID 4968850.0 as it's not in marked_images.
# Skipping PEAKID 4968870.0 as it's not in marked_images.
# Skipping PEAKID 4968993.0 as it's not in marked_images.
# Skipping PEAKID 4968994.0 as it's not in marked_images.
# Skipping PEAKID 4969003.0 as it's not in marked_images.
# Skipping PEAKID 4969004.0 as it's not in marked_images.
# Skipping PEAKID 4969028.0 as it's not in marked_images.
# Skipping PEAKID 4969031.0 as it's not in marked_images.
# Skipping PEAKID 4969032.0 as it's not in marked_images.
# Skipping PEAKID 4969062.0 as it's not in marked_images.
# Skipping PEAKID 4969063.0 as it's not in marked_images.
# Skipping PEAKID 4969071.0 as it's not in marked_images.
# Skipping PEAKID 4969185.0 as it's not in marked_images.
# Skipping PEAKID 4969186.0 as it's not in marked_images.
# Skipping PEAKID 4969285.0 as it's not in marked_images.
# Skipping PEAKID 4969308.0 as it's not in marked_images.
# Skipping PEAKID 4969312.0 as it's not in marked_images.
# Skipping PEAKID 4969314.0 as it's not in marked_images.
# Skipping PEAKID 4969349.0 as it's not in marked_images.
# Skipping PEAKID 4969404.0 as it's not in marked_images.
# Skipping PEAKID 4969405.0 as it's not in marked_images.
# Skipping PEAKID 4969406.0 as it's not in marked_images.
# Skipping PEAKID 4969407.0 as it's not in marked_images.
# Skipping PEAKID 4969414.0 as it's not in marked_images.
# Skipping PEAKID 4969506.0 as it's not in marked_images.
# Skipping PEAKID 4969565.0 as it's not in marked_images.
# Skipping PEAKID 4969620.0 as it's not in marked_images.
# Skipping PEAKID 4969621.0 as it's not in marked_images.
# Skipping PEAKID 4969715.0 as it's not in marked_images.
# Skipping PEAKID 4969868.0 as it's not in marked_images.
# Skipping PEAKID 4969927.0 as it's not in marked_images.
# Skipping PEAKID 4969965.0 as it's not in marked_images.
# Skipping PEAKID 4970186.0 as it's not in marked_images.
# Skipping PEAKID 4970210.0 as it's not in marked_images.
# Skipping PEAKID 4970246.0 as it's not in marked_images.
# Skipping PEAKID 4970346.0 as it's not in marked_images.
# Skipping PEAKID 4970417.0 as it's not in marked_images.
# Skipping PEAKID 4970704.0 as it's not in marked_images.
# Skipping PEAKID 4970738.0 as it's not in marked_images.
# Skipping PEAKID 4970856.0 as it's not in marked_images.
# Skipping PEAKID 4970920.0 as it's not in marked_images.
# Skipping PEAKID 4970964.0 as it's not in marked_images.
# Skipping PEAKID 4971067.0 as it's not in marked_images.
# Skipping PEAKID 4971120.0 as it's not in marked_images.
# Skipping PEAKID 4971121.0 as it's not in marked_images.
# Skipping PEAKID 4971127.0 as it's not in marked_images.
# Skipping PEAKID 4971128.0 as it's not in marked_images.
# Skipping PEAKID 4971172.0 as it's not in marked_images.
# Skipping PEAKID 4971183.0 as it's not in marked_images.
# Skipping PEAKID 4971218.0 as it's not in marked_images.
# Skipping PEAKID 4971256.0 as it's not in marked_images.
# Skipping PEAKID 4971326.0 as it's not in marked_images.
# Skipping PEAKID 4971356.0 as it's not in marked_images.
# Skipping PEAKID 4971392.0 as it's not in marked_images.
# Skipping PEAKID 4971419.0 as it's not in marked_images.
# Skipping PEAKID 4971420.0 as it's not in marked_images.
# Skipping PEAKID 4971481.0 as it's not in marked_images.
# Skipping PEAKID 4971486.0 as it's not in marked_images.
# Skipping PEAKID 4971536.0 as it's not in marked_images.
# Skipping PEAKID 4971725.0 as it's not in marked_images.
# Skipping PEAKID 4971729.0 as it's not in marked_images.
# Skipping PEAKID 4971767.0 as it's not in marked_images.
# Skipping PEAKID 4971822.0 as it's not in marked_images.
# Skipping PEAKID 4971847.0 as it's not in marked_images.
# Skipping PEAKID 4972102.0 as it's not in marked_images.
# Skipping PEAKID 4972141.0 as it's not in marked_images.
# Skipping PEAKID 4972337.0 as it's not in marked_images.
# Skipping PEAKID 4972830.0 as it's not in marked_images.
# Skipping PEAKID 4973086.0 as it's not in marked_images.
# Skipping PEAKID 4973199.0 as it's not in marked_images.
# Skipping PEAKID 4973223.0 as it's not in marked_images.
# Skipping PEAKID 4973300.0 as it's not in marked_images.
# Skipping PEAKID 4973413.0 as it's not in marked_images.
# Skipping PEAKID 4973647.0 as it's not in marked_images.
# Skipping PEAKID 4973700.0 as it's not in marked_images.
# Skipping PEAKID 4973758.0 as it's not in marked_images.
# Skipping PEAKID 4973848.0 as it's not in marked_images.
# Skipping PEAKID 4973973.0 as it's not in marked_images.
# Skipping PEAKID 4974014.0 as it's not in marked_images.
# Skipping PEAKID 4974047.0 as it's not in marked_images.
# Skipping PEAKID 4974147.0 as it's not in marked_images.
# Skipping PEAKID 4974148.0 as it's not in marked_images.
# Skipping PEAKID 4974197.0 as it's not in marked_images.
# Skipping PEAKID 4974198.0 as it's not in marked_images.
# Skipping PEAKID 4974262.0 as it's not in marked_images.
# Skipping PEAKID 4974389.0 as it's not in marked_images.
# Skipping PEAKID 4974581.0 as it's not in marked_images.
# Skipping PEAKID 4974599.0 as it's not in marked_images.
# Skipping PEAKID 4974620.0 as it's not in marked_images.
# Skipping PEAKID 4974756.0 as it's not in marked_images.
# Skipping PEAKID 4974851.0 as it's not in marked_images.
# Skipping PEAKID 4974899.0 as it's not in marked_images.
# Skipping PEAKID 4975050.0 as it's not in marked_images.
# Skipping PEAKID 4975051.0 as it's not in marked_images.
# Skipping PEAKID 4975081.0 as it's not in marked_images.
# Skipping PEAKID 4975123.0 as it's not in marked_images.
# Skipping PEAKID 4975124.0 as it's not in marked_images.
# Skipping PEAKID 4975125.0 as it's not in marked_images.
# Skipping PEAKID 4975126.0 as it's not in marked_images.
# Skipping PEAKID 4975360.0 as it's not in marked_images.
# Skipping PEAKID 4975398.0 as it's not in marked_images.
# Skipping PEAKID 4975514.0 as it's not in marked_images.
# Skipping PEAKID 4975515.0 as it's not in marked_images.
# Skipping PEAKID 4976415.0 as it's not in marked_images.
# Skipping PEAKID 4976630.0 as it's not in marked_images.
# Skipping PEAKID 4976686.0 as it's not in marked_images.
# Skipping PEAKID 4976808.0 as it's not in marked_images.
# Skipping PEAKID 4977040.0 as it's not in marked_images.
# Skipping PEAKID 4977089.0 as it's not in marked_images.
# Skipping PEAKID 4977201.0 as it's not in marked_images.
# Skipping PEAKID 4977222.0 as it's not in marked_images.
# Skipping PEAKID 4977298.0 as it's not in marked_images.
# Skipping PEAKID 4977389.0 as it's not in marked_images.
# Skipping PEAKID 4977451.0 as it's not in marked_images.
# Skipping PEAKID 4977895.0 as it's not in marked_images.
# Skipping PEAKID 4977987.0 as it's not in marked_images.
# Skipping PEAKID 4978271.0 as it's not in marked_images.
# Skipping PEAKID 4978272.0 as it's not in marked_images.
# Skipping PEAKID 4978394.0 as it's not in marked_images.
# Skipping PEAKID 4978395.0 as it's not in marked_images.
# Skipping PEAKID 4978397.0 as it's not in marked_images.
# Skipping PEAKID 4978436.0 as it's not in marked_images.
# Skipping PEAKID 4978437.0 as it's not in marked_images.
# Skipping PEAKID 4978438.0 as it's not in marked_images.
# Skipping PEAKID 4978460.0 as it's not in marked_images.
# Skipping PEAKID 4978544.0 as it's not in marked_images.
# Skipping PEAKID 4978545.0 as it's not in marked_images.
# Skipping PEAKID 4978579.0 as it's not in marked_images.
# Skipping PEAKID 4978580.0 as it's not in marked_images.
# Skipping PEAKID 4978581.0 as it's not in marked_images.
# Skipping PEAKID 4978582.0 as it's not in marked_images.
# Skipping PEAKID 4978898.0 as it's not in marked_images.
# Skipping PEAKID 4979251.0 as it's not in marked_images.
# Skipping PEAKID 4979327.0 as it's not in marked_images.
# Skipping PEAKID 4979328.0 as it's not in marked_images.
# Skipping PEAKID 4979374.0 as it's not in marked_images.
# Skipping PEAKID 4979375.0 as it's not in marked_images.
# Skipping PEAKID 4979376.0 as it's not in marked_images.
# Skipping PEAKID 4979377.0 as it's not in marked_images.
# Skipping PEAKID 4979378.0 as it's not in marked_images.
# Skipping PEAKID 4979447.0 as it's not in marked_images.
# Skipping PEAKID 4979494.0 as it's not in marked_images.
# Skipping PEAKID 4979495.0 as it's not in marked_images.
# Skipping PEAKID 4979523.0 as it's not in marked_images.
# Skipping PEAKID 4979525.0 as it's not in marked_images.
# Skipping PEAKID 4979526.0 as it's not in marked_images.
# Skipping PEAKID 4979561.0 as it's not in marked_images.
# Skipping PEAKID 4979596.0 as it's not in marked_images.
# Skipping PEAKID 4979718.0 as it's not in marked_images.
# Skipping PEAKID 4979759.0 as it's not in marked_images.
# Skipping PEAKID 4980288.0 as it's not in marked_images.
# Skipping PEAKID 4980289.0 as it's not in marked_images.
# Skipping PEAKID 4980324.0 as it's not in marked_images.
# Skipping PEAKID 4980396.0 as it's not in marked_images.
# Skipping PEAKID 4980397.0 as it's not in marked_images.
# Skipping PEAKID 4980509.0 as it's not in marked_images.
# Skipping PEAKID 4980545.0 as it's not in marked_images.
# Skipping PEAKID 4980546.0 as it's not in marked_images.
# Skipping PEAKID 4980588.0 as it's not in marked_images.
# Skipping PEAKID 4980589.0 as it's not in marked_images.
# Skipping PEAKID 4980619.0 as it's not in marked_images.
# Skipping PEAKID 4980620.0 as it's not in marked_images.
# Skipping PEAKID 4980622.0 as it's not in marked_images.
# Skipping PEAKID 4980665.0 as it's not in marked_images.
# Skipping PEAKID 4980666.0 as it's not in marked_images.
# Skipping PEAKID 4980687.0 as it's not in marked_images.
# Skipping PEAKID 4980721.0 as it's not in marked_images.
# Skipping PEAKID 4980768.0 as it's not in marked_images.
# Skipping PEAKID 4980805.0 as it's not in marked_images.
# Skipping PEAKID 4980806.0 as it's not in marked_images.
# Skipping PEAKID 4980807.0 as it's not in marked_images.
# Skipping PEAKID 4980808.0 as it's not in marked_images.
# Skipping PEAKID 4980865.0 as it's not in marked_images.
# Skipping PEAKID 4980992.0 as it's not in marked_images.
# Skipping PEAKID 4981142.0 as it's not in marked_images.
# Skipping PEAKID 4981170.0 as it's not in marked_images.
# Skipping PEAKID 4981212.0 as it's not in marked_images.
# Skipping PEAKID 4981279.0 as it's not in marked_images.
# Skipping PEAKID 4981316.0 as it's not in marked_images.
# Skipping PEAKID 4981317.0 as it's not in marked_images.
# Skipping PEAKID 4981318.0 as it's not in marked_images.
# Skipping PEAKID 4981319.0 as it's not in marked_images.
# Skipping PEAKID 4981320.0 as it's not in marked_images.
# Skipping PEAKID 4981321.0 as it's not in marked_images.
# Skipping PEAKID 4981522.0 as it's not in marked_images.
# Skipping PEAKID 4981601.0 as it's not in marked_images.
# Skipping PEAKID 4981634.0 as it's not in marked_images.
# Skipping PEAKID 4981733.0 as it's not in marked_images.
# Skipping PEAKID 4981765.0 as it's not in marked_images.
# Skipping PEAKID 4981766.0 as it's not in marked_images.
# Skipping PEAKID 4981955.0 as it's not in marked_images.
# Skipping PEAKID 4981991.0 as it's not in marked_images.
# Skipping PEAKID 4981992.0 as it's not in marked_images.
# Skipping PEAKID 4982240.0 as it's not in marked_images.
# Skipping PEAKID 4983035.0 as it's not in marked_images.
# Skipping PEAKID 4983070.0 as it's not in marked_images.
# Skipping PEAKID 4983211.0 as it's not in marked_images.
# Skipping PEAKID 4984099.0 as it's not in marked_images.
# Skipping PEAKID 4984208.0 as it's not in marked_images.
# Skipping PEAKID 4984623.0 as it's not in marked_images.
# Skipping PEAKID 4984651.0 as it's not in marked_images.
# Skipping PEAKID 4984652.0 as it's not in marked_images.
# Skipping PEAKID 4984871.0 as it's not in marked_images.
# Skipping PEAKID 4984872.0 as it's not in marked_images.
# Skipping PEAKID 4985205.0 as it's not in marked_images.
# Skipping PEAKID 4986245.0 as it's not in marked_images.
# Skipping PEAKID 4986336.0 as it's not in marked_images.
# Skipping PEAKID 4987585.0 as it's not in marked_images.
# Skipping PEAKID 4987621.0 as it's not in marked_images.
# Skipping PEAKID 4988894.0 as it's not in marked_images.
# Skipping PEAKID 4989109.0 as it's not in marked_images.
# Skipping PEAKID 4989110.0 as it's not in marked_images.
# Skipping PEAKID 4989111.0 as it's not in marked_images.
# Skipping PEAKID 4989112.0 as it's not in marked_images.
# Skipping PEAKID 4989113.0 as it's not in marked_images.
# Skipping PEAKID 4989114.0 as it's not in marked_images.
# Skipping PEAKID 4989115.0 as it's not in marked_images.
# Skipping PEAKID 4989116.0 as it's not in marked_images.
# Skipping PEAKID 4989117.0 as it's not in marked_images.
# Skipping PEAKID 4989118.0 as it's not in marked_images.
# Skipping PEAKID 4991382.0 as it's not in marked_images.
# Skipping PEAKID 4991716.0 as it's not in marked_images.
# Skipping PEAKID 4991717.0 as it's not in marked_images.
# Skipping PEAKID 4991747.0 as it's not in marked_images.
# Skipping PEAKID 4992057.0 as it's not in marked_images.
# Skipping PEAKID 4992572.0 as it's not in marked_images.
# Skipping PEAKID 4995709.0 as it's not in marked_images.
# Skipping PEAKID 4995771.0 as it's not in marked_images.
# Skipping PEAKID 4995794.0 as it's not in marked_images.
# Skipping PEAKID 4995795.0 as it's not in marked_images.
# Skipping PEAKID 4997350.0 as it's not in marked_images.
# Skipping PEAKID 4997394.0 as it's not in marked_images.
# Skipping PEAKID 4997425.0 as it's not in marked_images.
# Skipping PEAKID 4998392.0 as it's not in marked_images.
# Skipping PEAKID 4998393.0 as it's not in marked_images.
# Skipping PEAKID 4998479.0 as it's not in marked_images.
# Skipping PEAKID 4999095.0 as it's not in marked_images.
# Skipping PEAKID 4999430.0 as it's not in marked_images.
# Skipping PEAKID 4999462.0 as it's not in marked_images.
# Skipping PEAKID 4999913.0 as it's not in marked_images.
# Skipping PEAKID 5000862.0 as it's not in marked_images.
# Skipping PEAKID 5000879.0 as it's not in marked_images.
# Download complete.

# %% [markdown]
# To load more seamounts, it would be necessary to find out the highest number in the image titles, then to modify the .csv to only contain the seamounts after that and then to run the above script again.

# %% [markdown]
# ## Filter high-res data

# %%
import cv2
import os
import numpy as np

def crop_fixed_border(image, crop_pixels=70):
    """Crop a fixed number of pixels from each border."""
    height, width, _ = image.shape
    if height > crop_pixels * 2 and width > crop_pixels * 2:
        return image[crop_pixels:height-crop_pixels, crop_pixels:width-crop_pixels]
    else:
        print(f"Warning: Crop size too large for image {width}x{height}. Returning original image.")
        return image

def detect_blur(image, threshold=100.0):
    """Detect if an image is blurry using the variance of the Laplacian."""
    # Compute the Laplacian variance
    laplacian_var = cv2.Laplacian(image, cv2.CV_64F).var()
    is_blurry = laplacian_var < threshold
    return laplacian_var, is_blurry

def process_images(input_folder, high_res_folder, low_res_folder, crop_pixels=70, threshold=100.0):
    """Process images: crop, detect blur, and organize into folders."""
    os.makedirs(high_res_folder, exist_ok=True)
    os.makedirs(low_res_folder, exist_ok=True)

    log = []
    for filename in os.listdir(input_folder):
        file_path = os.path.join(input_folder, filename)
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.tif')):
            try:
                # Load the image
                image = cv2.imread(file_path)
                if image is None:
                    print(f"Image {file_path} is corrupt or unreadable.")
                    continue
                
                # Crop the image
                cropped_image = crop_fixed_border(image, crop_pixels)
                
                # Convert to grayscale for sharpness detection
                gray_image = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2GRAY)
                
                # Detect blur
                lap_var, is_blurry = detect_blur(gray_image, threshold)
                log.append((filename, lap_var, is_blurry))
                
                # Move files to the appropriate folder
                if is_blurry:
                    os.rename(file_path, os.path.join(low_res_folder, filename))
                else:
                    os.rename(file_path, os.path.join(high_res_folder, filename))
            
            except Exception as e:
                print(f"Error processing {file_path}: {e}")

    # Save log to a CSV file
    with open(os.path.join(high_res_folder, 'log.csv'), 'w') as log_file:
        log_file.write('Filename,Laplacian Variance,Blurry\n')
        for entry in log:
            log_file.write(f"{entry[0]},{entry[1]:.2f},{entry[2]}\n")

# Example usage
input_folder = './seamounts_galore'
high_res_folder = './seamounts_galore/high_res'
low_res_folder = './seamounts_galore/low_res'
process_images(input_folder, high_res_folder, low_res_folder, crop_pixels=70, threshold=150.0)
