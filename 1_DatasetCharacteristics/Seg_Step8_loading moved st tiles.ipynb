# %% [markdown]
# Key functionality: downloads moved tiles so that the mount is not always in the center

# %% [markdown]
# ## Download data

# %%
import os
import requests
import pandas as pd
import math
import random

# Parameters
seamounts_csv = "seamounts.csv"  # Path to the .csv file with seamount data
marked_images_folder = "marked_images"  # Folder containing already marked images
existing_tiles_folder = "seamounts_seg"  # Folder with existing downloaded tiles
output_folder = "seamounts_moved"  # Folder to save newly positioned images
bbox_csv = "merged_pixel_coordinates.csv"  # CSV file with bounding box coordinates
tile_pixels = 800  # Width and height of the image in pixels
tile_width_deg = 1.0  # Fixed width in degrees
api_base_url = "https://www.gmrt.org/services/ImageServer"

# Correction percentages for bounding box shifts
mod_w_pct = 0.3  # Reduce width shift by % of the calculated shift
mod_h_pct = 0.3  # Reduce height shift by % of the calculated shift

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# Load seamounts CSV
try:
    seamounts_df = pd.read_csv(seamounts_csv)
    print(f"Loaded {len(seamounts_df)} records from {seamounts_csv}.")
except Exception as e:
    print(f"Error loading seamounts CSV: {e}")
    exit()

# Load bounding box CSV
try:
    bbox_df = pd.read_csv(bbox_csv)
    print(f"Loaded {len(bbox_df)} bounding box records from {bbox_csv}.")
except Exception as e:
    print(f"Error loading bounding box CSV: {e}")
    exit()

# Function to calculate new bounding box coordinates
def adjust_bounding_box(bbox, width_shift_pct, height_shift_pct, mod_w_pct, mod_h_pct):
    """
    Adjust bounding box coordinates based on shifts in tile center,
    applying percentage-based corrections.
    """
    # Apply corrections to shifts
    corrected_width_shift = width_shift_pct * (1 - mod_w_pct)
    corrected_height_shift = height_shift_pct * (1 - mod_h_pct)

    shift_x = corrected_width_shift * tile_pixels
    shift_y = corrected_height_shift * tile_pixels

    new_bbox = {
        "x_min": bbox["x_min"] + shift_x,
        "y_min": bbox["y_min"] + shift_y,
        "x_max": bbox["x_max"] + shift_x,
        "y_max": bbox["y_max"] + shift_y,
    }
    return new_bbox

# Process each existing tile
for index, row in bbox_df.iterrows():
    try:
        # Extract data
        file_name = row["image_name"]
        if not os.path.exists(os.path.join(existing_tiles_folder, file_name)):
            print(f"Skipping {file_name} as it is not found in {existing_tiles_folder}.")
            continue

        # Parse bounding box
        bbox = {
            "x_min": row["x_min"],
            "y_min": row["y_min"],
            "x_max": row["x_max"],
            "y_max": row["y_max"],
        }

        # Match image_name with seamounts.csv to get geographical center
        peak_id = file_name.split(".")[0]
        seamount_row = seamounts_df[seamounts_df["PEAKID"] == float(peak_id)]
        if seamount_row.empty:
            print(f"Skipping {file_name} as it has no matching entry in {seamounts_csv}.")
            continue

        center_lon = float(seamount_row["LONG"].values[0])
        center_lat = float(seamount_row["LAT"].values[0])

        # Compute tile dimensions
        adjusted_height_deg = tile_width_deg * math.cos(math.radians(center_lat))

        # Generate 4 new tile positions
        for i in range(4):
            width_shift_pct = random.uniform(-0.15, 0.15)
            height_shift_pct = random.uniform(-0.15, 0.15)

            # Ensure shifts keep the bounding box within bounds
            new_bbox = adjust_bounding_box(bbox, width_shift_pct, height_shift_pct, mod_w_pct, mod_h_pct)
            if (
                new_bbox["x_min"] < 0 or new_bbox["x_max"] > tile_pixels or
                new_bbox["y_min"] < 0 or new_bbox["y_max"] > tile_pixels
            ):
                print(f"Skipping shift {width_shift_pct*100:.1f}%W, {height_shift_pct*100:.1f}%N as it exceeds bounds.")
                continue

            # Calculate new center
            new_center_lon = center_lon - width_shift_pct * tile_width_deg  # Subtract for west, add for east
            new_center_lat = center_lat + height_shift_pct * adjusted_height_deg

            # Download the new tile
            minlatitude = new_center_lat - (adjusted_height_deg / 2)
            maxlatitude = new_center_lat + (adjusted_height_deg / 2)
            minlongitude = new_center_lon - (tile_width_deg / 2)
            maxlongitude = new_center_lon + (tile_width_deg / 2)

            params = {
                "minlatitude": minlatitude,
                "maxlatitude": maxlatitude,
                "minlongitude": minlongitude,
                "maxlongitude": maxlongitude,
                "width": tile_pixels,
                "mask": "false",
                "download": "true",
            }

            new_file_name = f"{file_name.split('.')[0]}_{int(width_shift_pct*100)}W_{int(height_shift_pct*100)}N.png"
            output_file = os.path.join(output_folder, new_file_name)

            print(f"Downloading shifted tile: {new_file_name}...")
            response = requests.get(api_base_url, params=params)

            if response.status_code == 200:
                with open(output_file, "wb") as file:
                    file.write(response.content)
                print(f"Saved: {output_file}")

                # Add new bounding box entry
                new_bbox["image_name"] = new_file_name
                new_bbox_df = pd.DataFrame([new_bbox])  # Create a DataFrame for the new entry
                bbox_df = pd.concat([bbox_df, new_bbox_df], ignore_index=True)

                # Save the updated bounding box CSV after each new file
                bbox_df.to_csv(bbox_csv, index=False)
                print(f"Updated bounding box CSV saved after processing {new_file_name}.")
            else:
                print(f"Failed to download {new_file_name} - HTTP {response.status_code}")

    except Exception as e:
        print(f"Error processing {file_name}: {e}")
# Out:
# Loaded 33452 records from seamounts.csv.
# Loaded 500 bounding box records from merged_pixel_coordinates.csv.
# Downloading shifted tile: 2388515_0W_9N.png...
# Saved: seamounts_moved/2388515_0W_9N.png
# Updated bounding box CSV saved after processing 2388515_0W_9N.png.
# Downloading shifted tile: 2388515_-10W_6N.png...
# Saved: seamounts_moved/2388515_-10W_6N.png
# Updated bounding box CSV saved after processing 2388515_-10W_6N.png.
# Downloading shifted tile: 2388515_-13W_-7N.png...
# Saved: seamounts_moved/2388515_-13W_-7N.png
# Updated bounding box CSV saved after processing 2388515_-13W_-7N.png.
# Downloading shifted tile: 2388515_-11W_5N.png...
# Saved: seamounts_moved/2388515_-11W_5N.png
# Updated bounding box CSV saved after processing 2388515_-11W_5N.png.
# Downloading shifted tile: 2474327_1W_6N.png...
# Saved: seamounts_moved/2474327_1W_6N.png
# Updated bounding box CSV saved after processing 2474327_1W_6N.png.
# Downloading shifted tile: 2474327_-10W_11N.png...
# Saved: seamounts_moved/2474327_-10W_11N.png
# Updated bounding box CSV saved after processing 2474327_-10W_11N.png.
# Downloading shifted tile: 2474327_13W_-3N.png...
# Saved: seamounts_moved/2474327_13W_-3N.png
# Updated bounding box CSV saved after processing 2474327_13W_-3N.png.
# Downloading shifted tile: 2474327_8W_-10N.png...
# Saved: seamounts_moved/2474327_8W_-10N.png
# Updated bounding box CSV saved after processing 2474327_8W_-10N.png.
# Downloading shifted tile: 2556370_-3W_-10N.png...
# Saved: seamounts_moved/2556370_-3W_-10N.png
# Updated bounding box CSV saved after processing 2556370_-3W_-10N.png.
# Downloading shifted tile: 2556370_-13W_-10N.png...
# Saved: seamounts_moved/2556370_-13W_-10N.png
# Updated bounding box CSV saved after processing 2556370_-13W_-10N.png.
# Downloading shifted tile: 2556370_10W_10N.png...
# Saved: seamounts_moved/2556370_10W_10N.png
# Updated bounding box CSV saved after processing 2556370_10W_10N.png.
# Downloading shifted tile: 2556370_10W_14N.png...
# Saved: seamounts_moved/2556370_10W_14N.png
# Updated bounding box CSV saved after processing 2556370_10W_14N.png.
# Downloading shifted tile: 2660201_-4W_10N.png...
# Saved: seamounts_moved/2660201_-4W_10N.png
# Updated bounding box CSV saved after processing 2660201_-4W_10N.png.
# Downloading shifted tile: 2660201_11W_-6N.png...
# Saved: seamounts_moved/2660201_11W_-6N.png
# Updated bounding box CSV saved after processing 2660201_11W_-6N.png.
# Downloading shifted tile: 2660201_12W_8N.png...
# Saved: seamounts_moved/2660201_12W_8N.png
# Updated bounding box CSV saved after processing 2660201_12W_8N.png.
# Downloading shifted tile: 2660201_5W_12N.png...
# Saved: seamounts_moved/2660201_5W_12N.png
# Updated bounding box CSV saved after processing 2660201_5W_12N.png.
# Downloading shifted tile: 2785016_-4W_-13N.png...
# Saved: seamounts_moved/2785016_-4W_-13N.png
# Updated bounding box CSV saved after processing 2785016_-4W_-13N.png.
# Downloading shifted tile: 2785016_14W_8N.png...
# Saved: seamounts_moved/2785016_14W_8N.png
# Updated bounding box CSV saved after processing 2785016_14W_8N.png.
# Downloading shifted tile: 2785016_-1W_-6N.png...
# Saved: seamounts_moved/2785016_-1W_-6N.png
# Updated bounding box CSV saved after processing 2785016_-1W_-6N.png.
# Downloading shifted tile: 2785016_0W_-10N.png...
# Saved: seamounts_moved/2785016_0W_-10N.png
# Updated bounding box CSV saved after processing 2785016_0W_-10N.png.
# Downloading shifted tile: 2814673_-4W_-8N.png...
# Saved: seamounts_moved/2814673_-4W_-8N.png
# Updated bounding box CSV saved after processing 2814673_-4W_-8N.png.
# Downloading shifted tile: 2814673_9W_11N.png...
# Saved: seamounts_moved/2814673_9W_11N.png
# Updated bounding box CSV saved after processing 2814673_9W_11N.png.
# Downloading shifted tile: 2814673_-3W_-7N.png...
# Saved: seamounts_moved/2814673_-3W_-7N.png
# Updated bounding box CSV saved after processing 2814673_-3W_-7N.png.
# Downloading shifted tile: 2814673_14W_3N.png...
# Saved: seamounts_moved/2814673_14W_3N.png
# Updated bounding box CSV saved after processing 2814673_14W_3N.png.
# Downloading shifted tile: 2848549_5W_13N.png...
# Saved: seamounts_moved/2848549_5W_13N.png
# Updated bounding box CSV saved after processing 2848549_5W_13N.png.
# Downloading shifted tile: 2848549_-8W_-12N.png...
# Saved: seamounts_moved/2848549_-8W_-12N.png
# Updated bounding box CSV saved after processing 2848549_-8W_-12N.png.
# Downloading shifted tile: 2848549_0W_7N.png...
# Saved: seamounts_moved/2848549_0W_7N.png
# Updated bounding box CSV saved after processing 2848549_0W_7N.png.
# Downloading shifted tile: 2848549_-2W_-9N.png...
# Saved: seamounts_moved/2848549_-2W_-9N.png
# Updated bounding box CSV saved after processing 2848549_-2W_-9N.png.
# Downloading shifted tile: 2851391_10W_9N.png...
# Saved: seamounts_moved/2851391_10W_9N.png
# Updated bounding box CSV saved after processing 2851391_10W_9N.png.
# Downloading shifted tile: 2851391_3W_-8N.png...
# Saved: seamounts_moved/2851391_3W_-8N.png
# Updated bounding box CSV saved after processing 2851391_3W_-8N.png.
# Downloading shifted tile: 2851391_0W_-3N.png...
# Saved: seamounts_moved/2851391_0W_-3N.png
# Updated bounding box CSV saved after processing 2851391_0W_-3N.png.
# Downloading shifted tile: 2851391_8W_-8N.png...
# Saved: seamounts_moved/2851391_8W_-8N.png
# Updated bounding box CSV saved after processing 2851391_8W_-8N.png.
# Downloading shifted tile: 2884163_1W_11N.png...
# Saved: seamounts_moved/2884163_1W_11N.png
# Updated bounding box CSV saved after processing 2884163_1W_11N.png.
# Downloading shifted tile: 2884163_-7W_12N.png...
# Saved: seamounts_moved/2884163_-7W_12N.png
# Updated bounding box CSV saved after processing 2884163_-7W_12N.png.
# Downloading shifted tile: 2884163_-9W_13N.png...
# Saved: seamounts_moved/2884163_-9W_13N.png
# Updated bounding box CSV saved after processing 2884163_-9W_13N.png.
# Downloading shifted tile: 2884163_12W_11N.png...
# Saved: seamounts_moved/2884163_12W_11N.png
# Updated bounding box CSV saved after processing 2884163_12W_11N.png.
# Downloading shifted tile: 2946425_5W_-7N.png...
# Saved: seamounts_moved/2946425_5W_-7N.png
# Updated bounding box CSV saved after processing 2946425_5W_-7N.png.
# Downloading shifted tile: 2946425_8W_-2N.png...
# Saved: seamounts_moved/2946425_8W_-2N.png
# Updated bounding box CSV saved after processing 2946425_8W_-2N.png.
# Downloading shifted tile: 2946425_-3W_-2N.png...
# Saved: seamounts_moved/2946425_-3W_-2N.png
# Updated bounding box CSV saved after processing 2946425_-3W_-2N.png.
# Downloading shifted tile: 2946425_5W_-10N.png...
# Saved: seamounts_moved/2946425_5W_-10N.png
# Updated bounding box CSV saved after processing 2946425_5W_-10N.png.
# Downloading shifted tile: 2952050_6W_-14N.png...
# Saved: seamounts_moved/2952050_6W_-14N.png
# Updated bounding box CSV saved after processing 2952050_6W_-14N.png.
# Downloading shifted tile: 2952050_4W_5N.png...
# Saved: seamounts_moved/2952050_4W_5N.png
# Updated bounding box CSV saved after processing 2952050_4W_5N.png.
# Downloading shifted tile: 2952050_9W_5N.png...
# Saved: seamounts_moved/2952050_9W_5N.png
# Updated bounding box CSV saved after processing 2952050_9W_5N.png.
# Downloading shifted tile: 2952050_-9W_-12N.png...
# Saved: seamounts_moved/2952050_-9W_-12N.png
# Updated bounding box CSV saved after processing 2952050_-9W_-12N.png.
# Downloading shifted tile: 2971903_-7W_-11N.png...
# Saved: seamounts_moved/2971903_-7W_-11N.png
# Updated bounding box CSV saved after processing 2971903_-7W_-11N.png.
# Downloading shifted tile: 2971903_10W_9N.png...
# Saved: seamounts_moved/2971903_10W_9N.png
# Updated bounding box CSV saved after processing 2971903_10W_9N.png.
# Downloading shifted tile: 2971903_12W_12N.png...
# Saved: seamounts_moved/2971903_12W_12N.png
# Updated bounding box CSV saved after processing 2971903_12W_12N.png.
# Downloading shifted tile: 2971903_11W_-7N.png...
# Saved: seamounts_moved/2971903_11W_-7N.png
# Updated bounding box CSV saved after processing 2971903_11W_-7N.png.
# Downloading shifted tile: 2979182_-7W_-1N.png...
# Saved: seamounts_moved/2979182_-7W_-1N.png
# Updated bounding box CSV saved after processing 2979182_-7W_-1N.png.
# Downloading shifted tile: 2979182_8W_13N.png...
# Saved: seamounts_moved/2979182_8W_13N.png
# Updated bounding box CSV saved after processing 2979182_8W_13N.png.
# Downloading shifted tile: 2979182_9W_2N.png...
# Saved: seamounts_moved/2979182_9W_2N.png
# Updated bounding box CSV saved after processing 2979182_9W_2N.png.
# Downloading shifted tile: 2979182_0W_-5N.png...
# Saved: seamounts_moved/2979182_0W_-5N.png
# Updated bounding box CSV saved after processing 2979182_0W_-5N.png.
# Downloading shifted tile: 2982979_7W_-9N.png...
# Saved: seamounts_moved/2982979_7W_-9N.png
# Updated bounding box CSV saved after processing 2982979_7W_-9N.png.
# Downloading shifted tile: 2982979_11W_11N.png...
# Saved: seamounts_moved/2982979_11W_11N.png
# Updated bounding box CSV saved after processing 2982979_11W_11N.png.
# Downloading shifted tile: 2982979_2W_-5N.png...
# Saved: seamounts_moved/2982979_2W_-5N.png
# Updated bounding box CSV saved after processing 2982979_2W_-5N.png.
# Downloading shifted tile: 2982979_12W_6N.png...
# Saved: seamounts_moved/2982979_12W_6N.png
# Updated bounding box CSV saved after processing 2982979_12W_6N.png.
# Downloading shifted tile: 3017911_-11W_4N.png...
# Saved: seamounts_moved/3017911_-11W_4N.png
# Updated bounding box CSV saved after processing 3017911_-11W_4N.png.
# Downloading shifted tile: 3017911_-4W_7N.png...
# Saved: seamounts_moved/3017911_-4W_7N.png
# Updated bounding box CSV saved after processing 3017911_-4W_7N.png.
# Downloading shifted tile: 3017911_6W_0N.png...
# Saved: seamounts_moved/3017911_6W_0N.png
# Updated bounding box CSV saved after processing 3017911_6W_0N.png.
# Downloading shifted tile: 3017911_12W_0N.png...
# Saved: seamounts_moved/3017911_12W_0N.png
# Updated bounding box CSV saved after processing 3017911_12W_0N.png.
# Downloading shifted tile: 3024416_10W_-12N.png...
# Saved: seamounts_moved/3024416_10W_-12N.png
# Updated bounding box CSV saved after processing 3024416_10W_-12N.png.
# Downloading shifted tile: 3024416_0W_-3N.png...
# Saved: seamounts_moved/3024416_0W_-3N.png
# Updated bounding box CSV saved after processing 3024416_0W_-3N.png.
# Downloading shifted tile: 3024416_10W_10N.png...
# Saved: seamounts_moved/3024416_10W_10N.png
# Updated bounding box CSV saved after processing 3024416_10W_10N.png.
# Downloading shifted tile: 3024416_-9W_7N.png...
# Saved: seamounts_moved/3024416_-9W_7N.png
# Updated bounding box CSV saved after processing 3024416_-9W_7N.png.
# Downloading shifted tile: 3034731_-5W_-1N.png...
# Saved: seamounts_moved/3034731_-5W_-1N.png
# Updated bounding box CSV saved after processing 3034731_-5W_-1N.png.
# Downloading shifted tile: 3034731_-9W_-8N.png...
# Saved: seamounts_moved/3034731_-9W_-8N.png
# Updated bounding box CSV saved after processing 3034731_-9W_-8N.png.
# Downloading shifted tile: 3034731_-1W_1N.png...
# Saved: seamounts_moved/3034731_-1W_1N.png
# Updated bounding box CSV saved after processing 3034731_-1W_1N.png.
# Downloading shifted tile: 3034731_-10W_-8N.png...
# Saved: seamounts_moved/3034731_-10W_-8N.png
# Updated bounding box CSV saved after processing 3034731_-10W_-8N.png.
# Downloading shifted tile: 3099015_-12W_-6N.png...
# Saved: seamounts_moved/3099015_-12W_-6N.png
# Updated bounding box CSV saved after processing 3099015_-12W_-6N.png.
# Downloading shifted tile: 3099015_-1W_10N.png...
# Saved: seamounts_moved/3099015_-1W_10N.png
# Updated bounding box CSV saved after processing 3099015_-1W_10N.png.
# Downloading shifted tile: 3099015_-2W_-2N.png...
# Saved: seamounts_moved/3099015_-2W_-2N.png
# Updated bounding box CSV saved after processing 3099015_-2W_-2N.png.
# Downloading shifted tile: 3099015_-11W_8N.png...
# Saved: seamounts_moved/3099015_-11W_8N.png
# Updated bounding box CSV saved after processing 3099015_-11W_8N.png.
# Downloading shifted tile: 3109615_14W_-12N.png...
# Saved: seamounts_moved/3109615_14W_-12N.png
# Updated bounding box CSV saved after processing 3109615_14W_-12N.png.
# Downloading shifted tile: 3109615_0W_2N.png...
# Saved: seamounts_moved/3109615_0W_2N.png
# Updated bounding box CSV saved after processing 3109615_0W_2N.png.
# Downloading shifted tile: 3109615_7W_2N.png...
# Saved: seamounts_moved/3109615_7W_2N.png
# Updated bounding box CSV saved after processing 3109615_7W_2N.png.
# Downloading shifted tile: 3109615_-14W_-2N.png...
# Saved: seamounts_moved/3109615_-14W_-2N.png
# Updated bounding box CSV saved after processing 3109615_-14W_-2N.png.
# Downloading shifted tile: 3114058_5W_-9N.png...
# Saved: seamounts_moved/3114058_5W_-9N.png
# Updated bounding box CSV saved after processing 3114058_5W_-9N.png.
# Downloading shifted tile: 3114058_1W_-6N.png...
# Saved: seamounts_moved/3114058_1W_-6N.png
# Updated bounding box CSV saved after processing 3114058_1W_-6N.png.
# Downloading shifted tile: 3114058_14W_-9N.png...
# Saved: seamounts_moved/3114058_14W_-9N.png
# Updated bounding box CSV saved after processing 3114058_14W_-9N.png.
# Downloading shifted tile: 3114058_-2W_5N.png...
# Saved: seamounts_moved/3114058_-2W_5N.png
# Updated bounding box CSV saved after processing 3114058_-2W_5N.png.
# Downloading shifted tile: 3119848_4W_-1N.png...
# Saved: seamounts_moved/3119848_4W_-1N.png
# Updated bounding box CSV saved after processing 3119848_4W_-1N.png.
# Downloading shifted tile: 3119848_-11W_13N.png...
# Saved: seamounts_moved/3119848_-11W_13N.png
# Updated bounding box CSV saved after processing 3119848_-11W_13N.png.
# Downloading shifted tile: 3119848_-2W_-4N.png...
# Saved: seamounts_moved/3119848_-2W_-4N.png
# Updated bounding box CSV saved after processing 3119848_-2W_-4N.png.
# Downloading shifted tile: 3119848_-6W_12N.png...
# Saved: seamounts_moved/3119848_-6W_12N.png
# Updated bounding box CSV saved after processing 3119848_-6W_12N.png.
# Downloading shifted tile: 3131778_7W_9N.png...
# Saved: seamounts_moved/3131778_7W_9N.png
# Updated bounding box CSV saved after processing 3131778_7W_9N.png.
# Downloading shifted tile: 3131778_-13W_10N.png...
# Saved: seamounts_moved/3131778_-13W_10N.png
# Updated bounding box CSV saved after processing 3131778_-13W_10N.png.
# Downloading shifted tile: 3131778_4W_-10N.png...
# Saved: seamounts_moved/3131778_4W_-10N.png
# Updated bounding box CSV saved after processing 3131778_4W_-10N.png.
# Downloading shifted tile: 3131778_-10W_9N.png...
# Saved: seamounts_moved/3131778_-10W_9N.png
# Updated bounding box CSV saved after processing 3131778_-10W_9N.png.
# Downloading shifted tile: 3197462_-1W_1N.png...
# Saved: seamounts_moved/3197462_-1W_1N.png
# Updated bounding box CSV saved after processing 3197462_-1W_1N.png.
# Downloading shifted tile: 3197462_0W_13N.png...
# Saved: seamounts_moved/3197462_0W_13N.png
# Updated bounding box CSV saved after processing 3197462_0W_13N.png.
# Downloading shifted tile: 3197462_0W_13N.png...
# Saved: seamounts_moved/3197462_0W_13N.png
# Updated bounding box CSV saved after processing 3197462_0W_13N.png.
# Downloading shifted tile: 3197462_6W_13N.png...
# Saved: seamounts_moved/3197462_6W_13N.png
# Updated bounding box CSV saved after processing 3197462_6W_13N.png.
# Downloading shifted tile: 3246636_12W_-7N.png...
# Saved: seamounts_moved/3246636_12W_-7N.png
# Updated bounding box CSV saved after processing 3246636_12W_-7N.png.
# Downloading shifted tile: 3246636_6W_-1N.png...
# Saved: seamounts_moved/3246636_6W_-1N.png
# Updated bounding box CSV saved after processing 3246636_6W_-1N.png.
# Downloading shifted tile: 3246636_7W_3N.png...
# Saved: seamounts_moved/3246636_7W_3N.png
# Updated bounding box CSV saved after processing 3246636_7W_3N.png.
# Downloading shifted tile: 3246636_10W_6N.png...
# Saved: seamounts_moved/3246636_10W_6N.png
# Updated bounding box CSV saved after processing 3246636_10W_6N.png.
# Downloading shifted tile: 3251574_5W_-11N.png...
# Saved: seamounts_moved/3251574_5W_-11N.png
# Updated bounding box CSV saved after processing 3251574_5W_-11N.png.
# Downloading shifted tile: 3251574_-9W_7N.png...
# Saved: seamounts_moved/3251574_-9W_7N.png
# Updated bounding box CSV saved after processing 3251574_-9W_7N.png.
# Downloading shifted tile: 3251574_-12W_-6N.png...
# Saved: seamounts_moved/3251574_-12W_-6N.png
# Updated bounding box CSV saved after processing 3251574_-12W_-6N.png.
# Downloading shifted tile: 3251574_-6W_-4N.png...
# Saved: seamounts_moved/3251574_-6W_-4N.png
# Updated bounding box CSV saved after processing 3251574_-6W_-4N.png.
# Downloading shifted tile: 3259376_-3W_-2N.png...
# Saved: seamounts_moved/3259376_-3W_-2N.png
# Updated bounding box CSV saved after processing 3259376_-3W_-2N.png.
# Downloading shifted tile: 3259376_0W_4N.png...
# Saved: seamounts_moved/3259376_0W_4N.png
# Updated bounding box CSV saved after processing 3259376_0W_4N.png.
# Downloading shifted tile: 3259376_2W_7N.png...
# Saved: seamounts_moved/3259376_2W_7N.png
# Updated bounding box CSV saved after processing 3259376_2W_7N.png.
# Downloading shifted tile: 3259376_-1W_2N.png...
# Saved: seamounts_moved/3259376_-1W_2N.png
# Updated bounding box CSV saved after processing 3259376_-1W_2N.png.
# Downloading shifted tile: 3376684_-12W_-10N.png...
# Saved: seamounts_moved/3376684_-12W_-10N.png
# Updated bounding box CSV saved after processing 3376684_-12W_-10N.png.
# Downloading shifted tile: 3376684_2W_3N.png...
# Saved: seamounts_moved/3376684_2W_3N.png
# Updated bounding box CSV saved after processing 3376684_2W_3N.png.
# Downloading shifted tile: 3376684_14W_4N.png...
# Saved: seamounts_moved/3376684_14W_4N.png
# Updated bounding box CSV saved after processing 3376684_14W_4N.png.
# Downloading shifted tile: 3376684_7W_13N.png...
# Saved: seamounts_moved/3376684_7W_13N.png
# Updated bounding box CSV saved after processing 3376684_7W_13N.png.
# Downloading shifted tile: 3389598_-11W_-11N.png...
# Saved: seamounts_moved/3389598_-11W_-11N.png
# Updated bounding box CSV saved after processing 3389598_-11W_-11N.png.
# Downloading shifted tile: 3389598_7W_9N.png...
# Saved: seamounts_moved/3389598_7W_9N.png
# Updated bounding box CSV saved after processing 3389598_7W_9N.png.
# Downloading shifted tile: 3389598_10W_-9N.png...
# Saved: seamounts_moved/3389598_10W_-9N.png
# Updated bounding box CSV saved after processing 3389598_10W_-9N.png.
# Downloading shifted tile: 3389598_0W_-8N.png...
# Saved: seamounts_moved/3389598_0W_-8N.png
# Updated bounding box CSV saved after processing 3389598_0W_-8N.png.
# Downloading shifted tile: 3422242_8W_-3N.png...
# Saved: seamounts_moved/3422242_8W_-3N.png
# Updated bounding box CSV saved after processing 3422242_8W_-3N.png.
# Downloading shifted tile: 3422242_-13W_9N.png...
# Saved: seamounts_moved/3422242_-13W_9N.png
# Updated bounding box CSV saved after processing 3422242_-13W_9N.png.
# Downloading shifted tile: 3422242_-10W_-7N.png...
# Saved: seamounts_moved/3422242_-10W_-7N.png
# Updated bounding box CSV saved after processing 3422242_-10W_-7N.png.
# Downloading shifted tile: 3422242_9W_-6N.png...
# Saved: seamounts_moved/3422242_9W_-6N.png
# Updated bounding box CSV saved after processing 3422242_9W_-6N.png.
# Downloading shifted tile: 3425210_-9W_6N.png...
# Saved: seamounts_moved/3425210_-9W_6N.png
# Updated bounding box CSV saved after processing 3425210_-9W_6N.png.
# Downloading shifted tile: 3425210_3W_4N.png...
# Saved: seamounts_moved/3425210_3W_4N.png
# Updated bounding box CSV saved after processing 3425210_3W_4N.png.
# Downloading shifted tile: 3425210_2W_3N.png...
# Saved: seamounts_moved/3425210_2W_3N.png
# Updated bounding box CSV saved after processing 3425210_2W_3N.png.
# Downloading shifted tile: 3425210_3W_-7N.png...
# Saved: seamounts_moved/3425210_3W_-7N.png
# Updated bounding box CSV saved after processing 3425210_3W_-7N.png.
# Downloading shifted tile: 3427982_-1W_-6N.png...
# Saved: seamounts_moved/3427982_-1W_-6N.png
# Updated bounding box CSV saved after processing 3427982_-1W_-6N.png.
# Downloading shifted tile: 3427982_13W_-10N.png...
# Saved: seamounts_moved/3427982_13W_-10N.png
# Updated bounding box CSV saved after processing 3427982_13W_-10N.png.
# Downloading shifted tile: 3427982_0W_8N.png...
# Saved: seamounts_moved/3427982_0W_8N.png
# Updated bounding box CSV saved after processing 3427982_0W_8N.png.
# Downloading shifted tile: 3427982_-5W_-1N.png...
# Saved: seamounts_moved/3427982_-5W_-1N.png
# Updated bounding box CSV saved after processing 3427982_-5W_-1N.png.
# Downloading shifted tile: 3443964_-4W_13N.png...
# Saved: seamounts_moved/3443964_-4W_13N.png
# Updated bounding box CSV saved after processing 3443964_-4W_13N.png.
# Downloading shifted tile: 3443964_-12W_-5N.png...
# Saved: seamounts_moved/3443964_-12W_-5N.png
# Updated bounding box CSV saved after processing 3443964_-12W_-5N.png.
# Downloading shifted tile: 3443964_4W_10N.png...
# Saved: seamounts_moved/3443964_4W_10N.png
# Updated bounding box CSV saved after processing 3443964_4W_10N.png.
# Downloading shifted tile: 3443964_13W_-2N.png...
# Saved: seamounts_moved/3443964_13W_-2N.png
# Updated bounding box CSV saved after processing 3443964_13W_-2N.png.
# Downloading shifted tile: 3459203_-14W_2N.png...
# Saved: seamounts_moved/3459203_-14W_2N.png
# Updated bounding box CSV saved after processing 3459203_-14W_2N.png.
# Downloading shifted tile: 3459203_0W_0N.png...
# Saved: seamounts_moved/3459203_0W_0N.png
# Updated bounding box CSV saved after processing 3459203_0W_0N.png.
# Downloading shifted tile: 3459203_8W_1N.png...
# Saved: seamounts_moved/3459203_8W_1N.png
# Updated bounding box CSV saved after processing 3459203_8W_1N.png.
# Downloading shifted tile: 3459203_11W_-6N.png...
# Saved: seamounts_moved/3459203_11W_-6N.png
# Updated bounding box CSV saved after processing 3459203_11W_-6N.png.
# Downloading shifted tile: 3478496_-11W_-3N.png...
# Saved: seamounts_moved/3478496_-11W_-3N.png
# Updated bounding box CSV saved after processing 3478496_-11W_-3N.png.
# Downloading shifted tile: 3478496_4W_-12N.png...
# Saved: seamounts_moved/3478496_4W_-12N.png
# Updated bounding box CSV saved after processing 3478496_4W_-12N.png.
# Downloading shifted tile: 3478496_12W_8N.png...
# Saved: seamounts_moved/3478496_12W_8N.png
# Updated bounding box CSV saved after processing 3478496_12W_8N.png.
# Downloading shifted tile: 3478496_-3W_13N.png...
# Saved: seamounts_moved/3478496_-3W_13N.png
# Updated bounding box CSV saved after processing 3478496_-3W_13N.png.
# Downloading shifted tile: 3499370_1W_2N.png...
# Saved: seamounts_moved/3499370_1W_2N.png
# Updated bounding box CSV saved after processing 3499370_1W_2N.png.
# Downloading shifted tile: 3499370_7W_0N.png...
# Saved: seamounts_moved/3499370_7W_0N.png
# Updated bounding box CSV saved after processing 3499370_7W_0N.png.
# Downloading shifted tile: 3499370_4W_6N.png...
# Saved: seamounts_moved/3499370_4W_6N.png
# Updated bounding box CSV saved after processing 3499370_4W_6N.png.
# Downloading shifted tile: 3499370_7W_-7N.png...
# Saved: seamounts_moved/3499370_7W_-7N.png
# Updated bounding box CSV saved after processing 3499370_7W_-7N.png.
# Downloading shifted tile: 3568758_-3W_-14N.png...
# Saved: seamounts_moved/3568758_-3W_-14N.png
# Updated bounding box CSV saved after processing 3568758_-3W_-14N.png.
# Downloading shifted tile: 3568758_3W_0N.png...
# Saved: seamounts_moved/3568758_3W_0N.png
# Updated bounding box CSV saved after processing 3568758_3W_0N.png.
# Downloading shifted tile: 3568758_-6W_-5N.png...
# Saved: seamounts_moved/3568758_-6W_-5N.png
# Updated bounding box CSV saved after processing 3568758_-6W_-5N.png.
# Downloading shifted tile: 3568758_4W_0N.png...
# Saved: seamounts_moved/3568758_4W_0N.png
# Updated bounding box CSV saved after processing 3568758_4W_0N.png.
# Downloading shifted tile: 3586718_-1W_-2N.png...
# Saved: seamounts_moved/3586718_-1W_-2N.png
# Updated bounding box CSV saved after processing 3586718_-1W_-2N.png.
# Downloading shifted tile: 3586718_3W_6N.png...
# Saved: seamounts_moved/3586718_3W_6N.png
# Updated bounding box CSV saved after processing 3586718_3W_6N.png.
# Downloading shifted tile: 3586718_6W_-13N.png...
# Saved: seamounts_moved/3586718_6W_-13N.png
# Updated bounding box CSV saved after processing 3586718_6W_-13N.png.
# Downloading shifted tile: 3586718_-12W_-2N.png...
# Saved: seamounts_moved/3586718_-12W_-2N.png
# Updated bounding box CSV saved after processing 3586718_-12W_-2N.png.
# Downloading shifted tile: 3589874_0W_-3N.png...
# Saved: seamounts_moved/3589874_0W_-3N.png
# Updated bounding box CSV saved after processing 3589874_0W_-3N.png.
# Downloading shifted tile: 3589874_1W_5N.png...
# Saved: seamounts_moved/3589874_1W_5N.png
# Updated bounding box CSV saved after processing 3589874_1W_5N.png.
# Downloading shifted tile: 3589874_0W_11N.png...
# Saved: seamounts_moved/3589874_0W_11N.png
# Updated bounding box CSV saved after processing 3589874_0W_11N.png.
# Downloading shifted tile: 3589874_0W_0N.png...
# Saved: seamounts_moved/3589874_0W_0N.png
# Updated bounding box CSV saved after processing 3589874_0W_0N.png.
# Downloading shifted tile: 3598273_-14W_-2N.png...
# Saved: seamounts_moved/3598273_-14W_-2N.png
# Updated bounding box CSV saved after processing 3598273_-14W_-2N.png.
# Downloading shifted tile: 3598273_-7W_1N.png...
# Saved: seamounts_moved/3598273_-7W_1N.png
# Updated bounding box CSV saved after processing 3598273_-7W_1N.png.
# Downloading shifted tile: 3598273_-12W_0N.png...
# Saved: seamounts_moved/3598273_-12W_0N.png
# Updated bounding box CSV saved after processing 3598273_-12W_0N.png.
# Downloading shifted tile: 3598273_3W_9N.png...
# Saved: seamounts_moved/3598273_3W_9N.png
# Updated bounding box CSV saved after processing 3598273_3W_9N.png.
# Downloading shifted tile: 3649693_-4W_6N.png...
# Saved: seamounts_moved/3649693_-4W_6N.png
# Updated bounding box CSV saved after processing 3649693_-4W_6N.png.
# Downloading shifted tile: 3649693_-10W_11N.png...
# Saved: seamounts_moved/3649693_-10W_11N.png
# Updated bounding box CSV saved after processing 3649693_-10W_11N.png.
# Downloading shifted tile: 3649693_5W_-6N.png...
# Saved: seamounts_moved/3649693_5W_-6N.png
# Updated bounding box CSV saved after processing 3649693_5W_-6N.png.
# Downloading shifted tile: 3649693_10W_11N.png...
# Saved: seamounts_moved/3649693_10W_11N.png
# Updated bounding box CSV saved after processing 3649693_10W_11N.png.
# Downloading shifted tile: 3695243_-7W_-3N.png...
# Saved: seamounts_moved/3695243_-7W_-3N.png
# Updated bounding box CSV saved after processing 3695243_-7W_-3N.png.
# Downloading shifted tile: 3695243_-7W_-8N.png...
# Saved: seamounts_moved/3695243_-7W_-8N.png
# Updated bounding box CSV saved after processing 3695243_-7W_-8N.png.
# Downloading shifted tile: 3695243_8W_0N.png...
# Saved: seamounts_moved/3695243_8W_0N.png
# Updated bounding box CSV saved after processing 3695243_8W_0N.png.
# Downloading shifted tile: 3695243_4W_0N.png...
# Saved: seamounts_moved/3695243_4W_0N.png
# Updated bounding box CSV saved after processing 3695243_4W_0N.png.
# Downloading shifted tile: 3719367_10W_-10N.png...
# Saved: seamounts_moved/3719367_10W_-10N.png
# Updated bounding box CSV saved after processing 3719367_10W_-10N.png.
# Downloading shifted tile: 3719367_-2W_-1N.png...
# Saved: seamounts_moved/3719367_-2W_-1N.png
# Updated bounding box CSV saved after processing 3719367_-2W_-1N.png.
# Downloading shifted tile: 3719367_1W_-2N.png...
# Saved: seamounts_moved/3719367_1W_-2N.png
# Updated bounding box CSV saved after processing 3719367_1W_-2N.png.
# Downloading shifted tile: 3719367_5W_6N.png...
# Saved: seamounts_moved/3719367_5W_6N.png
# Updated bounding box CSV saved after processing 3719367_5W_6N.png.
# Downloading shifted tile: 3727549_0W_-5N.png...
# Saved: seamounts_moved/3727549_0W_-5N.png
# Updated bounding box CSV saved after processing 3727549_0W_-5N.png.
# Downloading shifted tile: 3727549_-12W_5N.png...
# Saved: seamounts_moved/3727549_-12W_5N.png
# Updated bounding box CSV saved after processing 3727549_-12W_5N.png.
# Downloading shifted tile: 3727549_11W_2N.png...
# Saved: seamounts_moved/3727549_11W_2N.png
# Updated bounding box CSV saved after processing 3727549_11W_2N.png.
# Downloading shifted tile: 3727549_4W_-6N.png...
# Saved: seamounts_moved/3727549_4W_-6N.png
# Updated bounding box CSV saved after processing 3727549_4W_-6N.png.
# Downloading shifted tile: 3773102_-2W_12N.png...
# Saved: seamounts_moved/3773102_-2W_12N.png
# Updated bounding box CSV saved after processing 3773102_-2W_12N.png.
# Downloading shifted tile: 3773102_-1W_5N.png...
# Saved: seamounts_moved/3773102_-1W_5N.png
# Updated bounding box CSV saved after processing 3773102_-1W_5N.png.
# Downloading shifted tile: 3773102_-10W_8N.png...
# Saved: seamounts_moved/3773102_-10W_8N.png
# Updated bounding box CSV saved after processing 3773102_-10W_8N.png.
# Downloading shifted tile: 3773102_-9W_-6N.png...
# Saved: seamounts_moved/3773102_-9W_-6N.png
# Updated bounding box CSV saved after processing 3773102_-9W_-6N.png.
# Downloading shifted tile: 3791733_4W_3N.png...
# Saved: seamounts_moved/3791733_4W_3N.png
# Updated bounding box CSV saved after processing 3791733_4W_3N.png.
# Downloading shifted tile: 3791733_-14W_1N.png...
# Saved: seamounts_moved/3791733_-14W_1N.png
# Updated bounding box CSV saved after processing 3791733_-14W_1N.png.
# Downloading shifted tile: 3791733_10W_14N.png...
# Saved: seamounts_moved/3791733_10W_14N.png
# Updated bounding box CSV saved after processing 3791733_10W_14N.png.
# Downloading shifted tile: 3791733_-4W_6N.png...
# Saved: seamounts_moved/3791733_-4W_6N.png
# Updated bounding box CSV saved after processing 3791733_-4W_6N.png.
# Downloading shifted tile: 3861455_7W_14N.png...
# Saved: seamounts_moved/3861455_7W_14N.png
# Updated bounding box CSV saved after processing 3861455_7W_14N.png.
# Downloading shifted tile: 3861455_0W_-4N.png...
# Saved: seamounts_moved/3861455_0W_-4N.png
# Updated bounding box CSV saved after processing 3861455_0W_-4N.png.
# Downloading shifted tile: 3861455_6W_3N.png...
# Saved: seamounts_moved/3861455_6W_3N.png
# Updated bounding box CSV saved after processing 3861455_6W_3N.png.
# Downloading shifted tile: 3861455_-10W_7N.png...
# Saved: seamounts_moved/3861455_-10W_7N.png
# Updated bounding box CSV saved after processing 3861455_-10W_7N.png.
# Downloading shifted tile: 4085738_-1W_11N.png...
# Saved: seamounts_moved/4085738_-1W_11N.png
# Updated bounding box CSV saved after processing 4085738_-1W_11N.png.
# Downloading shifted tile: 4085738_-8W_-9N.png...
# Saved: seamounts_moved/4085738_-8W_-9N.png
# Updated bounding box CSV saved after processing 4085738_-8W_-9N.png.
# Downloading shifted tile: 4085738_-4W_-6N.png...
# Saved: seamounts_moved/4085738_-4W_-6N.png
# Updated bounding box CSV saved after processing 4085738_-4W_-6N.png.
# Downloading shifted tile: 4085738_-10W_13N.png...
# Saved: seamounts_moved/4085738_-10W_13N.png
# Updated bounding box CSV saved after processing 4085738_-10W_13N.png.
# Downloading shifted tile: 4195974_-8W_-4N.png...
# Saved: seamounts_moved/4195974_-8W_-4N.png
# Updated bounding box CSV saved after processing 4195974_-8W_-4N.png.
# Downloading shifted tile: 4195974_-2W_8N.png...
# Saved: seamounts_moved/4195974_-2W_8N.png
# Updated bounding box CSV saved after processing 4195974_-2W_8N.png.
# Downloading shifted tile: 4195974_0W_6N.png...
# Saved: seamounts_moved/4195974_0W_6N.png
# Updated bounding box CSV saved after processing 4195974_0W_6N.png.
# Downloading shifted tile: 4195974_11W_-14N.png...
# Saved: seamounts_moved/4195974_11W_-14N.png
# Updated bounding box CSV saved after processing 4195974_11W_-14N.png.
# Downloading shifted tile: 4202544_-9W_0N.png...
# Saved: seamounts_moved/4202544_-9W_0N.png
# Updated bounding box CSV saved after processing 4202544_-9W_0N.png.
# Downloading shifted tile: 4202544_12W_-4N.png...
# Saved: seamounts_moved/4202544_12W_-4N.png
# Updated bounding box CSV saved after processing 4202544_12W_-4N.png.
# Downloading shifted tile: 4202544_-12W_3N.png...
# Saved: seamounts_moved/4202544_-12W_3N.png
# Updated bounding box CSV saved after processing 4202544_-12W_3N.png.
# Downloading shifted tile: 4202544_3W_-12N.png...
# Saved: seamounts_moved/4202544_3W_-12N.png
# Updated bounding box CSV saved after processing 4202544_3W_-12N.png.
# Downloading shifted tile: 4239444_-6W_-12N.png...
# Saved: seamounts_moved/4239444_-6W_-12N.png
# Updated bounding box CSV saved after processing 4239444_-6W_-12N.png.
# Downloading shifted tile: 4239444_-3W_-2N.png...
# Saved: seamounts_moved/4239444_-3W_-2N.png
# Updated bounding box CSV saved after processing 4239444_-3W_-2N.png.
# Downloading shifted tile: 4239444_13W_-10N.png...
# Saved: seamounts_moved/4239444_13W_-10N.png
# Updated bounding box CSV saved after processing 4239444_13W_-10N.png.
# Downloading shifted tile: 4239444_13W_-7N.png...
# Saved: seamounts_moved/4239444_13W_-7N.png
# Updated bounding box CSV saved after processing 4239444_13W_-7N.png.
# Downloading shifted tile: 4286077_-9W_6N.png...
# Saved: seamounts_moved/4286077_-9W_6N.png
# Updated bounding box CSV saved after processing 4286077_-9W_6N.png.
# Downloading shifted tile: 4286077_6W_9N.png...
# Saved: seamounts_moved/4286077_6W_9N.png
# Updated bounding box CSV saved after processing 4286077_6W_9N.png.
# Downloading shifted tile: 4286077_-10W_-9N.png...
# Saved: seamounts_moved/4286077_-10W_-9N.png
# Updated bounding box CSV saved after processing 4286077_-10W_-9N.png.
# Downloading shifted tile: 4286077_-2W_6N.png...
# Saved: seamounts_moved/4286077_-2W_6N.png
# Updated bounding box CSV saved after processing 4286077_-2W_6N.png.
# Downloading shifted tile: 4339439_14W_-9N.png...
# Saved: seamounts_moved/4339439_14W_-9N.png
# Updated bounding box CSV saved after processing 4339439_14W_-9N.png.
# Downloading shifted tile: 4339439_3W_-6N.png...
# Saved: seamounts_moved/4339439_3W_-6N.png
# Updated bounding box CSV saved after processing 4339439_3W_-6N.png.
# Downloading shifted tile: 4339439_-3W_12N.png...
# Saved: seamounts_moved/4339439_-3W_12N.png
# Updated bounding box CSV saved after processing 4339439_-3W_12N.png.
# Downloading shifted tile: 4339439_7W_4N.png...
# Saved: seamounts_moved/4339439_7W_4N.png
# Updated bounding box CSV saved after processing 4339439_7W_4N.png.
# Downloading shifted tile: 4388465_2W_4N.png...
# Saved: seamounts_moved/4388465_2W_4N.png
# Updated bounding box CSV saved after processing 4388465_2W_4N.png.
# Downloading shifted tile: 4388465_8W_-1N.png...
# Saved: seamounts_moved/4388465_8W_-1N.png
# Updated bounding box CSV saved after processing 4388465_8W_-1N.png.
# Downloading shifted tile: 4388465_7W_-1N.png...
# Saved: seamounts_moved/4388465_7W_-1N.png
# Updated bounding box CSV saved after processing 4388465_7W_-1N.png.
# Downloading shifted tile: 4388465_-2W_-1N.png...
# Saved: seamounts_moved/4388465_-2W_-1N.png
# Updated bounding box CSV saved after processing 4388465_-2W_-1N.png.
# Downloading shifted tile: 4512941_7W_2N.png...
# Saved: seamounts_moved/4512941_7W_2N.png
# Updated bounding box CSV saved after processing 4512941_7W_2N.png.
# Downloading shifted tile: 4512941_-14W_10N.png...
# Saved: seamounts_moved/4512941_-14W_10N.png
# Updated bounding box CSV saved after processing 4512941_-14W_10N.png.
# Downloading shifted tile: 4512941_-12W_-11N.png...
# Saved: seamounts_moved/4512941_-12W_-11N.png
# Updated bounding box CSV saved after processing 4512941_-12W_-11N.png.
# Downloading shifted tile: 4512941_14W_4N.png...
# Saved: seamounts_moved/4512941_14W_4N.png
# Updated bounding box CSV saved after processing 4512941_14W_4N.png.
# Downloading shifted tile: 4513875_-14W_-14N.png...
# Saved: seamounts_moved/4513875_-14W_-14N.png
# Updated bounding box CSV saved after processing 4513875_-14W_-14N.png.
# Downloading shifted tile: 4513875_12W_11N.png...
# Saved: seamounts_moved/4513875_12W_11N.png
# Updated bounding box CSV saved after processing 4513875_12W_11N.png.
# Downloading shifted tile: 4513875_-14W_-10N.png...
# Saved: seamounts_moved/4513875_-14W_-10N.png
# Updated bounding box CSV saved after processing 4513875_-14W_-10N.png.
# Downloading shifted tile: 4513875_9W_8N.png...
# Saved: seamounts_moved/4513875_9W_8N.png
# Updated bounding box CSV saved after processing 4513875_9W_8N.png.
# Downloading shifted tile: 4517596_-6W_-14N.png...
# Saved: seamounts_moved/4517596_-6W_-14N.png
# Updated bounding box CSV saved after processing 4517596_-6W_-14N.png.
# Downloading shifted tile: 4517596_-9W_-12N.png...
# Saved: seamounts_moved/4517596_-9W_-12N.png
# Updated bounding box CSV saved after processing 4517596_-9W_-12N.png.
# Downloading shifted tile: 4517596_9W_6N.png...
# Saved: seamounts_moved/4517596_9W_6N.png
# Updated bounding box CSV saved after processing 4517596_9W_6N.png.
# Downloading shifted tile: 4517596_13W_1N.png...
# Saved: seamounts_moved/4517596_13W_1N.png
# Updated bounding box CSV saved after processing 4517596_13W_1N.png.
# Downloading shifted tile: 4525212_-7W_-10N.png...
# Saved: seamounts_moved/4525212_-7W_-10N.png
# Updated bounding box CSV saved after processing 4525212_-7W_-10N.png.
# Downloading shifted tile: 4525212_0W_-4N.png...
# Saved: seamounts_moved/4525212_0W_-4N.png
# Updated bounding box CSV saved after processing 4525212_0W_-4N.png.
# Downloading shifted tile: 4525212_-1W_8N.png...
# Saved: seamounts_moved/4525212_-1W_8N.png
# Updated bounding box CSV saved after processing 4525212_-1W_8N.png.
# Downloading shifted tile: 4525212_4W_-7N.png...
# Saved: seamounts_moved/4525212_4W_-7N.png
# Updated bounding box CSV saved after processing 4525212_4W_-7N.png.
# Downloading shifted tile: 4540426_5W_13N.png...
# Saved: seamounts_moved/4540426_5W_13N.png
# Updated bounding box CSV saved after processing 4540426_5W_13N.png.
# Downloading shifted tile: 4540426_-5W_8N.png...
# Saved: seamounts_moved/4540426_-5W_8N.png
# Updated bounding box CSV saved after processing 4540426_-5W_8N.png.
# Downloading shifted tile: 4540426_-12W_-3N.png...
# Saved: seamounts_moved/4540426_-12W_-3N.png
# Updated bounding box CSV saved after processing 4540426_-12W_-3N.png.
# Downloading shifted tile: 4540426_12W_4N.png...
# Saved: seamounts_moved/4540426_12W_4N.png
# Updated bounding box CSV saved after processing 4540426_12W_4N.png.
# Downloading shifted tile: 4548566_-6W_2N.png...
# Saved: seamounts_moved/4548566_-6W_2N.png
# Updated bounding box CSV saved after processing 4548566_-6W_2N.png.
# Downloading shifted tile: 4548566_-10W_8N.png...
# Saved: seamounts_moved/4548566_-10W_8N.png
# Updated bounding box CSV saved after processing 4548566_-10W_8N.png.
# Downloading shifted tile: 4548566_-6W_-6N.png...
# Saved: seamounts_moved/4548566_-6W_-6N.png
# Updated bounding box CSV saved after processing 4548566_-6W_-6N.png.
# Downloading shifted tile: 4548566_-5W_-5N.png...
# Saved: seamounts_moved/4548566_-5W_-5N.png
# Updated bounding box CSV saved after processing 4548566_-5W_-5N.png.
# Downloading shifted tile: 4647674_-1W_-4N.png...
# Saved: seamounts_moved/4647674_-1W_-4N.png
# Updated bounding box CSV saved after processing 4647674_-1W_-4N.png.
# Downloading shifted tile: 4647674_13W_10N.png...
# Saved: seamounts_moved/4647674_13W_10N.png
# Updated bounding box CSV saved after processing 4647674_13W_10N.png.
# Downloading shifted tile: 4647674_3W_-7N.png...
# Saved: seamounts_moved/4647674_3W_-7N.png
# Updated bounding box CSV saved after processing 4647674_3W_-7N.png.
# Downloading shifted tile: 4647674_10W_-4N.png...
# Saved: seamounts_moved/4647674_10W_-4N.png
# Updated bounding box CSV saved after processing 4647674_10W_-4N.png.
# Downloading shifted tile: 4647770_-14W_-1N.png...
# Saved: seamounts_moved/4647770_-14W_-1N.png
# Updated bounding box CSV saved after processing 4647770_-14W_-1N.png.
# Downloading shifted tile: 4647770_7W_-3N.png...
# Saved: seamounts_moved/4647770_7W_-3N.png
# Updated bounding box CSV saved after processing 4647770_7W_-3N.png.
# Downloading shifted tile: 4647770_3W_-8N.png...
# Saved: seamounts_moved/4647770_3W_-8N.png
# Updated bounding box CSV saved after processing 4647770_3W_-8N.png.
# Downloading shifted tile: 4647770_-2W_9N.png...
# Saved: seamounts_moved/4647770_-2W_9N.png
# Updated bounding box CSV saved after processing 4647770_-2W_9N.png.
# Downloading shifted tile: 4698037_-4W_6N.png...
# Saved: seamounts_moved/4698037_-4W_6N.png
# Updated bounding box CSV saved after processing 4698037_-4W_6N.png.
# Downloading shifted tile: 4698037_-9W_-4N.png...
# Saved: seamounts_moved/4698037_-9W_-4N.png
# Updated bounding box CSV saved after processing 4698037_-9W_-4N.png.
# Downloading shifted tile: 4698037_13W_0N.png...
# Saved: seamounts_moved/4698037_13W_0N.png
# Updated bounding box CSV saved after processing 4698037_13W_0N.png.
# Downloading shifted tile: 4698037_9W_0N.png...
# Saved: seamounts_moved/4698037_9W_0N.png
# Updated bounding box CSV saved after processing 4698037_9W_0N.png.
# Downloading shifted tile: 4715430_-1W_13N.png...
# Saved: seamounts_moved/4715430_-1W_13N.png
# Updated bounding box CSV saved after processing 4715430_-1W_13N.png.
# Downloading shifted tile: 4715430_-11W_-10N.png...
# Saved: seamounts_moved/4715430_-11W_-10N.png
# Updated bounding box CSV saved after processing 4715430_-11W_-10N.png.
# Downloading shifted tile: 4715430_-12W_-10N.png...
# Saved: seamounts_moved/4715430_-12W_-10N.png
# Updated bounding box CSV saved after processing 4715430_-12W_-10N.png.
# Downloading shifted tile: 4715430_11W_-12N.png...
# Saved: seamounts_moved/4715430_11W_-12N.png
# Updated bounding box CSV saved after processing 4715430_11W_-12N.png.
# Downloading shifted tile: 4800703_10W_13N.png...
# Saved: seamounts_moved/4800703_10W_13N.png
# Updated bounding box CSV saved after processing 4800703_10W_13N.png.
# Downloading shifted tile: 4800703_-4W_9N.png...
# Saved: seamounts_moved/4800703_-4W_9N.png
# Updated bounding box CSV saved after processing 4800703_-4W_9N.png.
# Downloading shifted tile: 4800703_-6W_5N.png...
# Saved: seamounts_moved/4800703_-6W_5N.png
# Updated bounding box CSV saved after processing 4800703_-6W_5N.png.
# Downloading shifted tile: 4800703_9W_12N.png...
# Saved: seamounts_moved/4800703_9W_12N.png
# Updated bounding box CSV saved after processing 4800703_9W_12N.png.
# Downloading shifted tile: 4802577_4W_7N.png...
# Saved: seamounts_moved/4802577_4W_7N.png
# Updated bounding box CSV saved after processing 4802577_4W_7N.png.
# Downloading shifted tile: 4802577_14W_-8N.png...
# Saved: seamounts_moved/4802577_14W_-8N.png
# Updated bounding box CSV saved after processing 4802577_14W_-8N.png.
# Downloading shifted tile: 4802577_-6W_-4N.png...
# Saved: seamounts_moved/4802577_-6W_-4N.png
# Updated bounding box CSV saved after processing 4802577_-6W_-4N.png.
# Downloading shifted tile: 4802577_11W_-11N.png...
# Saved: seamounts_moved/4802577_11W_-11N.png
# Updated bounding box CSV saved after processing 4802577_11W_-11N.png.
# Downloading shifted tile: 4826044_10W_0N.png...
# Saved: seamounts_moved/4826044_10W_0N.png
# Updated bounding box CSV saved after processing 4826044_10W_0N.png.
# Downloading shifted tile: 4826044_5W_1N.png...
# Saved: seamounts_moved/4826044_5W_1N.png
# Updated bounding box CSV saved after processing 4826044_5W_1N.png.
# Downloading shifted tile: 4826044_-9W_12N.png...
# Saved: seamounts_moved/4826044_-9W_12N.png
# Updated bounding box CSV saved after processing 4826044_-9W_12N.png.
# Downloading shifted tile: 4826044_8W_-14N.png...
# Saved: seamounts_moved/4826044_8W_-14N.png
# Updated bounding box CSV saved after processing 4826044_8W_-14N.png.
# Downloading shifted tile: 4917719_13W_-14N.png...
# Saved: seamounts_moved/4917719_13W_-14N.png
# Updated bounding box CSV saved after processing 4917719_13W_-14N.png.
# Downloading shifted tile: 4917719_6W_-6N.png...
# Saved: seamounts_moved/4917719_6W_-6N.png
# Updated bounding box CSV saved after processing 4917719_6W_-6N.png.
# Downloading shifted tile: 4917719_-7W_8N.png...
# Saved: seamounts_moved/4917719_-7W_8N.png
# Updated bounding box CSV saved after processing 4917719_-7W_8N.png.
# Downloading shifted tile: 4917719_6W_-4N.png...
# Saved: seamounts_moved/4917719_6W_-4N.png
# Updated bounding box CSV saved after processing 4917719_6W_-4N.png.
# Downloading shifted tile: 495762_9W_-6N.png...
# Saved: seamounts_moved/495762_9W_-6N.png
# Updated bounding box CSV saved after processing 495762_9W_-6N.png.
# Downloading shifted tile: 495762_7W_-13N.png...
# Saved: seamounts_moved/495762_7W_-13N.png
# Updated bounding box CSV saved after processing 495762_7W_-13N.png.
# Downloading shifted tile: 495762_5W_12N.png...
# Saved: seamounts_moved/495762_5W_12N.png
# Updated bounding box CSV saved after processing 495762_5W_12N.png.
# Downloading shifted tile: 495762_10W_9N.png...
# Saved: seamounts_moved/495762_10W_9N.png
# Updated bounding box CSV saved after processing 495762_10W_9N.png.
# Downloading shifted tile: 541616_5W_3N.png...
# Saved: seamounts_moved/541616_5W_3N.png
# Updated bounding box CSV saved after processing 541616_5W_3N.png.
# Downloading shifted tile: 541616_-2W_-6N.png...
# Saved: seamounts_moved/541616_-2W_-6N.png
# Updated bounding box CSV saved after processing 541616_-2W_-6N.png.
# Downloading shifted tile: 541616_1W_-5N.png...
# Saved: seamounts_moved/541616_1W_-5N.png
# Updated bounding box CSV saved after processing 541616_1W_-5N.png.
# Downloading shifted tile: 541616_-5W_-6N.png...
# Saved: seamounts_moved/541616_-5W_-6N.png
# Updated bounding box CSV saved after processing 541616_-5W_-6N.png.
# Downloading shifted tile: 549179_1W_-9N.png...
# Saved: seamounts_moved/549179_1W_-9N.png
# Updated bounding box CSV saved after processing 549179_1W_-9N.png.
# Downloading shifted tile: 549179_-6W_0N.png...
# Saved: seamounts_moved/549179_-6W_0N.png
# Updated bounding box CSV saved after processing 549179_-6W_0N.png.
# Downloading shifted tile: 549179_-10W_0N.png...
# Saved: seamounts_moved/549179_-10W_0N.png
# Updated bounding box CSV saved after processing 549179_-10W_0N.png.
# Downloading shifted tile: 549179_1W_9N.png...
# Saved: seamounts_moved/549179_1W_9N.png
# Updated bounding box CSV saved after processing 549179_1W_9N.png.
# Downloading shifted tile: 633623_-10W_7N.png...
# Saved: seamounts_moved/633623_-10W_7N.png
# Updated bounding box CSV saved after processing 633623_-10W_7N.png.
# Downloading shifted tile: 633623_3W_8N.png...
# Saved: seamounts_moved/633623_3W_8N.png
# Updated bounding box CSV saved after processing 633623_3W_8N.png.
# Downloading shifted tile: 633623_0W_12N.png...
# Saved: seamounts_moved/633623_0W_12N.png
# Updated bounding box CSV saved after processing 633623_0W_12N.png.
# Downloading shifted tile: 633623_6W_-12N.png...
# Saved: seamounts_moved/633623_6W_-12N.png
# Updated bounding box CSV saved after processing 633623_6W_-12N.png.
# Downloading shifted tile: 660423_0W_0N.png...
# Saved: seamounts_moved/660423_0W_0N.png
# Updated bounding box CSV saved after processing 660423_0W_0N.png.
# Downloading shifted tile: 660423_-5W_-9N.png...
# Saved: seamounts_moved/660423_-5W_-9N.png
# Updated bounding box CSV saved after processing 660423_-5W_-9N.png.
# Downloading shifted tile: 660423_-12W_5N.png...
# Saved: seamounts_moved/660423_-12W_5N.png
# Updated bounding box CSV saved after processing 660423_-12W_5N.png.
# Downloading shifted tile: 660423_-7W_3N.png...
# Saved: seamounts_moved/660423_-7W_3N.png
# Updated bounding box CSV saved after processing 660423_-7W_3N.png.
# Downloading shifted tile: 717269_-5W_-4N.png...
# Saved: seamounts_moved/717269_-5W_-4N.png
# Updated bounding box CSV saved after processing 717269_-5W_-4N.png.
# Downloading shifted tile: 717269_-11W_7N.png...
# Saved: seamounts_moved/717269_-11W_7N.png
# Updated bounding box CSV saved after processing 717269_-11W_7N.png.
# Downloading shifted tile: 717269_10W_3N.png...
# Saved: seamounts_moved/717269_10W_3N.png
# Updated bounding box CSV saved after processing 717269_10W_3N.png.
# Downloading shifted tile: 717269_-11W_-2N.png...
# Saved: seamounts_moved/717269_-11W_-2N.png
# Updated bounding box CSV saved after processing 717269_-11W_-2N.png.
# Downloading shifted tile: 731018_-8W_2N.png...
# Saved: seamounts_moved/731018_-8W_2N.png
# Updated bounding box CSV saved after processing 731018_-8W_2N.png.
# Downloading shifted tile: 731018_14W_7N.png...
# Saved: seamounts_moved/731018_14W_7N.png
# Updated bounding box CSV saved after processing 731018_14W_7N.png.
# Downloading shifted tile: 731018_7W_3N.png...
# Saved: seamounts_moved/731018_7W_3N.png
# Updated bounding box CSV saved after processing 731018_7W_3N.png.
# Downloading shifted tile: 731018_8W_-9N.png...
# Saved: seamounts_moved/731018_8W_-9N.png
# Updated bounding box CSV saved after processing 731018_8W_-9N.png.
# Downloading shifted tile: 731523_-4W_0N.png...
# Saved: seamounts_moved/731523_-4W_0N.png
# Updated bounding box CSV saved after processing 731523_-4W_0N.png.
# Downloading shifted tile: 731523_-9W_14N.png...
# Saved: seamounts_moved/731523_-9W_14N.png
# Updated bounding box CSV saved after processing 731523_-9W_14N.png.
# Downloading shifted tile: 731523_-6W_-3N.png...
# Saved: seamounts_moved/731523_-6W_-3N.png
# Updated bounding box CSV saved after processing 731523_-6W_-3N.png.
# Downloading shifted tile: 731523_-3W_-8N.png...
# Saved: seamounts_moved/731523_-3W_-8N.png
# Updated bounding box CSV saved after processing 731523_-3W_-8N.png.
# Downloading shifted tile: 860355_13W_-4N.png...
# Saved: seamounts_moved/860355_13W_-4N.png
# ...
# Downloading shifted tile: 3557823_4W_-1N.png...
# Saved: seamounts_moved/3557823_4W_-1N.png
# Updated bounding box CSV saved after processing 3557823_4W_-1N.png.
# Downloading shifted tile: 3557823_8W_9N.png...
# Saved: seamounts_moved/3557823_8W_9N.png
# Updated bounding box CSV saved after processing 3557823_8W_9N.png.
# Downloading shifted tile: 3557823_-1W_-9N.png...
# Saved: seamounts_moved/3557823_-1W_-9N.png
# Updated bounding box CSV saved after processing 3557823_-1W_-9N.png.
# Downloading shifted tile: 3557823_-13W_2N.png...
# Saved: seamounts_moved/3557823_-13W_2N.png
# Updated bounding box CSV saved after processing 3557823_-13W_2N.png.
# Downloading shifted tile: 3562248_-2W_-6N.png...
# Saved: seamounts_moved/3562248_-2W_-6N.png
# Updated bounding box CSV saved after processing 3562248_-2W_-6N.png.
# Downloading shifted tile: 3562248_8W_-4N.png...
# Saved: seamounts_moved/3562248_8W_-4N.png
# Updated bounding box CSV saved after processing 3562248_8W_-4N.png.
# Downloading shifted tile: 3562248_9W_0N.png...
# Saved: seamounts_moved/3562248_9W_0N.png
# Updated bounding box CSV saved after processing 3562248_9W_0N.png.
# Downloading shifted tile: 3562248_-12W_-11N.png...
# Saved: seamounts_moved/3562248_-12W_-11N.png
# Updated bounding box CSV saved after processing 3562248_-12W_-11N.png.
# Downloading shifted tile: 3563758_-4W_-10N.png...
# Saved: seamounts_moved/3563758_-4W_-10N.png
# Updated bounding box CSV saved after processing 3563758_-4W_-10N.png.
# Downloading shifted tile: 3563758_0W_-7N.png...
# Saved: seamounts_moved/3563758_0W_-7N.png
# Updated bounding box CSV saved after processing 3563758_0W_-7N.png.
# Downloading shifted tile: 3563758_0W_7N.png...
# Saved: seamounts_moved/3563758_0W_7N.png
# Updated bounding box CSV saved after processing 3563758_0W_7N.png.
# Downloading shifted tile: 3563758_0W_14N.png...
# Saved: seamounts_moved/3563758_0W_14N.png
# Updated bounding box CSV saved after processing 3563758_0W_14N.png.
# Downloading shifted tile: 3565688_4W_11N.png...
# Saved: seamounts_moved/3565688_4W_11N.png
# Updated bounding box CSV saved after processing 3565688_4W_11N.png.
# Downloading shifted tile: 3565688_11W_4N.png...
# Saved: seamounts_moved/3565688_11W_4N.png
# Updated bounding box CSV saved after processing 3565688_11W_4N.png.
# Downloading shifted tile: 3565688_-14W_2N.png...
# Saved: seamounts_moved/3565688_-14W_2N.png
# Updated bounding box CSV saved after processing 3565688_-14W_2N.png.
# Downloading shifted tile: 3565688_14W_11N.png...
# Saved: seamounts_moved/3565688_14W_11N.png
# Updated bounding box CSV saved after processing 3565688_14W_11N.png.
# Downloading shifted tile: 3570863_12W_-2N.png...
# Saved: seamounts_moved/3570863_12W_-2N.png
# Updated bounding box CSV saved after processing 3570863_12W_-2N.png.
# Downloading shifted tile: 3570863_-13W_4N.png...
# Saved: seamounts_moved/3570863_-13W_4N.png
# Updated bounding box CSV saved after processing 3570863_-13W_4N.png.
# Downloading shifted tile: 3570863_2W_2N.png...
# Saved: seamounts_moved/3570863_2W_2N.png
# Updated bounding box CSV saved after processing 3570863_2W_2N.png.
# Downloading shifted tile: 3570863_-7W_7N.png...
# Saved: seamounts_moved/3570863_-7W_7N.png
# Updated bounding box CSV saved after processing 3570863_-7W_7N.png.
# Downloading shifted tile: 3572596_-2W_12N.png...
# Saved: seamounts_moved/3572596_-2W_12N.png
# Updated bounding box CSV saved after processing 3572596_-2W_12N.png.
# Downloading shifted tile: 3572596_0W_11N.png...
# Saved: seamounts_moved/3572596_0W_11N.png
# Updated bounding box CSV saved after processing 3572596_0W_11N.png.
# Downloading shifted tile: 3572596_9W_12N.png...
# Saved: seamounts_moved/3572596_9W_12N.png
# Updated bounding box CSV saved after processing 3572596_9W_12N.png.
# Downloading shifted tile: 3572596_-11W_-2N.png...
# Saved: seamounts_moved/3572596_-11W_-2N.png
# Updated bounding box CSV saved after processing 3572596_-11W_-2N.png.
# Downloading shifted tile: 3576846_-12W_13N.png...
# Saved: seamounts_moved/3576846_-12W_13N.png
# Updated bounding box CSV saved after processing 3576846_-12W_13N.png.
# Downloading shifted tile: 3576846_6W_-2N.png...
# Saved: seamounts_moved/3576846_6W_-2N.png
# Updated bounding box CSV saved after processing 3576846_6W_-2N.png.
# Downloading shifted tile: 3576846_13W_-5N.png...
# Saved: seamounts_moved/3576846_13W_-5N.png
# Updated bounding box CSV saved after processing 3576846_13W_-5N.png.
# Downloading shifted tile: 3576846_-14W_13N.png...
# Saved: seamounts_moved/3576846_-14W_13N.png
# Updated bounding box CSV saved after processing 3576846_-14W_13N.png.
# Downloading shifted tile: 3581119_11W_-7N.png...
# Saved: seamounts_moved/3581119_11W_-7N.png
# Updated bounding box CSV saved after processing 3581119_11W_-7N.png.
# Downloading shifted tile: 3581119_-12W_12N.png...
# Saved: seamounts_moved/3581119_-12W_12N.png
# Updated bounding box CSV saved after processing 3581119_-12W_12N.png.
# Downloading shifted tile: 3581119_-11W_-9N.png...
# Saved: seamounts_moved/3581119_-11W_-9N.png
# Updated bounding box CSV saved after processing 3581119_-11W_-9N.png.
# Downloading shifted tile: 3581119_-12W_6N.png...
# Saved: seamounts_moved/3581119_-12W_6N.png
# Updated bounding box CSV saved after processing 3581119_-12W_6N.png.
# Downloading shifted tile: 3584918_-6W_6N.png...
# Saved: seamounts_moved/3584918_-6W_6N.png
# Updated bounding box CSV saved after processing 3584918_-6W_6N.png.
# Downloading shifted tile: 3584918_-1W_-7N.png...
# Saved: seamounts_moved/3584918_-1W_-7N.png
# Updated bounding box CSV saved after processing 3584918_-1W_-7N.png.
# Downloading shifted tile: 3584918_1W_3N.png...
# Saved: seamounts_moved/3584918_1W_3N.png
# Updated bounding box CSV saved after processing 3584918_1W_3N.png.
# Downloading shifted tile: 3584918_-12W_7N.png...
# Saved: seamounts_moved/3584918_-12W_7N.png
# Updated bounding box CSV saved after processing 3584918_-12W_7N.png.
# Downloading shifted tile: 360059_-7W_1N.png...
# Saved: seamounts_moved/360059_-7W_1N.png
# Updated bounding box CSV saved after processing 360059_-7W_1N.png.
# Downloading shifted tile: 360059_-3W_-11N.png...
# Saved: seamounts_moved/360059_-3W_-11N.png
# Updated bounding box CSV saved after processing 360059_-3W_-11N.png.
# Downloading shifted tile: 360059_5W_9N.png...
# Saved: seamounts_moved/360059_5W_9N.png
# Updated bounding box CSV saved after processing 360059_5W_9N.png.
# Downloading shifted tile: 360059_-9W_12N.png...
# Saved: seamounts_moved/360059_-9W_12N.png
# Updated bounding box CSV saved after processing 360059_-9W_12N.png.
# Downloading shifted tile: 3607579_6W_-2N.png...
# Saved: seamounts_moved/3607579_6W_-2N.png
# Updated bounding box CSV saved after processing 3607579_6W_-2N.png.
# Downloading shifted tile: 3607579_-1W_14N.png...
# Saved: seamounts_moved/3607579_-1W_14N.png
# Updated bounding box CSV saved after processing 3607579_-1W_14N.png.
# Downloading shifted tile: 3607579_6W_2N.png...
# Saved: seamounts_moved/3607579_6W_2N.png
# Updated bounding box CSV saved after processing 3607579_6W_2N.png.
# Downloading shifted tile: 3607579_8W_8N.png...
# Saved: seamounts_moved/3607579_8W_8N.png
# Updated bounding box CSV saved after processing 3607579_8W_8N.png.
# Downloading shifted tile: 3619236_10W_-8N.png...
# Saved: seamounts_moved/3619236_10W_-8N.png
# Updated bounding box CSV saved after processing 3619236_10W_-8N.png.
# Downloading shifted tile: 3619236_14W_-2N.png...
# Saved: seamounts_moved/3619236_14W_-2N.png
# Updated bounding box CSV saved after processing 3619236_14W_-2N.png.
# Downloading shifted tile: 3619236_6W_-9N.png...
# Saved: seamounts_moved/3619236_6W_-9N.png
# Updated bounding box CSV saved after processing 3619236_6W_-9N.png.
# Downloading shifted tile: 3619236_-13W_8N.png...
# Saved: seamounts_moved/3619236_-13W_8N.png
# Updated bounding box CSV saved after processing 3619236_-13W_8N.png.
# Downloading shifted tile: 3619783_1W_-2N.png...
# Saved: seamounts_moved/3619783_1W_-2N.png
# Updated bounding box CSV saved after processing 3619783_1W_-2N.png.
# Downloading shifted tile: 3619783_0W_8N.png...
# Saved: seamounts_moved/3619783_0W_8N.png
# Updated bounding box CSV saved after processing 3619783_0W_8N.png.
# Downloading shifted tile: 3619783_5W_-14N.png...
# Saved: seamounts_moved/3619783_5W_-14N.png
# Updated bounding box CSV saved after processing 3619783_5W_-14N.png.
# Downloading shifted tile: 3619783_3W_13N.png...
# Saved: seamounts_moved/3619783_3W_13N.png
# Updated bounding box CSV saved after processing 3619783_3W_13N.png.
# Downloading shifted tile: 3651446_-8W_-9N.png...
# Saved: seamounts_moved/3651446_-8W_-9N.png
# Updated bounding box CSV saved after processing 3651446_-8W_-9N.png.
# Downloading shifted tile: 3651446_9W_-5N.png...
# Saved: seamounts_moved/3651446_9W_-5N.png
# Updated bounding box CSV saved after processing 3651446_9W_-5N.png.
# Downloading shifted tile: 3651446_3W_-12N.png...
# Saved: seamounts_moved/3651446_3W_-12N.png
# Updated bounding box CSV saved after processing 3651446_3W_-12N.png.
# Downloading shifted tile: 3651446_6W_-5N.png...
# Saved: seamounts_moved/3651446_6W_-5N.png
# Updated bounding box CSV saved after processing 3651446_6W_-5N.png.
# Downloading shifted tile: 3670350_6W_-10N.png...
# Saved: seamounts_moved/3670350_6W_-10N.png
# Updated bounding box CSV saved after processing 3670350_6W_-10N.png.
# Downloading shifted tile: 3670350_14W_4N.png...
# Saved: seamounts_moved/3670350_14W_4N.png
# Updated bounding box CSV saved after processing 3670350_14W_4N.png.
# Downloading shifted tile: 3670350_3W_-9N.png...
# Saved: seamounts_moved/3670350_3W_-9N.png
# Updated bounding box CSV saved after processing 3670350_3W_-9N.png.
# Downloading shifted tile: 3670350_11W_-5N.png...
# Saved: seamounts_moved/3670350_11W_-5N.png
# Updated bounding box CSV saved after processing 3670350_11W_-5N.png.
# Downloading shifted tile: 3672630_-12W_0N.png...
# Saved: seamounts_moved/3672630_-12W_0N.png
# Updated bounding box CSV saved after processing 3672630_-12W_0N.png.
# Downloading shifted tile: 3672630_0W_3N.png...
# Saved: seamounts_moved/3672630_0W_3N.png
# Updated bounding box CSV saved after processing 3672630_0W_3N.png.
# Downloading shifted tile: 3672630_-9W_12N.png...
# Saved: seamounts_moved/3672630_-9W_12N.png
# Updated bounding box CSV saved after processing 3672630_-9W_12N.png.
# Downloading shifted tile: 3672630_-8W_0N.png...
# Saved: seamounts_moved/3672630_-8W_0N.png
# Updated bounding box CSV saved after processing 3672630_-8W_0N.png.
# Downloading shifted tile: 3672999_11W_5N.png...
# Saved: seamounts_moved/3672999_11W_5N.png
# Updated bounding box CSV saved after processing 3672999_11W_5N.png.
# Downloading shifted tile: 3672999_-10W_9N.png...
# Saved: seamounts_moved/3672999_-10W_9N.png
# Updated bounding box CSV saved after processing 3672999_-10W_9N.png.
# Downloading shifted tile: 3672999_1W_10N.png...
# Saved: seamounts_moved/3672999_1W_10N.png
# Updated bounding box CSV saved after processing 3672999_1W_10N.png.
# Downloading shifted tile: 3672999_-9W_14N.png...
# Saved: seamounts_moved/3672999_-9W_14N.png
# Updated bounding box CSV saved after processing 3672999_-9W_14N.png.
# Downloading shifted tile: 3674682_8W_-4N.png...
# Saved: seamounts_moved/3674682_8W_-4N.png
# Updated bounding box CSV saved after processing 3674682_8W_-4N.png.
# Downloading shifted tile: 3674682_12W_13N.png...
# Saved: seamounts_moved/3674682_12W_13N.png
# Updated bounding box CSV saved after processing 3674682_12W_13N.png.
# Downloading shifted tile: 3674682_4W_-1N.png...
# Saved: seamounts_moved/3674682_4W_-1N.png
# Updated bounding box CSV saved after processing 3674682_4W_-1N.png.
# Downloading shifted tile: 3674682_0W_-4N.png...
# Saved: seamounts_moved/3674682_0W_-4N.png
# Updated bounding box CSV saved after processing 3674682_0W_-4N.png.
# Downloading shifted tile: 3675614_2W_-3N.png...
# Saved: seamounts_moved/3675614_2W_-3N.png
# Updated bounding box CSV saved after processing 3675614_2W_-3N.png.
# Downloading shifted tile: 3675614_2W_10N.png...
# Saved: seamounts_moved/3675614_2W_10N.png
# Updated bounding box CSV saved after processing 3675614_2W_10N.png.
# Downloading shifted tile: 3675614_0W_-12N.png...
# Saved: seamounts_moved/3675614_0W_-12N.png
# Updated bounding box CSV saved after processing 3675614_0W_-12N.png.
# Downloading shifted tile: 3675614_13W_8N.png...
# Saved: seamounts_moved/3675614_13W_8N.png
# Updated bounding box CSV saved after processing 3675614_13W_8N.png.
# Downloading shifted tile: 3684081_7W_-9N.png...
# Saved: seamounts_moved/3684081_7W_-9N.png
# Updated bounding box CSV saved after processing 3684081_7W_-9N.png.
# Downloading shifted tile: 3684081_-14W_-1N.png...
# Saved: seamounts_moved/3684081_-14W_-1N.png
# Updated bounding box CSV saved after processing 3684081_-14W_-1N.png.
# Downloading shifted tile: 3684081_-6W_11N.png...
# Saved: seamounts_moved/3684081_-6W_11N.png
# Updated bounding box CSV saved after processing 3684081_-6W_11N.png.
# Downloading shifted tile: 3684081_-11W_-1N.png...
# Saved: seamounts_moved/3684081_-11W_-1N.png
# Updated bounding box CSV saved after processing 3684081_-11W_-1N.png.
# Downloading shifted tile: 3693466_-2W_11N.png...
# Saved: seamounts_moved/3693466_-2W_11N.png
# Updated bounding box CSV saved after processing 3693466_-2W_11N.png.
# Downloading shifted tile: 3693466_8W_-10N.png...
# Saved: seamounts_moved/3693466_8W_-10N.png
# Updated bounding box CSV saved after processing 3693466_8W_-10N.png.
# Downloading shifted tile: 3693466_2W_-14N.png...
# Saved: seamounts_moved/3693466_2W_-14N.png
# Updated bounding box CSV saved after processing 3693466_2W_-14N.png.
# Downloading shifted tile: 3693466_-8W_-7N.png...
# Saved: seamounts_moved/3693466_-8W_-7N.png
# Updated bounding box CSV saved after processing 3693466_-8W_-7N.png.
# Downloading shifted tile: 3704975_-8W_-8N.png...
# Saved: seamounts_moved/3704975_-8W_-8N.png
# Updated bounding box CSV saved after processing 3704975_-8W_-8N.png.
# Downloading shifted tile: 3704975_-3W_4N.png...
# Saved: seamounts_moved/3704975_-3W_4N.png
# Updated bounding box CSV saved after processing 3704975_-3W_4N.png.
# Downloading shifted tile: 3704975_-5W_-7N.png...
# Saved: seamounts_moved/3704975_-5W_-7N.png
# Updated bounding box CSV saved after processing 3704975_-5W_-7N.png.
# Downloading shifted tile: 3704975_-1W_2N.png...
# Saved: seamounts_moved/3704975_-1W_2N.png
# Updated bounding box CSV saved after processing 3704975_-1W_2N.png.
# Downloading shifted tile: 3709055_-8W_8N.png...
# Saved: seamounts_moved/3709055_-8W_8N.png
# Updated bounding box CSV saved after processing 3709055_-8W_8N.png.
# Downloading shifted tile: 3709055_-14W_7N.png...
# Saved: seamounts_moved/3709055_-14W_7N.png
# Updated bounding box CSV saved after processing 3709055_-14W_7N.png.
# Downloading shifted tile: 3709055_1W_-14N.png...
# Saved: seamounts_moved/3709055_1W_-14N.png
# Updated bounding box CSV saved after processing 3709055_1W_-14N.png.
# Downloading shifted tile: 3709055_10W_-5N.png...
# Saved: seamounts_moved/3709055_10W_-5N.png
# Updated bounding box CSV saved after processing 3709055_10W_-5N.png.
# Downloading shifted tile: 3709895_13W_8N.png...
# Saved: seamounts_moved/3709895_13W_8N.png
# Updated bounding box CSV saved after processing 3709895_13W_8N.png.
# Downloading shifted tile: 3709895_-7W_6N.png...
# Saved: seamounts_moved/3709895_-7W_6N.png
# Updated bounding box CSV saved after processing 3709895_-7W_6N.png.
# Downloading shifted tile: 3709895_-7W_0N.png...
# Saved: seamounts_moved/3709895_-7W_0N.png
# Updated bounding box CSV saved after processing 3709895_-7W_0N.png.
# Downloading shifted tile: 3709895_2W_14N.png...
# Saved: seamounts_moved/3709895_2W_14N.png
# Updated bounding box CSV saved after processing 3709895_2W_14N.png.
# Downloading shifted tile: 3712994_4W_-1N.png...
# Saved: seamounts_moved/3712994_4W_-1N.png
# Updated bounding box CSV saved after processing 3712994_4W_-1N.png.
# Downloading shifted tile: 3712994_-2W_-6N.png...
# Saved: seamounts_moved/3712994_-2W_-6N.png
# Updated bounding box CSV saved after processing 3712994_-2W_-6N.png.
# Downloading shifted tile: 3712994_-4W_-3N.png...
# Saved: seamounts_moved/3712994_-4W_-3N.png
# Updated bounding box CSV saved after processing 3712994_-4W_-3N.png.
# Downloading shifted tile: 3712994_11W_-13N.png...
# Saved: seamounts_moved/3712994_11W_-13N.png
# Updated bounding box CSV saved after processing 3712994_11W_-13N.png.

# %% [markdown]
# To load more seamounts, it would be necessary to find out the highest number in the image titles, then to modify the .csv to only contain the seamounts after that and then to run the above script again.

# %% [markdown]
# ## Filter high-res data

# %%
import cv2
import os
import numpy as np

def crop_fixed_border(image, crop_pixels=70):
    """Crop a fixed number of pixels from each border."""
    height, width, _ = image.shape
    if height > crop_pixels * 2 and width > crop_pixels * 2:
        return image[crop_pixels:height-crop_pixels, crop_pixels:width-crop_pixels]
    else:
        print(f"Warning: Crop size too large for image {width}x{height}. Returning original image.")
        return image

def detect_blur(image, threshold=100.0):
    """Detect if an image is blurry using the variance of the Laplacian."""
    # Compute the Laplacian variance
    laplacian_var = cv2.Laplacian(image, cv2.CV_64F).var()
    is_blurry = laplacian_var < threshold
    return laplacian_var, is_blurry

def process_images(input_folder, high_res_folder, low_res_folder, crop_pixels=70, threshold=100.0):
    """Process images: crop, detect blur, and organize into folders."""
    os.makedirs(high_res_folder, exist_ok=True)
    os.makedirs(low_res_folder, exist_ok=True)

    log = []
    for filename in os.listdir(input_folder):
        file_path = os.path.join(input_folder, filename)
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.tif')):
            try:
                # Load the image
                image = cv2.imread(file_path)
                if image is None:
                    print(f"Image {file_path} is corrupt or unreadable.")
                    continue
                
                # Crop the image
                cropped_image = crop_fixed_border(image, crop_pixels)
                
                # Convert to grayscale for sharpness detection
                gray_image = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2GRAY)
                
                # Detect blur
                lap_var, is_blurry = detect_blur(gray_image, threshold)
                log.append((filename, lap_var, is_blurry))
                
                # Move files to the appropriate folder
                if is_blurry:
                    os.rename(file_path, os.path.join(low_res_folder, filename))
                else:
                    os.rename(file_path, os.path.join(high_res_folder, filename))
            
            except Exception as e:
                print(f"Error processing {file_path}: {e}")

    # Save log to a CSV file
    with open(os.path.join(high_res_folder, 'log.csv'), 'w') as log_file:
        log_file.write('Filename,Laplacian Variance,Blurry\n')
        for entry in log:
            log_file.write(f"{entry[0]},{entry[1]:.2f},{entry[2]}\n")

# Example usage
input_folder = './seamounts_galore'
high_res_folder = './seamounts_galore/high_res'
low_res_folder = './seamounts_galore/low_res'
process_images(input_folder, high_res_folder, low_res_folder, crop_pixels=70, threshold=150.0)
