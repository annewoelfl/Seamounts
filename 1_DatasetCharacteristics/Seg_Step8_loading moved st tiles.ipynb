# %% [markdown]
# Key functionality: downloads moved tiles so that the mount is not always in the center

# %% [markdown]
# ## Download data

# %%
import os
import requests
import pandas as pd
import math
import random

# Parameters
csv_file = "seamounts.csv"  # Path to the .csv file with seamount data
marked_images_folder = "marked_images"  # Folder containing already marked images
existing_tiles_folder = "seamounts_seg"  # Folder with existing downloaded tiles
output_folder = "seamounts_moved"  # Folder to save newly positioned images
bbox_csv = "merged_pixel_coordinates.csv"  # CSV file with bounding box coordinates
tile_pixels = 800  # Width and height of the image in pixels
tile_width_deg = 1.0  # Fixed width in degrees
api_base_url = "https://www.gmrt.org/services/ImageServer"

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# Load bounding box CSV
try:
    bbox_df = pd.read_csv(bbox_csv)
    print(f"Loaded {len(bbox_df)} bounding box records from {bbox_csv}.")
except Exception as e:
    print(f"Error loading bounding box CSV: {e}")
    exit()

# Function to calculate new bounding box coordinates
def adjust_bounding_box(bbox, width_shift_pct, height_shift_pct):
    """
    Adjust bounding box coordinates based on shifts in tile center.
    """
    x_center = (bbox["x_min"] + bbox["x_max"]) / 2
    y_center = (bbox["y_min"] + bbox["y_max"]) / 2

    # Shift center
    new_x_center = x_center + width_shift_pct * tile_pixels
    new_y_center = y_center + height_shift_pct * tile_pixels

    # Adjust box coordinates
    x_shift = new_x_center - x_center
    y_shift = new_y_center - y_center
    new_bbox = {
        "x_min": bbox["x_min"] + x_shift,
        "y_min": bbox["y_min"] + y_shift,
        "x_max": bbox["x_max"] + x_shift,
        "y_max": bbox["y_max"] + y_shift,
    }
    return new_bbox

# Process each existing tile
for index, row in bbox_df.iterrows():
    try:
        # Extract data
        file_name = row["image_name"]
        if not os.path.exists(os.path.join(existing_tiles_folder, file_name)):
            print(f"Skipping {file_name} as it is not found in {existing_tiles_folder}.")
            continue

        # Parse bounding box
        bbox = {
            "x_min": row["x_min"],
            "y_min": row["y_min"],
            "x_max": row["x_max"],
            "y_max": row["y_max"],
        }

        # Compute tile dimensions
        center_lat = float(file_name.split(".")[0])  # Extract center latitude from filename
        adjusted_height_deg = tile_width_deg * math.cos(math.radians(center_lat))

        # Generate 4 new tile positions
        for i in range(4):
            width_shift_pct = random.uniform(-0.15, -0.05) if random.choice([True, False]) else random.uniform(0.05, 0.15)
            height_shift_pct = random.uniform(-0.15, -0.05) if random.choice([True, False]) else random.uniform(0.05, 0.15)

            # Ensure shifts keep the bounding box within bounds
            new_bbox = adjust_bounding_box(bbox, width_shift_pct, height_shift_pct)
            if (
                new_bbox["x_min"] < 0 or new_bbox["x_max"] > tile_pixels or
                new_bbox["y_min"] < 0 or new_bbox["y_max"] > tile_pixels
            ):
                print(f"Skipping shift {width_shift_pct*100:.1f}%W, {height_shift_pct*100:.1f}%N as it exceeds bounds.")
                continue

            # Calculate new center
            new_center_lon = float(row["LONG"]) + width_shift_pct * tile_width_deg
            new_center_lat = float(row["LAT"]) + height_shift_pct * adjusted_height_deg

            # Download the new tile
            minlatitude = new_center_lat - (adjusted_height_deg / 2)
            maxlatitude = new_center_lat + (adjusted_height_deg / 2)
            minlongitude = new_center_lon - (tile_width_deg / 2)
            maxlongitude = new_center_lon + (tile_width_deg / 2)

            params = {
                "minlatitude": minlatitude,
                "maxlatitude": maxlatitude,
                "minlongitude": minlongitude,
                "maxlongitude": maxlongitude,
                "width": tile_pixels,
                "mask": "false",
                "download": "true",
            }

            new_file_name = f"{file_name.split('.')[0]}_{int(width_shift_pct*100)}W{int(height_shift_pct*100)}N.png"
            output_file = os.path.join(output_folder, new_file_name)

            print(f"Downloading shifted tile: {new_file_name}...")
            response = requests.get(api_base_url, params=params)

            if response.status_code == 200:
                with open(output_file, "wb") as file:
                    file.write(response.content)
                print(f"Saved: {output_file}")

                # Add new bounding box entry
                new_bbox["image_name"] = new_file_name
                bbox_df = bbox_df.append(new_bbox, ignore_index=True)
            else:
                print(f"Failed to download {new_file_name} - HTTP {response.status_code}")

    except Exception as e:
        print(f"Error processing {file_name}: {e}")

# Save updated bounding box CSV
bbox_df.to_csv(bbox_csv, index=False)
print("Updated bounding box CSV saved.")
# Out:
# Loaded 500 bounding box records from merged_pixel_coordinates.csv.
# Error processing 2388515.0.png: 'LONG'
# Error processing 2474327.0.png: 'LONG'
# Error processing 2556370.0.png: 'LONG'
# Error processing 2660201.0.png: 'LONG'
# Error processing 2785016.0.png: 'LONG'
# Error processing 2814673.0.png: 'LONG'
# Error processing 2848549.0.png: 'LONG'
# Error processing 2851391.0.png: 'LONG'
# Error processing 2884163.0.png: 'LONG'
# Error processing 2946425.0.png: 'LONG'
# Error processing 2952050.0.png: 'LONG'
# Error processing 2971903.0.png: 'LONG'
# Error processing 2979182.0.png: 'LONG'
# Error processing 2982979.0.png: 'LONG'
# Error processing 3017911.0.png: 'LONG'
# Error processing 3024416.0.png: 'LONG'
# Error processing 3034731.0.png: 'LONG'
# Error processing 3099015.0.png: 'LONG'
# Error processing 3109615.0.png: 'LONG'
# Error processing 3114058.0.png: 'LONG'
# Error processing 3119848.0.png: 'LONG'
# Error processing 3131778.0.png: 'LONG'
# Error processing 3197462.0.png: 'LONG'
# Error processing 3246636.0.png: 'LONG'
# Error processing 3251574.0.png: 'LONG'
# Error processing 3259376.0.png: 'LONG'
# Error processing 3376684.0.png: 'LONG'
# Error processing 3389598.0.png: 'LONG'
# Error processing 3422242.0.png: 'LONG'
# Error processing 3425210.0.png: 'LONG'
# Error processing 3427982.0.png: 'LONG'
# Error processing 3443964.0.png: 'LONG'
# Error processing 3459203.0.png: 'LONG'
# Error processing 3478496.0.png: 'LONG'
# Error processing 3499370.0.png: 'LONG'
# Error processing 3568758.0.png: 'LONG'
# Error processing 3586718.0.png: 'LONG'
# Error processing 3589874.0.png: 'LONG'
# Error processing 3598273.0.png: 'LONG'
# Error processing 3649693.0.png: 'LONG'
# Error processing 3695243.0.png: 'LONG'
# Error processing 3719367.0.png: 'LONG'
# Error processing 3727549.0.png: 'LONG'
# Error processing 3773102.0.png: 'LONG'
# Error processing 3791733.0.png: 'LONG'
# Error processing 3861455.0.png: 'LONG'
# Error processing 4085738.0.png: 'LONG'
# Error processing 4195974.0.png: 'LONG'
# Error processing 4202544.0.png: 'LONG'
# Error processing 4239444.0.png: 'LONG'
# Error processing 4286077.0.png: 'LONG'
# Error processing 4339439.0.png: 'LONG'
# Error processing 4388465.0.png: 'LONG'
# Error processing 4512941.0.png: 'LONG'
# Error processing 4513875.0.png: 'LONG'
# Error processing 4517596.0.png: 'LONG'
# Error processing 4525212.0.png: 'LONG'
# Error processing 4540426.0.png: 'LONG'
# Error processing 4548566.0.png: 'LONG'
# Error processing 4647674.0.png: 'LONG'
# Error processing 4647770.0.png: 'LONG'
# Error processing 4698037.0.png: 'LONG'
# Error processing 4715430.0.png: 'LONG'
# Error processing 4800703.0.png: 'LONG'
# Error processing 4802577.0.png: 'LONG'
# Skipping shift 10.2%W, -12.0%N as it exceeds bounds.
# Skipping shift -10.1%W, -13.2%N as it exceeds bounds.
# Error processing 4826044.0.png: 'LONG'
# Error processing 4917719.0.png: 'LONG'
# Error processing 495762.0.png: 'LONG'
# Error processing 541616.0.png: 'LONG'
# Error processing 549179.0.png: 'LONG'
# Error processing 633623.0.png: 'LONG'
# Error processing 660423.0.png: 'LONG'
# Error processing 717269.0.png: 'LONG'
# Error processing 731018.0.png: 'LONG'
# Error processing 731523.0.png: 'LONG'
# Error processing 860355.0.png: 'LONG'
# Error processing 914526.0.png: 'LONG'
# Error processing 3727082.0.png: 'LONG'
# Error processing 3734559.0.png: 'LONG'
# Error processing 3752228.0.png: 'LONG'
# Error processing 3752636.0.png: 'LONG'
# Error processing 3768789.0.png: 'LONG'
# Error processing 3780935.0.png: 'LONG'
# Error processing 3800217.0.png: 'LONG'
# Error processing 3811377.0.png: 'LONG'
# Error processing 3813719.0.png: 'LONG'
# Error processing 3829861.0.png: 'LONG'
# Error processing 3857966.0.png: 'LONG'
# Error processing 3863915.0.png: 'LONG'
# Error processing 3878685.0.png: 'LONG'
# Error processing 3896410.0.png: 'LONG'
# Error processing 3901098.0.png: 'LONG'
# Error processing 3911481.0.png: 'LONG'
# Error processing 3915980.0.png: 'LONG'
# Error processing 3916035.0.png: 'LONG'
# Error processing 3916105.0.png: 'LONG'
# Error processing 3919949.0.png: 'LONG'
# Error processing 3921579.0.png: 'LONG'
# Error processing 3940882.0.png: 'LONG'
# Error processing 3948077.0.png: 'LONG'
# Error processing 3948903.0.png: 'LONG'
# Error processing 3957556.0.png: 'LONG'
# Error processing 3960543.0.png: 'LONG'
# Error processing 3974828.0.png: 'LONG'
# Error processing 3978188.0.png: 'LONG'
# Error processing 4014249.0.png: 'LONG'
# Error processing 4022275.0.png: 'LONG'
# Error processing 4048693.0.png: 'LONG'
# Error processing 4078518.0.png: 'LONG'
# Error processing 4079727.0.png: 'LONG'
# Error processing 4100547.0.png: 'LONG'
# Error processing 4100672.0.png: 'LONG'
# Error processing 4107093.0.png: 'LONG'
# Error processing 4112870.0.png: 'LONG'
# Error processing 4119044.0.png: 'LONG'
# Error processing 4123185.0.png: 'LONG'
# Error processing 4123984.0.png: 'LONG'
# Error processing 4126205.0.png: 'LONG'
# Error processing 412667.0.png: 'LONG'
# Error processing 4130568.0.png: 'LONG'
# Error processing 4150200.0.png: 'LONG'
# Error processing 4151021.0.png: 'LONG'
# Error processing 4156260.0.png: 'LONG'
# Error processing 4159228.0.png: 'LONG'
# Error processing 4159446.0.png: 'LONG'
# Error processing 4172135.0.png: 'LONG'
# Error processing 4173030.0.png: 'LONG'
# Error processing 4189954.0.png: 'LONG'
# Error processing 4194559.0.png: 'LONG'
# Error processing 4194560.0.png: 'LONG'
# Error processing 4195872.0.png: 'LONG'
# Error processing 4198444.0.png: 'LONG'
# Error processing 4200862.0.png: 'LONG'
# Error processing 4216333.0.png: 'LONG'
# Error processing 4219197.0.png: 'LONG'
# Error processing 4222050.0.png: 'LONG'
# Error processing 4222606.0.png: 'LONG'
# Error processing 4225574.0.png: 'LONG'
# Error processing 4226650.0.png: 'LONG'
# Error processing 4239034.0.png: 'LONG'
# Error processing 4240258.0.png: 'LONG'
# Skipping shift 13.9%W, -13.2%N as it exceeds bounds.
# Error processing 424420.0.png: 'LONG'
# Error processing 4244866.0.png: 'LONG'
# Error processing 4252775.0.png: 'LONG'
# Error processing 4253181.0.png: 'LONG'
# Error processing 4255837.0.png: 'LONG'
# Error processing 4262018.0.png: 'LONG'
# Error processing 4268391.0.png: 'LONG'
# Error processing 4287157.0.png: 'LONG'
# Error processing 4289089.0.png: 'LONG'
# Error processing 4298233.0.png: 'LONG'
# Error processing 4315993.0.png: 'LONG'
# Error processing 434824.0.png: 'LONG'
# Error processing 4353605.0.png: 'LONG'
# Error processing 4357447.0.png: 'LONG'
# Error processing 4381633.0.png: 'LONG'
# Error processing 4405480.0.png: 'LONG'
# Error processing 440886.0.png: 'LONG'
# Error processing 4470827.0.png: 'LONG'
# Error processing 4471281.0.png: 'LONG'
# Error processing 4473069.0.png: 'LONG'
# Error processing 4508885.0.png: 'LONG'
# Error processing 4526801.0.png: 'LONG'
# Error processing 4531157.0.png: 'LONG'
# Error processing 4542795.0.png: 'LONG'
# Error processing 4551468.0.png: 'LONG'
# Error processing 4565226.0.png: 'LONG'
# Error processing 4566021.0.png: 'LONG'
# Error processing 4573939.0.png: 'LONG'
# Error processing 4590954.0.png: 'LONG'
# Error processing 4596174.0.png: 'LONG'
# Error processing 4597206.0.png: 'LONG'
# Error processing 4598834.0.png: 'LONG'
# Error processing 4605431.0.png: 'LONG'
# Error processing 4616927.0.png: 'LONG'
# Error processing 4622125.0.png: 'LONG'
# Error processing 4625064.0.png: 'LONG'
# Error processing 4631069.0.png: 'LONG'
# Error processing 4633053.0.png: 'LONG'
# Error processing 4645396.0.png: 'LONG'
# Error processing 4651100.0.png: 'LONG'
# Error processing 4654952.0.png: 'LONG'
# Error processing 4662232.0.png: 'LONG'
# Error processing 4663094.0.png: 'LONG'
# Error processing 4663371.0.png: 'LONG'
# Error processing 4674440.0.png: 'LONG'
# Error processing 4701227.0.png: 'LONG'
# Error processing 4701404.0.png: 'LONG'
# Error processing 471046.0.png: 'LONG'
# Error processing 4710925.0.png: 'LONG'
# Error processing 4715430.0.png: 'LONG'
# Error processing 4715483.0.png: 'LONG'
# Error processing 4716395.0.png: 'LONG'
# Error processing 4723360.0.png: 'LONG'
# Error processing 4731962.0.png: 'LONG'
# Error processing 4744956.0.png: 'LONG'
# Error processing 474704.0.png: 'LONG'
# Error processing 4748414.0.png: 'LONG'
# Error processing 4748795.0.png: 'LONG'
# Error processing 4763866.0.png: 'LONG'
# Error processing 4772902.0.png: 'LONG'
# Error processing 4782097.0.png: 'LONG'
# Error processing 4787081.0.png: 'LONG'
# Skipping shift -5.9%W, -11.5%N as it exceeds bounds.
# Error processing 4804188.0.png: 'LONG'
# Error processing 4808720.0.png: 'LONG'
# Skipping shift -5.2%W, -13.9%N as it exceeds bounds.
# Error processing 4827698.0.png: 'LONG'
# Skipping shift 11.5%W, -14.7%N as it exceeds bounds.
# Error processing 482771.0.png: 'LONG'
# Error processing 4844474.0.png: 'LONG'
# Error processing 484714.0.png: 'LONG'
# Error processing 488767.0.png: 'LONG'
# Skipping shift 9.4%W, -11.8%N as it exceeds bounds.
# Error processing 4898668.0.png: 'LONG'
# Error processing 4909393.0.png: 'LONG'
# Error processing 4910111.0.png: 'LONG'
# Error processing 491093.0.png: 'LONG'
# Error processing 4923176.0.png: 'LONG'
# Error processing 498972.0.png: 'LONG'
# Error processing 512094.0.png: 'LONG'
# Error processing 513718.0.png: 'LONG'
# Error processing 515426.0.png: 'LONG'
# Error processing 521041.0.png: 'LONG'
# Error processing 524508.0.png: 'LONG'
# Error processing 525652.0.png: 'LONG'
# Error processing 565196.0.png: 'LONG'
# Error processing 579433.0.png: 'LONG'
# Error processing 579726.0.png: 'LONG'
# Error processing 586580.0.png: 'LONG'
# Error processing 587314.0.png: 'LONG'
# Error processing 598079.0.png: 'LONG'
# Error processing 599586.0.png: 'LONG'
# Error processing 604188.0.png: 'LONG'
# Error processing 610429.0.png: 'LONG'
# Error processing 612940.0.png: 'LONG'
# Error processing 618373.0.png: 'LONG'
# Error processing 621360.0.png: 'LONG'
# Error processing 621855.0.png: 'LONG'
# Error processing 626949.0.png: 'LONG'
# Error processing 628876.0.png: 'LONG'
# Error processing 633480.0.png: 'LONG'
# Error processing 633984.0.png: 'LONG'
# Error processing 635030.0.png: 'LONG'
# Error processing 639315.0.png: 'LONG'
# Error processing 670480.0.png: 'LONG'
# Error processing 677339.0.png: 'LONG'
# Error processing 687551.0.png: 'LONG'
# Error processing 690455.0.png: 'LONG'
# Error processing 706912.0.png: 'LONG'
# Error processing 710711.0.png: 'LONG'
# Error processing 732153.0.png: 'LONG'
# Error processing 747921.0.png: 'LONG'
# Error processing 754584.0.png: 'LONG'
# Error processing 777065.0.png: 'LONG'
# Error processing 794254.0.png: 'LONG'
# Error processing 827728.0.png: 'LONG'
# Error processing 836830.0.png: 'LONG'
# Error processing 844380.0.png: 'LONG'
# Error processing 848775.0.png: 'LONG'
# Error processing 867705.0.png: 'LONG'
# Error processing 873866.0.png: 'LONG'
# Error processing 890401.0.png: 'LONG'
# Error processing 899666.0.png: 'LONG'
# Error processing 901639.0.png: 'LONG'
# Error processing 926608.0.png: 'LONG'
# Error processing 929067.0.png: 'LONG'
# Error processing 929076.0.png: 'LONG'
# Error processing 932328.0.png: 'LONG'
# Error processing 933396.0.png: 'LONG'
# Error processing 933429.0.png: 'LONG'
# Error processing 977224.0.png: 'LONG'
# Error processing 994105.0.png: 'LONG'
# Error processing 998828.0.png: 'LONG'
# Error processing 2076953.0.png: 'LONG'
# Error processing 2276072.0.png: 'LONG'
# Skipping shift 13.2%W, -11.3%N as it exceeds bounds.
# Error processing 2284600.0.png: 'LONG'
# Error processing 2448495.0.png: 'LONG'
# Skipping shift -11.2%W, -14.5%N as it exceeds bounds.
# Error processing 2449834.0.png: 'LONG'
# Error processing 2590517.0.png: 'LONG'
# Error processing 2619334.0.png: 'LONG'
# Error processing 2644830.0.png: 'LONG'
# Error processing 2654007.0.png: 'LONG'
# Error processing 2718896.0.png: 'LONG'
# Error processing 2796759.0.png: 'LONG'
# Error processing 2831308.0.png: 'LONG'
# Error processing 2840739.0.png: 'LONG'
# Error processing 2850875.0.png: 'LONG'
# Error processing 2884157.0.png: 'LONG'
# Error processing 2910300.0.png: 'LONG'
# Error processing 3016624.0.png: 'LONG'
# Error processing 3130415.0.png: 'LONG'
# Error processing 3212788.0.png: 'LONG'
# Error processing 3236799.0.png: 'LONG'
# Error processing 3264516.0.png: 'LONG'
# Error processing 3275072.0.png: 'LONG'
# Error processing 3286309.0.png: 'LONG'
# Error processing 3335605.0.png: 'LONG'
# Error processing 3359383.0.png: 'LONG'
# Error processing 3374066.0.png: 'LONG'
# Error processing 3379680.0.png: 'LONG'
# Error processing 3430916.0.png: 'LONG'
# Error processing 3433645.0.png: 'LONG'
# Error processing 3462092.0.png: 'LONG'
# Error processing 3475579.0.png: 'LONG'
# Error processing 3520793.0.png: 'LONG'
# Error processing 3577821.0.png: 'LONG'
# Error processing 3634839.0.png: 'LONG'
# Error processing 3684053.0.png: 'LONG'
# Error processing 3707808.0.png: 'LONG'
# Error processing 3743596.0.png: 'LONG'
# Error processing 3816377.0.png: 'LONG'
# Error processing 3871203.0.png: 'LONG'
# Error processing 3927829.0.png: 'LONG'
# Error processing 4021630.0.png: 'LONG'
# Error processing 4051890.0.png: 'LONG'
# Error processing 4067508.0.png: 'LONG'
# Error processing 4107875.0.png: 'LONG'
# Error processing 4173505.0.png: 'LONG'
# Error processing 4195186.0.png: 'LONG'
# Error processing 4231890.0.png: 'LONG'
# Error processing 4273201.0.png: 'LONG'
# Error processing 4306426.0.png: 'LONG'
# Error processing 4349101.0.png: 'LONG'
# Error processing 4355249.0.png: 'LONG'
# Error processing 4545330.0.png: 'LONG'
# Error processing 4547413.0.png: 'LONG'
# Error processing 463254.0.png: 'LONG'
# Error processing 4648630.0.png: 'LONG'
# Error processing 4650301.0.png: 'LONG'
# Error processing 4657220.0.png: 'LONG'
# Error processing 4709073.0.png: 'LONG'
# Error processing 4714653.0.png: 'LONG'
# Error processing 4734275.0.png: 'LONG'
# Error processing 4782791.0.png: 'LONG'
# Error processing 4793330.0.png: 'LONG'
# Error processing 4871033.0.png: 'LONG'
# Error processing 521672.0.png: 'LONG'
# Error processing 599891.0.png: 'LONG'
# Error processing 605965.0.png: 'LONG'
# Error processing 671012.0.png: 'LONG'
# Error processing 688841.0.png: 'LONG'
# Error processing 844402.0.png: 'LONG'
# Error processing 846666.0.png: 'LONG'
# Error processing 973680.0.png: 'LONG'
# Error processing 993162.0.png: 'LONG'
# Error processing 1001431.0.png: 'LONG'
# Skipping shift -9.7%W, -13.0%N as it exceeds bounds.
# Error processing 1013016.0.png: 'LONG'
# Error processing 1025041.0.png: 'LONG'
# Error processing 2002867.0.png: 'LONG'
# Error processing 2076096.0.png: 'LONG'
# Error processing 2120674.0.png: 'LONG'
# Error processing 2203770.0.png: 'LONG'
# Error processing 2325818.0.png: 'LONG'
# Error processing 2327372.0.png: 'LONG'
# Error processing 2358338.0.png: 'LONG'
# Error processing 2392192.0.png: 'LONG'
# Error processing 2392966.0.png: 'LONG'
# Error processing 2394421.0.png: 'LONG'
# Error processing 2395572.0.png: 'LONG'
# Error processing 2401816.0.png: 'LONG'
# Error processing 2414507.0.png: 'LONG'
# Error processing 2419181.0.png: 'LONG'
# Error processing 2438586.0.png: 'LONG'
# Skipping shift -6.4%W, -14.2%N as it exceeds bounds.
# Error processing 2451447.0.png: 'LONG'
# Error processing 2474642.0.png: 'LONG'
# Error processing 2486137.0.png: 'LONG'
# Error processing 2554156.0.png: 'LONG'
# Error processing 2581063.0.png: 'LONG'
# Error processing 2593656.0.png: 'LONG'
# Skipping shift 14.4%W, -14.5%N as it exceeds bounds.
# Error processing 2619027.0.png: 'LONG'
# Error processing 2624703.0.png: 'LONG'
# Error processing 2627248.0.png: 'LONG'
# Error processing 2657009.0.png: 'LONG'
# Error processing 2681196.0.png: 'LONG'
# Error processing 2691027.0.png: 'LONG'
# Skipping shift 13.5%W, -14.8%N as it exceeds bounds.
# Error processing 2692198.0.png: 'LONG'
# Error processing 2698278.0.png: 'LONG'
# Error processing 2701105.0.png: 'LONG'
# Error processing 2708692.0.png: 'LONG'
# Error processing 2709245.0.png: 'LONG'
# Error processing 2711567.0.png: 'LONG'
# Error processing 2714397.0.png: 'LONG'
# Error processing 2725962.0.png: 'LONG'
# Skipping shift -14.9%W, -13.2%N as it exceeds bounds.
# Error processing 2747848.0.png: 'LONG'
# Error processing 2754015.0.png: 'LONG'
# Error processing 2759106.0.png: 'LONG'
# Error processing 2772117.0.png: 'LONG'
# Error processing 2779873.0.png: 'LONG'
# Error processing 2798451.0.png: 'LONG'
# Skipping shift 11.6%W, -13.8%N as it exceeds bounds.
# Error processing 2799659.0.png: 'LONG'
# Error processing 2799865.0.png: 'LONG'
# Skipping shift 8.4%W, -14.6%N as it exceeds bounds.
# Error processing 2809584.0.png: 'LONG'
# Error processing 2819970.0.png: 'LONG'
# Error processing 2841042.0.png: 'LONG'
# Error processing 2853267.0.png: 'LONG'
# Error processing 2858689.0.png: 'LONG'
# Error processing 2859007.0.png: 'LONG'
# Error processing 2862843.0.png: 'LONG'
# Error processing 2887480.0.png: 'LONG'
# Error processing 2915152.0.png: 'LONG'
# Error processing 2938197.0.png: 'LONG'
# Error processing 2948196.0.png: 'LONG'
# Error processing 2948771.0.png: 'LONG'
# Error processing 2969582.0.png: 'LONG'
# Error processing 2977724.0.png: 'LONG'
# Error processing 2990037.0.png: 'LONG'
# Error processing 3006956.0.png: 'LONG'
# Error processing 3025152.0.png: 'LONG'
# Error processing 3040350.0.png: 'LONG'
# Error processing 3052025.0.png: 'LONG'
# Error processing 3052364.0.png: 'LONG'
# Error processing 3075749.0.png: 'LONG'
# Error processing 3102700.0.png: 'LONG'
# Error processing 3124927.0.png: 'LONG'
# Error processing 3136367.0.png: 'LONG'
# Error processing 3144556.0.png: 'LONG'
# Error processing 3150169.0.png: 'LONG'
# Error processing 3151439.0.png: 'LONG'
# Error processing 3152402.0.png: 'LONG'
# Error processing 3153478.0.png: 'LONG'
# Error processing 3157722.0.png: 'LONG'
# Error processing 3162926.0.png: 'LONG'
# Error processing 3164590.0.png: 'LONG'
# Error processing 3171106.0.png: 'LONG'
# Error processing 3171779.0.png: 'LONG'
# Error processing 3178074.0.png: 'LONG'
# Error processing 3179633.0.png: 'LONG'
# Error processing 3180885.0.png: 'LONG'
# Error processing 3196254.0.png: 'LONG'
# Error processing 3208217.0.png: 'LONG'
# Error processing 3212787.0.png: 'LONG'
# Error processing 3217863.0.png: 'LONG'
# Error processing 3225859.0.png: 'LONG'
# Error processing 3236197.0.png: 'LONG'
# Error processing 3243668.0.png: 'LONG'
# Error processing 3244844.0.png: 'LONG'
# Error processing 3251562.0.png: 'LONG'
# Error processing 3261427.0.png: 'LONG'
# Error processing 3267268.0.png: 'LONG'
# Error processing 3270824.0.png: 'LONG'
# Error processing 3276211.0.png: 'LONG'
# Error processing 3279108.0.png: 'LONG'
# Error processing 3284791.0.png: 'LONG'
# Error processing 3285799.0.png: 'LONG'
# Error processing 3285828.0.png: 'LONG'
# Error processing 3287082.0.png: 'LONG'
# Error processing 3313632.0.png: 'LONG'
# Skipping shift -9.4%W, -14.8%N as it exceeds bounds.
# Error processing 3320133.0.png: 'LONG'
# Error processing 3322589.0.png: 'LONG'
# Error processing 3324235.0.png: 'LONG'
# Error processing 3336410.0.png: 'LONG'
# Error processing 3347335.0.png: 'LONG'
# Error processing 3354850.0.png: 'LONG'
# Error processing 3361406.0.png: 'LONG'
# Error processing 336209.0.png: 'LONG'
# Error processing 3363688.0.png: 'LONG'
# Error processing 3373064.0.png: 'LONG'
# Error processing 3376699.0.png: 'LONG'
# Error processing 3378505.0.png: 'LONG'
# Error processing 3383881.0.png: 'LONG'
# Error processing 3386477.0.png: 'LONG'
# Error processing 3391881.0.png: 'LONG'
# Error processing 3396855.0.png: 'LONG'
# Error processing 3409397.0.png: 'LONG'
# Error processing 3421463.0.png: 'LONG'
# Error processing 3425473.0.png: 'LONG'
# Error processing 3441619.0.png: 'LONG'
# Error processing 3448638.0.png: 'LONG'
# Skipping shift -8.6%W, -14.9%N as it exceeds bounds.
# Error processing 3449432.0.png: 'LONG'
# Error processing 3487419.0.png: 'LONG'
# Error processing 3493043.0.png: 'LONG'
# Error processing 3498905.0.png: 'LONG'
# Error processing 3499812.0.png: 'LONG'
# Error processing 3499845.0.png: 'LONG'
# Error processing 3513265.0.png: 'LONG'
# Error processing 3528703.0.png: 'LONG'
# Error processing 3543250.0.png: 'LONG'
# Error processing 3544822.0.png: 'LONG'
# Error processing 3557823.0.png: 'LONG'
# Error processing 3562248.0.png: 'LONG'
# Error processing 3563758.0.png: 'LONG'
# Error processing 3565688.0.png: 'LONG'
# Error processing 3570863.0.png: 'LONG'
# Error processing 3572596.0.png: 'LONG'
# Error processing 3576846.0.png: 'LONG'
# Error processing 3581119.0.png: 'LONG'
# Error processing 3584918.0.png: 'LONG'
# Error processing 360059.0.png: 'LONG'
# Error processing 3607579.0.png: 'LONG'
# Error processing 3619236.0.png: 'LONG'
# Error processing 3619783.0.png: 'LONG'
# Error processing 3651446.0.png: 'LONG'
# Error processing 3670350.0.png: 'LONG'
# Error processing 3672630.0.png: 'LONG'
# Error processing 3672999.0.png: 'LONG'
# Error processing 3674682.0.png: 'LONG'
# Error processing 3675614.0.png: 'LONG'
# Error processing 3684081.0.png: 'LONG'
# Error processing 3693466.0.png: 'LONG'
# Error processing 3704975.0.png: 'LONG'
# Error processing 3709055.0.png: 'LONG'
# Error processing 3709895.0.png: 'LONG'
# Error processing 3712994.0.png: 'LONG'
# Updated bounding box CSV saved.

# %% [markdown]
# To load more seamounts, it would be necessary to find out the highest number in the image titles, then to modify the .csv to only contain the seamounts after that and then to run the above script again.

# %% [markdown]
# ## Filter high-res data

# %%
import cv2
import os
import numpy as np

def crop_fixed_border(image, crop_pixels=70):
    """Crop a fixed number of pixels from each border."""
    height, width, _ = image.shape
    if height > crop_pixels * 2 and width > crop_pixels * 2:
        return image[crop_pixels:height-crop_pixels, crop_pixels:width-crop_pixels]
    else:
        print(f"Warning: Crop size too large for image {width}x{height}. Returning original image.")
        return image

def detect_blur(image, threshold=100.0):
    """Detect if an image is blurry using the variance of the Laplacian."""
    # Compute the Laplacian variance
    laplacian_var = cv2.Laplacian(image, cv2.CV_64F).var()
    is_blurry = laplacian_var < threshold
    return laplacian_var, is_blurry

def process_images(input_folder, high_res_folder, low_res_folder, crop_pixels=70, threshold=100.0):
    """Process images: crop, detect blur, and organize into folders."""
    os.makedirs(high_res_folder, exist_ok=True)
    os.makedirs(low_res_folder, exist_ok=True)

    log = []
    for filename in os.listdir(input_folder):
        file_path = os.path.join(input_folder, filename)
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.tif')):
            try:
                # Load the image
                image = cv2.imread(file_path)
                if image is None:
                    print(f"Image {file_path} is corrupt or unreadable.")
                    continue
                
                # Crop the image
                cropped_image = crop_fixed_border(image, crop_pixels)
                
                # Convert to grayscale for sharpness detection
                gray_image = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2GRAY)
                
                # Detect blur
                lap_var, is_blurry = detect_blur(gray_image, threshold)
                log.append((filename, lap_var, is_blurry))
                
                # Move files to the appropriate folder
                if is_blurry:
                    os.rename(file_path, os.path.join(low_res_folder, filename))
                else:
                    os.rename(file_path, os.path.join(high_res_folder, filename))
            
            except Exception as e:
                print(f"Error processing {file_path}: {e}")

    # Save log to a CSV file
    with open(os.path.join(high_res_folder, 'log.csv'), 'w') as log_file:
        log_file.write('Filename,Laplacian Variance,Blurry\n')
        for entry in log:
            log_file.write(f"{entry[0]},{entry[1]:.2f},{entry[2]}\n")

# Example usage
input_folder = './seamounts_galore'
high_res_folder = './seamounts_galore/high_res'
low_res_folder = './seamounts_galore/low_res'
process_images(input_folder, high_res_folder, low_res_folder, crop_pixels=70, threshold=150.0)
