# %%
import os
import requests
import time
import math

# Parameters
start_lat = 30  # Starting latitude
start_lon = -60  # Starting longitude
num_tiles = 10  # Number of tiles in each direction
tile_width_deg = 1  # Width of each tile in degrees (longitude)
tile_pixels = 800  # Pixel width/height of each tile
output_folder = "equal_tiles"

# Ensure the output directory exists
os.makedirs(output_folder, exist_ok=True)

# Base URL for the ImageServer
base_url = "https://www.gmrt.org/services/ImageServer"

# Function to calculate the height in degrees for Mercator projection
def calculate_lat_height(center_lat, pixel_height, pixel_width):
    lat_rad = math.radians(center_lat)
    degrees_per_pixel = math.cos(lat_rad)
    return (pixel_height / pixel_width) * degrees_per_pixel

# Store grid data for visualization
grid_data = []

# Start downloading tiles
current_lat = start_lat
for i in range(num_tiles):  # Loop for latitude tiles
    current_lon = start_lon
    for j in range(num_tiles):  # Loop for longitude tiles
        # Calculate tile bounds
        tile_height_deg = calculate_lat_height(current_lat, tile_pixels, tile_pixels)
        minlatitude = current_lat
        maxlatitude = current_lat + tile_height_deg
        minlongitude = current_lon
        maxlongitude = current_lon + tile_width_deg

        # Store grid information for visualization
        grid_data.append((minlatitude, maxlatitude, minlongitude, maxlongitude))

        # Construct the URL
        params = {
            "minlatitude": minlatitude,
            "maxlatitude": maxlatitude,
            "minlongitude": minlongitude,
            "maxlongitude": maxlongitude,
            "width": tile_pixels,
            "mask": "false",
            "download": "true",
        }

        # Format the file name
        tile_name = (
            f"tile_{minlatitude:.1f}_{maxlatitude:.1f}_"
            f"{minlongitude:.1f}_{maxlongitude:.1f}.png"
        )

        # Download the tile
        try:
            print(f"Downloading tile: {tile_name}")
            response = requests.get(base_url, params=params)

            if response.status_code == 200:
                # Save the image
                with open(os.path.join(output_folder, tile_name), "wb") as file:
                    file.write(response.content)
            else:
                print(f"Failed to download tile: {tile_name} - HTTP {response.status_code}")
        except Exception as e:
            print(f"Error downloading tile {tile_name}: {e}")

        # Move to the next tile (longitude)
        current_lon += tile_width_deg

        # Respectful delay between requests
        time.sleep(1)

    # Move to the next tile row (latitude)
    current_lat += tile_height_deg

print("Download complete.")
# Out:
# Downloading tile: tile_30.0_30.9_-60.0_-59.0.png
# Downloading tile: tile_30.0_30.9_-59.0_-58.0.png
# Downloading tile: tile_30.0_30.9_-58.0_-57.0.png
# Downloading tile: tile_30.0_30.9_-57.0_-56.0.png
# Downloading tile: tile_30.0_30.9_-56.0_-55.0.png
# Downloading tile: tile_30.0_30.9_-55.0_-54.0.png
# Downloading tile: tile_30.0_30.9_-54.0_-53.0.png
# Downloading tile: tile_30.0_30.9_-53.0_-52.0.png
# Downloading tile: tile_30.0_30.9_-52.0_-51.0.png
# Downloading tile: tile_30.0_30.9_-51.0_-50.0.png
# Downloading tile: tile_30.9_31.7_-60.0_-59.0.png
# Downloading tile: tile_30.9_31.7_-59.0_-58.0.png
# Downloading tile: tile_30.9_31.7_-58.0_-57.0.png
# Downloading tile: tile_30.9_31.7_-57.0_-56.0.png
# Downloading tile: tile_30.9_31.7_-56.0_-55.0.png
# Downloading tile: tile_30.9_31.7_-55.0_-54.0.png
# Downloading tile: tile_30.9_31.7_-54.0_-53.0.png
# Downloading tile: tile_30.9_31.7_-53.0_-52.0.png
# Downloading tile: tile_30.9_31.7_-52.0_-51.0.png
# Downloading tile: tile_30.9_31.7_-51.0_-50.0.png
# Downloading tile: tile_31.7_32.6_-60.0_-59.0.png
# Downloading tile: tile_31.7_32.6_-59.0_-58.0.png
# Downloading tile: tile_31.7_32.6_-58.0_-57.0.png
# Downloading tile: tile_31.7_32.6_-57.0_-56.0.png
# Downloading tile: tile_31.7_32.6_-56.0_-55.0.png
# Downloading tile: tile_31.7_32.6_-55.0_-54.0.png
# Downloading tile: tile_31.7_32.6_-54.0_-53.0.png
# Downloading tile: tile_31.7_32.6_-53.0_-52.0.png
# Downloading tile: tile_31.7_32.6_-52.0_-51.0.png
# Downloading tile: tile_31.7_32.6_-51.0_-50.0.png
# Downloading tile: tile_32.6_33.4_-60.0_-59.0.png
# Downloading tile: tile_32.6_33.4_-59.0_-58.0.png
# Downloading tile: tile_32.6_33.4_-58.0_-57.0.png
# Downloading tile: tile_32.6_33.4_-57.0_-56.0.png
# Downloading tile: tile_32.6_33.4_-56.0_-55.0.png
# Downloading tile: tile_32.6_33.4_-55.0_-54.0.png
# Downloading tile: tile_32.6_33.4_-54.0_-53.0.png
# Downloading tile: tile_32.6_33.4_-53.0_-52.0.png
# Downloading tile: tile_32.6_33.4_-52.0_-51.0.png
# Downloading tile: tile_32.6_33.4_-51.0_-50.0.png
# Downloading tile: tile_33.4_34.3_-60.0_-59.0.png
# Downloading tile: tile_33.4_34.3_-59.0_-58.0.png
# Downloading tile: tile_33.4_34.3_-58.0_-57.0.png
# Downloading tile: tile_33.4_34.3_-57.0_-56.0.png
# Downloading tile: tile_33.4_34.3_-56.0_-55.0.png
# Downloading tile: tile_33.4_34.3_-55.0_-54.0.png
# Downloading tile: tile_33.4_34.3_-54.0_-53.0.png
# Downloading tile: tile_33.4_34.3_-53.0_-52.0.png
# Downloading tile: tile_33.4_34.3_-52.0_-51.0.png
# Downloading tile: tile_33.4_34.3_-51.0_-50.0.png
# Downloading tile: tile_34.3_35.1_-60.0_-59.0.png
# Downloading tile: tile_34.3_35.1_-59.0_-58.0.png
# Downloading tile: tile_34.3_35.1_-58.0_-57.0.png
# Downloading tile: tile_34.3_35.1_-57.0_-56.0.png
# Downloading tile: tile_34.3_35.1_-56.0_-55.0.png
# Downloading tile: tile_34.3_35.1_-55.0_-54.0.png
# Downloading tile: tile_34.3_35.1_-54.0_-53.0.png
# Downloading tile: tile_34.3_35.1_-53.0_-52.0.png
# Downloading tile: tile_34.3_35.1_-52.0_-51.0.png
# Downloading tile: tile_34.3_35.1_-51.0_-50.0.png
# Downloading tile: tile_35.1_35.9_-60.0_-59.0.png
# Downloading tile: tile_35.1_35.9_-59.0_-58.0.png
# Downloading tile: tile_35.1_35.9_-58.0_-57.0.png
# Downloading tile: tile_35.1_35.9_-57.0_-56.0.png
# Downloading tile: tile_35.1_35.9_-56.0_-55.0.png
# Downloading tile: tile_35.1_35.9_-55.0_-54.0.png
# Downloading tile: tile_35.1_35.9_-54.0_-53.0.png
# Downloading tile: tile_35.1_35.9_-53.0_-52.0.png
# Downloading tile: tile_35.1_35.9_-52.0_-51.0.png
# Downloading tile: tile_35.1_35.9_-51.0_-50.0.png
# Downloading tile: tile_35.9_36.7_-60.0_-59.0.png
# Downloading tile: tile_35.9_36.7_-59.0_-58.0.png
# Downloading tile: tile_35.9_36.7_-58.0_-57.0.png
# Downloading tile: tile_35.9_36.7_-57.0_-56.0.png
# Downloading tile: tile_35.9_36.7_-56.0_-55.0.png
# Downloading tile: tile_35.9_36.7_-55.0_-54.0.png
# Downloading tile: tile_35.9_36.7_-54.0_-53.0.png
# Downloading tile: tile_35.9_36.7_-53.0_-52.0.png
# Downloading tile: tile_35.9_36.7_-52.0_-51.0.png
# Downloading tile: tile_35.9_36.7_-51.0_-50.0.png
# Downloading tile: tile_36.7_37.5_-60.0_-59.0.png
# Downloading tile: tile_36.7_37.5_-59.0_-58.0.png
# Downloading tile: tile_36.7_37.5_-58.0_-57.0.png
# Downloading tile: tile_36.7_37.5_-57.0_-56.0.png
# Downloading tile: tile_36.7_37.5_-56.0_-55.0.png
# Downloading tile: tile_36.7_37.5_-55.0_-54.0.png
# Downloading tile: tile_36.7_37.5_-54.0_-53.0.png
# Downloading tile: tile_36.7_37.5_-53.0_-52.0.png
# Downloading tile: tile_36.7_37.5_-52.0_-51.0.png
# Downloading tile: tile_36.7_37.5_-51.0_-50.0.png
# Downloading tile: tile_37.5_38.3_-60.0_-59.0.png
# Downloading tile: tile_37.5_38.3_-59.0_-58.0.png
# Downloading tile: tile_37.5_38.3_-58.0_-57.0.png
# Downloading tile: tile_37.5_38.3_-57.0_-56.0.png
# Downloading tile: tile_37.5_38.3_-56.0_-55.0.png
# Downloading tile: tile_37.5_38.3_-55.0_-54.0.png
# Downloading tile: tile_37.5_38.3_-54.0_-53.0.png
# Downloading tile: tile_37.5_38.3_-53.0_-52.0.png
# Downloading tile: tile_37.5_38.3_-52.0_-51.0.png
# Downloading tile: tile_37.5_38.3_-51.0_-50.0.png
# Download complete.

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import os
import requests
import time
import math

# Define grid data
# grid_data = [(minlatitude, maxlatitude, minlongitude, maxlongitude), ...]

# Set up the map
fig, ax = plt.subplots(
    figsize=(12, 8), subplot_kw={"projection": ccrs.PlateCarree()}
)

# Add map features
ax.set_extent([start_lon, start_lon + num_tiles * tile_width_deg,
               start_lat, start_lat + num_tiles * calculate_lat_height(start_lat, tile_pixels, tile_pixels) * num_tiles], crs=ccrs.PlateCarree())
ax.add_feature(cfeature.LAND, edgecolor="black")
ax.add_feature(cfeature.COASTLINE)
ax.gridlines(draw_labels=True)

# Plot the grid
for minlat, maxlat, minlon, maxlon in grid_data:
    # Draw rectangle for each tile
    ax.plot(
        [minlon, maxlon, maxlon, minlon, minlon],
        [minlat, minlat, maxlat, maxlat, minlat],
        color="red",
        transform=ccrs.PlateCarree(),
    )

# Show the map
plt.title("Visualization of Downloaded Tiles")
plt.show()
