# %% [markdown]
# Check CUDA

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("CUDA devices:", torch.cuda.device_count())
print("Current device:", torch.cuda.current_device())

# %% [markdown]
# Check pixel coord file

# %%
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os

# Path to your folder containing images
image_folder = '../1_DatasetCharacteristics/seamounts_seg_cropped'

# Load the CSV file
csv_file = '../1_DatasetCharacteristics/merged_pixel_coordinates.csv'
df = pd.read_csv(csv_file)

# Select 20 random rows from the DataFrame
random_rows = df.sample(n=20, random_state=42)  # 'random_state' ensures reproducibility

# Loop through the randomly selected rows
for _, row in random_rows.iterrows():
    # Get image file name and bounding box coordinates
    image_name = row['image_name']
    x_min, y_min, x_max, y_max = int(row['x_min']), int(row['y_min']), int(row['x_max']), int(row['y_max'])
    
    # Load the image
    image_path = os.path.join(image_folder, image_name)
    image = cv2.imread(image_path)
    
    # Check if the image is loaded successfully
    if image is None:
        print(f"Error: Could not load image {image_name}")
        continue
    
    # Convert image from BGR (OpenCV format) to RGB (matplotlib format)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Draw the bounding box on the image
    cv2.rectangle(image_rgb, (x_min, y_min), (x_max, y_max), (255, 0, 0), 2)  # Red bounding box
    
    # Display the image with the bounding box
    plt.figure(figsize=(10, 10))
    plt.imshow(image_rgb)
    plt.axis('off')  # Turn off axis
    plt.title(image_name)
    plt.show()

# %%
import os
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
import cv2
import numpy as np
import matplotlib.pyplot as plt
import keras_tuner as kt
import tensorflow.keras.backend as K

# Paths to data
image_dir = "../1_DatasetCharacteristics/seamounts_seg_cropped"
csv_path = "../1_DatasetCharacteristics/merged_pixel_coordinates.csv"

# Constants
IMAGE_SIZE = (256, 256)  # Reduced image size to 128x128
BATCH_SIZE = 16  # Reduced batch size to 8
EPOCHS = 40

# Load bounding box data
bbox_data = pd.read_csv(csv_path)

# Function to load images
def load_image(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)  # Load in color (BGR format)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB format
    image = image / 255.0  # Normalize pixel values to [0, 1]
    return image

# Function to preprocess bounding boxes
def preprocess_bboxes(row, original_size, resized_size):
    x_min, y_min, x_max, y_max = row[['x_min', 'y_min', 'x_max', 'y_max']]
    orig_height, orig_width = original_size
    resized_height, resized_width = resized_size

    if x_min == -1 and y_min == -1 and x_max == -1 and y_max == -1:
        return [-1, -1, -1, -1]  # No object case

    # Scale the bounding box coordinates according to the resizing ratio
    x_min = x_min * (resized_width / orig_width)
    y_min = y_min * (resized_height / orig_height)
    x_max = x_max * (resized_width / orig_width)
    y_max = y_max * (resized_height / orig_height)

    # Normalize coordinates to [0, 1]
    x_min /= resized_width
    y_min /= resized_height
    x_max /= resized_width
    y_max /= resized_height

    return [x_min, y_min, x_max, y_max]

# Prepare dataset
image_paths = []
bboxes = []
has_objects = []
for _, row in bbox_data.iterrows():
    img_path = os.path.join(image_dir, row['image_name'])
    if os.path.exists(img_path):
        # Load image without resizing to get original dimensions
        original_image = load_image(img_path)
        original_size = (original_image.shape[0], original_image.shape[1])

        # Preprocess bounding box
        bbox = preprocess_bboxes(row, original_size, IMAGE_SIZE)
        bboxes.append(bbox)

        # Add object presence label
        has_objects.append(0 if bbox == [-1, -1, -1, -1] else 1)

        # Resize the image
        image_paths.append(img_path)

# Convert to numpy arrays
bboxes = np.array(bboxes)
has_objects = np.array(has_objects)

# Split data
X_train_paths, X_val_paths, y_train_bboxes, y_val_bboxes, y_train_class, y_val_class = train_test_split(
    image_paths, bboxes, has_objects, test_size=0.2, random_state=42
)

# Define Huber loss
def huber_loss(y_true, y_pred, delta=1.0):
    error = y_true - y_pred
    is_small_error = tf.abs(error) <= delta
    small_error_loss = 0.5 * tf.square(error)
    large_error_loss = delta * (tf.abs(error) - 0.5 * delta)
    return tf.where(is_small_error, small_error_loss, large_error_loss)

# Custom data generator
class ImageDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, image_paths, bboxes, has_objects, batch_size, image_size, shuffle=True):
        self.image_paths = image_paths
        self.bboxes = bboxes
        self.has_objects = has_objects
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.indices = np.arange(len(self.image_paths))
        
    def __len__(self):
        return int(np.floor(len(self.image_paths) / self.batch_size))
    
    def __getitem__(self, index):
        batch_indices = self.indices[index * self.batch_size : (index + 1) * self.batch_size]
        batch_image_paths = [self.image_paths[i] for i in batch_indices]
        batch_bboxes = [self.bboxes[i] for i in batch_indices]
        batch_has_objects = [self.has_objects[i] for i in batch_indices]
        
        # Load and preprocess batch images
        images = np.array([self.load_image(image_path) for image_path in batch_image_paths])
        bboxes = np.array(batch_bboxes)
        has_objects = np.array(batch_has_objects)
        
        return images, {'class_output': has_objects, 'bbox_output': bboxes}
    
    def load_image(self, image_path):
        image = cv2.imread(image_path, cv2.IMREAD_COLOR)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = cv2.resize(image, self.image_size)  # Resize image to fixed size
        image = image / 255.0  # Normalize
        return image

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# Modify model to accept hyperparameters from Keras Tuner
def create_model_with_hyperparameters(hp):
    inputs = layers.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
    
    # Shared convolutional base
    x = layers.Conv2D(
        hp.Int('conv1_filters', min_value=32, max_value=64, step=32),  # Reduced filter range
        (3, 3), activation='relu', padding='same')(inputs)
    x = layers.MaxPooling2D((2, 2))(x)
    
    x = layers.Conv2D(
        hp.Int('conv2_filters', min_value=64, max_value=128, step=64),  # Reduced filter range
        (3, 3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    
    x = layers.Conv2D(
        hp.Int('conv3_filters', min_value=128, max_value=256, step=128),  # Reduced filter range
        (3, 3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    
    x = layers.Flatten()(x)
    
    # Fully connected layers with smaller units
    x = layers.Dense(
        hp.Int('dense1_units', min_value=256, max_value=1024, step=256),  # Reduced units range
        activation='relu')(x)
    x = layers.Dropout(hp.Float('dropout_rate', min_value=0.2, max_value=0.5, step=0.1))(x)
    
    x = layers.Dense(
        hp.Int('dense2_units', min_value=128, max_value=512, step=128),  # Reduced units range
        activation='relu')(x)
    x = layers.Dropout(hp.Float('dropout_rate', min_value=0.2, max_value=0.5, step=0.1))(x)
    
    # Output layers
    class_output = layers.Dense(1, activation='sigmoid', name='class_output')(x)
    bbox_output = layers.Dense(4, activation='linear', name='bbox_output')(x)
    
    model = models.Model(inputs, [class_output, bbox_output])
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            hp.Float('learning_rate', min_value=1e-5, max_value=1e-2, sampling='LOG', default=1e-3)
        ),
        loss={
            'class_output': 'binary_crossentropy',
            'bbox_output': huber_loss
        },
        loss_weights={
            'class_output': 1.0,
            'bbox_output': 1.0
        },
        metrics={
            'class_output': ['accuracy'],
            'bbox_output': ['mae']
        }
    )
    
    return model

# Hyperparameter search with reduced complexity
def tune_model():
    tuner = kt.Hyperband(
        create_model_with_hyperparameters, 
        objective='val_loss',
        max_epochs=40,  # Fewer epochs
        hyperband_iterations=1,  # Fewer iterations
        directory='tuning_results',
        project_name='seamount_detection',
        overwrite=True  # Overwrite existing files
    )

    tuner.search(
        train_generator,
        validation_data=val_generator,
        epochs=40,  # Fewer epochs
        callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)]  # Early stopping
    )
    
    # Get the best model and hyperparameters
    best_model = tuner.get_best_models(1)[0]
    best_hyperparameters = tuner.oracle.get_best_trials(1)[0].hyperparameters
    print("Best hyperparameters:", best_hyperparameters.values)
    
    return best_model

# Training and validation data generators
train_generator = ImageDataGenerator(X_train_paths, y_train_bboxes, y_train_class, BATCH_SIZE, IMAGE_SIZE)
val_generator = ImageDataGenerator(X_val_paths, y_val_bboxes, y_val_class, BATCH_SIZE, IMAGE_SIZE)

# Tune the model
best_model = tune_model()

# Train the model
best_model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS
)

# Clear session to release memory after training
K.clear_session()
# Out:
# Trial 90 Complete [00h 01m 43s]
# val_loss: 0.3290186822414398
#
# Best val_loss So Far: 0.24369417130947113
# Total elapsed time: 02h 12m 06s
# Best hyperparameters: {'conv1_filters': 64, 'conv2_filters': 128, 'conv3_filters': 128, 'dense1_units': 1024, 'dropout_rate': 0.2, 'dense2_units': 128, 'learning_rate': 0.00014763284782764668, 'tuner/epochs': 40, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}
# Epoch 1/40
# 148/148 [==============================] - 15s 96ms/step - loss: 0.0774 - class_output_loss: 0.0337 - bbox_output_loss: 0.0437 - class_output_accuracy: 0.9941 - bbox_output_mae: 0.2250 - val_loss: 0.2542 - val_class_output_loss: 0.1959 - val_bbox_output_loss: 0.0584 - val_class_output_accuracy: 0.9493 - val_bbox_output_mae: 0.2012
# Epoch 2/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0551 - class_output_loss: 0.0196 - bbox_output_loss: 0.0355 - class_output_accuracy: 0.9983 - bbox_output_mae: 0.2039 - val_loss: 0.2644 - val_class_output_loss: 0.2089 - val_bbox_output_loss: 0.0554 - val_class_output_accuracy: 0.9459 - val_bbox_output_mae: 0.1841
# Epoch 3/40
# 148/148 [==============================] - 14s 95ms/step - loss: 0.0509 - class_output_loss: 0.0172 - bbox_output_loss: 0.0337 - class_output_accuracy: 0.9979 - bbox_output_mae: 0.1985 - val_loss: 0.2569 - val_class_output_loss: 0.2004 - val_bbox_output_loss: 0.0565 - val_class_output_accuracy: 0.9409 - val_bbox_output_mae: 0.1945
# Epoch 4/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0390 - class_output_loss: 0.0112 - bbox_output_loss: 0.0279 - class_output_accuracy: 0.9987 - bbox_output_mae: 0.1795 - val_loss: 0.2587 - val_class_output_loss: 0.2037 - val_bbox_output_loss: 0.0550 - val_class_output_accuracy: 0.9426 - val_bbox_output_mae: 0.1872
# Epoch 5/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0346 - class_output_loss: 0.0091 - bbox_output_loss: 0.0255 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1722 - val_loss: 0.2695 - val_class_output_loss: 0.2153 - val_bbox_output_loss: 0.0542 - val_class_output_accuracy: 0.9476 - val_bbox_output_mae: 0.1781
# Epoch 6/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0289 - class_output_loss: 0.0066 - bbox_output_loss: 0.0223 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1613 - val_loss: 0.2686 - val_class_output_loss: 0.2146 - val_bbox_output_loss: 0.0540 - val_class_output_accuracy: 0.9443 - val_bbox_output_mae: 0.1776
# Epoch 7/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0316 - class_output_loss: 0.0087 - bbox_output_loss: 0.0229 - class_output_accuracy: 0.9996 - bbox_output_mae: 0.1608 - val_loss: 0.2745 - val_class_output_loss: 0.2120 - val_bbox_output_loss: 0.0625 - val_class_output_accuracy: 0.9375 - val_bbox_output_mae: 0.2211
# Epoch 8/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0395 - class_output_loss: 0.0137 - bbox_output_loss: 0.0258 - class_output_accuracy: 0.9975 - bbox_output_mae: 0.1682 - val_loss: 0.2870 - val_class_output_loss: 0.2286 - val_bbox_output_loss: 0.0585 - val_class_output_accuracy: 0.9392 - val_bbox_output_mae: 0.1936
# Epoch 9/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0233 - class_output_loss: 0.0049 - bbox_output_loss: 0.0184 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1447 - val_loss: 0.2624 - val_class_output_loss: 0.2083 - val_bbox_output_loss: 0.0541 - val_class_output_accuracy: 0.9459 - val_bbox_output_mae: 0.1863
# Epoch 10/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0205 - class_output_loss: 0.0042 - bbox_output_loss: 0.0162 - class_output_accuracy: 0.9996 - bbox_output_mae: 0.1364 - val_loss: 0.3059 - val_class_output_loss: 0.2475 - val_bbox_output_loss: 0.0584 - val_class_output_accuracy: 0.9426 - val_bbox_output_mae: 0.1915
# Epoch 11/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0188 - class_output_loss: 0.0033 - bbox_output_loss: 0.0154 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1314 - val_loss: 0.2903 - val_class_output_loss: 0.2361 - val_bbox_output_loss: 0.0542 - val_class_output_accuracy: 0.9426 - val_bbox_output_mae: 0.1755
# Epoch 12/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0175 - class_output_loss: 0.0031 - bbox_output_loss: 0.0143 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1271 - val_loss: 0.2830 - val_class_output_loss: 0.2298 - val_bbox_output_loss: 0.0532 - val_class_output_accuracy: 0.9476 - val_bbox_output_mae: 0.1771
# Epoch 13/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0171 - class_output_loss: 0.0031 - bbox_output_loss: 0.0140 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1235 - val_loss: 0.3043 - val_class_output_loss: 0.2495 - val_bbox_output_loss: 0.0547 - val_class_output_accuracy: 0.9409 - val_bbox_output_mae: 0.1794
# Epoch 14/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0154 - class_output_loss: 0.0025 - bbox_output_loss: 0.0129 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1169 - val_loss: 0.2995 - val_class_output_loss: 0.2459 - val_bbox_output_loss: 0.0536 - val_class_output_accuracy: 0.9459 - val_bbox_output_mae: 0.1745
# Epoch 15/40
# 148/148 [==============================] - 14s 95ms/step - loss: 0.0141 - class_output_loss: 0.0021 - bbox_output_loss: 0.0120 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1139 - val_loss: 0.2990 - val_class_output_loss: 0.2445 - val_bbox_output_loss: 0.0545 - val_class_output_accuracy: 0.9443 - val_bbox_output_mae: 0.1826
# Epoch 16/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0129 - class_output_loss: 0.0018 - bbox_output_loss: 0.0110 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1085 - val_loss: 0.2905 - val_class_output_loss: 0.2390 - val_bbox_output_loss: 0.0514 - val_class_output_accuracy: 0.9443 - val_bbox_output_mae: 0.1726
# Epoch 17/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0122 - class_output_loss: 0.0016 - bbox_output_loss: 0.0106 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1059 - val_loss: 0.3055 - val_class_output_loss: 0.2522 - val_bbox_output_loss: 0.0533 - val_class_output_accuracy: 0.9426 - val_bbox_output_mae: 0.1787
# Epoch 18/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0114 - class_output_loss: 0.0015 - bbox_output_loss: 0.0099 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1025 - val_loss: 0.3062 - val_class_output_loss: 0.2522 - val_bbox_output_loss: 0.0540 - val_class_output_accuracy: 0.9443 - val_bbox_output_mae: 0.1830
# Epoch 19/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0128 - class_output_loss: 0.0017 - bbox_output_loss: 0.0111 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1072 - val_loss: 0.3182 - val_class_output_loss: 0.2648 - val_bbox_output_loss: 0.0534 - val_class_output_accuracy: 0.9426 - val_bbox_output_mae: 0.1805
# Epoch 20/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0103 - class_output_loss: 0.0011 - bbox_output_loss: 0.0092 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0988 - val_loss: 0.3305 - val_class_output_loss: 0.2780 - val_bbox_output_loss: 0.0524 - val_class_output_accuracy: 0.9426 - val_bbox_output_mae: 0.1708
# Epoch 21/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0096 - class_output_loss: 0.0010 - bbox_output_loss: 0.0086 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0964 - val_loss: 0.3194 - val_class_output_loss: 0.2686 - val_bbox_output_loss: 0.0508 - val_class_output_accuracy: 0.9443 - val_bbox_output_mae: 0.1688
# Epoch 22/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0715 - class_output_loss: 0.0396 - bbox_output_loss: 0.0319 - class_output_accuracy: 0.9865 - bbox_output_mae: 0.1731 - val_loss: 0.4597 - val_class_output_loss: 0.3918 - val_bbox_output_loss: 0.0679 - val_class_output_accuracy: 0.9358 - val_bbox_output_mae: 0.2130
# Epoch 23/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0278 - class_output_loss: 0.0080 - bbox_output_loss: 0.0199 - class_output_accuracy: 0.9987 - bbox_output_mae: 0.1394 - val_loss: 0.3387 - val_class_output_loss: 0.2809 - val_bbox_output_loss: 0.0578 - val_class_output_accuracy: 0.9426 - val_bbox_output_mae: 0.1944
# Epoch 24/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0140 - class_output_loss: 0.0022 - bbox_output_loss: 0.0118 - class_output_accuracy: 0.9996 - bbox_output_mae: 0.1097 - val_loss: 0.3601 - val_class_output_loss: 0.3035 - val_bbox_output_loss: 0.0566 - val_class_output_accuracy: 0.9443 - val_bbox_output_mae: 0.1803
# Epoch 25/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0113 - class_output_loss: 0.0011 - bbox_output_loss: 0.0102 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1012 - val_loss: 0.3566 - val_class_output_loss: 0.3019 - val_bbox_output_loss: 0.0547 - val_class_output_accuracy: 0.9426 - val_bbox_output_mae: 0.1753
# Epoch 26/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0095 - class_output_loss: 8.5610e-04 - bbox_output_loss: 0.0087 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0941 - val_loss: 0.3312 - val_class_output_loss: 0.2787 - val_bbox_output_loss: 0.0525 - val_class_output_accuracy: 0.9426 - val_bbox_output_mae: 0.1746
# Epoch 27/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0088 - class_output_loss: 7.4705e-04 - bbox_output_loss: 0.0080 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0917 - val_loss: 0.3411 - val_class_output_loss: 0.2882 - val_bbox_output_loss: 0.0529 - val_class_output_accuracy: 0.9443 - val_bbox_output_mae: 0.1737
# Epoch 28/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0082 - class_output_loss: 6.3998e-04 - bbox_output_loss: 0.0076 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0899 - val_loss: 0.3527 - val_class_output_loss: 0.3000 - val_bbox_output_loss: 0.0527 - val_class_output_accuracy: 0.9409 - val_bbox_output_mae: 0.1726
# Epoch 29/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0083 - class_output_loss: 6.6002e-04 - bbox_output_loss: 0.0076 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0880 - val_loss: 0.3340 - val_class_output_loss: 0.2827 - val_bbox_output_loss: 0.0513 - val_class_output_accuracy: 0.9459 - val_bbox_output_mae: 0.1718
# Epoch 30/40
# 148/148 [==============================] - 14s 95ms/step - loss: 0.0080 - class_output_loss: 7.0488e-04 - bbox_output_loss: 0.0073 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0866 - val_loss: 0.3350 - val_class_output_loss: 0.2837 - val_bbox_output_loss: 0.0513 - val_class_output_accuracy: 0.9459 - val_bbox_output_mae: 0.1693
# Epoch 31/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0081 - class_output_loss: 8.5425e-04 - bbox_output_loss: 0.0072 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0874 - val_loss: 0.3561 - val_class_output_loss: 0.3037 - val_bbox_output_loss: 0.0524 - val_class_output_accuracy: 0.9459 - val_bbox_output_mae: 0.1708
# Epoch 32/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0071 - class_output_loss: 4.8083e-04 - bbox_output_loss: 0.0066 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0835 - val_loss: 0.3574 - val_class_output_loss: 0.3044 - val_bbox_output_loss: 0.0530 - val_class_output_accuracy: 0.9459 - val_bbox_output_mae: 0.1760
# Epoch 33/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0069 - class_output_loss: 4.5972e-04 - bbox_output_loss: 0.0064 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0821 - val_loss: 0.3380 - val_class_output_loss: 0.2881 - val_bbox_output_loss: 0.0499 - val_class_output_accuracy: 0.9459 - val_bbox_output_mae: 0.1680
# Epoch 34/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0067 - class_output_loss: 3.8623e-04 - bbox_output_loss: 0.0064 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0819 - val_loss: 0.3674 - val_class_output_loss: 0.3142 - val_bbox_output_loss: 0.0532 - val_class_output_accuracy: 0.9409 - val_bbox_output_mae: 0.1768
# Epoch 35/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0172 - class_output_loss: 0.0080 - bbox_output_loss: 0.0092 - class_output_accuracy: 0.9979 - bbox_output_mae: 0.0905 - val_loss: 0.7180 - val_class_output_loss: 0.6049 - val_bbox_output_loss: 0.1130 - val_class_output_accuracy: 0.8699 - val_bbox_output_mae: 0.2814
# Epoch 36/40
# 148/148 [==============================] - 14s 93ms/step - loss: 0.0173 - class_output_loss: 0.0044 - bbox_output_loss: 0.0129 - class_output_accuracy: 0.9987 - bbox_output_mae: 0.1127 - val_loss: 0.3805 - val_class_output_loss: 0.3228 - val_bbox_output_loss: 0.0576 - val_class_output_accuracy: 0.9392 - val_bbox_output_mae: 0.1897
# Epoch 37/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0087 - class_output_loss: 5.6588e-04 - bbox_output_loss: 0.0081 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0915 - val_loss: 0.3746 - val_class_output_loss: 0.3191 - val_bbox_output_loss: 0.0556 - val_class_output_accuracy: 0.9426 - val_bbox_output_mae: 0.1825
# Epoch 38/40
# 148/148 [==============================] - 14s 93ms/step - loss: 0.0079 - class_output_loss: 5.7677e-04 - bbox_output_loss: 0.0073 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0864 - val_loss: 0.3463 - val_class_output_loss: 0.2935 - val_bbox_output_loss: 0.0528 - val_class_output_accuracy: 0.9493 - val_bbox_output_mae: 0.1793
# Epoch 39/40
# 148/148 [==============================] - 14s 94ms/step - loss: 0.0073 - class_output_loss: 4.6957e-04 - bbox_output_loss: 0.0069 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0835 - val_loss: 0.3667 - val_class_output_loss: 0.3140 - val_bbox_output_loss: 0.0527 - val_class_output_accuracy: 0.9459 - val_bbox_output_mae: 0.1780
# Epoch 40/40
# 148/148 [==============================] - 14s 93ms/step - loss: 0.0088 - class_output_loss: 8.5415e-04 - bbox_output_loss: 0.0080 - class_output_accuracy: 0.9996 - bbox_output_mae: 0.0895 - val_loss: 0.3914 - val_class_output_loss: 0.3375 - val_bbox_output_loss: 0.0539 - val_class_output_accuracy: 0.9459 - val_bbox_output_mae: 0.1725

# %% [markdown]
# ## Using the found values on the 1_1 model:

# %%
import os
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Paths to data
image_dir = "../1_DatasetCharacteristics/seamounts_seg_cropped"
csv_path = "../1_DatasetCharacteristics/merged_pixel_coordinates.csv"

# Constants
IMAGE_SIZE = (256, 256)  # Resize images to 256x256 (as per the original code)
BATCH_SIZE = 16
EPOCHS = 40  # Adjusted to 40 from Keras tuner results

# Hyperparameters from Keras Tuner results
conv1_filters = 64
conv2_filters = 128
conv3_filters = 128
dense1_units = 1024
dropout_rate = 0.2
dense2_units = 128
learning_rate = 0.00014763284782764668

# Load bounding box data
bbox_data = pd.read_csv(csv_path)

# Function to load images
def load_image(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)  # Load in color (BGR format)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB format
    image = image / 255.0  # Normalize pixel values to [0, 1]
    return image

# Function to preprocess bounding boxes
def preprocess_bboxes(row, original_size, resized_size):
    x_min, y_min, x_max, y_max = row[['x_min', 'y_min', 'x_max', 'y_max']]
    orig_height, orig_width = original_size
    resized_height, resized_width = resized_size

    if x_min == -1 and y_min == -1 and x_max == -1 and y_max == -1:
        return [-1, -1, -1, -1]  # No object case

    # Scale the bounding box coordinates according to the resizing ratio
    x_min = x_min * (resized_width / orig_width)
    y_min = y_min * (resized_height / orig_height)
    x_max = x_max * (resized_width / orig_width)
    y_max = y_max * (resized_height / orig_height)

    # Normalize coordinates to [0, 1]
    x_min /= resized_width
    y_min /= resized_height
    x_max /= resized_width
    y_max /= resized_height

    return [x_min, y_min, x_max, y_max]

# Prepare dataset
images = []
bboxes = []
has_objects = []
for _, row in bbox_data.iterrows():
    img_path = os.path.join(image_dir, row['image_name'])
    if os.path.exists(img_path):
        # Load image without resizing to get original dimensions
        original_image = load_image(img_path)
        original_size = (original_image.shape[0], original_image.shape[1])

        # Preprocess bounding box
        bbox = preprocess_bboxes(row, original_size, IMAGE_SIZE)
        bboxes.append(bbox)

        # Add object presence label
        has_objects.append(0 if bbox == [-1, -1, -1, -1] else 1)

        # Resize the image
        resized_image = cv2.resize(original_image, IMAGE_SIZE)
        images.append(resized_image)

images = np.array(images)
bboxes = np.array(bboxes)
has_objects = np.array(has_objects)

# Split data
X_train, X_val, y_train_bboxes, y_val_bboxes, y_train_class, y_val_class = train_test_split(
    images, bboxes, has_objects, test_size=0.2, random_state=42
)

# Define Huber loss
def huber_loss(y_true, y_pred, delta=1.0):
    error = y_true - y_pred
    is_small_error = tf.abs(error) <= delta
    small_error_loss = 0.5 * tf.square(error)
    large_error_loss = delta * (tf.abs(error) - 0.5 * delta)
    return tf.where(is_small_error, small_error_loss, large_error_loss)

# Custom combined loss function
def custom_loss(y_true, y_pred):
    class_true, bbox_true = y_true
    class_pred, bbox_pred = y_pred
    
    # Binary cross-entropy for classification
    class_loss = tf.keras.losses.binary_crossentropy(class_true, class_pred)
    
    # Huber loss for bounding box regression (only for positive class)
    bbox_loss = huber_loss(bbox_true, bbox_pred)
    bbox_loss = tf.where(class_true == 1, bbox_loss, 0.0)
    
    return class_loss + bbox_loss

# Define the model architecture
def create_model_with_no_object_detection():
    inputs = layers.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
    
    # Shared convolutional base
    x = layers.Conv2D(conv1_filters, (3, 3), activation='relu', padding='same')(inputs)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(conv2_filters, (3, 3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(conv3_filters, (3, 3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    
    # Additional layers for optimization
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Flatten()(x)
    
    # Fully connected layers
    x = layers.Dense(dense1_units, activation='relu')(x)
    x = layers.Dropout(dropout_rate)(x)
    x = layers.Dense(dense2_units, activation='relu')(x)
    x = layers.Dropout(dropout_rate)(x)
    
    # Classification branch
    class_output = layers.Dense(1, activation='sigmoid', name='class_output')(x)
    
    # Bounding box regression branch
    bbox_output = layers.Dense(4, activation='linear', name='bbox_output')(x)
    
    model = models.Model(inputs, [class_output, bbox_output])
    return model

# Compile the model with the Adam optimizer and a learning rate from Keras Tuner result
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# Create and compile the model
model = create_model_with_no_object_detection()
model.compile(
    optimizer=optimizer,
    loss={
        'class_output': 'binary_crossentropy',
        'bbox_output': huber_loss
    },
    loss_weights={
        'class_output': 1.0,
        'bbox_output': 1.0
    },
    metrics={
        'class_output': ['accuracy'],
        'bbox_output': ['mae']
    }
)

# Train the model
history = model.fit(
    X_train, {'class_output': y_train_class, 'bbox_output': y_train_bboxes},
    validation_data=(X_val, {'class_output': y_val_class, 'bbox_output': y_val_bboxes}),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1
)

# Save the trained model (optional)
# model_save_path = "objdet_with_no_object_model.h5"
# model.save(model_save_path)
# print(f"Model saved to {model_save_path}")

# Evaluate the model
val_loss = model.evaluate(
    X_val, {'class_output': y_val_class, 'bbox_output': y_val_bboxes}
)
print(f"Validation Loss: {val_loss}")

# Visualization of predictions
def plot_predictions_with_no_object(images, true_bboxes, pred_bboxes, true_classes, pred_classes):
    for i in range(5):  # Show 5 examples
        img = images[i]
        true_bbox = true_bboxes[i]
        pred_bbox = pred_bboxes[i]
        true_class = true_classes[i]
        pred_class = pred_classes[i]

        plt.imshow(img)
        if pred_class < 0.5:  # No object detected
            plt.title("No object detected")
        else:
            h, w, _ = img.shape
            true_rect = [
                true_bbox[0] * w, true_bbox[1] * h,
                (true_bbox[2] - true_bbox[0]) * w, (true_bbox[3] - true_bbox[1]) * h
            ]
            plt.gca().add_patch(plt.Rectangle(
                (true_rect[0], true_rect[1]),
                true_rect[2], true_rect[3],
                edgecolor='green', facecolor='none', lw=2, label='True'
            ))
            pred_rect = [
                pred_bbox[0] * w, pred_bbox[1] * h,
                (pred_bbox[2] - pred_bbox[0]) * w, (pred_bbox[3] - pred_bbox[1]) * h
            ]
            plt.gca().add_patch(plt.Rectangle(
                (pred_rect[0], pred_rect[1]),
                pred_rect[2], pred_rect[3],
                edgecolor='red', facecolor='none', lw=2, label='Predicted'
            ))
        plt.legend()
        plt.show()

# Make predictions
pred_classes, pred_bboxes = model.predict(X_val)
plot_predictions_with_no_object(X_val, y_val_bboxes, pred_bboxes, y_val_class, pred_classes)
# Out:
# Epoch 1/40
# 149/149 [==============================] - 41s 162ms/step - loss: 0.5777 - class_output_loss: 0.4188 - bbox_output_loss: 0.1589 - class_output_accuracy: 0.8371 - bbox_output_mae: 0.4143 - val_loss: 0.5112 - val_class_output_loss: 0.3803 - val_bbox_output_loss: 0.1309 - val_class_output_accuracy: 0.8389 - val_bbox_output_mae: 0.3915
# Epoch 2/40
# 149/149 [==============================] - 17s 115ms/step - loss: 0.4466 - class_output_loss: 0.3008 - bbox_output_loss: 0.1458 - class_output_accuracy: 0.8619 - bbox_output_mae: 0.4204 - val_loss: 0.3576 - val_class_output_loss: 0.2570 - val_bbox_output_loss: 0.1006 - val_class_output_accuracy: 0.9430 - val_bbox_output_mae: 0.3158
# Epoch 3/40
# 149/149 [==============================] - 17s 116ms/step - loss: 0.3220 - class_output_loss: 0.2134 - bbox_output_loss: 0.1087 - class_output_accuracy: 0.9291 - bbox_output_mae: 0.3600 - val_loss: 0.2872 - val_class_output_loss: 0.2105 - val_bbox_output_loss: 0.0766 - val_class_output_accuracy: 0.9295 - val_bbox_output_mae: 0.2355
# Epoch 4/40
# 149/149 [==============================] - 17s 116ms/step - loss: 0.2498 - class_output_loss: 0.1630 - bbox_output_loss: 0.0868 - class_output_accuracy: 0.9479 - bbox_output_mae: 0.3109 - val_loss: 0.2198 - val_class_output_loss: 0.1625 - val_bbox_output_loss: 0.0574 - val_class_output_accuracy: 0.9480 - val_bbox_output_mae: 0.2384
# Epoch 5/40
# 149/149 [==============================] - 17s 115ms/step - loss: 0.1940 - class_output_loss: 0.1233 - bbox_output_loss: 0.0706 - class_output_accuracy: 0.9563 - bbox_output_mae: 0.2777 - val_loss: 0.1834 - val_class_output_loss: 0.1352 - val_bbox_output_loss: 0.0482 - val_class_output_accuracy: 0.9547 - val_bbox_output_mae: 0.1830
# Epoch 6/40
# 149/149 [==============================] - 18s 121ms/step - loss: 0.1689 - class_output_loss: 0.1012 - bbox_output_loss: 0.0677 - class_output_accuracy: 0.9656 - bbox_output_mae: 0.2724 - val_loss: 0.2161 - val_class_output_loss: 0.1560 - val_bbox_output_loss: 0.0600 - val_class_output_accuracy: 0.9329 - val_bbox_output_mae: 0.2037
# Epoch 7/40
# 149/149 [==============================] - 17s 117ms/step - loss: 0.1565 - class_output_loss: 0.0929 - bbox_output_loss: 0.0636 - class_output_accuracy: 0.9681 - bbox_output_mae: 0.2642 - val_loss: 0.2006 - val_class_output_loss: 0.1473 - val_bbox_output_loss: 0.0533 - val_class_output_accuracy: 0.9413 - val_bbox_output_mae: 0.2123
# Epoch 8/40
# 149/149 [==============================] - 17s 116ms/step - loss: 0.1176 - class_output_loss: 0.0658 - bbox_output_loss: 0.0518 - class_output_accuracy: 0.9803 - bbox_output_mae: 0.2400 - val_loss: 0.1576 - val_class_output_loss: 0.1191 - val_bbox_output_loss: 0.0385 - val_class_output_accuracy: 0.9564 - val_bbox_output_mae: 0.1597
# Epoch 9/40
# 149/149 [==============================] - 19s 125ms/step - loss: 0.0952 - class_output_loss: 0.0492 - bbox_output_loss: 0.0459 - class_output_accuracy: 0.9857 - bbox_output_mae: 0.2251 - val_loss: 0.1654 - val_class_output_loss: 0.1218 - val_bbox_output_loss: 0.0435 - val_class_output_accuracy: 0.9597 - val_bbox_output_mae: 0.1788
# Epoch 10/40
# 149/149 [==============================] - 17s 117ms/step - loss: 0.0911 - class_output_loss: 0.0476 - bbox_output_loss: 0.0434 - class_output_accuracy: 0.9866 - bbox_output_mae: 0.2175 - val_loss: 0.1792 - val_class_output_loss: 0.1323 - val_bbox_output_loss: 0.0469 - val_class_output_accuracy: 0.9547 - val_bbox_output_mae: 0.1801
# Epoch 11/40
# 149/149 [==============================] - 17s 115ms/step - loss: 0.0871 - class_output_loss: 0.0451 - bbox_output_loss: 0.0420 - class_output_accuracy: 0.9861 - bbox_output_mae: 0.2146 - val_loss: 0.1596 - val_class_output_loss: 0.1195 - val_bbox_output_loss: 0.0401 - val_class_output_accuracy: 0.9631 - val_bbox_output_mae: 0.1562
# Epoch 12/40
# 149/149 [==============================] - 17s 116ms/step - loss: 0.0478 - class_output_loss: 0.0169 - bbox_output_loss: 0.0309 - class_output_accuracy: 0.9979 - bbox_output_mae: 0.1870 - val_loss: 0.1537 - val_class_output_loss: 0.1170 - val_bbox_output_loss: 0.0368 - val_class_output_accuracy: 0.9664 - val_bbox_output_mae: 0.1445
# Epoch 13/40
# 149/149 [==============================] - 18s 122ms/step - loss: 0.0348 - class_output_loss: 0.0104 - bbox_output_loss: 0.0244 - class_output_accuracy: 0.9996 - bbox_output_mae: 0.1686 - val_loss: 0.1514 - val_class_output_loss: 0.1170 - val_bbox_output_loss: 0.0344 - val_class_output_accuracy: 0.9631 - val_bbox_output_mae: 0.1308
# Epoch 14/40
# 149/149 [==============================] - 17s 117ms/step - loss: 0.0277 - class_output_loss: 0.0070 - bbox_output_loss: 0.0207 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1556 - val_loss: 0.1466 - val_class_output_loss: 0.1140 - val_bbox_output_loss: 0.0327 - val_class_output_accuracy: 0.9664 - val_bbox_output_mae: 0.1230
# Epoch 15/40
# 149/149 [==============================] - 17s 114ms/step - loss: 0.0243 - class_output_loss: 0.0056 - bbox_output_loss: 0.0187 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1477 - val_loss: 0.1464 - val_class_output_loss: 0.1138 - val_bbox_output_loss: 0.0327 - val_class_output_accuracy: 0.9664 - val_bbox_output_mae: 0.1243
# Epoch 16/40
# 149/149 [==============================] - 17s 114ms/step - loss: 0.0216 - class_output_loss: 0.0050 - bbox_output_loss: 0.0166 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1390 - val_loss: 0.1589 - val_class_output_loss: 0.1256 - val_bbox_output_loss: 0.0333 - val_class_output_accuracy: 0.9648 - val_bbox_output_mae: 0.1230
# Epoch 17/40
# 149/149 [==============================] - 17s 115ms/step - loss: 0.0192 - class_output_loss: 0.0040 - bbox_output_loss: 0.0152 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1321 - val_loss: 0.1588 - val_class_output_loss: 0.1250 - val_bbox_output_loss: 0.0338 - val_class_output_accuracy: 0.9614 - val_bbox_output_mae: 0.1256
# Epoch 18/40
# 149/149 [==============================] - 17s 114ms/step - loss: 0.0183 - class_output_loss: 0.0039 - bbox_output_loss: 0.0145 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1287 - val_loss: 0.1488 - val_class_output_loss: 0.1168 - val_bbox_output_loss: 0.0320 - val_class_output_accuracy: 0.9664 - val_bbox_output_mae: 0.1219
# Epoch 19/40
# 149/149 [==============================] - 18s 119ms/step - loss: 0.0167 - class_output_loss: 0.0033 - bbox_output_loss: 0.0134 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1232 - val_loss: 0.1574 - val_class_output_loss: 0.1252 - val_bbox_output_loss: 0.0322 - val_class_output_accuracy: 0.9681 - val_bbox_output_mae: 0.1204
# Epoch 20/40
# 149/149 [==============================] - 18s 119ms/step - loss: 0.0144 - class_output_loss: 0.0026 - bbox_output_loss: 0.0118 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1160 - val_loss: 0.1555 - val_class_output_loss: 0.1237 - val_bbox_output_loss: 0.0319 - val_class_output_accuracy: 0.9648 - val_bbox_output_mae: 0.1194
# Epoch 21/40
# 149/149 [==============================] - 17s 114ms/step - loss: 0.0138 - class_output_loss: 0.0026 - bbox_output_loss: 0.0112 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1123 - val_loss: 0.1671 - val_class_output_loss: 0.1343 - val_bbox_output_loss: 0.0328 - val_class_output_accuracy: 0.9614 - val_bbox_output_mae: 0.1196
# Epoch 22/40
# 149/149 [==============================] - 17s 116ms/step - loss: 0.0121 - class_output_loss: 0.0021 - bbox_output_loss: 0.0100 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1062 - val_loss: 0.1611 - val_class_output_loss: 0.1298 - val_bbox_output_loss: 0.0313 - val_class_output_accuracy: 0.9698 - val_bbox_output_mae: 0.1207
# Epoch 23/40
# 149/149 [==============================] - 18s 119ms/step - loss: 0.0117 - class_output_loss: 0.0018 - bbox_output_loss: 0.0098 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1038 - val_loss: 0.1621 - val_class_output_loss: 0.1300 - val_bbox_output_loss: 0.0321 - val_class_output_accuracy: 0.9631 - val_bbox_output_mae: 0.1229
# Epoch 24/40
# 149/149 [==============================] - 18s 118ms/step - loss: 0.0109 - class_output_loss: 0.0016 - bbox_output_loss: 0.0093 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.1019 - val_loss: 0.1643 - val_class_output_loss: 0.1323 - val_bbox_output_loss: 0.0320 - val_class_output_accuracy: 0.9664 - val_bbox_output_mae: 0.1179
# Epoch 25/40
# 149/149 [==============================] - 17s 117ms/step - loss: 0.0101 - class_output_loss: 0.0015 - bbox_output_loss: 0.0086 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0980 - val_loss: 0.1852 - val_class_output_loss: 0.1513 - val_bbox_output_loss: 0.0338 - val_class_output_accuracy: 0.9648 - val_bbox_output_mae: 0.1205
# Epoch 26/40
# 149/149 [==============================] - 17s 115ms/step - loss: 0.0093 - class_output_loss: 0.0012 - bbox_output_loss: 0.0081 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0946 - val_loss: 0.1755 - val_class_output_loss: 0.1438 - val_bbox_output_loss: 0.0317 - val_class_output_accuracy: 0.9631 - val_bbox_output_mae: 0.1165
# Epoch 27/40
# 149/149 [==============================] - 17s 115ms/step - loss: 0.0091 - class_output_loss: 0.0012 - bbox_output_loss: 0.0079 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0927 - val_loss: 0.1861 - val_class_output_loss: 0.1519 - val_bbox_output_loss: 0.0342 - val_class_output_accuracy: 0.9648 - val_bbox_output_mae: 0.1267
# Epoch 28/40
# 149/149 [==============================] - 17s 115ms/step - loss: 0.0088 - class_output_loss: 0.0011 - bbox_output_loss: 0.0077 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0926 - val_loss: 0.1699 - val_class_output_loss: 0.1387 - val_bbox_output_loss: 0.0312 - val_class_output_accuracy: 0.9648 - val_bbox_output_mae: 0.1197
# Epoch 29/40
# 149/149 [==============================] - 17s 116ms/step - loss: 0.0089 - class_output_loss: 0.0011 - bbox_output_loss: 0.0078 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0914 - val_loss: 0.1804 - val_class_output_loss: 0.1489 - val_bbox_output_loss: 0.0315 - val_class_output_accuracy: 0.9664 - val_bbox_output_mae: 0.1149
# Epoch 30/40
# 149/149 [==============================] - 17s 116ms/step - loss: 0.0085 - class_output_loss: 0.0010 - bbox_output_loss: 0.0074 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0892 - val_loss: 0.1873 - val_class_output_loss: 0.1546 - val_bbox_output_loss: 0.0327 - val_class_output_accuracy: 0.9648 - val_bbox_output_mae: 0.1190
# Epoch 31/40
# 149/149 [==============================] - 17s 115ms/step - loss: 0.0076 - class_output_loss: 8.3468e-04 - bbox_output_loss: 0.0068 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0862 - val_loss: 0.1717 - val_class_output_loss: 0.1412 - val_bbox_output_loss: 0.0306 - val_class_output_accuracy: 0.9648 - val_bbox_output_mae: 0.1172
# Epoch 32/40
# 149/149 [==============================] - 17s 115ms/step - loss: 0.0077 - class_output_loss: 8.3081e-04 - bbox_output_loss: 0.0069 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0879 - val_loss: 0.1793 - val_class_output_loss: 0.1485 - val_bbox_output_loss: 0.0307 - val_class_output_accuracy: 0.9664 - val_bbox_output_mae: 0.1129
# Epoch 33/40
# 149/149 [==============================] - 17s 115ms/step - loss: 0.0069 - class_output_loss: 6.7273e-04 - bbox_output_loss: 0.0062 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0832 - val_loss: 0.1945 - val_class_output_loss: 0.1639 - val_bbox_output_loss: 0.0305 - val_class_output_accuracy: 0.9664 - val_bbox_output_mae: 0.1102
# Epoch 34/40
# 149/149 [==============================] - 17s 115ms/step - loss: 0.0066 - class_output_loss: 5.6772e-04 - bbox_output_loss: 0.0060 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0824 - val_loss: 0.1861 - val_class_output_loss: 0.1551 - val_bbox_output_loss: 0.0310 - val_class_output_accuracy: 0.9681 - val_bbox_output_mae: 0.1122
# Epoch 35/40
# 149/149 [==============================] - 17s 115ms/step - loss: 0.0060 - class_output_loss: 5.6081e-04 - bbox_output_loss: 0.0055 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0787 - val_loss: 0.1841 - val_class_output_loss: 0.1529 - val_bbox_output_loss: 0.0312 - val_class_output_accuracy: 0.9681 - val_bbox_output_mae: 0.1250
# Epoch 36/40
# 149/149 [==============================] - 17s 114ms/step - loss: 0.0063 - class_output_loss: 5.6006e-04 - bbox_output_loss: 0.0058 - class_output_accuracy: 1.0000 - bbox_output_mae: 0.0805 - val_loss: 0.2012 - val_class_output_loss: 0.1674 - val_bbox_output_loss: 0.0338 - val_class_output_accuracy: 0.9648 - val_bbox_output_mae: 0.1243
# Epoch 37/40
# 149/149 [==============================] - 17s 115ms/step - loss: 0.0672 - class_output_loss: 0.0445 - bbox_output_loss: 0.0228 - class_output_accuracy: 0.9882 - bbox_output_mae: 0.1295 - val_loss: 0.2914 - val_class_output_loss: 0.2301 - val_bbox_output_loss: 0.0613 - val_class_output_accuracy: 0.9262 - val_bbox_output_mae: 0.2130
# Epoch 38/40
# 149/149 [==============================] - 17s 113ms/step - loss: 0.0906 - class_output_loss: 0.0583 - bbox_output_loss: 0.0324 - class_output_accuracy: 0.9794 - bbox_output_mae: 0.1658 - val_loss: 0.2309 - val_class_output_loss: 0.1843 - val_bbox_output_loss: 0.0465 - val_class_output_accuracy: 0.9497 - val_bbox_output_mae: 0.1617
# Epoch 39/40
# 149/149 [==============================] - 18s 124ms/step - loss: 0.0396 - class_output_loss: 0.0221 - bbox_output_loss: 0.0175 - class_output_accuracy: 0.9920 - bbox_output_mae: 0.1232 - val_loss: 0.1629 - val_class_output_loss: 0.1273 - val_bbox_output_loss: 0.0356 - val_class_output_accuracy: 0.9648 - val_bbox_output_mae: 0.1528
# Epoch 40/40
# 149/149 [==============================] - 18s 122ms/step - loss: 0.0133 - class_output_loss: 0.0039 - bbox_output_loss: 0.0094 - class_output_accuracy: 0.9996 - bbox_output_mae: 0.0978 - val_loss: 0.1765 - val_class_output_loss: 0.1450 - val_bbox_output_loss: 0.0315 - val_class_output_accuracy: 0.9698 - val_bbox_output_mae: 0.1283
# 19/19 [==============================] - 4s 120ms/step - loss: 0.1765 - class_output_loss: 0.1450 - bbox_output_loss: 0.0315 - class_output_accuracy: 0.9698 - bbox_output_mae: 0.1283
# Validation Loss: [0.17653660476207733, 0.14499326050281525, 0.03154332563281059, 0.9697986841201782, 0.12826396524906158]
# 19/19 [==============================] - 1s 62ms/step
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## More Evaluation Data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# Plot the learning curve (Training & Validation Loss, Accuracy, and MAE)
def plot_learning_curves(history):
    # Extract the loss values from history
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    # Extract the accuracy and MAE values from history (for classification and bbox prediction)
    class_accuracy = history.history['class_output_accuracy']
    val_class_accuracy = history.history['val_class_output_accuracy']
    
    bbox_mae = history.history['bbox_output_mae']
    val_bbox_mae = history.history['val_bbox_output_mae']
    
    # Plot the loss curve
    plt.figure(figsize=(12, 8))

    # Plot Loss Curve
    plt.subplot(2, 2, 1)
    plt.plot(loss, label='Training Loss', color='blue')
    plt.plot(val_loss, label='Validation Loss', color='orange')
    plt.title("Learning Curve (Loss)")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()

    # Plot Accuracy Curve for Classification
    plt.subplot(2, 2, 2)
    plt.plot(class_accuracy, label='Training Accuracy', color='green')
    plt.plot(val_class_accuracy, label='Validation Accuracy', color='red')
    plt.title("Learning Curve (Classification Accuracy)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()

    # Plot MAE Curve for Bounding Box Regression
    plt.subplot(2, 2, 3)
    plt.plot(bbox_mae, label='Training MAE', color='purple')
    plt.plot(val_bbox_mae, label='Validation MAE', color='brown')
    plt.title("Learning Curve (Bounding Box MAE)")
    plt.xlabel("Epochs")
    plt.ylabel("MAE")
    plt.legend()

    # Show all plots
    plt.tight_layout()
    plt.show()

# Function to calculate IoU (Intersection over Union) excluding true no-object cases
def calculate_iou(true_bbox, pred_bbox, true_class, pred_class):
    # Exclude IoU calculation if the true class has no object (true_class < 0.5)
    if true_class < 0.5:  # True class has no object, so exclude IoU calculation
        return None  # Skip IoU calculation for true no-object cases

    x_min_true, y_min_true, x_max_true, y_max_true = true_bbox
    x_min_pred, y_min_pred, x_max_pred, y_max_pred = pred_bbox

    # Calculate intersection
    inter_x_min = max(x_min_true, x_min_pred)
    inter_y_min = max(y_min_true, y_min_pred)
    inter_x_max = min(x_max_true, x_max_pred)
    inter_y_max = min(y_max_true, y_max_pred)

    inter_width = max(0, inter_x_max - inter_x_min)
    inter_height = max(0, inter_y_max - inter_y_min)
    intersection = inter_width * inter_height

    # Calculate union
    true_area = (x_max_true - x_min_true) * (y_max_true - y_min_true)
    pred_area = (x_max_pred - x_min_pred) * (y_max_pred - y_min_pred)
    union = true_area + pred_area - intersection

    return intersection / union if union > 0 else 0.0

# Function to evaluate IoU for validation set (excluding true no-object cases)
def evaluate_iou(y_val_bboxes, pred_bboxes, y_val_class, pred_classes):
    ious = []
    for i in range(len(y_val_bboxes)):
        iou = calculate_iou(y_val_bboxes[i], pred_bboxes[i], y_val_class[i], pred_classes[i])
        if iou is not None:  # Only append IoU values for valid cases
            ious.append(iou)

    average_iou = np.mean(ious)
    print(f"Average IoU on Validation Set (excluding true no-object cases): {average_iou:.4f}")

    return ious

# Function to plot IoU distribution (excluding true no-object cases)
def plot_iou_distribution(ious):
    plt.figure(figsize=(8, 6))
    plt.hist(ious, bins=20, range=(0, 1), color='blue', alpha=0.7, edgecolor='black')
    plt.title("IoU Distribution on Validation Set (Only Object Detected)")
    plt.xlabel("IoU")
    plt.ylabel("Frequency")
    plt.show()

# Function to plot predictions with IoU
def plot_predictions_with_iou(images, true_bboxes, pred_bboxes, true_classes, pred_classes, ious, num_examples=5):
    for i in range(num_examples):
        img = images[i]
        true_bbox = true_bboxes[i]
        pred_bbox = pred_bboxes[i]
        true_class = true_classes[i]
        pred_class = pred_classes[i]
        iou = ious[i]

        plt.imshow(img)
        if pred_class < 0.5:  # No object detected by model
            plt.title(f"No object detected (IoU: {iou:.2f})")
        else:
            h, w, _ = img.shape
            true_rect = [
                true_bbox[0] * w, true_bbox[1] * h,
                (true_bbox[2] - true_bbox[0]) * w, (true_bbox[3] - true_bbox[1]) * h
            ]
            plt.gca().add_patch(plt.Rectangle(
                (true_rect[0], true_rect[1]),
                true_rect[2], true_rect[3],
                edgecolor='green', facecolor='none', lw=2, label='True'
            ))
            pred_rect = [
                pred_bbox[0] * w, pred_bbox[1] * h,
                (pred_bbox[2] - pred_bbox[0]) * w, (pred_bbox[3] - pred_bbox[1]) * h
            ]
            plt.gca().add_patch(plt.Rectangle(
                (pred_rect[0], pred_rect[1]),
                pred_rect[2], pred_rect[3],
                edgecolor='red', facecolor='none', lw=2, label='Predicted'
            ))
            plt.title(f"Object detected (IoU: {iou:.2f})")
        plt.legend()
        plt.show()

# Assuming you have your model's history and prediction results
# Example usage:

plot_learning_curves(history)  # Plot training/validation learning curves

# Assuming you have the following data available:
# y_val_bboxes: Ground truth bounding boxes for validation set
# pred_bboxes: Predicted bounding boxes by the model
# y_val_class: Ground truth class labels for validation set
# pred_classes: Predicted class probabilities by the model
# X_val: Validation images

# Calculate and evaluate IoU
ious = evaluate_iou(y_val_bboxes, pred_bboxes, y_val_class, pred_classes)  # Calculate IoU values

# Plot the IoU distribution (excluding true no-object cases)
plot_iou_distribution(ious)  # Plot the distribution of IoU values

# Visualize predictions with IoU
plot_predictions_with_iou(X_val, y_val_bboxes, pred_bboxes, y_val_class, pred_classes, ious)  # Visualize predictions with IoU
# Out:
# Average IoU on Validation Set (excluding true no-object cases): 0.3834
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Test on unseen unlabeled data

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Path to the new data (unlabeled)
unlabeled_image_dir = "../1_DatasetCharacteristics/seamount_images_equal_tiles_cropped"

# Function to load images (same as in training)
def load_image(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)  # Load in color (BGR format)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB format
    image = image / 255.0  # Normalize pixel values to [0, 1]
    return image

# Function to plot predictions (same as before)
def plot_predictions_with_no_object(images, pred_bboxes, pred_classes):
    for i in range(20):  # Show 5 examples
        img = images[i]
        pred_bbox = pred_bboxes[i]
        pred_class = pred_classes[i]

        plt.imshow(img)
        if pred_class < 0.5:  # No object detected
            plt.title("No object detected")
        else:
            h, w, _ = img.shape
            pred_rect = [
                pred_bbox[0] * w, pred_bbox[1] * h,
                (pred_bbox[2] - pred_bbox[0]) * w, (pred_bbox[3] - pred_bbox[1]) * h
            ]
            plt.gca().add_patch(plt.Rectangle(
                (pred_rect[0], pred_rect[1]),
                pred_rect[2], pred_rect[3],
                edgecolor='red', facecolor='none', lw=2, label='Predicted'
            ))
        plt.legend()
        plt.show()

# Load the trained model (if not already loaded)
# If you already have the model loaded, you can skip this step.
# model = load_model('objdet_with_no_object_model.h5', custom_objects={'huber_loss': huber_loss})

# Load and preprocess unseen images
unlabeled_images = []
for image_name in os.listdir(unlabeled_image_dir):
    img_path = os.path.join(unlabeled_image_dir, image_name)
    if os.path.exists(img_path):
        img = load_image(img_path)
        resized_img = cv2.resize(img, IMAGE_SIZE)  # Resize images to match the model input size
        unlabeled_images.append(resized_img)

unlabeled_images = np.array(unlabeled_images)

# Make predictions on the unseen data
pred_classes, pred_bboxes = model.predict(unlabeled_images)

# Visualize the predictions
plot_predictions_with_no_object(unlabeled_images, pred_bboxes, pred_classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 57
#      54 unlabeled_images = np.array(unlabeled_images)
#      56 # Make predictions on the unseen data
# ---> 57 pred_classes, pred_bboxes = model.predict(unlabeled_images)
#      59 # Visualize the predictions
#      60 plot_predictions_with_no_object(unlabeled_images, pred_bboxes, pred_classes)
#
# NameError: name 'model' is not defined
